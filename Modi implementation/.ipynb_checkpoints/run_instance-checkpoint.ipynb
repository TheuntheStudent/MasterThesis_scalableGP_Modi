# %%
from genetic_programming import GeneticProgramming
from fitness_functions.Gymnax_fitness_function import GymFitnessFunction

import jax
import jax.numpy as jnp
import jax.random as jr

import brax
from brax import envs
import matplotlib.pyplot as plt

class BraxGymnaxWrapper:
    def __init__(self, env_name, backend):
        self.env = envs.get_environment(env_name=env_name, backend=backend)
        self.observation_space = self.env.observation_size
        self.action_space = self.env.action_size

    # state, env_state = self.env.reset(subkey, self.env_params)

    def reset(self, key, params=None):
        #state consists of pipeline_state, obs, reward, done, metrics, info
        state = self.env.reset(key)
        return state.obs, state

     # next_state, next_env_state, reward, done, _ = self.env.step(
     #            subkey, env_state, action, self.env_params
     #        )

    def step(self, key, state, action, params=None):

      action = action.reshape(self.action_space)
      next_state = self.env.step(state, action)
      done = next_state.done

      # Freeze state after done
      obs = jnp.where(done, state.obs, next_state.obs)
      new_state = jax.tree.map(
          lambda new, old: jnp.where(done, old, new),
          next_state,
          state
      )

      reward = jnp.where(done, 0.0, next_state.reward)

      return obs, new_state, reward, done, {}
# Out:
# E0506 09:35:56.923795    3712 cuda_executor.cc:1526] Could not get kernel mode driver version: (INVALID_ARGUMENT: Version does not match the format X.Y.Z)
# E0506 09:35:56.932196    3624 cuda_executor.cc:1526] Could not get kernel mode driver version: (INVALID_ARGUMENT: Version does not match the format X.Y.Z)
# These device(s) are detected: [CudaDevice(id=0)]
# Failed to import warp: No module named 'warp'
# Failed to import mujoco_warp: No module named 'warp'

# %%
brax_env = BraxGymnaxWrapper('inverted_pendulum', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    # ("sin", lambda x: jnp.sin(x), 1, 0.1),
    # ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=1, max_nodes= 15)
# Out:
# /home/theun/yes/envs/modi_kozax/lib/python3.12/site-packages/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Compiling code for evaluation and evolution...
# Finished compilation in 80.59 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: -1.0, equation: [-0.999]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -252.8125, equation: [3.42*y1]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]
# Final pareto front:
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -233.3125, equation: [2*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [0.0991*y0 + 2*y1]

# %%
brax_env = BraxGymnaxWrapper('inverted_double_pendulum', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    # ("sin", lambda x: jnp.sin(x), 1, 0.1),
    # ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=1, max_nodes= 15)
# Out:
# /home/theun/yes/envs/modi_kozax/lib/python3.12/site-packages/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Compiling code for evaluation and evolution...
# Finished compilation in 76.08 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 3, fitness: -758.82421875, equation: [-0.262*y7]
# Complexity: 7, fitness: -8778.92578125, equation: [y2*y3 - 2.86*y2]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -775.4652709960938, equation: [y2 - y7]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -1087.872802734375, equation: [-0.878*y7]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -1087.872802734375, equation: [-0.878*y7]
# Complexity: 5, fitness: -8552.125, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.125, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -8962.689453125, equation: [y1*y2*y7 - 2.86*y2]
# Complexity: 15, fitness: -8966.8623046875, equation: [(y0**3 + y2)*(y2**2*y4 - 1.76)]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -8962.689453125, equation: [y1*y2*y7 - 2.86*y2]
# Complexity: 13, fitness: -8966.259765625, equation: [(y0**3 + y2)*(y2**2 - 1.76)]
# Complexity: 15, fitness: -8966.8623046875, equation: [(y0**3 + y2)*(y2**2*y4 - 1.76)]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -8962.689453125, equation: [y1*y2*y7 - 2.86*y2]
# Complexity: 11, fitness: -9205.171875, equation: [-2.86*y2**2*y7 - 2.86*y2]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -9165.849609375, equation: [y0*y1*y7 - 2.86*y2]
# Complexity: 11, fitness: -9205.173828125, equation: [-2.86*y2**2*y7 - 2.86*y2]
# Complexity: 15, fitness: -9290.6318359375, equation: [(y0**3 - 1.76)*(y0**3 + y2)]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -9165.849609375, equation: [y0*y1*y7 - 2.86*y2]
# Complexity: 11, fitness: -9205.173828125, equation: [-2.86*y2**2*y7 - 2.86*y2]
# Complexity: 13, fitness: -9335.248046875, equation: [y0*y1*y7 + y2*y3 - 2.86*y2]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -9165.849609375, equation: [y0*y1*y7 - 2.86*y2]
# Complexity: 11, fitness: -9342.076171875, equation: [-y0*y2*y7 - 1.86*y2]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -9165.849609375, equation: [y0*y1*y7 - 2.86*y2]
# Complexity: 11, fitness: -9342.076171875, equation: [-y0*y2*y7 - 1.86*y2]
# Complexity: 15, fitness: -9356.0732421875, equation: [-2.86*y2 - 0.887*y3*y5*y7*(-y2 + y7)]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -9165.849609375, equation: [y0*y1*y7 - 2.86*y2]
# Complexity: 11, fitness: -9342.076171875, equation: [-y0*y2*y7 - 1.86*y2]
# Complexity: 15, fitness: -9356.0732421875, equation: [-2.86*y2 - 0.887*y3*y5*y7*(-y2 + y7)]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -9165.849609375, equation: [y0*y1*y7 - 2.86*y2]
# Complexity: 11, fitness: -9343.345703125, equation: [y0*y1*(-y1 + y7) - 2.86*y2]
# Complexity: 15, fitness: -9356.0732421875, equation: [-2.86*y2 - 0.887*y3*y5*y7*(-y2 + y7)]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -9165.849609375, equation: [y0*y1*y7 - 2.86*y2]
# Complexity: 11, fitness: -9343.345703125, equation: [y0*y1*(-y1 + y7) - 2.86*y2]
# Complexity: 15, fitness: -9356.0732421875, equation: [-2.86*y2 - 0.887*y3*y5*y7*(-y2 + y7)]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -9165.849609375, equation: [y0*y1*y7 - 2.86*y2]
# Complexity: 11, fitness: -9343.345703125, equation: [y0*y1*(-y1 + y7) - 2.86*y2]
# Complexity: 13, fitness: -9357.2236328125, equation: [-2.86*y2**2*y7 - 1.86*y2]
# Complexity: 15, fitness: -9357.849609375, equation: [-2.86*y0*y2*y7 + y2*y3 - 2.86*y2]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -9165.849609375, equation: [y0*y1*y7 - 2.86*y2]
# Complexity: 11, fitness: -9343.345703125, equation: [y0*y1*(-y1 + y7) - 2.86*y2]
# Complexity: 13, fitness: -9357.2236328125, equation: [-2.86*y2**2*y7 - 1.86*y2]
# Complexity: 15, fitness: -9357.849609375, equation: [-2.86*y0*y2*y7 + y2*y3 - 2.86*y2]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -9165.849609375, equation: [y0*y1*y7 - 2.86*y2]
# Complexity: 11, fitness: -9343.345703125, equation: [y0*y1*(-y1 + y7) - 2.86*y2]
# Complexity: 13, fitness: -9357.666015625, equation: [-2.86*y0*y2*y7 - 1.86*y2]
# Complexity: 15, fitness: -9357.849609375, equation: [-2.86*y0*y2*y7 + y2*y3 - 2.86*y2]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -9165.849609375, equation: [y0*y1*y7 - 2.86*y2]
# Complexity: 11, fitness: -9350.087890625, equation: [-2.86*y0*y2*y7 - 2.86*y2]
# Complexity: 13, fitness: -9357.666015625, equation: [-2.86*y0*y2*y7 - 1.86*y2]
# Complexity: 15, fitness: -9357.849609375, equation: [-2.86*y0*y2*y7 + y2*y3 - 2.86*y2]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -9165.849609375, equation: [y0*y1*y7 - 2.86*y2]
# Complexity: 11, fitness: -9350.087890625, equation: [-2.86*y0*y2*y7 - 2.86*y2]
# Complexity: 13, fitness: -9357.666015625, equation: [-2.86*y0*y2*y7 - 1.86*y2]
# Complexity: 15, fitness: -9357.849609375, equation: [-2.86*y0*y2*y7 + y2*y3 - 2.86*y2]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -9165.849609375, equation: [y0*y1*y7 - 2.86*y2]
# Complexity: 11, fitness: -9350.087890625, equation: [-2.86*y0*y2*y7 - 2.86*y2]
# Complexity: 13, fitness: -9357.666015625, equation: [-2.86*y0*y2*y7 - 1.86*y2]
# Complexity: 15, fitness: -9357.849609375, equation: [-2.86*y0*y2*y7 + y2*y3 - 2.86*y2]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -9165.849609375, equation: [y0*y1*y7 - 2.86*y2]
# Complexity: 11, fitness: -9350.087890625, equation: [-2.86*y0*y2*y7 - 2.86*y2]
# Complexity: 13, fitness: -9357.666015625, equation: [-2.86*y0*y2*y7 - 1.86*y2]
# Complexity: 15, fitness: -9357.849609375, equation: [-2.86*y0*y2*y7 + y2*y3 - 2.86*y2]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -4602.3134765625, equation: [-2.86*y2]
# Complexity: 5, fitness: -8552.134765625, equation: [-1.86*y2]
# Complexity: 7, fitness: -8778.927734375, equation: [y2*y3 - 2.86*y2]
# Complexity: 9, fitness: -9165.849609375, equation: [y0*y1*y7 - 2.86*y2]
# Complexity: 11, fitness: -9350.087890625, equation: [-2.86*y0*y2*y7 - 2.86*y2]
# Complexity: 13, fitness: -9357.666015625, equation: [-2.86*y0*y2*y7 - 1.86*y2]
# Complexity: 15, fitness: -9357.849609375, equation: [-2.86*y0*y2*y7 + y2*y3 - 2.86*y2]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 9, fitness: -9200.005859375, equation: [-2.86*y2*(y2*y7 + y4)]
# Complexity: 11, fitness: -9350.087890625, equation: [-2.86*y0*y2*y7 - 2.86*y2]
# Complexity: 13, fitness: -9357.666015625, equation: [-2.86*y0*y2*y7 - 1.86*y2]
# Complexity: 15, fitness: -9357.849609375, equation: [-2.86*y0*y2*y7 + y2*y3 - 2.86*y2]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 9, fitness: -9200.005859375, equation: [-2.86*y2*(y2*y7 + y4)]
# Complexity: 11, fitness: -9350.087890625, equation: [-2.86*y0*y2*y7 - 2.86*y2]
# Complexity: 13, fitness: -9357.666015625, equation: [-2.86*y0*y2*y7 - 1.86*y2]
# Complexity: 15, fitness: -9357.849609375, equation: [-2.86*y0*y2*y7 + y2*y3 - 2.86*y2]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 9, fitness: -9200.005859375, equation: [-2.86*y2*(y2*y7 + y4)]
# Complexity: 11, fitness: -9350.087890625, equation: [-2.86*y0*y2*y7 - 2.86*y2]
# Complexity: 13, fitness: -9357.666015625, equation: [-2.86*y0*y2*y7 - 1.86*y2]
# Complexity: 15, fitness: -9357.849609375, equation: [-2.86*y0*y2*y7 + y2*y3 - 2.86*y2]
# Final pareto front:
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 9, fitness: -9200.005859375, equation: [-2.86*y2*(y2*y7 + y4)]
# Complexity: 11, fitness: -9350.087890625, equation: [-2.86*y0*y2*y7 - 2.86*y2]
# Complexity: 13, fitness: -9357.666015625, equation: [-2.86*y0*y2*y7 - 1.86*y2]
# Complexity: 15, fitness: -9357.849609375, equation: [-2.86*y0*y2*y7 + y2*y3 - 2.86*y2]

# %%
brax_env = BraxGymnaxWrapper('reacher', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    # ("sin", lambda x: jnp.sin(x), 1, 0.1),
    # ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=2, max_nodes= 30)
# Out:
# /home/theun/yes/envs/modi_kozax/lib/python3.12/site-packages/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Compiling code for evaluation and evolution...
# Finished compilation in 150.14 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 3, fitness: 112.77131652832031, equation: [0, y6 + y8]
# Complexity: 5, fitness: 109.94471740722656, equation: [0, y1*y5 + y4]
# Complexity: 13, fitness: 99.15975952148438, equation: [y9*(y10 + y8)*(2*y10 + y6 - 0.835), y10 + y8]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 112.77131652832031, equation: [0, y6 + y8]
# Complexity: 5, fitness: 109.94471740722656, equation: [0, y1*y5 + y4]
# Complexity: 7, fitness: 108.53164672851562, equation: [0, y8*(y3 + y4 + y7)]
# Complexity: 13, fitness: 95.24038696289062, equation: [y9*(y10 + y8)*(y10 + y2 + y6 - 0.835), y10 + y8]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 7, fitness: 79.70348358154297, equation: [0, 2*y5*y8 + y5*y9]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 79.61508178710938, equation: [0, y5*y8**2 + y5*y8]
# Complexity: 7, fitness: 77.93547821044922, equation: [0, y5*y6 + 2*y5*y8]
# Complexity: 23, fitness: 76.93152618408203, equation: [y9*(y7 + y9)*(y10*y7*(y4 + y6) + y2*y3 + y5*y8 - y9), y10*y7*(y4 + y6) + 2*y5*y8]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 79.61508178710938, equation: [0, y5*y8**2 + y5*y8]
# Complexity: 7, fitness: 77.93547821044922, equation: [0, y5*y6 + 2*y5*y8]
# Complexity: 23, fitness: 72.97456359863281, equation: [y9*(y7 + y9)*(y10*y7*(y4 + y6) - 0.183*y3 + y5*y8 - y9), y10*y7*(y4 + y6) + 2*y5*y8]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 79.0379867553711, equation: [0, 1.42*y5*y8]
# Complexity: 7, fitness: 77.27616882324219, equation: [0, y4*y8 + 2*y5*y8]
# Complexity: 21, fitness: 76.6595230102539, equation: [y9*(y7 + y9)*(y2*y3 + y5*y8 + y6*(y4 + y6) - y9), 2*y5*y8 + y6*(y4 + y6)]
# Complexity: 23, fitness: 72.97456359863281, equation: [y9*(y7 + y9)*(y10*y7*(y4 + y6) - 0.183*y3 + y5*y8 - y9), y10*y7*(y4 + y6) + 2*y5*y8]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 77.27616882324219, equation: [0, y4*y8 + 2*y5*y8]
# Complexity: 21, fitness: 75.78579711914062, equation: [y9*(y7 + y9)*(y10*y5 + y10*y6*y7 + y5*y8 - y9), y10*y5 + 2*y5*y8]
# Complexity: 23, fitness: 69.93081665039062, equation: [y9*(-y10*y7**2 + y8*(y0 + y8))*(y10 + y2*y8 + y6 - 0.835), -y10*y7**2 + y8*(y0 + y8)]
# Complexity: 25, fitness: 66.6830062866211, equation: [y9*(y7 + y9)*(y1*y9*(y4 + y6) + y10*y6*y7 + y5*y8 - y9), y1*y9*(y4 + y6) + 2*y5*y8]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 77.27616882324219, equation: [0, y4*y8 + 2*y5*y8]
# Complexity: 15, fitness: 76.90570831298828, equation: [0, y10*y7*(y4 + y6) + 2*y5*y8 + y5*(y10*y7*(y4 + y6) + y5*y8 + y8)]
# Complexity: 19, fitness: 68.6473617553711, equation: [y9*(2*y10 - 0.835)*(-y10*y7**2 + y8*(y0 + y8)), -y10*y7**2 + y8*(y0 + y8)]
# Complexity: 21, fitness: 60.89240646362305, equation: [y9*(y6 + y9)*(y10*y6*y7 + y2*y6 + y5*y8 - y9), y2*y6 + 2*y5*y8]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 76.9023208618164, equation: [0, 3*y5*y8]
# Complexity: 13, fitness: 76.6527099609375, equation: [0, 3*y5*y8 + 2*y5*(y5*y8 + y8**2)]
# Complexity: 17, fitness: 76.39490509033203, equation: [0, y4*y8 + 3*y5*y8 + 2*y5*(y5*y8 + y8**2)]
# Complexity: 19, fitness: 60.76265335083008, equation: [y9*(y6 + y9)*(y2*y6 + y5*y8 + y6*y9 - y9), y2*y6 + 2*y5*y8]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 76.2799072265625, equation: [0, y3*y8 + 2*y5*y8]
# Complexity: 17, fitness: 60.24604034423828, equation: [y9*(y6 + y9)*(y2*y6 + y5*y8 + y6 - y9), y2*y6 + 2*y5*y8]
# Complexity: 27, fitness: 48.69750213623047, equation: [y9*(0.0824*y10*y4**2 + y8*(y0 + y8))*(y10 + 2*y2*y8 + y6 - 0.835), 0.0824*y10*y4**2 - 0.0824*y4 + y8*(y0 + y8)]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 76.2799072265625, equation: [0, y3*y8 + 2*y5*y8]
# Complexity: 17, fitness: 60.24604034423828, equation: [y9*(y6 + y9)*(y2*y6 + y5*y8 + y6 - y9), y2*y6 + 2*y5*y8]
# Complexity: 25, fitness: 50.55217361450195, equation: [y9*(-y10*y7**2 + y8*(y0 + y8))*(-0.0824*y10*y4 + y10 + y6 - 0.835), -y10*y7**2 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 27, fitness: 48.69750213623047, equation: [y9*(0.0824*y10*y4**2 + y8*(y0 + y8))*(y10 + 2*y2*y8 + y6 - 0.835), 0.0824*y10*y4**2 - 0.0824*y4 + y8*(y0 + y8)]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 76.2799072265625, equation: [0, y3*y8 + 2*y5*y8]
# Complexity: 17, fitness: 60.24604034423828, equation: [y9*(y6 + y9)*(y2*y6 + y5*y8 + y6 - y9), y2*y6 + 2*y5*y8]
# Complexity: 23, fitness: 49.90802001953125, equation: [y9*(0.0824*y10*y4**2 + y8*(y0 + y8))*(y10 + 2*y6 - 0.835), 0.0824*y10*y4**2 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 27, fitness: 47.6784782409668, equation: [y9*(0.0824*y10*y4**2 + y8*(y0 + y8))*(2*y2*y8 + y4 + y6 - 0.835), 0.0824*y10*y4**2 - 0.0824*y4 + y8*(y0 + y8)]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 76.2799072265625, equation: [0, y3*y8 + 2*y5*y8]
# Complexity: 17, fitness: 60.24604034423828, equation: [y9*(y6 + y9)*(y2*y6 + y5*y8 + y6 - y9), y2*y6 + 2*y5*y8]
# Complexity: 21, fitness: 50.68379592895508, equation: [y9*(0.0824*y2*y4**2 + y8*(y0 + y8))*(y10 + y6 - 0.835), 0.0824*y2*y4**2 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 23, fitness: 49.90802001953125, equation: [y9*(0.0824*y10*y4**2 + y8*(y0 + y8))*(y10 + 2*y6 - 0.835), 0.0824*y10*y4**2 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 25, fitness: 48.69750213623047, equation: [y9*(0.0824*y10*y4**2 + y8*(y0 + y8))*(2*y2*y8 + y6 - 0.835), 0.0824*y10*y4**2 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 27, fitness: 47.67401123046875, equation: [y9*(0.0824*y4**2*y5 + y8*(y0 + y8))*(2*y2*y8 + y4 + y6 - 0.835), 0.0824*y4**2*y5 - 0.0824*y4 + y8*(y0 + y8)]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 76.2799072265625, equation: [0, y3*y8 + 2*y5*y8]
# Complexity: 17, fitness: 60.24604034423828, equation: [y9*(y6 + y9)*(y2*y6 + y5*y8 + y6 - y9), y2*y6 + 2*y5*y8]
# Complexity: 21, fitness: 50.68379592895508, equation: [y9*(0.0824*y2*y4**2 + y8*(y0 + y8))*(y10 + y6 - 0.835), 0.0824*y2*y4**2 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 23, fitness: 49.90802001953125, equation: [y9*(0.0824*y10*y4**2 + y8*(y0 + y8))*(y10 + 2*y6 - 0.835), 0.0824*y10*y4**2 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 25, fitness: 46.92128372192383, equation: [y9*(0.0824*y10*y4**2 + y8*(y0 + y8))*(y2 + y3*y9 + y4 - 0.835), 0.0824*y10*y4**2 - 0.0824*y4 + y8*(y0 + y8)]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 76.2799072265625, equation: [0, y3*y8 + 2*y5*y8]
# Complexity: 17, fitness: 60.24604034423828, equation: [y9*(y6 + y9)*(y2*y6 + y5*y8 + y6 - y9), y2*y6 + 2*y5*y8]
# Complexity: 21, fitness: 50.68379592895508, equation: [y9*(0.0824*y2*y4**2 + y8*(y0 + y8))*(y10 + y6 - 0.835), 0.0824*y2*y4**2 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 23, fitness: 49.90802001953125, equation: [y9*(0.0824*y10*y4**2 + y8*(y0 + y8))*(y10 + 2*y6 - 0.835), 0.0824*y10*y4**2 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 25, fitness: 46.92128372192383, equation: [y9*(0.0824*y10*y4**2 + y8*(y0 + y8))*(y2 + y3*y9 + y4 - 0.835), 0.0824*y10*y4**2 - 0.0824*y4 + y8*(y0 + y8)]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 76.2799072265625, equation: [0, y3*y8 + 2*y5*y8]
# Complexity: 17, fitness: 60.24604034423828, equation: [y9*(y6 + y9)*(y2*y6 + y5*y8 + y6 - y9), y2*y6 + 2*y5*y8]
# Complexity: 21, fitness: 50.68379592895508, equation: [y9*(0.0824*y2*y4**2 + y8*(y0 + y8))*(y10 + y6 - 0.835), 0.0824*y2*y4**2 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 23, fitness: 48.48353576660156, equation: [y9*(0.0824*y10*y4**2 + y8*(y0 + y8))*(y2 + y4 + y9 - 0.835), 0.0824*y10*y4**2 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 25, fitness: 46.92128372192383, equation: [y9*(0.0824*y10*y4**2 + y8*(y0 + y8))*(y2 + y3*y9 + y4 - 0.835), 0.0824*y10*y4**2 - 0.0824*y4 + y8*(y0 + y8)]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 76.2799072265625, equation: [0, y3*y8 + 2*y5*y8]
# Complexity: 17, fitness: 59.346046447753906, equation: [y9**2*(y2*y6 + y5*y8 - 1.18*y9), y2*y6 + 2*y5*y8]
# Complexity: 19, fitness: 49.70745086669922, equation: [y9*(0.918*y4 - 0.835)*(-y4*y6 + y8*(y0 + y8)), -y4*y6 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 23, fitness: 46.136959075927734, equation: [y9*(0.0824*y4*y5*y7 + y8*(y0 + y8))*(y2 + y4 + y6 - 0.835), 0.0824*y4*y5*y7 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 25, fitness: 44.61455535888672, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y2*y8*y9 + y4 - 0.835), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 76.2799072265625, equation: [0, y3*y8 + 2*y5*y8]
# Complexity: 17, fitness: 59.346046447753906, equation: [y9**2*(y2*y6 + y5*y8 - 1.18*y9), y2*y6 + 2*y5*y8]
# Complexity: 19, fitness: 49.34204864501953, equation: [y9*(0.918*y4 - 0.835)*(y4*y6 + y8*(y0 + y8)), y4*y6 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 21, fitness: 47.629146575927734, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y4 + y9 - 0.835), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 23, fitness: 45.859519958496094, equation: [y9*(0.918*y4 - 0.835)*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8)), -y3*(y10 - 0.0824*y4) - 0.165*y4 + y8*(y0 + y8)]
# Complexity: 25, fitness: 44.61455535888672, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y2*y8*y9 + y4 - 0.835), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 76.2799072265625, equation: [0, y3*y8 + 2*y5*y8]
# Complexity: 17, fitness: 55.36091613769531, equation: [y9*(y8 + y9)*(-0.105*y2*y6 - 0.105*y5*y8 - y9), y2*y6 + 2*y5*y8]
# Complexity: 19, fitness: 49.34204864501953, equation: [y9*(0.918*y4 - 0.835)*(y4*y6 + y8*(y0 + y8)), y4*y6 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 21, fitness: 44.56414794921875, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y10 + y4 - 0.835), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 25, fitness: 44.072723388671875, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y2 + y4 + y8*y9 - 0.835), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 76.2799072265625, equation: [0, y3*y8 + 2*y5*y8]
# Complexity: 17, fitness: 55.36091613769531, equation: [y9*(y8 + y9)*(-0.105*y2*y6 - 0.105*y5*y8 - y9), y2*y6 + 2*y5*y8]
# Complexity: 19, fitness: 49.34204864501953, equation: [y9*(0.918*y4 - 0.835)*(y4*y6 + y8*(y0 + y8)), y4*y6 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 21, fitness: 44.56414794921875, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y10 + y4 - 0.835), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 25, fitness: 43.83380126953125, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y2*(y0 + y8) + y4 - 0.835), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 76.2799072265625, equation: [0, y3*y8 + 2*y5*y8]
# Complexity: 17, fitness: 55.36091613769531, equation: [y9*(y8 + y9)*(-0.105*y2*y6 - 0.105*y5*y8 - y9), y2*y6 + 2*y5*y8]
# Complexity: 19, fitness: 49.34204864501953, equation: [y9*(0.918*y4 - 0.835)*(y4*y6 + y8*(y0 + y8)), y4*y6 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 21, fitness: 44.56414794921875, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y10 + y4 - 0.835), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 25, fitness: 43.83380126953125, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y2*(y0 + y8) + y4 - 0.835), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 76.2799072265625, equation: [0, y3*y8 + 2*y5*y8]
# Complexity: 17, fitness: 55.36091613769531, equation: [y9*(y8 + y9)*(-0.105*y2*y6 - 0.105*y5*y8 - y9), y2*y6 + 2*y5*y8]
# Complexity: 19, fitness: 49.34204864501953, equation: [y9*(0.918*y4 - 0.835)*(y4*y6 + y8*(y0 + y8)), y4*y6 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 21, fitness: 44.56414794921875, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y10 + y4 - 0.835), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 25, fitness: 43.83380126953125, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y2*(y0 + y8) + y4 - 0.835), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 76.2799072265625, equation: [0, y3*y8 + 2*y5*y8]
# Complexity: 17, fitness: 55.36091613769531, equation: [y9*(y8 + y9)*(-0.105*y2*y6 - 0.105*y5*y8 - y9), y2*y6 + 2*y5*y8]
# Complexity: 19, fitness: 49.34204864501953, equation: [y9*(0.918*y4 - 0.835)*(y4*y6 + y8*(y0 + y8)), y4*y6 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 21, fitness: 44.56414794921875, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y10 + y4 - 0.835), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 23, fitness: 43.53578186035156, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y2*y8 + y4 - 0.835), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 25, fitness: 43.37442398071289, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y2*y9*(y4 - 0.835) - 0.917), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]
# Final pareto front:
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 7, fitness: 76.2799072265625, equation: [0, y3*y8 + 2*y5*y8]
# Complexity: 17, fitness: 55.36091613769531, equation: [y9*(y8 + y9)*(-0.105*y2*y6 - 0.105*y5*y8 - y9), y2*y6 + 2*y5*y8]
# Complexity: 19, fitness: 49.34204864501953, equation: [y9*(0.918*y4 - 0.835)*(y4*y6 + y8*(y0 + y8)), y4*y6 - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 21, fitness: 44.56414794921875, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y10 + y4 - 0.835), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 23, fitness: 43.53578186035156, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y2*y8 + y4 - 0.835), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]
# Complexity: 25, fitness: 43.37442398071289, equation: [y9*(-y3*(y10 - 0.0824*y4) + y8*(y0 + y8))*(y2*y9*(y4 - 0.835) - 0.917), -y3*(y10 - 0.0824*y4) - 0.0824*y4 + y8*(y0 + y8)]

# %%
brax_env = BraxGymnaxWrapper('swimmer', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    # ("sin", lambda x: jnp.sin(x), 1, 0.1),
    # ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=2, max_nodes= 30)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Compiling code for evaluation and evolution...
# Finished compilation in 177.74 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 3, fitness: -23.38439178466797, equation: [0, y6 + y7]
# Complexity: 5, fitness: -27.81826400756836, equation: [0.47*y1, 0.47*y1*y3]
# Complexity: 7, fitness: -32.211402893066406, equation: [0, 2*y1 + y5 - 0.341]
# Complexity: 11, fitness: -73.76416778564453, equation: [-y3 + y4 - y7, -y0 - y1*y6 - y3 + y4 - y7]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -82.91305541992188, equation: [y0 + y6, y0 + 2*y6]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -84.55081176757812, equation: [y0 + y6, y0 + 2*y6]
# Complexity: 11, fitness: -110.59341430664062, equation: [y0 + y6, 2*y0 + y1 + y5 + 4*y6 - 0.341]
# Complexity: 17, fitness: -116.31561279296875, equation: [-y3 + y4 - y7, -y0 - y1*y6 + y4 + y6]
# Complexity: 19, fitness: -149.4588623046875, equation: [y3 + y4, y0 + y1 + 5*y3 + y4 + 2*y6 + 2*y7]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -169.68460083007812, equation: [y0 + y6, y0 + y4 + y6]
# Complexity: 15, fitness: -191.44747924804688, equation: [2*y0 + y1*y4 + y2*(y0 + y1*y4 - y6 + y7 - 2.15) - 2*y6 + y7 - 2.15, y1*y4 + y7 - 1.05]
# Complexity: 17, fitness: -208.12733459472656, equation: [-y3 + y4 - y7, -y0 - y1*y6 - y3 + y4 + y6 + y7]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -169.68460083007812, equation: [y0 + y6, y0 + y4 + y6]
# Complexity: 9, fitness: -206.79515075683594, equation: [2*y0 + y3 + y7, 2*y0 + y1 + y3 + y7]
# Complexity: 17, fitness: -214.2982635498047, equation: [-y1 - y3 + 2*y4 - y5, -y0 - y1*y6 - y1 - y3 + 2*y4 - y5 + y6]
# Complexity: 19, fitness: -222.4452362060547, equation: [y0 + y4, y0*(y0 + 2*y4) + y0 + y1 + 2*y3 + 2*y4 + y7]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -169.68460083007812, equation: [y0 + y6, y0 + y4 + y6]
# Complexity: 9, fitness: -206.79515075683594, equation: [2*y0 + y3 + y7, 2*y0 + y1 + y3 + y7]
# Complexity: 17, fitness: -214.8744659423828, equation: [-y1 - y3 + 2*y4 - y5, -y0 - y1*y6 - y1 - y3 + 2*y4 - y5 + y6]
# Complexity: 19, fitness: -222.4452362060547, equation: [y0 + y4, y0*(y0 + 2*y4) + y0 + y1 + 2*y3 + 2*y4 + y7]
# Complexity: 21, fitness: -227.59799194335938, equation: [-y3 + y4 - y7, -y0 - y1*y6 + 2*y1 - y3 + y4 + y6 + y7]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -169.68460083007812, equation: [y0 + y6, y0 + y4 + y6]
# Complexity: 9, fitness: -206.79515075683594, equation: [2*y0 + y3 + y7, 2*y0 + y1 + y3 + y7]
# Complexity: 13, fitness: -237.6898651123047, equation: [y0 - 1.94*y2, y0 + 2*y1 - 0.969*y2]
# Complexity: 29, fitness: -284.652587890625, equation: [-y1 + y4, -y0 + y1**2*(2*y1 + y3 + 2*y7) - y1*y6 - y1 + y4 + y6]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -169.68460083007812, equation: [y0 + y6, y0 + y4 + y6]
# Complexity: 7, fitness: -271.86444091796875, equation: [-y4 + y6, y3*y4 + y4]
# Complexity: 9, fitness: -280.30859375, equation: [y0 - 2.2*y2, y0 + y1 - 1.1*y2 + 0.15]
# Complexity: 19, fitness: -302.8933410644531, equation: [y0 + y2**2*(y1 + y4) - 1.94*y2, y0 + y1 + y2**2*(y1 + y4) + y2**2 - 0.969*y2]
# Complexity: 21, fitness: -314.4002685546875, equation: [y0 + y2*y5*y6 + y3 + y4 - 0.411, y0 + y1*(y0 + 0.636*y1*(y1 + y2*y5*y6 + y4 - 0.411) + y3) + 0.636*y1*(y1 + y2*y5*y6 + y4 - 0.411) + y2*y5*y6 + y3]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -169.68460083007812, equation: [y0 + y6, y0 + y4 + y6]
# Complexity: 7, fitness: -271.91058349609375, equation: [-y4 + y6, y3*y4 + y4]
# Complexity: 9, fitness: -280.30859375, equation: [y0 - 2.2*y2, y0 + y1 - 1.1*y2 + 0.15]
# Complexity: 11, fitness: -316.0115966796875, equation: [y0 - 1.94*y2, y0 + y1 - 0.969*y2]
# Complexity: 19, fitness: -318.5865783691406, equation: [y0 + y4, y0*(y0 + 2*y4) + y0 + 2*y3*(y1 + y7) + 2*y4]
# Complexity: 29, fitness: -349.46441650390625, equation: [-y1 + y4, y1**2*(2*y1 + y3 + 2*y7) - y1*y6 - y1 + y4 + y6 - y7]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -177.50967407226562, equation: [-y1 - y4 + y6, y1 + y4]
# Complexity: 7, fitness: -271.981689453125, equation: [-y4 + y6, y3*y4 + y4]
# Complexity: 9, fitness: -280.30859375, equation: [y0 - 2.2*y2, y0 + y1 - 1.1*y2 + 0.15]
# Complexity: 11, fitness: -316.0115966796875, equation: [y0 - 1.94*y2, y0 + y1 - 0.969*y2]
# Complexity: 17, fitness: -317.4678955078125, equation: [y0 + y4, y0*(y0 + 2*y4) + y0 + 2*y3*y7 + 2*y4]
# Complexity: 19, fitness: -318.5865783691406, equation: [y0 + y4, y0*(y0 + 2*y4) + y0 + 2*y3*(y1 + y7) + 2*y4]
# Complexity: 21, fitness: -320.5347900390625, equation: [y0 + y4, y0*(y0 + y3 + y4 + 0.462) + y0 + 2*y3*(y1 + y7) + y3 + y4 + 0.462]
# Complexity: 23, fitness: -335.8851623535156, equation: [2*y0 - 1.94*y2 + y6, 5*y0 + 2*y1 - 1.94*y2 + 4*y6 + 2*y7]
# Complexity: 25, fitness: -341.21923828125, equation: [y0 + y4, y0 + 2*y3*(y1 + y7) + 2*y4]
# Complexity: 29, fitness: -360.09393310546875, equation: [-y1 + y4, y1**2*(2*y1 + y3 + 2*y7) - y1*y3 - y1 + y4 + y6 - y7]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -229.18930053710938, equation: [y4 + y6 - 0.0778, y4 - 0.0778]
# Complexity: 7, fitness: -271.981689453125, equation: [-y4 + y6, y3*y4 + y4]
# Complexity: 9, fitness: -320.36761474609375, equation: [-2.2*y2 + y6, y1 - 1.1*y2 + y4 + y6]
# Complexity: 11, fitness: -321.75787353515625, equation: [y0 - 2.2*y2, y0 + y1 - 1.1*y2]
# Complexity: 21, fitness: -329.65673828125, equation: [y0 + y4, y0 + 0.636*y1*(y0 + 2*y4 + y5*y7) + 2*y3*(y1 + y7) + 2*y4]
# Complexity: 23, fitness: -335.8851623535156, equation: [2*y0 - 1.94*y2 + y6, 5*y0 + 2*y1 - 1.94*y2 + 4*y6 + 2*y7]
# Complexity: 25, fitness: -341.2209777832031, equation: [y0 + y4, y0 + 2*y3*(y1 + y7) + 2*y4]
# Complexity: 27, fitness: -352.91168212890625, equation: [-y1 + y4, y1**2*(2*y1 + y3 + 2*y7) - y1 + y4 - y5 + y6 - y7]
# Complexity: 29, fitness: -360.09393310546875, equation: [-y1 + y4, y1**2*(2*y1 + y3 + 2*y7) - y1*y3 - y1 + y4 + y6 - y7]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -229.18930053710938, equation: [y4 + y6 - 0.0778, y4 - 0.0778]
# Complexity: 7, fitness: -271.981689453125, equation: [-y4 + y6, y3*y4 + y4]
# Complexity: 9, fitness: -320.36761474609375, equation: [-2.2*y2 + y6, y1 - 1.1*y2 + y4 + y6]
# Complexity: 11, fitness: -321.75787353515625, equation: [y0 - 2.2*y2, y0 + y1 - 1.1*y2]
# Complexity: 19, fitness: -337.48846435546875, equation: [y0 + y4, y0*(y0 + y3 + y4) + y0 + 2*y3*(y1 + y7) + y3 + y4]
# Complexity: 25, fitness: -341.2209777832031, equation: [y0 + y4, y0 + 2*y3*(y1 + y7) + 2*y4]
# Complexity: 27, fitness: -357.8446044921875, equation: [-y1 + y4, y1**2*(2*y1 + y3 + 2*y7) - y1 - y3 + y4 + y6 - y7]
# Complexity: 29, fitness: -363.72259521484375, equation: [-y1 + y4, y1**2*(y1 + y3 + 2*y7 - 0.471) - y1*y3 - y1 + y4 + y6 - y7]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -229.18930053710938, equation: [y4 + y6 - 0.0778, y4 - 0.0778]
# Complexity: 7, fitness: -271.981689453125, equation: [-y4 + y6, y3*y4 + y4]
# Complexity: 9, fitness: -320.36761474609375, equation: [-2.2*y2 + y6, y1 - 1.1*y2 + y4 + y6]
# Complexity: 11, fitness: -321.75787353515625, equation: [y0 - 2.2*y2, y0 + y1 - 1.1*y2]
# Complexity: 19, fitness: -342.96343994140625, equation: [-2.2*y2 + y6, -y0*y2*(y1 + y4) + y1 - 1.1*y2 + y6]
# Complexity: 25, fitness: -344.6588134765625, equation: [y0 + y4, y0 + 2*y3*(y7 - 1.1) + 2*y4]
# Complexity: 27, fitness: -363.04541015625, equation: [-y1 + y4, y1**2*(2*y1 + y2 + 2*y7) - y1*y3 - 2*y1 + y4 + y6 - y7]
# Complexity: 29, fitness: -363.82147216796875, equation: [-y1 + y4, y1**2*(y1 + y3 + 2*y7 - 0.471) - y1*y3 - y1 + y4 + y6 - y7]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -229.18930053710938, equation: [y4 + y6 - 0.0778, y4 - 0.0778]
# Complexity: 7, fitness: -271.981689453125, equation: [-y4 + y6, y3*y4 + y4]
# Complexity: 9, fitness: -320.36761474609375, equation: [-2.2*y2 + y6, y1 - 1.1*y2 + y4 + y6]
# Complexity: 11, fitness: -321.75787353515625, equation: [y0 - 2.2*y2, y0 + y1 - 1.1*y2]
# Complexity: 19, fitness: -342.96343994140625, equation: [-2.2*y2 + y6, -y0*y2*(y1 + y4) + y1 - 1.1*y2 + y6]
# Complexity: 25, fitness: -344.6588134765625, equation: [y0 + y4, y0 + 2*y3*(y7 - 1.1) + 2*y4]
# Complexity: 27, fitness: -363.04541015625, equation: [-y1 + y4, y1**2*(2*y1 + y2 + 2*y7) - y1*y3 - 2*y1 + y4 + y6 - y7]
# Complexity: 29, fitness: -363.82147216796875, equation: [-y1 + y4, y1**2*(y1 + y3 + 2*y7 - 0.471) - y1*y3 - y1 + y4 + y6 - y7]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -229.18930053710938, equation: [y4 + y6 - 0.0778, y4 - 0.0778]
# Complexity: 7, fitness: -271.981689453125, equation: [-y4 + y6, y3*y4 + y4]
# Complexity: 9, fitness: -320.36761474609375, equation: [-2.2*y2 + y6, y1 - 1.1*y2 + y4 + y6]
# Complexity: 11, fitness: -321.75787353515625, equation: [y0 - 2.2*y2, y0 + y1 - 1.1*y2]
# Complexity: 19, fitness: -355.1622009277344, equation: [y0 + y4, y0 + y3*y7 + y4]
# Complexity: 27, fitness: -364.5227355957031, equation: [-y1 + y4, y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -229.18930053710938, equation: [y4 + y6 - 0.0778, y4 - 0.0778]
# Complexity: 7, fitness: -271.981689453125, equation: [-y4 + y6, y3*y4 + y4]
# Complexity: 9, fitness: -338.3904113769531, equation: [y0 + y4, y0 + 3*y1 + 2*y4]
# Complexity: 19, fitness: -355.1622009277344, equation: [y0 + y4, y0 + y3*y7 + y4]
# Complexity: 25, fitness: -356.2202453613281, equation: [-y1 + y4, y1**2*(y0 + y1 + y3 + 2*y7) - 2*y1 + y6 - y7]
# Complexity: 27, fitness: -364.5227355957031, equation: [-y1 + y4, y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.88134765625, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 19, fitness: -355.1622009277344, equation: [y0 + y4, y0 + y3*y7 + y4]
# Complexity: 25, fitness: -359.99853515625, equation: [-y1 + y4, -y0 + y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# Complexity: 27, fitness: -364.5227355957031, equation: [-y1 + y4, y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.88134765625, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 19, fitness: -355.1622009277344, equation: [y0 + y4, y0 + y3*y7 + y4]
# Complexity: 23, fitness: -356.83721923828125, equation: [y0 + y4, y0*y1*y2 + y3*y7 + y4]
# Complexity: 25, fitness: -359.99853515625, equation: [-y1 + y4, -y0 + y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# Complexity: 27, fitness: -364.59100341796875, equation: [-y1 + y4, y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.88134765625, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 19, fitness: -355.1622009277344, equation: [y0 + y4, y0 + y3*y7 + y4]
# Complexity: 23, fitness: -356.83721923828125, equation: [y0 + y4, y0*y1*y2 + y3*y7 + y4]
# Complexity: 25, fitness: -359.99853515625, equation: [-y1 + y4, -y0 + y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# Complexity: 27, fitness: -364.59100341796875, equation: [-y1 + y4, y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.88134765625, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 19, fitness: -355.1622009277344, equation: [y0 + y4, y0 + y3*y7 + y4]
# Complexity: 23, fitness: -356.83721923828125, equation: [y0 + y4, y0*y1*y2 + y3*y7 + y4]
# Complexity: 25, fitness: -359.99853515625, equation: [-y1 + y4, -y0 + y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# Complexity: 27, fitness: -364.59100341796875, equation: [-y1 + y4, y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.88134765625, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 19, fitness: -355.1622009277344, equation: [y0 + y4, y0 + y3*y7 + y4]
# Complexity: 23, fitness: -356.83721923828125, equation: [y0 + y4, y0*y1*y2 + y3*y7 + y4]
# Complexity: 25, fitness: -360.06744384765625, equation: [-y1 + y4, -y0 + y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# Complexity: 27, fitness: -364.59100341796875, equation: [-y1 + y4, y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.88134765625, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 17, fitness: -356.90380859375, equation: [y0 + y4, y1*y2*(0.892*y0 - 0.108*y3*y7 - 0.215*y4) + y3*y7 + y4]
# Complexity: 25, fitness: -360.06744384765625, equation: [-y1 + y4, -y0 + y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# Complexity: 27, fitness: -364.59100341796875, equation: [-y1 + y4, y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.88134765625, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 17, fitness: -356.9979553222656, equation: [y0 + y4, y1*y2*(1.11*y0 + 0.108*y3*y7 + 0.215*y4) + y3*y7 + y4]
# Complexity: 25, fitness: -361.86358642578125, equation: [-y1 + y4, y1**2*(y0 + 2*y1 + 2*y7) - y1 - y2 + y6 - y7]
# Complexity: 27, fitness: -364.59100341796875, equation: [-y1 + y4, y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.88134765625, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 17, fitness: -356.9979553222656, equation: [y0 + y4, y1*y2*(1.11*y0 + 0.108*y3*y7 + 0.215*y4) + y3*y7 + y4]
# Complexity: 25, fitness: -362.03240966796875, equation: [-y1 + y4, y1**2*(y0 + 2*y1 + 2*y7) - y1 - y2 + y6 - y7]
# Complexity: 27, fitness: -364.59100341796875, equation: [-y1 + y4, y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# Complexity: 29, fitness: -364.6166076660156, equation: [-y1 + y4, y1**2*(y0 + y1 + 2*y7 + 0.396) - y1 + y6 - y7]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.88134765625, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 17, fitness: -356.9979553222656, equation: [y0 + y4, y1*y2*(1.11*y0 + 0.108*y3*y7 + 0.215*y4) + y3*y7 + y4]
# Complexity: 25, fitness: -362.03240966796875, equation: [-y1 + y4, y1**2*(y0 + 2*y1 + 2*y7) - y1 - y2 + y6 - y7]
# Complexity: 27, fitness: -364.59100341796875, equation: [-y1 + y4, y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# Complexity: 29, fitness: -364.6216125488281, equation: [-y1 + y4, y1**2*(y0 + y1 + 2*y7 + 0.396) - y1 + y6 - y7]
# Final pareto front:
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.88134765625, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 17, fitness: -356.9979553222656, equation: [y0 + y4, y1*y2*(1.11*y0 + 0.108*y3*y7 + 0.215*y4) + y3*y7 + y4]
# Complexity: 25, fitness: -362.03240966796875, equation: [-y1 + y4, y1**2*(y0 + 2*y1 + 2*y7) - y1 - y2 + y6 - y7]
# Complexity: 27, fitness: -364.59100341796875, equation: [-y1 + y4, y1**2*(y0 + y1 + y3 + 2*y7) - y1 + y6 - y7]
# Complexity: 29, fitness: -364.6216125488281, equation: [-y1 + y4, y1**2*(y0 + y1 + 2*y7 + 0.396) - y1 + y6 - y7]

# %%
pf = strategy.pareto_front[1]
print(pf[-1])
# Out:
# [[[ 0.         -1.         -1.          0.          0.        ]
#   [12.         -1.         -1.          0.          0.        ]
#   [ 6.         -1.         -1.          0.          0.        ]
#   [ 9.         -1.         -1.          0.          0.        ]
#   [ 3.          3.          2.          1.          0.        ]
#   [11.         -1.         -1.          0.          0.        ]
#   [ 2.          5.          4.          0.          0.        ]
#   [ 9.         -1.         -1.          0.          0.        ]
#   [ 3.          7.          6.          0.          0.        ]
#   [12.         -1.         -1.          0.          0.        ]
#   [ 8.         -1.         -1.          0.          0.        ]
#   [ 4.         10.          9.          0.          0.        ]
#   [ 9.         -1.         -1.          0.          0.        ]
#   [ 2.         12.         11.          2.          0.        ]
#   [ 2.         13.          8.          0.          0.        ]
#   [ 2.         14.          1.          0.          0.        ]
#   [ 6.         -1.         -1.          0.          0.        ]
#   [ 6.         -1.         -1.          0.          0.        ]
#   [ 4.         17.         16.          0.          0.        ]
#   [ 1.         -1.         -1.          0.          0.39555058]
#   [12.         -1.         -1.          0.          0.        ]
#   [ 6.         -1.         -1.          0.          0.        ]
#   [ 2.         21.         20.          0.          0.        ]
#   [ 2.         22.         19.          0.          0.        ]
#   [12.         -1.         -1.          0.          0.        ]
#   [ 5.         -1.         -1.          0.          0.        ]
#   [ 2.         25.         24.          0.          0.        ]
#   [ 2.         26.         23.          0.          0.        ]
#   [ 4.         27.         18.          0.          0.        ]
#   [ 3.         28.         15.          2.          0.        ]]]

# %%
brax_env = BraxGymnaxWrapper('hopper', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    # ("sin", lambda x: jnp.sin(x), 1, 0.1),
    # ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=3, max_nodes = 31)
# Out:
# /home/theun/yes/envs/modi_kozax/lib/python3.12/site-packages/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Compiling code for evaluation and evolution...
# Finished compilation in 222.05 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 3, fitness: -253.8053436279297, equation: [0, y9**2, 0]
# Complexity: 5, fitness: -313.97747802734375, equation: [0, y0 + y7*y8, y7*y8]
# Complexity: 9, fitness: -343.5119323730469, equation: [y0 + y1 - y3 + y5 - y9, 0, -y5 + y9]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -250.20826721191406, equation: [0, y4, 0]
# Complexity: 3, fitness: -310.43511962890625, equation: [0, y7*y9, 0]
# Complexity: 5, fitness: -364.2060546875, equation: [0, y0*y7*y8, y7*y8]
# Complexity: 7, fitness: -394.6515808105469, equation: [0, y2*y6 + y7*y8, y7*y8]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -250.21795654296875, equation: [0, y4, 0]
# Complexity: 3, fitness: -310.43511962890625, equation: [0, y7*y9, 0]
# Complexity: 5, fitness: -364.2060546875, equation: [0, y0*y7*y8, y7*y8]
# Complexity: 7, fitness: -394.6515808105469, equation: [0, y2*y6 + y7*y8, y7*y8]
# Complexity: 11, fitness: -417.3872375488281, equation: [0, y1*(y2 + y3 - y5 - y6 + y9), -y5 + y9]
# Complexity: 15, fitness: -1025.663330078125, equation: [0, y4*(y0 + y4 + y9), y3 - y4*(y0 + y4 + y9) + y4 - 0.769*y7]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -250.21795654296875, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 7, fitness: -425.86279296875, equation: [0, y1*(y3 - y5 + y9), -y5 + y9]
# Complexity: 9, fitness: -471.6175842285156, equation: [y1 + y5 - y7, 0, -y5 + y9]
# Complexity: 11, fitness: -810.7020263671875, equation: [0, y0*y4, -y0*y4 + y3 + y4 - 0.769*y7]
# Complexity: 13, fitness: -956.5850219726562, equation: [0, y4*(y0 + y7), y3 - y4*(y0 + y7) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.663330078125, equation: [0, y4*(y0 + y4 + y9), y3 - y4*(y0 + y4 + y9) + y4 - 0.769*y7]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -250.21795654296875, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -460.49993896484375, equation: [0, 0, y2 + y3 - 2*y5 + 2*y9]
# Complexity: 9, fitness: -471.6175842285156, equation: [y1 + y5 - y7, 0, -y5 + y9]
# Complexity: 11, fitness: -810.7020263671875, equation: [0, y0*y4, -y0*y4 + y3 + y4 - 0.769*y7]
# Complexity: 13, fitness: -956.5850219726562, equation: [0, y4*(y0 + y7), y3 - y4*(y0 + y7) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.663330078125, equation: [0, y4*(y0 + y4 + y9), y3 - y4*(y0 + y4 + y9) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1026.8853759765625, equation: [0, y4*(y0 - y10*y7 + y4), y3 - y4*(y0 - y10*y7 + y4) + y4 - 0.769*y7]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -250.21795654296875, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -810.7020263671875, equation: [0, y0*y4, -y0*y4 + y3 + y4 - 0.769*y7]
# Complexity: 13, fitness: -956.5850219726562, equation: [0, y4*(y0 + y7), y3 - y4*(y0 + y7) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.663330078125, equation: [0, y4*(y0 + y4 + y9), y3 - y4*(y0 + y4 + y9) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1026.8853759765625, equation: [0, y4*(y0 - y10*y7 + y4), y3 - y4*(y0 - y10*y7 + y4) + y4 - 0.769*y7]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.663330078125, equation: [0, y4*(y0 + y4 + y9), y3 - y4*(y0 + y4 + y9) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1026.8853759765625, equation: [0, y4*(y0 - y10*y7 + y4), y3 - y4*(y0 - y10*y7 + y4) + y4 - 0.769*y7]
# Complexity: 21, fitness: -1048.1170654296875, equation: [0, y0**2*y7*y9 + y4*(-y0**2*y7*y9 + y0 + y4), y3 - y4*(-y0**2*y7*y9 + y0 + y4) + y4 - 0.769*y7]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.663330078125, equation: [0, y4*(y0 + y4 + y9), y3 - y4*(y0 + y4 + y9) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1026.8853759765625, equation: [0, y4*(y0 - y10*y7 + y4), y3 - y4*(y0 - y10*y7 + y4) + y4 - 0.769*y7]
# Complexity: 21, fitness: -1048.1170654296875, equation: [0, y0**2*y7*y9 + y4*(-y0**2*y7*y9 + y0 + y4), y3 - y4*(-y0**2*y7*y9 + y0 + y4) + y4 - 0.769*y7]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.663330078125, equation: [0, y4*(y0 + y4 + y9), y3 - y4*(y0 + y4 + y9) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1026.8853759765625, equation: [0, y4*(y0 - y10*y7 + y4), y3 - y4*(y0 - y10*y7 + y4) + y4 - 0.769*y7]
# Complexity: 21, fitness: -1060.283935546875, equation: [0, y0**2*y7*y9 + y4*(-y0**2*y7*y9 + y0 + y4), y3 - y4*(-y0**2*y7*y9 + y0 + y4) + y4 - 0.769*y7]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.663330078125, equation: [0, y4*(y0 + y4 + y9), y3 - y4*(y0 + y4 + y9) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1026.8853759765625, equation: [0, y4*(y0 - y10*y7 + y4), y3 - y4*(y0 - y10*y7 + y4) + y4 - 0.769*y7]
# Complexity: 21, fitness: -1062.130126953125, equation: [0, y0**2*y7*y9 + y4*(-y0**2*y7*y9 + y0 + y4), y3 - y4*(-y0**2*y7*y9 + y0 + y4) + y4 - 0.769*y7]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.663330078125, equation: [0, y4*(y0 + y4 + y9), y3 - y4*(y0 + y4 + y9) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1026.8853759765625, equation: [0, y4*(y0 - y10*y7 + y4), y3 - y4*(y0 - y10*y7 + y4) + y4 - 0.769*y7]
# Complexity: 21, fitness: -1063.2554931640625, equation: [0, y0**2*y7*y9 + y4*(-y0**2*y7*y9 + y0 + y4), y3 - y4*(-y0**2*y7*y9 + y0 + y4) + y4 - 0.769*y7]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 13, fitness: -1023.618896484375, equation: [0, y4*(y0 + y4), y3 - y4*(y0 + y4) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.663330078125, equation: [0, y4*(y0 + y4 + y9), y3 - y4*(y0 + y4 + y9) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1026.8853759765625, equation: [0, y4*(y0 - y10*y7 + y4), y3 - y4*(y0 - y10*y7 + y4) + y4 - 0.769*y7]
# Complexity: 21, fitness: -1063.2554931640625, equation: [0, y0**2*y7*y9 + y4*(-y0**2*y7*y9 + y0 + y4), y3 - y4*(-y0**2*y7*y9 + y0 + y4) + y4 - 0.769*y7]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 13, fitness: -1023.618896484375, equation: [0, y4*(y0 + y4), y3 - y4*(y0 + y4) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.663330078125, equation: [0, y4*(y0 + y4 + y9), y3 - y4*(y0 + y4 + y9) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1026.8853759765625, equation: [0, y4*(y0 - y10*y7 + y4), y3 - y4*(y0 - y10*y7 + y4) + y4 - 0.769*y7]
# Complexity: 19, fitness: -1033.83056640625, equation: [-y3 + y6 - y7, -y3 + y9*(y2*(-y3 - y5 + y6 - y7 + y9) + y9 - 0.875), -y5 + y9]
# Complexity: 21, fitness: -1063.2554931640625, equation: [0, y0**2*y7*y9 + y4*(-y0**2*y7*y9 + y0 + y4), y3 - y4*(-y0**2*y7*y9 + y0 + y4) + y4 - 0.769*y7]
# Complexity: 27, fitness: -1150.7198486328125, equation: [-y3*y5*y9**2 - y7 + y9, -y3 - y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 13, fitness: -1023.618896484375, equation: [0, y4*(y0 + y4), y3 - y4*(y0 + y4) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.663330078125, equation: [0, y4*(y0 + y4 + y9), y3 - y4*(y0 + y4 + y9) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1033.070556640625, equation: [0, y4*(y0 - y4*y5 + y4), y3 - y4*(y0 - y4*y5 + y4) + y4 - 0.769*y7]
# Complexity: 19, fitness: -1033.83056640625, equation: [-y3 + y6 - y7, -y3 + y9*(y2*(-y3 - y5 + y6 - y7 + y9) + y9 - 0.875), -y5 + y9]
# Complexity: 21, fitness: -1063.2554931640625, equation: [0, y0**2*y7*y9 + y4*(-y0**2*y7*y9 + y0 + y4), y3 - y4*(-y0**2*y7*y9 + y0 + y4) + y4 - 0.769*y7]
# Complexity: 25, fitness: -1076.0489501953125, equation: [-y2*y5*y9 - y7 + y9, -y3 - y7 + y9*(y2*(-y2*y5*y9 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 27, fitness: -1156.146728515625, equation: [-y3*y5*y9**2 - y7 + y9, -y3 - y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 13, fitness: -1023.618896484375, equation: [0, y4*(y0 + y4), y3 - y4*(y0 + y4) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.663330078125, equation: [0, y4*(y0 + y4 + y9), y3 - y4*(y0 + y4 + y9) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1033.070556640625, equation: [0, y4*(y0 - y4*y5 + y4), y3 - y4*(y0 - y4*y5 + y4) + y4 - 0.769*y7]
# Complexity: 19, fitness: -1033.83056640625, equation: [-y3 + y6 - y7, -y3 + y9*(y2*(-y3 - y5 + y6 - y7 + y9) + y9 - 0.875), -y5 + y9]
# Complexity: 21, fitness: -1063.2554931640625, equation: [0, y0**2*y7*y9 + y4*(-y0**2*y7*y9 + y0 + y4), y3 - y4*(-y0**2*y7*y9 + y0 + y4) + y4 - 0.769*y7]
# Complexity: 25, fitness: -1148.8671875, equation: [-y3*y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 27, fitness: -1156.146728515625, equation: [-y3*y5*y9**2 - y7 + y9, -y3 - y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 13, fitness: -1023.618896484375, equation: [0, y4*(y0 + y4), y3 - y4*(y0 + y4) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.663330078125, equation: [0, y4*(y0 + y4 + y9), y3 - y4*(y0 + y4 + y9) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1033.070556640625, equation: [0, y4*(y0 - y4*y5 + y4), y3 - y4*(y0 - y4*y5 + y4) + y4 - 0.769*y7]
# Complexity: 19, fitness: -1035.2725830078125, equation: [0, y10*y5*y9 + y4*(y0 - y10*y5*y9 + y4), y3 - y4*(y0 - y10*y5*y9 + y4) + y4 - 0.769*y7]
# Complexity: 21, fitness: -1063.2554931640625, equation: [0, y0**2*y7*y9 + y4*(-y0**2*y7*y9 + y0 + y4), y3 - y4*(-y0**2*y7*y9 + y0 + y4) + y4 - 0.769*y7]
# Complexity: 23, fitness: -1084.52734375, equation: [-y5*y7*y9 - y7 + y9, -y7 + y9*(y2*(-y5*y7*y9 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 25, fitness: -1148.8671875, equation: [-y3*y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 27, fitness: -1156.146728515625, equation: [-y3*y5*y9**2 - y7 + y9, -y3 - y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 13, fitness: -1023.618896484375, equation: [0, y4*(y0 + y4), y3 - y4*(y0 + y4) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.66455078125, equation: [0, y4*(y0 - y3 + y4), y3 - y4*(y0 - y3 + y4) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1033.070556640625, equation: [0, y4*(y0 - y4*y5 + y4), y3 - y4*(y0 - y4*y5 + y4) + y4 - 0.769*y7]
# Complexity: 19, fitness: -1035.2725830078125, equation: [0, y10*y5*y9 + y4*(y0 - y10*y5*y9 + y4), y3 - y4*(y0 - y10*y5*y9 + y4) + y4 - 0.769*y7]
# Complexity: 21, fitness: -1063.2554931640625, equation: [0, y0**2*y7*y9 + y4*(-y0**2*y7*y9 + y0 + y4), y3 - y4*(-y0**2*y7*y9 + y0 + y4) + y4 - 0.769*y7]
# Complexity: 23, fitness: -1103.245361328125, equation: [-y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y5 + y9)*(-y5*y9**2 - y7 + y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 25, fitness: -1148.8671875, equation: [-y3*y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 27, fitness: -1156.146728515625, equation: [-y3*y5*y9**2 - y7 + y9, -y3 - y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 13, fitness: -1023.618896484375, equation: [0, y4*(y0 + y4), y3 - y4*(y0 + y4) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.66455078125, equation: [0, y4*(y0 - y3 + y4), y3 - y4*(y0 - y3 + y4) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1033.070556640625, equation: [0, y4*(y0 - y4*y5 + y4), y3 - y4*(y0 - y4*y5 + y4) + y4 - 0.769*y7]
# Complexity: 19, fitness: -1035.2725830078125, equation: [0, y10*y5*y9 + y4*(y0 - y10*y5*y9 + y4), y3 - y4*(y0 - y10*y5*y9 + y4) + y4 - 0.769*y7]
# Complexity: 21, fitness: -1063.2554931640625, equation: [0, y0**2*y7*y9 + y4*(-y0**2*y7*y9 + y0 + y4), y3 - y4*(-y0**2*y7*y9 + y0 + y4) + y4 - 0.769*y7]
# Complexity: 23, fitness: -1103.245361328125, equation: [-y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y5 + y9)*(-y5*y9**2 - y7 + y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 25, fitness: -1148.8671875, equation: [-y3*y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 27, fitness: -1156.146728515625, equation: [-y3*y5*y9**2 - y7 + y9, -y3 - y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 13, fitness: -1023.618896484375, equation: [0, y4*(y0 + y4), y3 - y4*(y0 + y4) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.66455078125, equation: [0, y4*(y0 - y3 + y4), y3 - y4*(y0 - y3 + y4) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1033.070556640625, equation: [0, y4*(y0 - y4*y5 + y4), y3 - y4*(y0 - y4*y5 + y4) + y4 - 0.769*y7]
# Complexity: 19, fitness: -1035.2725830078125, equation: [0, y10*y5*y9 + y4*(y0 - y10*y5*y9 + y4), y3 - y4*(y0 - y10*y5*y9 + y4) + y4 - 0.769*y7]
# Complexity: 21, fitness: -1076.70263671875, equation: [-y5*y9 - y7 + y9, -y7 + y9*(y2*(-y5*y9 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 23, fitness: -1103.245361328125, equation: [-y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y5 + y9)*(-y5*y9**2 - y7 + y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 25, fitness: -1148.8671875, equation: [-y3*y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 27, fitness: -1156.146728515625, equation: [-y3*y5*y9**2 - y7 + y9, -y3 - y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 13, fitness: -1023.618896484375, equation: [0, y4*(y0 + y4), y3 - y4*(y0 + y4) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.66455078125, equation: [0, y4*(y0 - y3 + y4), y3 - y4*(y0 - y3 + y4) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1033.070556640625, equation: [0, y4*(y0 - y4*y5 + y4), y3 - y4*(y0 - y4*y5 + y4) + y4 - 0.769*y7]
# Complexity: 19, fitness: -1035.2725830078125, equation: [0, y10*y5*y9 + y4*(y0 - y10*y5*y9 + y4), y3 - y4*(y0 - y10*y5*y9 + y4) + y4 - 0.769*y7]
# Complexity: 21, fitness: -1076.70263671875, equation: [-y5*y9 - y7 + y9, -y7 + y9*(y2*(-y5*y9 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 23, fitness: -1103.245361328125, equation: [-y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y5 + y9)*(-y5*y9**2 - y7 + y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 25, fitness: -1148.8671875, equation: [-y3*y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 27, fitness: -1156.987548828125, equation: [-y2*y9**2 - y7 + y9, -y3 - y7 + y9*(y5*y9*(-y2*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y2*y9 + y5*y9 - y5 + y9]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 13, fitness: -1023.618896484375, equation: [0, y4*(y0 + y4), y3 - y4*(y0 + y4) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.66455078125, equation: [0, y4*(y0 - y3 + y4), y3 - y4*(y0 - y3 + y4) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1033.070556640625, equation: [0, y4*(y0 - y4*y5 + y4), y3 - y4*(y0 - y4*y5 + y4) + y4 - 0.769*y7]
# Complexity: 19, fitness: -1035.2725830078125, equation: [0, y10*y5*y9 + y4*(y0 - y10*y5*y9 + y4), y3 - y4*(y0 - y10*y5*y9 + y4) + y4 - 0.769*y7]
# Complexity: 21, fitness: -1076.70263671875, equation: [-y5*y9 - y7 + y9, -y7 + y9*(y2*(-y5*y9 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 23, fitness: -1103.245361328125, equation: [-y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y5 + y9)*(-y5*y9**2 - y7 + y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 25, fitness: -1148.8671875, equation: [-y3*y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 27, fitness: -1157.30810546875, equation: [-y3*y5**2*y9**2 - y7 + y9, -y7 + y9*(y2*(-y3*y5**2*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 13, fitness: -1023.618896484375, equation: [0, y4*(y0 + y4), y3 - y4*(y0 + y4) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.66455078125, equation: [0, y4*(y0 - y3 + y4), y3 - y4*(y0 - y3 + y4) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1033.070556640625, equation: [0, y4*(y0 - y4*y5 + y4), y3 - y4*(y0 - y4*y5 + y4) + y4 - 0.769*y7]
# Complexity: 19, fitness: -1035.2725830078125, equation: [0, y10*y5*y9 + y4*(y0 - y10*y5*y9 + y4), y3 - y4*(y0 - y10*y5*y9 + y4) + y4 - 0.769*y7]
# Complexity: 21, fitness: -1078.8406982421875, equation: [0, y4*(y0 + y1*y7 + 2*y4 + y8), y3 - y4*(y0 + y1*y7 + 2*y4 + y8) + y4 - 0.769*y7]
# Complexity: 23, fitness: -1103.245361328125, equation: [-y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y5 + y9)*(-y5*y9**2 - y7 + y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 25, fitness: -1152.977294921875, equation: [-y3*y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 27, fitness: -1157.30810546875, equation: [-y3*y5**2*y9**2 - y7 + y9, -y7 + y9*(y2*(-y3*y5**2*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 29, fitness: -1166.88232421875, equation: [-y5**2*y9**3 - y7 + y9, -y7 + y9*(y3*y9*(-y5**2*y9**3 - y5 - y7 + 2*y9) + y9 - 0.875), 2*y5*y9 - y5 + y9]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 9, fitness: -602.4540405273438, equation: [0, -y3 - y7 + y9*(-y5 + y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 13, fitness: -1023.618896484375, equation: [0, y4*(y0 + y4), y3 - y4*(y0 + y4) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.66455078125, equation: [0, y4*(y0 - y3 + y4), y3 - y4*(y0 - y3 + y4) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1033.070556640625, equation: [0, y4*(y0 - y4*y5 + y4), y3 - y4*(y0 - y4*y5 + y4) + y4 - 0.769*y7]
# Complexity: 19, fitness: -1035.2725830078125, equation: [0, y10*y5*y9 + y4*(y0 - y10*y5*y9 + y4), y3 - y4*(y0 - y10*y5*y9 + y4) + y4 - 0.769*y7]
# Complexity: 21, fitness: -1078.8406982421875, equation: [0, y4*(y0 + y1*y7 + 2*y4 + y8), y3 - y4*(y0 + y1*y7 + 2*y4 + y8) + y4 - 0.769*y7]
# Complexity: 23, fitness: -1103.245361328125, equation: [-y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y5 + y9)*(-y5*y9**2 - y7 + y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 25, fitness: -1152.977294921875, equation: [-y3*y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 27, fitness: -1157.30810546875, equation: [-y3*y5**2*y9**2 - y7 + y9, -y7 + y9*(y2*(-y3*y5**2*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 29, fitness: -1166.88232421875, equation: [-y5**2*y9**3 - y7 + y9, -y7 + y9*(y3*y9*(-y5**2*y9**3 - y5 - y7 + 2*y9) + y9 - 0.875), 2*y5*y9 - y5 + y9]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 9, fitness: -602.4540405273438, equation: [0, -y3 - y7 + y9*(-y5 + y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 13, fitness: -1023.618896484375, equation: [0, y4*(y0 + y4), y3 - y4*(y0 + y4) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.66455078125, equation: [0, y4*(y0 - y3 + y4), y3 - y4*(y0 - y3 + y4) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1033.070556640625, equation: [0, y4*(y0 - y4*y5 + y4), y3 - y4*(y0 - y4*y5 + y4) + y4 - 0.769*y7]
# Complexity: 19, fitness: -1037.724853515625, equation: [-y3 - y7 + y9, -y7 + y9*(y2*(-y3 - y5 - y7 + 2*y9) + y9 - 0.875), -y5 + y9]
# Complexity: 21, fitness: -1078.8406982421875, equation: [0, y4*(y0 + y1*y7 + 2*y4 + y8), y3 - y4*(y0 + y1*y7 + 2*y4 + y8) + y4 - 0.769*y7]
# Complexity: 23, fitness: -1103.245361328125, equation: [-y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y5 + y9)*(-y5*y9**2 - y7 + y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 25, fitness: -1152.977294921875, equation: [-y3*y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 27, fitness: -1157.30810546875, equation: [-y3*y5**2*y9**2 - y7 + y9, -y7 + y9*(y2*(-y3*y5**2*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 29, fitness: -1171.244140625, equation: [-y5**2*y9**3 - y7 + y9, -y7 + y9*(y3*y9*(-y5**2*y9**3 - y5 - y7 + 2*y9) + y9 - 0.875), 2*y5*y9 - y5 + y9]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 9, fitness: -602.4540405273438, equation: [0, -y3 - y7 + y9*(-y5 + y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 13, fitness: -1023.618896484375, equation: [0, y4*(y0 + y4), y3 - y4*(y0 + y4) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.66455078125, equation: [0, y4*(y0 - y3 + y4), y3 - y4*(y0 - y3 + y4) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1037.083984375, equation: [0, y4**2 + y4*(y0 - y4**2 + y4), y3 - y4*(y0 - y4**2 + y4) + y4 - 0.769*y7]
# Complexity: 19, fitness: -1037.724853515625, equation: [-y3 - y7 + y9, -y7 + y9*(y2*(-y3 - y5 - y7 + 2*y9) + y9 - 0.875), -y5 + y9]
# Complexity: 21, fitness: -1078.8406982421875, equation: [0, y4*(y0 + y1*y7 + 2*y4 + y8), y3 - y4*(y0 + y1*y7 + 2*y4 + y8) + y4 - 0.769*y7]
# Complexity: 23, fitness: -1103.245361328125, equation: [-y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y5 + y9)*(-y5*y9**2 - y7 + y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 25, fitness: -1152.977294921875, equation: [-y3*y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 27, fitness: -1158.0693359375, equation: [-y3*y5*y9**2 - y7 + y9, -y3 - y7 + y9*(y2*(-y5 + y9)*(-y3*y5*y9**2 - y7 + y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 29, fitness: -1171.244140625, equation: [-y5**2*y9**3 - y7 + y9, -y7 + y9*(y3*y9*(-y5**2*y9**3 - y5 - y7 + 2*y9) + y9 - 0.875), 2*y5*y9 - y5 + y9]
# Final pareto front:
# Complexity: 1, fitness: -250.30404663085938, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.30377197265625, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -428.3620300292969, equation: [0, 0, -2*y5 + y7 + 2*y9]
# Complexity: 7, fitness: -542.358642578125, equation: [0, y7*(-y5 + 2*y9), -y5 + y9]
# Complexity: 9, fitness: -602.4540405273438, equation: [0, -y3 - y7 + y9*(-y5 + y9), -y5 + y9]
# Complexity: 11, fitness: -958.4342041015625, equation: [0, 1.28*y4, y3 - 0.285*y4 - 0.769*y7]
# Complexity: 13, fitness: -1023.618896484375, equation: [0, y4*(y0 + y4), y3 - y4*(y0 + y4) + y4 - 0.769*y7]
# Complexity: 15, fitness: -1025.66455078125, equation: [0, y4*(y0 - y3 + y4), y3 - y4*(y0 - y3 + y4) + y4 - 0.769*y7]
# Complexity: 17, fitness: -1037.083984375, equation: [0, y4**2 + y4*(y0 - y4**2 + y4), y3 - y4*(y0 - y4**2 + y4) + y4 - 0.769*y7]
# Complexity: 19, fitness: -1037.724853515625, equation: [-y3 - y7 + y9, -y7 + y9*(y2*(-y3 - y5 - y7 + 2*y9) + y9 - 0.875), -y5 + y9]
# Complexity: 21, fitness: -1078.8406982421875, equation: [0, y4*(y0 + y1*y7 + 2*y4 + y8), y3 - y4*(y0 + y1*y7 + 2*y4 + y8) + y4 - 0.769*y7]
# Complexity: 23, fitness: -1103.245361328125, equation: [-y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y5 + y9)*(-y5*y9**2 - y7 + y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 25, fitness: -1152.977294921875, equation: [-y3*y5*y9**2 - y7 + y9, -y7 + y9*(y2*(-y3*y5*y9**2 - y5 - y7 + 2*y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 27, fitness: -1158.0693359375, equation: [-y3*y5*y9**2 - y7 + y9, -y3 - y7 + y9*(y2*(-y5 + y9)*(-y3*y5*y9**2 - y7 + y9) + y9 - 0.875), y5*y9 - y5 + y9]
# Complexity: 29, fitness: -1171.244140625, equation: [-y5**2*y9**3 - y7 + y9, -y7 + y9*(y3*y9*(-y5**2*y9**3 - y5 - y7 + 2*y9) + y9 - 0.875), 2*y5*y9 - y5 + y9]

# %%
brax_env = BraxGymnaxWrapper('walker2d', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    # ("sin", lambda x: jnp.sin(x), 1, 0.1),
    # ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=6, max_nodes = 31)
# Out:
# /home/theun/yes/envs/modi_kozax/lib/python3.12/site-packages/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10', 'y11', 'y12', 'y13', 'y14', 'y15', 'y16'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Compiling code for evaluation and evolution...
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
# Canceled future for execute_request message before replies were done
# Canceled future for execute_request message before replies were done.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
brax_env = BraxGymnaxWrapper('half cheetah', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    # ("sin", lambda x: jnp.sin(x), 1, 0.1),
    # ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=6, max_nodes = 31)

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)

# %%
brax_env = BraxGymnaxWrapper('ant', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    # ("sin", lambda x: jnp.sin(x), 1, 0.1),
    # ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=8, max_nodes = 31)

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)

# %%
pf = strategy.pareto_front[1]
print(pf[-1])

# %%
print(pf[-1])
# Out:
# [[[ 8.        -1.        -1.         0.         0.       ]
#   [10.        -1.        -1.         0.         0.       ]
#   [ 1.        -1.        -1.         0.         0.7010061]
#   [ 4.         2.         1.         0.         0.       ]
#   [13.        -1.        -1.         0.         0.       ]
#   [10.        -1.        -1.         0.         0.       ]
#   [ 4.         5.         4.         2.         0.       ]
#   [ 2.         6.         3.         0.         0.       ]
#   [ 6.        -1.        -1.         0.         0.       ]
#   [ 4.         8.         7.         2.         0.       ]
#   [ 2.         9.         0.         0.         0.       ]
#   [ 8.        -1.        -1.         0.         0.       ]
#   [ 2.        11.        10.         0.         0.       ]
#   [13.        -1.        -1.         0.         0.       ]
#   [ 4.        13.        12.         2.         0.       ]]]
