# %%
# !pip install kozax
# !pip install brax
# !pip install gymnax
# !pip install jaxtyping
# !pip install wandb
# !pip install python-telegram-bot==21.6
# Out:
# ERROR: Ignored the following versions that require a different python version: 0.0.1 Requires-Python ~=3.10; 0.0.10 Requires-Python >=3.10; 0.0.11 Requires-Python >=3.10; 0.0.13 Requires-Python >=3.10; 0.0.2 Requires-Python ~=3.10; 0.0.3 Requires-Python ~=3.10; 0.0.4 Requires-Python ~=3.10; 0.0.5 Requires-Python >=3.10; 0.0.6 Requires-Python >=3.10; 0.0.7 Requires-Python >=3.10; 0.0.8 Requires-Python >=3.10; 0.0.9 Requires-Python >=3.10
# ERROR: Could not find a version that satisfies the requirement kozax (from versions: none)
# ERROR: No matching distribution found for kozax
# Requirement already satisfied: brax in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (0.0.15)
# Requirement already satisfied: absl-py in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from brax) (1.0.0)
# Requirement already satisfied: dataclasses in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from brax) (0.6)
# Requirement already satisfied: dm-env in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from brax) (1.6)
# Requirement already satisfied: flax in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from brax) (0.6.0)
# Requirement already satisfied: gym in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from brax) (0.26.2)
# Requirement already satisfied: grpcio in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from brax) (1.70.0)
# Requirement already satisfied: jax in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from brax) (0.3.17)
# Requirement already satisfied: jaxlib in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from brax) (0.3.15)
# Requirement already satisfied: numpy in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from brax) (1.21.5)
# Requirement already satisfied: optax in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from brax) (0.1.4)
# Requirement already satisfied: Pillow in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from brax) (9.0.0)
# Requirement already satisfied: pytinyrenderer in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from brax) (0.0.14)
# Requirement already satisfied: tensorboardX in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from brax) (2.6)
# Requirement already satisfied: trimesh in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from brax) (4.11.2)
# Requirement already satisfied: typing-extensions in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from brax) (4.13.2)
# Requirement already satisfied: PyYAML>=6.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from brax) (6.0.3)
# Requirement already satisfied: six in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from absl-py->brax) (1.17.0)
# Requirement already satisfied: dm-tree in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from dm-env->brax) (0.1.8)
# Requirement already satisfied: matplotlib in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from flax->brax) (3.5.1)
# Requirement already satisfied: msgpack in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from flax->brax) (1.0.3)
# Requirement already satisfied: rich~=11.1 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from flax->brax) (11.2.0)
# Requirement already satisfied: opt-einsum in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from jax->brax) (3.4.0)
# Requirement already satisfied: scipy>=1.5 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from jax->brax) (1.8.0)
# Requirement already satisfied: etils[epath] in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from jax->brax) (1.3.0)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from gym->brax) (3.1.2)
# Requirement already satisfied: gym-notices>=0.0.4 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from gym->brax) (0.1.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from gym->brax) (8.5.0)
# Requirement already satisfied: chex>=0.1.5 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from optax->brax) (0.1.5)
# Requirement already satisfied: packaging in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from tensorboardX->brax) (24.1)
# Requirement already satisfied: protobuf<4,>=3.8.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from tensorboardX->brax) (3.19.4)
# Requirement already satisfied: toolz>=0.9.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from chex>=0.1.5->optax->brax) (1.0.0)
# Requirement already satisfied: zipp>=3.20 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from importlib-metadata>=4.8.0->gym->brax) (3.20.2)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from rich~=11.1->flax->brax) (0.4.6)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from rich~=11.1->flax->brax) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from rich~=11.1->flax->brax) (2.19.2)
# Requirement already satisfied: importlib_resources in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from etils[epath]->jax->brax) (6.4.5)
# Requirement already satisfied: cycler>=0.10 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from matplotlib->flax->brax) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from matplotlib->flax->brax) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from matplotlib->flax->brax) (1.4.7)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from matplotlib->flax->brax) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from matplotlib->flax->brax) (2.9.0.post0)
# Requirement already satisfied: gymnax in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (0.0.6)
# Requirement already satisfied: jax in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from gymnax) (0.3.17)
# Requirement already satisfied: jaxlib in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from gymnax) (0.3.15)
# Requirement already satisfied: chex in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from gymnax) (0.1.5)
# Requirement already satisfied: flax in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from gymnax) (0.6.0)
# Requirement already satisfied: pyyaml in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from gymnax) (6.0.3)
# Requirement already satisfied: gym>=0.26 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from gymnax) (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from gym>=0.26->gymnax) (1.21.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from gym>=0.26->gymnax) (3.1.2)
# Requirement already satisfied: gym-notices>=0.0.4 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from gym>=0.26->gymnax) (0.1.0)
# Requirement already satisfied: importlib-metadata>=4.8.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from gym>=0.26->gymnax) (8.5.0)
# Requirement already satisfied: absl-py>=0.9.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from chex->gymnax) (1.0.0)
# Requirement already satisfied: dm-tree>=0.1.5 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from chex->gymnax) (0.1.8)
# Requirement already satisfied: toolz>=0.9.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from chex->gymnax) (1.0.0)
# Requirement already satisfied: opt-einsum in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from jax->gymnax) (3.4.0)
# Requirement already satisfied: scipy>=1.5 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from jax->gymnax) (1.8.0)
# Requirement already satisfied: typing-extensions in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from jax->gymnax) (4.13.2)
# Requirement already satisfied: etils[epath] in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from jax->gymnax) (1.3.0)
# Requirement already satisfied: matplotlib in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from flax->gymnax) (3.5.1)
# Requirement already satisfied: msgpack in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from flax->gymnax) (1.0.3)
# Requirement already satisfied: optax in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from flax->gymnax) (0.1.4)
# Requirement already satisfied: rich~=11.1 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from flax->gymnax) (11.2.0)
# Requirement already satisfied: six in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from absl-py>=0.9.0->chex->gymnax) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from importlib-metadata>=4.8.0->gym>=0.26->gymnax) (3.20.2)
# Requirement already satisfied: colorama<0.5.0,>=0.4.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from rich~=11.1->flax->gymnax) (0.4.6)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from rich~=11.1->flax->gymnax) (0.9.1)
# Requirement already satisfied: pygments<3.0.0,>=2.6.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from rich~=11.1->flax->gymnax) (2.19.2)
# Requirement already satisfied: importlib_resources in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from etils[epath]->jax->gymnax) (6.4.5)
# Requirement already satisfied: cycler>=0.10 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from matplotlib->flax->gymnax) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from matplotlib->flax->gymnax) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from matplotlib->flax->gymnax) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from matplotlib->flax->gymnax) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from matplotlib->flax->gymnax) (9.0.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from matplotlib->flax->gymnax) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from matplotlib->flax->gymnax) (2.9.0.post0)
# Requirement already satisfied: jaxtyping in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (0.2.19)
# Requirement already satisfied: numpy>=1.20.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from jaxtyping) (1.21.5)
# Requirement already satisfied: typeguard>=2.13.3 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from jaxtyping) (4.4.0)
# Requirement already satisfied: typing-extensions>=3.7.4.1 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from jaxtyping) (4.13.2)
# Requirement already satisfied: importlib-metadata>=3.6 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from typeguard>=2.13.3->jaxtyping) (8.5.0)
# Requirement already satisfied: zipp>=3.20 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from importlib-metadata>=3.6->typeguard>=2.13.3->jaxtyping) (3.20.2)
# Requirement already satisfied: wandb in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (0.18.3)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from wandb) (8.1.8)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from wandb) (3.1.46)
# Requirement already satisfied: platformdirs in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from wandb) (3.10.0)
# Requirement already satisfied: protobuf!=4.21.0,!=5.28.0,<6,>=3.12.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from wandb) (3.19.4)
# Requirement already satisfied: psutil>=5.0.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from wandb) (7.2.2)
# Requirement already satisfied: pyyaml in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from wandb) (6.0.3)
# Requirement already satisfied: requests<3,>=2.0.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from wandb) (2.54.0)
# Requirement already satisfied: setproctitle in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from wandb) (1.3.7)
# Requirement already satisfied: setuptools in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from wandb) (75.1.0)
# Requirement already satisfied: typing-extensions in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from wandb) (4.13.2)
# Requirement already satisfied: six>=1.4.0 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from docker-pycreds>=0.4.0->wandb) (1.17.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.12)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from requests<3,>=2.0.0->wandb) (2024.8.30)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.2)
# Requirement already satisfied: python-telegram-bot==21.6 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (21.6)
# Requirement already satisfied: httpx~=0.27 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from python-telegram-bot==21.6) (0.28.1)
# Requirement already satisfied: anyio in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from httpx~=0.27->python-telegram-bot==21.6) (4.5.2)
# Requirement already satisfied: certifi in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from httpx~=0.27->python-telegram-bot==21.6) (2024.8.30)
# Requirement already satisfied: httpcore==1.* in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from httpx~=0.27->python-telegram-bot==21.6) (1.0.9)
# Requirement already satisfied: idna in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from httpx~=0.27->python-telegram-bot==21.6) (3.7)
# Requirement already satisfied: h11>=0.16 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from httpcore==1.*->httpx~=0.27->python-telegram-bot==21.6) (0.16.0)
# Requirement already satisfied: sniffio>=1.1 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from anyio->httpx~=0.27->python-telegram-bot==21.6) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from anyio->httpx~=0.27->python-telegram-bot==21.6) (1.2.2)
# Requirement already satisfied: typing-extensions>=4.1 in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from anyio->httpx~=0.27->python-telegram-bot==21.6) (4.13.2)

# %%
# !pip install dm_env
# Out:
# Requirement already satisfied: dm_env in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (1.6)
# Requirement already satisfied: absl-py in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from dm_env) (1.0.0)
# Requirement already satisfied: dm-tree in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from dm_env) (0.1.8)
# Requirement already satisfied: numpy in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from dm_env) (1.21.5)
# Requirement already satisfied: six in /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages (from absl-py->dm_env) (1.17.0)

# %%
brax.__version__
# Out:
# '0.0.15'

# %%
wandb.__version__
# Out:
# '0.18.3'

# %%
import telegram
print(telegram.__file__)
print(telegram.__version__ if hasattr(telegram, '__version__') else 'no version attribute')
print(telegram.Bot)
# Out:
# /home/theun/miniconda3/envs/gpax/lib/python3.8/site-packages/telegram/__init__.py
# no version attribute
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[18], line 4
#       2 print(telegram.__file__)
#       3 print(telegram.__version__ if hasattr(telegram, '__version__') else 'no version attribute')
# ----> 4 print(telegram.Bot)
#
# AttributeError: module 'telegram' has no attribute 'Bot'

# %%
telegram.__version__
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 telegram.__version__
#
# NameError: name 'telegram' is not defined

# %%
# Specify the cores to use for XLA
import functools
import os
os.environ["XLA_FLAGS"] = '--xla_force_host_platform_device_count=10'
import jax
import jax.numpy as jnp
import jax.random as jr

#import gymnax
import brax
from brax import envs
import matplotlib.pyplot as plt

import wandb
import run
# Out:
# Gym has been unmaintained since 2022 and does not support NumPy 2.0 amongst other critical functionality.
# Please upgrade to Gymnasium, the maintained drop-in replacement of Gym, or contact the authors of your software and request that they upgrade.
# Users of this version of Gym should be able to simply replace 'import gym' with 'import gymnasium as gym' in the vast majority of cases.
# See the migration guide at https://gymnasium.farama.org/introduction/migration_guide/ for additional information.
# WARNING:absl:No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 15
#      12 import matplotlib.pyplot as plt
#      14 import wandb
# ---> 15 import run
#
# File ~/cgpax/run.py:17
#      13 from functools import partial
#      15 from cgpax.individual import generate_population
# ---> 17 from cgpax.run_utils import update_config_with_env_data, compile_parents_selection, compile_mutation, \
#      18     init_environment_from_config, compute_parallel_runs_indexes, init_environments, compute_masks, \
#      19     compile_genome_evaluation, init_tracking, update_tracking, compute_genome_transformation_function, \
#      20     compile_survival_selection, compute_novelty_scores, normalize_array, compile_crossover, \
#      21     config_to_run_name, compute_weights_mutation_function, notify_update, process_dictionary
#      24 def run(config: Dict, wandb_run: Run) -> None:
#      25     rnd_key = random.PRNGKey(config["seed"])
#
# File ~/cgpax/cgpax/run_utils.py:317
#     312     return run_name, env_name, solver, ea, fitness, seed
#     315 # methods for update notifications
# --> 317 async def send_telegram_text(bot: telegram.Bot, chat: str, text: str):
#     318     await bot.send_message(chat, text=text)
#     321 def notify_update(text: str, bot: telegram.Bot = None, chat: str = None):
#
# AttributeError: module 'telegram' has no attribute 'Bot'

# %%
run.main()
