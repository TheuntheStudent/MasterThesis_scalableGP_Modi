# %%
from genetic_programming import GeneticProgramming
from fitness_functions.Gymnax_fitness_function import GymFitnessFunction

import jax
import jax.numpy as jnp
import jax.random as jr

import brax
from brax import envs
import matplotlib.pyplot as plt

class BraxGymnaxWrapper:
    def __init__(self, env_name, backend):
        self.env = envs.get_environment(env_name=env_name, backend=backend)
        self.observation_space = self.env.observation_size
        self.action_space = self.env.action_size

    # state, env_state = self.env.reset(subkey, self.env_params)

    def reset(self, key, params=None):
        #state consists of pipeline_state, obs, reward, done, metrics, info
        state = self.env.reset(key)
        return state.obs, state

     # next_state, next_env_state, reward, done, _ = self.env.step(
     #            subkey, env_state, action, self.env_params
     #        )

    def step(self, key, state, action, params=None):

      action = action.reshape(self.action_space)
      next_state = self.env.step(state, action)
      done = next_state.done

      # Freeze state after done
      obs = jnp.where(done, state.obs, next_state.obs)
      new_state = jax.tree.map(
          lambda new, old: jnp.where(done, old, new),
          next_state,
          state
      )

      reward = jnp.where(done, 0.0, next_state.reward)

      return obs, new_state, reward, done, {}
# Out:
# These device(s) are detected: [CudaDevice(id=0)]
# Failed to import warp: No module named 'warp'
# Failed to import mujoco_warp: No module named 'warp'

# %%
brax_env = BraxGymnaxWrapper('inverted_pendulum', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=1, max_nodes=31)
# Out:
# /home/theun/yes/envs/modi_kozax/lib/python3.12/site-packages/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated) 0.5 high
# Compiling code for evaluation and evolution...
# Finished compilation in 133.08 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: -7.25, equation: [-0.0638]
# Complexity: 2, fitness: -93.875, equation: [sin(y3)]
# Complexity: 4, fitness: -233.375, equation: [y1 + sin(y1)]
# Complexity: 5, fitness: -252.8125, equation: [3.42*y1]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2**2]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# Final pareto front:
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]

# %%
brax_env = BraxGymnaxWrapper('inverted_double_pendulum', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=1, max_nodes=31)
# Out:
# /home/theun/yes/envs/modi_kozax/lib/python3.12/site-packages/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated) 0.5 high
# Compiling code for evaluation and evolution...
# Finished compilation in 156.43 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: -184.10488891601562, equation: [-0.0638]
# Complexity: 2, fitness: -440.75897216796875, equation: [sin(y1)]
# Complexity: 3, fitness: -775.4652709960938, equation: [y2 - y7]
# Complexity: 7, fitness: -1006.9361572265625, equation: [0.486*y7*(y7 - 1.94)]
# Complexity: 9, fitness: -1246.233154296875, equation: [(y1 - 0.743)*(y2 + y4*y7)]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -424.4704895019531, equation: [y6]
# Complexity: 2, fitness: -440.75897216796875, equation: [sin(y1)]
# Complexity: 3, fitness: -815.1287231445312, equation: [y1 - y7]
# Complexity: 7, fitness: -1006.9361572265625, equation: [0.486*y7*(y7 - 1.94)]
# Complexity: 9, fitness: -1246.233154296875, equation: [(y1 - 0.743)*(y2 + y4*y7)]
# Complexity: 15, fitness: -2016.470703125, equation: [(y0**2 + y2)*(y3*y6 + 2*y5 - 1.76)]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -908.64208984375, equation: [y5 - y7]
# Complexity: 7, fitness: -1006.9361572265625, equation: [0.486*y7*(y7 - 1.94)]
# Complexity: 9, fitness: -1246.233154296875, equation: [(y1 - 0.743)*(y2 + y4*y7)]
# Complexity: 12, fitness: -6038.86962890625, equation: [-y2*(y3 + 1.25) + sin(y2*y7)]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -908.64208984375, equation: [y5 - y7]
# Complexity: 4, fitness: -908.6424560546875, equation: [sin(y5 - y7)]
# Complexity: 7, fitness: -1080.20654296875, equation: [y5*y7**2 - y7]
# Complexity: 9, fitness: -1246.233154296875, equation: [(y1 - 0.743)*(y2 + y4*y7)]
# Complexity: 11, fitness: -3549.811279296875, equation: [y2*(y3*y6 + 2*y5 - 1.76)]
# Complexity: 12, fitness: -6038.86962890625, equation: [-y2*(y3 + 1.25) + sin(y2*y7)]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -908.64208984375, equation: [y5 - y7]
# Complexity: 4, fitness: -908.6424560546875, equation: [sin(y5 - y7)]
# Complexity: 5, fitness: -1047.342041015625, equation: [y7*(y1 - 0.743)]
# Complexity: 7, fitness: -4066.92822265625, equation: [y2*(y1 + y5 - 1.76)]
# Complexity: 11, fitness: -6638.6884765625, equation: [y2*(y3*y6 + y5 + y6 - 1.76)]
# Complexity: 15, fitness: -7006.37109375, equation: [(y2*y5 + y2)*(y3*y6 + 2*y5 - 1.76)]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 14, fitness: -9210.853515625, equation: [-y2*(y4 + 1.25) + sin(y6*y7**2)]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 14, fitness: -9210.853515625, equation: [-y2*(y4 + 1.25) + sin(y6*y7**2)]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 14, fitness: -9210.853515625, equation: [-y2*(y4 + 1.25) + sin(y6*y7**2)]
# Complexity: 15, fitness: -9210.8603515625, equation: [-y2*(y4 + 1.25) + sin(y6*y7*sin(y7))]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 14, fitness: -9317.79296875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 18, fitness: -9318.369140625, equation: [-y2*(y4 + 1.44) + sin(y7*(y1*y2 + y6*y7))]
# Complexity: 22, fitness: -9355.9814453125, equation: [-y2*(y0*y7 + y3 + 1.01) + sin(y1*y2**2*y7**2)]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -8875.0625, equation: [y2*(y2*y6 - 1.76)]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 18, fitness: -9318.369140625, equation: [-y2*(y4 + 1.44) + sin(y7*(y1*y2 + y6*y7))]
# Complexity: 22, fitness: -9355.9814453125, equation: [-y2*(y0*y7 + y3 + 1.01) + sin(y1*y2**2*y7**2)]
# Complexity: 24, fitness: -9356.76171875, equation: [-y2*(y0*y7 + y3 + 0.897) + sin(y1*y2**2*y4*y5*y7)]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -8875.0625, equation: [y2*(y2*y6 - 1.76)]
# Complexity: 12, fitness: -8892.578125, equation: [y2*(y1*y6*(y5 - cos(y4)) - 1.76)]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 18, fitness: -9357.0048828125, equation: [-y2*(y0*y7 + 1.91) - sin(0.0741*y2**2*y7)]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -8875.0625, equation: [y2*(y2*y6 - 1.76)]
# Complexity: 12, fitness: -8892.578125, equation: [y2*(y1*y6*(y5 - cos(y4)) - 1.76)]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 18, fitness: -9357.0048828125, equation: [-y2*(y0*y7 + 1.91) - sin(0.0741*y2**2*y7)]
# Complexity: 26, fitness: -9357.2578125, equation: [-y2*(y0*y7 + y1**2*y4 + y3 + 0.85) + sin(y1**2*y2**2*y7)]
# Complexity: 28, fitness: -9357.517578125, equation: [-y2*y3*(y4 + 1.24)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y5 + y7))]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 26, fitness: -9357.2578125, equation: [-y2*(y0*y7 + y1**2*y4 + y3 + 0.85) + sin(y1**2*y2**2*y7)]
# Complexity: 28, fitness: -9357.517578125, equation: [-y2*y3*(y4 + 1.24)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y5 + y7))]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 24, fitness: -9357.6669921875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*(-0.0741*y2*y3 - 0.968*y2))]
# Complexity: 26, fitness: -9358.19140625, equation: [-y2*y3*(y3 + 0.388)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y5 + y7))]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 20, fitness: -9357.4775390625, equation: [-y2*(y0*y7 + y3 + 0.897) + sin(y2*y5*(y2 - y7))]
# Complexity: 24, fitness: -9357.849609375, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*(-0.0741*y2*y3 - 0.968*y7))]
# Complexity: 26, fitness: -9358.19140625, equation: [-y2*y3*(y3 + 0.388)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y5 + y7))]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9110.923828125, equation: [y2*(y1*(y2*y5 + y7) - 1.76)]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 21, fitness: -9358.0224609375, equation: [-y2*(y0*y7 + sin(y3) + 0.897) + sin(y2*y5*(y2 - y7))]
# Complexity: 26, fitness: -9358.19140625, equation: [-y2*y3*(y3 + 0.388)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y5 + y7))]
# Complexity: 28, fitness: -9358.7802734375, equation: [-y2*y3*(y4 + 1.24)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y6 + y7))]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9110.923828125, equation: [y2*(y1*(y2*y5 + y7) - 1.76)]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 21, fitness: -9358.0224609375, equation: [-y2*(y0*y7 + sin(y3) + 0.897) + sin(y2*y5*(y2 - y7))]
# Complexity: 26, fitness: -9358.208984375, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*(-0.0741*y0*y3 - 0.968*y0 - 0.968*y7))]
# Complexity: 28, fitness: -9358.7802734375, equation: [-y2*y3*(y4 + 1.24)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y6 + y7))]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9110.923828125, equation: [y2*(y1*(y2*y5 + y7) - 1.76)]
# Complexity: 13, fitness: -9156.6298828125, equation: [y2*((y2 + y6)*(y2*y5 + y7) - 1.76)]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 21, fitness: -9358.0224609375, equation: [-y2*(y0*y7 + sin(y3) + 0.897) + sin(y2*y5*(y2 - y7))]
# Complexity: 26, fitness: -9358.208984375, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*(-0.0741*y0*y3 - 0.968*y0 - 0.968*y7))]
# Complexity: 28, fitness: -9359.22265625, equation: [-y2*y3*(y3 + 0.85)*(y4 + 1.24)*(y0*y7 + 0.797) + sin(y6*y7*(y6 + y7))]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9110.923828125, equation: [y2*(y1*(y2*y5 + y7) - 1.76)]
# Complexity: 13, fitness: -9156.6298828125, equation: [y2*((y2 + y6)*(y2*y5 + y7) - 1.76)]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 21, fitness: -9358.0224609375, equation: [-y2*(y0*y7 + sin(y3) + 0.897) + sin(y2*y5*(y2 - y7))]
# Complexity: 26, fitness: -9359.123046875, equation: [-y2*y3*(y4 + 0.388)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y6 + y7))]
# Complexity: 28, fitness: -9359.22265625, equation: [-y2*y3*(y3 + 0.85)*(y4 + 1.24)*(y0*y7 + 0.797) + sin(y6*y7*(y6 + y7))]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9110.923828125, equation: [y2*(y1*(y2*y5 + y7) - 1.76)]
# Complexity: 13, fitness: -9156.6298828125, equation: [y2*((y2 + y6)*(y2*y5 + y7) - 1.76)]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 21, fitness: -9358.0224609375, equation: [-y2*(y0*y7 + sin(y3) + 0.897) + sin(y2*y5*(y2 - y7))]
# Complexity: 25, fitness: -9358.0830078125, equation: [-y2*y3*(y3 + 0.388)*(y3 + sin(y3**2) + 0.85) + sin(y6*y7*(y5 + y7))]
# Complexity: 26, fitness: -9359.123046875, equation: [-y2*y3*(y4 + 0.388)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y6 + y7))]
# Complexity: 28, fitness: -9359.22265625, equation: [-y2*y3*(y3 + 0.85)*(y4 + 1.24)*(y0*y7 + 0.797) + sin(y6*y7*(y6 + y7))]
# Complexity: 30, fitness: -9359.2421875, equation: [-y2*y3*(y3 + 1.18)*(2*y0*y7 + 1.65) + sin(y6*y7*(y6 + y7))]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9110.923828125, equation: [y2*(y1*(y2*y5 + y7) - 1.76)]
# Complexity: 13, fitness: -9156.6298828125, equation: [y2*((y2 + y6)*(y2*y5 + y7) - 1.76)]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 21, fitness: -9358.0224609375, equation: [-y2*(y0*y7 + sin(y3) + 0.897) + sin(y2*y5*(y2 - y7))]
# Complexity: 24, fitness: -9358.9375, equation: [-1.98*y2*y3*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y6 + y7))]
# Complexity: 26, fitness: -9359.123046875, equation: [-y2*y3*(y4 + 0.388)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y6 + y7))]
# Complexity: 28, fitness: -9359.22265625, equation: [-y2*y3*(y3 + 0.85)*(y4 + 1.24)*(y0*y7 + 0.797) + sin(y6*y7*(y6 + y7))]
# Complexity: 30, fitness: -9359.25390625, equation: [-y2*y3*(y3 + 1.18)*(y0*y7 + y7**2 + 1.65) + sin(y6*y7*(y6 + y7))]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9110.923828125, equation: [y2*(y1*(y2*y5 + y7) - 1.76)]
# Complexity: 13, fitness: -9156.6298828125, equation: [y2*((y2 + y6)*(y2*y5 + y7) - 1.76)]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 21, fitness: -9358.0224609375, equation: [-y2*(y0*y7 + sin(y3) + 0.897) + sin(y2*y5*(y2 - y7))]
# Complexity: 24, fitness: -9358.9375, equation: [-1.98*y2*y3*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y6 + y7))]
# Complexity: 26, fitness: -9359.123046875, equation: [-y2*y3*(y4 + 0.388)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y6 + y7))]
# Complexity: 28, fitness: -9359.22265625, equation: [-y2*y3*(y3 + 0.85)*(y4 + 1.24)*(y0*y7 + 0.797) + sin(y6*y7*(y6 + y7))]
# Complexity: 30, fitness: -9359.25390625, equation: [-y2*y3*(y3 + 1.18)*(y0*y7 + y7**2 + 1.65) + sin(y6*y7*(y6 + y7))]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9110.923828125, equation: [y2*(y1*(y2*y5 + y7) - 1.76)]
# Complexity: 13, fitness: -9156.6298828125, equation: [y2*((y2 + y6)*(y2*y5 + y7) - 1.76)]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 21, fitness: -9358.0224609375, equation: [-y2*(y0*y7 + sin(y3) + 0.897) + sin(y2*y5*(y2 - y7))]
# Complexity: 24, fitness: -9358.9375, equation: [-1.98*y2*y3*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y6 + y7))]
# Complexity: 26, fitness: -9359.123046875, equation: [-y2*y3*(y4 + 0.388)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y6 + y7))]
# Complexity: 28, fitness: -9359.22265625, equation: [-y2*y3*(y3 + 0.85)*(y4 + 1.24)*(y0*y7 + 0.797) + sin(y6*y7*(y6 + y7))]
# Complexity: 30, fitness: -9359.25390625, equation: [-y2*y3*(y3 + 1.18)*(y0*y7 + y7**2 + 1.65) + sin(y6*y7*(y6 + y7))]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9110.923828125, equation: [y2*(y1*(y2*y5 + y7) - 1.76)]
# Complexity: 13, fitness: -9156.6298828125, equation: [y2*((y2 + y6)*(y2*y5 + y7) - 1.76)]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 21, fitness: -9358.0224609375, equation: [-y2*(y0*y7 + sin(y3) + 0.897) + sin(y2*y5*(y2 - y7))]
# Complexity: 24, fitness: -9359.166015625, equation: [-2.09*y2*y3*(y3 + 0.85)*(y0*y7 + 0.797) + sin(y6*y7*(y6 + y7))]
# Complexity: 26, fitness: -9359.2548828125, equation: [-2.03*y2*y3*(y0*y7 + y7**2 + 1.65) + sin(y6*y7*(y6 + y7))]
# Final pareto front:
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9110.923828125, equation: [y2*(y1*(y2*y5 + y7) - 1.76)]
# Complexity: 13, fitness: -9156.6298828125, equation: [y2*((y2 + y6)*(y2*y5 + y7) - 1.76)]
# Complexity: 14, fitness: -9317.794921875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 21, fitness: -9358.0224609375, equation: [-y2*(y0*y7 + sin(y3) + 0.897) + sin(y2*y5*(y2 - y7))]
# Complexity: 24, fitness: -9359.166015625, equation: [-2.09*y2*y3*(y3 + 0.85)*(y0*y7 + 0.797) + sin(y6*y7*(y6 + y7))]
# Complexity: 26, fitness: -9359.2548828125, equation: [-2.03*y2*y3*(y0*y7 + y7**2 + 1.65) + sin(y6*y7*(y6 + y7))]

# %%
brax_env = BraxGymnaxWrapper('reacher', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=2, max_nodes=31)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated) 0.5 high
# Compiling code for evaluation and evolution...
# Finished compilation in 125.26 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: 637.1117553710938, equation: [0.639, 0]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 4, fitness: 112.74169921875, equation: [0, -sin(y6 - y8)]
# Complexity: 5, fitness: 111.38760375976562, equation: [0, 2*y1*y5 + y4]
# Complexity: 7, fitness: 110.91987609863281, equation: [0, y8*(y1*y10 + 0.599)]
# Complexity: 9, fitness: 107.21183013916016, equation: [0, y5*(y0*y8 - y6 + y7)]
# Complexity: 11, fitness: 106.92889404296875, equation: [y3*y5*(y0 + y3)*(y10 + y8), (y0 + y3)*(y10 + y8)]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 14, fitness: 79.46275329589844, equation: [y3*y5**2*y8*(y10 + y8), y5*y8*(y10 + y8) + y5*y8 + sin(y3*y5**2*y8*(y10 + y8) - y6)]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 11, fitness: 77.9782943725586, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y6)]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 80.12791442871094, equation: [0, y2*y5*y8 + y5*y8]
# Complexity: 7, fitness: 79.60067749023438, equation: [0, y5*y8**2*y9 + y5*y8**2 + y5*y8]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, y10 + 2*y5*y8]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 16, fitness: 68.294189453125, equation: [y5*y8*(y5 - y9)*(y8 + y9 + 0.599), y5*y8*(y8 + y9 + 0.599) + y5*y8 + sin(y5*y8*(y5 - y9)*(y8 + y9 + 0.599) - y6)]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 16, fitness: 68.294189453125, equation: [y5*y8*(y5 - y9)*(y8 + y9 + 0.599), y5*y8*(y8 + y9 + 0.599) + y5*y8 + sin(y5*y8*(y5 - y9)*(y8 + y9 + 0.599) - y6)]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 16, fitness: 68.294189453125, equation: [y5*y8*(y5 - y9)*(y8 + y9 + 0.599), y5*y8*(y8 + y9 + 0.599) + y5*y8 + sin(y5*y8*(y5 - y9)*(y8 + y9 + 0.599) - y6)]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 16, fitness: 68.294189453125, equation: [y5*y8*(y5 - y9)*(y8 + y9 + 0.599), y5*y8*(y8 + y9 + 0.599) + y5*y8 + sin(y5*y8*(y5 - y9)*(y8 + y9 + 0.599) - y6)]
# Complexity: 26, fitness: 67.22303771972656, equation: [y5*y8*(y5 - y9)*(0.546*y5**2*y8**2 + y8 + 0.599), 0.546*y5**2*y8**2 + y5*y8*(0.546*y5**2*y8**2 + y8 + 0.599) + 2.55*y5*y8 + sin(y5*y8*(y5 - y9)*(0.546*y5**2*y8**2 + y8 + 0.599) - 2*y6)]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 16, fitness: 68.294189453125, equation: [y5*y8*(y5 - y9)*(y8 + y9 + 0.599), y5*y8*(y8 + y9 + 0.599) + y5*y8 + sin(y5*y8*(y5 - y9)*(y8 + y9 + 0.599) - y6)]
# Complexity: 18, fitness: 65.7887191772461, equation: [y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39), y5*y8*(y5*y8 + y8 + 1.39) + 2*y5*y8 + sin(y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39) - y6)]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 16, fitness: 68.03741455078125, equation: [y5*y8*(y5 - y9)*(2*y8 + 0.599), y5*y8*(2*y8 + 0.599) + y5*y8 + sin(y5*y8*(y5 - y9)*(2*y8 + 0.599) - y6)]
# Complexity: 18, fitness: 65.7887191772461, equation: [y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39), y5*y8*(y5*y8 + y8 + 1.39) + 2*y5*y8 + sin(y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39) - y6)]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 14, fitness: 73.1689453125, equation: [y5*y8*(y5 - y9)*(y9 + 1.39), y5*y8*(y9 + 1.39) + y5*y8 + sin(y5*y8*(y5 - y9)*(y9 + 1.39) - y6)]
# Complexity: 16, fitness: 68.03741455078125, equation: [y5*y8*(y5 - y9)*(2*y8 + 0.599), y5*y8*(2*y8 + 0.599) + y5*y8 + sin(y5*y8*(y5 - y9)*(2*y8 + 0.599) - y6)]
# Complexity: 18, fitness: 65.7887191772461, equation: [y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39), y5*y8*(y5*y8 + y8 + 1.39) + 2*y5*y8 + sin(y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39) - y6)]
# Complexity: 30, fitness: 60.01545715332031, equation: [y5*y8*(2*y2 + y5**2*y8*(y10 + y8) + 0.599)*(-y5*y8 + y5 - y8), y5*y8*(y10 + y8) + y5*y8*(2*y2 + y5**2*y8*(y10 + y8) + 0.599) + 3*y5*y8 + sin(y5*y8*(2*y2 + y5**2*y8*(y10 + y8) + 0.599)*(-y5*y8 + y5 - y8) - y6)]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 14, fitness: 73.1689453125, equation: [y5*y8*(y5 - y9)*(y9 + 1.39), y5*y8*(y9 + 1.39) + y5*y8 + sin(y5*y8*(y5 - y9)*(y9 + 1.39) - y6)]
# Complexity: 16, fitness: 68.03741455078125, equation: [y5*y8*(y5 - y9)*(2*y8 + 0.599), y5*y8*(2*y8 + 0.599) + y5*y8 + sin(y5*y8*(y5 - y9)*(2*y8 + 0.599) - y6)]
# Complexity: 18, fitness: 65.7887191772461, equation: [y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39), y5*y8*(y5*y8 + y8 + 1.39) + 2*y5*y8 + sin(y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39) - y6)]
# Complexity: 26, fitness: 64.92778778076172, equation: [y3*y8*(y0 + y5*y8)*(y1*y5 - y5**2*y8*(y10 + y8)), y1*y5 + y3*y8*(y1*y5 - y5**2*y8*(y10 + y8)) + y3*y8 + y5*y8*(y10 + y8) + 2*y5*y8 + sin(y3*y8*(y0 + y5*y8)*(y1*y5 - y5**2*y8*(y10 + y8)) - y6)]
# Complexity: 28, fitness: 64.0428466796875, equation: [y5*y8*(2*y2 + y5**2*y8*(y10 + y8) + 0.599)*(y5 - y6 - y8), y5*y8*(y10 + y8) + y5*y8*(2*y2 + y5**2*y8*(y10 + y8) + 0.599) + 2*y5*y8 + sin(y5*y8*(2*y2 + y5**2*y8*(y10 + y8) + 0.599)*(y5 - y6 - y8) - y6)]
# Complexity: 29, fitness: 61.48265075683594, equation: [y5*y8*(2*y2 + y5**2*y8*(y10 + y8) + 0.599)*(-y5*y8 + y5 - y8), y5*y8*(y10 + y8) + y5*y8*(2*y2 + y5**2*y8*(y10 + y8) + 0.599)*(-y5*y8 + y5 - y8) + y5*y8*(2*y2 + y5**2*y8*(y10 + y8) + 0.599) + 3*y5*y8 - y6]
# Complexity: 30, fitness: 60.01545715332031, equation: [y5*y8*(2*y2 + y5**2*y8*(y10 + y8) + 0.599)*(-y5*y8 + y5 - y8), y5*y8*(y10 + y8) + y5*y8*(2*y2 + y5**2*y8*(y10 + y8) + 0.599) + 3*y5*y8 + sin(y5*y8*(2*y2 + y5**2*y8*(y10 + y8) + 0.599)*(-y5*y8 + y5 - y8) - y6)]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 14, fitness: 73.1689453125, equation: [y5*y8*(y5 - y9)*(y9 + 1.39), y5*y8*(y9 + 1.39) + y5*y8 + sin(y5*y8*(y5 - y9)*(y9 + 1.39) - y6)]
# Complexity: 15, fitness: 68.79729461669922, equation: [y5*y8*(y5 - y9)*(y5 + cos(y9)), y5*y8*(y5 + cos(y9)) + y5*y8 + sin(y5*y8*(y5 - y9)*(y5 + cos(y9)) - y6)]
# Complexity: 16, fitness: 68.03741455078125, equation: [y5*y8*(y5 - y9)*(2*y8 + 0.599), y5*y8*(2*y8 + 0.599) + y5*y8 + sin(y5*y8*(y5 - y9)*(2*y8 + 0.599) - y6)]
# Complexity: 18, fitness: 65.7887191772461, equation: [y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39), y5*y8*(y5*y8 + y8 + 1.39) + 2*y5*y8 + sin(y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39) - y6)]
# Complexity: 19, fitness: 62.547645568847656, equation: [y5*y8*(y5 - y9 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y5 - y9 + 1.39)*(-y5*y8 + y5 - y8) + y5*y8*(y5 - y9 + 1.39) + 2*y5*y8 - y6]
# Complexity: 27, fitness: 59.231201171875, equation: [y5*y8*(2*y2 + y5**2*(y10 + y8) + 0.599)*(-y5*y8 + y5 - y8), y5*y8*(2*y2 + y5**2*(y10 + y8) + 0.599)*(-y5*y8 + y5 - y8) + y5*y8*(2*y2 + y5**2*(y10 + y8) + 0.599) + 2*y5*y8 + y5*(y10 + y8) - y6]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 14, fitness: 67.24742126464844, equation: [y5*y8*(-y5*y8 + y5 - y8), 2*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 18, fitness: 65.7887191772461, equation: [y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39), y5*y8*(y5*y8 + y8 + 1.39) + 2*y5*y8 + sin(y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39) - y6)]
# Complexity: 19, fitness: 60.61381530761719, equation: [y5*y8*(y5 + y9 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y5 + y9 + 1.39)*(-y5*y8 + y5 - y8) + y5*y8*(y5 + y9 + 1.39) + 2*y5*y8 - y6]
# Complexity: 27, fitness: 59.231201171875, equation: [y5*y8*(2*y2 + y5**2*(y10 + y8) + 0.599)*(-y5*y8 + y5 - y8), y5*y8*(2*y2 + y5**2*(y10 + y8) + 0.599)*(-y5*y8 + y5 - y8) + y5*y8*(2*y2 + y5**2*(y10 + y8) + 0.599) + 2*y5*y8 + y5*(y10 + y8) - y6]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 14, fitness: 67.24742126464844, equation: [y5*y8*(-y5*y8 + y5 - y8), 2*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 18, fitness: 65.7887191772461, equation: [y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39), y5*y8*(y5*y8 + y8 + 1.39) + 2*y5*y8 + sin(y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39) - y6)]
# Complexity: 19, fitness: 60.61381530761719, equation: [y5*y8*(y5 + y9 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y5 + y9 + 1.39)*(-y5*y8 + y5 - y8) + y5*y8*(y5 + y9 + 1.39) + 2*y5*y8 - y6]
# Complexity: 22, fitness: 58.91992950439453, equation: [y5*y8*(-y5*y8 + y5 - y8)*(y5*y8 - y9 + 1.39), y5*y8*(y5*y8 - y9 + 1.39) + 3*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - y8)*(y5*y8 - y9 + 1.39) - y6)]
# Complexity: 25, fitness: 54.84864807128906, equation: [y5*y8*(-y5*y8 + y5 - sin(y8))*(y1 + 2*y2 + y5 + 0.599), y5*y8*(y1 + 2*y2 + y5 + 0.599) + 2*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - sin(y8))*(y1 + 2*y2 + y5 + 0.599) - y6)]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 14, fitness: 67.24742126464844, equation: [y5*y8*(-y5*y8 + y5 - y8), 2*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 18, fitness: 65.7887191772461, equation: [y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39), y5*y8*(y5*y8 + y8 + 1.39) + 2*y5*y8 + sin(y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39) - y6)]
# Complexity: 19, fitness: 60.61381530761719, equation: [y5*y8*(y5 + y9 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y5 + y9 + 1.39)*(-y5*y8 + y5 - y8) + y5*y8*(y5 + y9 + 1.39) + 2*y5*y8 - y6]
# Complexity: 22, fitness: 54.95915222167969, equation: [y5*y8*(-y5*y8 + y5 - y8)*(y5*y8 + y8 + 1.39), y5*y8*(y5*y8 + y8 + 1.39) + 3*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - y8)*(y5*y8 + y8 + 1.39) - y6)]
# Complexity: 25, fitness: 54.84864807128906, equation: [y5*y8*(-y5*y8 + y5 - sin(y8))*(y1 + 2*y2 + y5 + 0.599), y5*y8*(y1 + 2*y2 + y5 + 0.599) + 2*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - sin(y8))*(y1 + 2*y2 + y5 + 0.599) - y6)]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 14, fitness: 67.24742126464844, equation: [y5*y8*(-y5*y8 + y5 - y8), 2*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 18, fitness: 65.7887191772461, equation: [y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39), y5*y8*(y5*y8 + y8 + 1.39) + 2*y5*y8 + sin(y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39) - y6)]
# Complexity: 19, fitness: 60.61381530761719, equation: [y5*y8*(y5 + y9 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y5 + y9 + 1.39)*(-y5*y8 + y5 - y8) + y5*y8*(y5 + y9 + 1.39) + 2*y5*y8 - y6]
# Complexity: 22, fitness: 54.95915222167969, equation: [y5*y8*(-y5*y8 + y5 - y8)*(y5*y8 + y8 + 1.39), y5*y8*(y5*y8 + y8 + 1.39) + 3*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - y8)*(y5*y8 + y8 + 1.39) - y6)]
# Complexity: 25, fitness: 54.84864807128906, equation: [y5*y8*(-y5*y8 + y5 - sin(y8))*(y1 + 2*y2 + y5 + 0.599), y5*y8*(y1 + 2*y2 + y5 + 0.599) + 2*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - sin(y8))*(y1 + 2*y2 + y5 + 0.599) - y6)]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 14, fitness: 67.24742126464844, equation: [y5*y8*(-y5*y8 + y5 - y8), 2*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 18, fitness: 65.7887191772461, equation: [y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39), y5*y8*(y5*y8 + y8 + 1.39) + 2*y5*y8 + sin(y5*y8*(y5 - y9)*(y5*y8 + y8 + 1.39) - y6)]
# Complexity: 19, fitness: 60.61381530761719, equation: [y5*y8*(y5 + y9 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y5 + y9 + 1.39)*(-y5*y8 + y5 - y8) + y5*y8*(y5 + y9 + 1.39) + 2*y5*y8 - y6]
# Complexity: 20, fitness: 59.301212310791016, equation: [y5*y8*y9*(y10 + 1.39)*(-y5*y8 + y5 - y8) + y5*y8*(y10 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y10 + 1.39) + 2*y5*y8 + sin(y5*y8*y9*(y10 + 1.39)*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 21, fitness: 53.948631286621094, equation: [y5*y8*(-y5*y8 + y5 - y8)*(y0 + y2 + y5 + 0.599), y5*y8*(-y5*y8 + y5 - y8)*(y0 + y2 + y5 + 0.599) + y5*y8*(y0 + y2 + y5 + 0.599) + 2*y5*y8 - y6]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 14, fitness: 67.24742126464844, equation: [y5*y8*(-y5*y8 + y5 - y8), 2*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 18, fitness: 60.10296630859375, equation: [y5*y8*(y8 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y8 + 1.39) + 2*y5*y8 + sin(y5*y8*(y8 + 1.39)*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 20, fitness: 59.301212310791016, equation: [y5*y8*y9*(y10 + 1.39)*(-y5*y8 + y5 - y8) + y5*y8*(y10 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y10 + 1.39) + 2*y5*y8 + sin(y5*y8*y9*(y10 + 1.39)*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 21, fitness: 53.948631286621094, equation: [y5*y8*(-y5*y8 + y5 - y8)*(y0 + y2 + y5 + 0.599), y5*y8*(-y5*y8 + y5 - y8)*(y0 + y2 + y5 + 0.599) + y5*y8*(y0 + y2 + y5 + 0.599) + 2*y5*y8 - y6]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 14, fitness: 67.24742126464844, equation: [y5*y8*(-y5*y8 + y5 - y8), 2*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 18, fitness: 60.10296630859375, equation: [y5*y8*(y8 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y8 + 1.39) + 2*y5*y8 + sin(y5*y8*(y8 + 1.39)*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 20, fitness: 55.25229263305664, equation: [y5*y8*(y5*y8 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y5*y8 + 1.39) + 3*y5*y8 + sin(y5*y8*(y5*y8 + 1.39)*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 21, fitness: 53.948631286621094, equation: [y5*y8*(-y5*y8 + y5 - y8)*(y0 + y2 + y5 + 0.599), y5*y8*(-y5*y8 + y5 - y8)*(y0 + y2 + y5 + 0.599) + y5*y8*(y0 + y2 + y5 + 0.599) + 2*y5*y8 - y6]
# Complexity: 24, fitness: 53.865386962890625, equation: [y5*y8*(0.824*y0 + y5*y8 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(0.824*y0 + y5*y8 + 1.39) + 3*y5*y8 + sin(y5*y8*(0.824*y0 + y5*y8 + 1.39)*(-y5*y8 + y5 - y8) - y6)]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 14, fitness: 67.24742126464844, equation: [y5*y8*(-y5*y8 + y5 - y8), 2*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 18, fitness: 60.10296630859375, equation: [y5*y8*(y8 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y8 + 1.39) + 2*y5*y8 + sin(y5*y8*(y8 + 1.39)*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 20, fitness: 55.25229263305664, equation: [y5*y8*(y5*y8 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y5*y8 + 1.39) + 3*y5*y8 + sin(y5*y8*(y5*y8 + 1.39)*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 21, fitness: 53.47004699707031, equation: [y5*y8*(-y5*y8 + y5 - y8)*(y0 + y2 + y4 + 0.599), y5*y8*(-y5*y8 + y5 - y8)*(y0 + y2 + y4 + 0.599) + y5*y8*(y0 + y2 + y4 + 0.599) + 2*y5*y8 - y6]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 14, fitness: 67.24742126464844, equation: [y5*y8*(-y5*y8 + y5 - y8), 2*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 18, fitness: 60.10296630859375, equation: [y5*y8*(y8 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y8 + 1.39) + 2*y5*y8 + sin(y5*y8*(y8 + 1.39)*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 20, fitness: 55.25229263305664, equation: [y5*y8*(y5*y8 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y5*y8 + 1.39) + 3*y5*y8 + sin(y5*y8*(y5*y8 + 1.39)*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 21, fitness: 53.47004699707031, equation: [y5*y8*(-y5*y8 + y5 - y8)*(y0 + y2 + y4 + 0.599), y5*y8*(-y5*y8 + y5 - y8)*(y0 + y2 + y4 + 0.599) + y5*y8*(y0 + y2 + y4 + 0.599) + 2*y5*y8 - y6]
# Complexity: 28, fitness: 51.736080169677734, equation: [y5*y8*(0.824*y0 + y5*(y5*y8 + y8) + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(0.824*y0 + y5*(y5*y8 + y8) + 1.39) + 3*y5*y8 + y5*(y5*y8 + y8) + sin(y5*y8*(0.824*y0 + y5*(y5*y8 + y8) + 1.39)*(-y5*y8 + y5 - y8) - y6)]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 14, fitness: 67.24742126464844, equation: [y5*y8*(-y5*y8 + y5 - y8), 2*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 18, fitness: 55.675819396972656, equation: [y5*y8*(y1 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y1 + 1.39) + 2*y5*y8 + sin(y5*y8*(y1 + 1.39)*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 20, fitness: 55.25229263305664, equation: [y5*y8*(y5*y8 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y5*y8 + 1.39) + 3*y5*y8 + sin(y5*y8*(y5*y8 + 1.39)*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 21, fitness: 53.47004699707031, equation: [y5*y8*(-y5*y8 + y5 - y8)*(y0 + y2 + y4 + 0.599), y5*y8*(-y5*y8 + y5 - y8)*(y0 + y2 + y4 + 0.599) + y5*y8*(y0 + y2 + y4 + 0.599) + 2*y5*y8 - y6]
# Complexity: 28, fitness: 49.78461456298828, equation: [y5*y8*(0.824*y0 + y5*(y5*y8 + y8) + 1.39)*(-y5*y9 + y5 - y8), y5*y8*(0.824*y0 + y5*(y5*y8 + y8) + 1.39) + 2*y5*y8 + y5*y9 + y5*(y5*y8 + y8) + sin(y5*y8*(0.824*y0 + y5*(y5*y8 + y8) + 1.39)*(-y5*y9 + y5 - y8) - y6)]
# Final pareto front:
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.8353500366211, equation: [0, 2*y5*y8 + 2*sin(y6)]
# Complexity: 7, fitness: 76.90401458740234, equation: [0, y5*y8 + sin(y5*y8) - sin(y6 - sin(y5*y8))]
# Complexity: 8, fitness: 76.8395767211914, equation: [0, y5*y8*sin(y5*y8) + 2*y5*y8 + sin(y5*y8)]
# Complexity: 9, fitness: 76.3722915649414, equation: [0, 4*y5*y8 - y6]
# Complexity: 11, fitness: 76.11385345458984, equation: [0, 2*y5*y8 + y5*(2*y5*y8 - y9)]
# Complexity: 14, fitness: 67.24742126464844, equation: [y5*y8*(-y5*y8 + y5 - y8), 2*y5*y8 + sin(y5*y8*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 18, fitness: 55.675819396972656, equation: [y5*y8*(y1 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y1 + 1.39) + 2*y5*y8 + sin(y5*y8*(y1 + 1.39)*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 20, fitness: 55.25229263305664, equation: [y5*y8*(y5*y8 + 1.39)*(-y5*y8 + y5 - y8), y5*y8*(y5*y8 + 1.39) + 3*y5*y8 + sin(y5*y8*(y5*y8 + 1.39)*(-y5*y8 + y5 - y8) - y6)]
# Complexity: 21, fitness: 53.47004699707031, equation: [y5*y8*(-y5*y8 + y5 - y8)*(y0 + y2 + y4 + 0.599), y5*y8*(-y5*y8 + y5 - y8)*(y0 + y2 + y4 + 0.599) + y5*y8*(y0 + y2 + y4 + 0.599) + 2*y5*y8 - y6]
# Complexity: 28, fitness: 49.78461456298828, equation: [y5*y8*(0.824*y0 + y5*(y5*y8 + y8) + 1.39)*(-y5*y9 + y5 - y8), y5*y8*(0.824*y0 + y5*(y5*y8 + y8) + 1.39) + 2*y5*y8 + y5*y9 + y5*(y5*y8 + y8) + sin(y5*y8*(0.824*y0 + y5*(y5*y8 + y8) + 1.39)*(-y5*y9 + y5 - y8) - y6)]

# %%
brax_env = BraxGymnaxWrapper('swimmer', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=2, max_nodes=31)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated) 0.5 high
# Compiling code for evaluation and evolution...
# Finished compilation in 112.15 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: 7.4526896476745605, equation: [0.839, 0]
# Complexity: 2, fitness: -11.424619674682617, equation: [0, sin(y6)]
# Complexity: 3, fitness: -24.344547271728516, equation: [0, y6 + y7]
# Complexity: 5, fitness: -138.55441284179688, equation: [2.42*y6, 1.42*y6]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -12.504684448242188, equation: [y7, 0]
# Complexity: 3, fitness: -24.344547271728516, equation: [0, y6 + y7]
# Complexity: 5, fitness: -138.88497924804688, equation: [2.42*y6, 1.42*y6]
# Complexity: 7, fitness: -255.30979919433594, equation: [y0 + y1 + y6 - y7, y1 + y6]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -138.9135284423828, equation: [2.42*y6, 1.42*y6]
# Complexity: 6, fitness: -151.4186248779297, equation: [y0 + y6, (y0 + y6)*cos(y0)]
# Complexity: 7, fitness: -255.30979919433594, equation: [y0 + y1 + y6 - y7, y1 + y6]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -138.9317169189453, equation: [2.42*y6, 1.42*y6]
# Complexity: 6, fitness: -151.4186248779297, equation: [y0 + y6, (y0 + y6)*cos(y0)]
# Complexity: 7, fitness: -255.30979919433594, equation: [y0 + y1 + y6 - y7, y1 + y6]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -138.9317169189453, equation: [2.42*y6, 1.42*y6]
# Complexity: 6, fitness: -222.41934204101562, equation: [2*y6, 2*y6*cos(y0)]
# Complexity: 7, fitness: -255.30979919433594, equation: [y0 + y1 + y6 - y7, y1 + y6]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -166.72994995117188, equation: [y0 + y6 + y7, y6 + y7]
# Complexity: 6, fitness: -222.41934204101562, equation: [2*y6, 2*y6*cos(y0)]
# Complexity: 7, fitness: -255.30979919433594, equation: [y0 + y1 + y6 - y7, y1 + y6]
# Complexity: 13, fitness: -317.06646728515625, equation: [5*y0 + 4*y1 + 2*y6 - y7, 3*y1 + 2*y6]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -166.72994995117188, equation: [y0 + y6 + y7, y6 + y7]
# Complexity: 6, fitness: -222.41934204101562, equation: [2*y6, 2*y6*cos(y0)]
# Complexity: 7, fitness: -255.30979919433594, equation: [y0 + y1 + y6 - y7, y1 + y6]
# Complexity: 8, fitness: -327.9547119140625, equation: [0.242*y1 + y4 + sin(y0), 0.121*y1 + y4]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -167.3812255859375, equation: [y0 + y6 + y7, y6 + y7]
# Complexity: 6, fitness: -222.41934204101562, equation: [2*y6, 2*y6*cos(y0)]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -327.9547119140625, equation: [0.242*y1 + y4 + sin(y0), 0.121*y1 + y4]
# Complexity: 11, fitness: -331.48944091796875, equation: [5*y0 + 2*y1 + 2*y4 - y7, y1 + y4]
# Complexity: 13, fitness: -337.0541687011719, equation: [3*y0 + 2*y1 + 2*y6 - y7, 2*y1 + 2*y6 + y7]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -209.48016357421875, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -222.41934204101562, equation: [2*y6, 2*y6*cos(y0)]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -327.9547119140625, equation: [0.242*y1 + y4 + sin(y0), 0.121*y1 + y4]
# Complexity: 9, fitness: -328.9313659667969, equation: [0.242*y1 + sin(y0) + sin(y4), 0.121*y1 + sin(y4)]
# Complexity: 11, fitness: -331.48944091796875, equation: [5*y0 + 2*y1 + 2*y4 - y7, y1 + y4]
# Complexity: 13, fitness: -337.0541687011719, equation: [3*y0 + 2*y1 + 2*y6 - y7, 2*y1 + 2*y6 + y7]
# Complexity: 17, fitness: -337.3783874511719, equation: [5*y0 + 4.77*y1 + 2*y6 - y7, 3*y1 + 2*y6]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -209.48016357421875, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -222.41934204101562, equation: [2*y6, 2*y6*cos(y0)]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -327.9547119140625, equation: [0.242*y1 + y4 + sin(y0), 0.121*y1 + y4]
# Complexity: 9, fitness: -330.44671630859375, equation: [5*y0 + 2*y1 + 2*y4, y1 + y4]
# Complexity: 11, fitness: -331.48944091796875, equation: [5*y0 + 2*y1 + 2*y4 - y7, y1 + y4]
# Complexity: 13, fitness: -337.10321044921875, equation: [3*y0 + 2*y1 + 2*y6 - y7, 2*y1 + 2*y6 + y7]
# Complexity: 17, fitness: -337.8460693359375, equation: [5*y0 + 4.77*y1 + 2*y6 - y7, 3*y1 + 2*y6]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -209.48016357421875, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -222.41934204101562, equation: [2*y6, 2*y6*cos(y0)]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -327.9547119140625, equation: [0.242*y1 + y4 + sin(y0), 0.121*y1 + y4]
# Complexity: 9, fitness: -358.957763671875, equation: [4*y0 + 2*y1 + 2*y4 + y5, y1 + y4]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -209.48016357421875, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -222.41934204101562, equation: [2*y6, 2*y6*cos(y0)]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -327.9547119140625, equation: [0.242*y1 + y4 + sin(y0), 0.121*y1 + y4]
# Complexity: 9, fitness: -358.957763671875, equation: [4*y0 + 2*y1 + 2*y4 + y5, y1 + y4]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -12.504687309265137, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -209.48016357421875, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -222.41934204101562, equation: [2*y6, 2*y6*cos(y0)]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -329.50750732421875, equation: [y0 + 0.242*y1 + sin(y4), 0.121*y1 + sin(y4)]
# Complexity: 9, fitness: -358.957763671875, equation: [4*y0 + 2*y1 + 2*y4 + y5, y1 + y4]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -12.504687309265137, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -209.48016357421875, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -253.7861328125, equation: [y0 + y6 + cos(y0 + y6 + y7), y0 + y6 + y7]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -329.50750732421875, equation: [y0 + 0.242*y1 + sin(y4), 0.121*y1 + sin(y4)]
# Complexity: 9, fitness: -358.957763671875, equation: [4*y0 + 2*y1 + 2*y4 + y5, y1 + y4]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -12.504687309265137, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -209.48016357421875, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -253.7861328125, equation: [y0 + y6 + cos(y0 + y6 + y7), y0 + y6 + y7]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -329.50750732421875, equation: [y0 + 0.242*y1 + sin(y4), 0.121*y1 + sin(y4)]
# Complexity: 9, fitness: -358.957763671875, equation: [4*y0 + 2*y1 + 2*y4 + y5, y1 + y4]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -12.504687309265137, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -209.48016357421875, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -291.0406494140625, equation: [y0 + y6 + sin(y0 + y6 + y7), y0 + y6 + y7]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -329.50750732421875, equation: [y0 + 0.242*y1 + sin(y4), 0.121*y1 + sin(y4)]
# Complexity: 9, fitness: -358.957763671875, equation: [4*y0 + 2*y1 + 2*y4 + y5, y1 + y4]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -12.504687309265137, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -209.48016357421875, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -291.0406494140625, equation: [y0 + y6 + sin(y0 + y6 + y7), y0 + y6 + y7]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -329.50750732421875, equation: [y0 + 0.242*y1 + sin(y4), 0.121*y1 + sin(y4)]
# Complexity: 9, fitness: -358.957763671875, equation: [4*y0 + 2*y1 + 2*y4 + y5, y1 + y4]
# Complexity: 13, fitness: -359.5653381347656, equation: [4*y0 + 2*y1 + 2.47*y4 + y5, y1 + y4]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -12.504687309265137, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -217.96359252929688, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -291.0406494140625, equation: [y0 + y6 + sin(y0 + y6 + y7), y0 + y6 + y7]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -329.50750732421875, equation: [y0 + 0.242*y1 + sin(y4), 0.121*y1 + sin(y4)]
# Complexity: 9, fitness: -358.957763671875, equation: [4*y0 + 2*y1 + 2*y4 + y5, y1 + y4]
# Complexity: 13, fitness: -359.5653381347656, equation: [4*y0 + 2*y1 + 2.47*y4 + y5, y1 + y4]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -12.504687309265137, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -217.96359252929688, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -291.0406494140625, equation: [y0 + y6 + sin(y0 + y6 + y7), y0 + y6 + y7]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -329.50750732421875, equation: [y0 + 0.242*y1 + sin(y4), 0.121*y1 + sin(y4)]
# Complexity: 9, fitness: -358.957763671875, equation: [4*y0 + 2*y1 + 2*y4 + y5, y1 + y4]
# Complexity: 13, fitness: -359.5653381347656, equation: [4*y0 + 2*y1 + 2.47*y4 + y5, y1 + y4]
# Complexity: 21, fitness: -361.8668212890625, equation: [10*y0 + 6*y1 + y3*y4 + 6*y4 + 4*y5, 2*y1 + 2*y4]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -12.504687309265137, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -217.96359252929688, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -291.0406494140625, equation: [y0 + y6 + sin(y0 + y6 + y7), y0 + y6 + y7]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -329.50750732421875, equation: [y0 + 0.242*y1 + sin(y4), 0.121*y1 + sin(y4)]
# Complexity: 9, fitness: -358.957763671875, equation: [4*y0 + 2*y1 + 2*y4 + y5, y1 + y4]
# Complexity: 13, fitness: -359.9701232910156, equation: [6*y0 + 3*y1 + y3*y4 + 3*y4 + 2*y5, y1 + y4]
# Complexity: 21, fitness: -361.8668212890625, equation: [10*y0 + 6*y1 + y3*y4 + 6*y4 + 4*y5, 2*y1 + 2*y4]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -12.504687309265137, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -217.96359252929688, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -291.0406494140625, equation: [y0 + y6 + sin(y0 + y6 + y7), y0 + y6 + y7]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -329.50750732421875, equation: [y0 + 0.242*y1 + sin(y4), 0.121*y1 + sin(y4)]
# Complexity: 9, fitness: -358.957763671875, equation: [4*y0 + 2*y1 + 2*y4 + y5, y1 + y4]
# Complexity: 13, fitness: -361.387451171875, equation: [5*y0 + 2*y1 + 2*y4 - 0.473*y7, y1 + y4]
# Complexity: 21, fitness: -361.86688232421875, equation: [10*y0 + 6*y1 + y3*y4 + 6*y4 + 4*y5, 2*y1 + 2*y4]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -12.504687309265137, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -217.96359252929688, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -291.0406494140625, equation: [y0 + y6 + sin(y0 + y6 + y7), y0 + y6 + y7]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -329.50750732421875, equation: [y0 + 0.242*y1 + sin(y4), 0.121*y1 + sin(y4)]
# Complexity: 9, fitness: -358.9577941894531, equation: [4*y0 + 2*y1 + 2*y4 + y5, y1 + y4]
# Complexity: 10, fitness: -360.72137451171875, equation: [5*y0 + y1 + y4 + sin(3*y0 + y1 + y4), y1 + y4]
# Complexity: 13, fitness: -361.387451171875, equation: [5*y0 + 2*y1 + 2*y4 - 0.473*y7, y1 + y4]
# Complexity: 21, fitness: -361.86688232421875, equation: [10*y0 + 6*y1 + y3*y4 + 6*y4 + 4*y5, 2*y1 + 2*y4]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -12.504687309265137, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -217.96359252929688, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -291.0406494140625, equation: [y0 + y6 + sin(y0 + y6 + y7), y0 + y6 + y7]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -329.50750732421875, equation: [y0 + 0.242*y1 + sin(y4), 0.121*y1 + sin(y4)]
# Complexity: 9, fitness: -358.9577941894531, equation: [4*y0 + 2*y1 + 2*y4 + y5, y1 + y4]
# Complexity: 10, fitness: -360.72137451171875, equation: [5*y0 + y1 + y4 + sin(3*y0 + y1 + y4), y1 + y4]
# Complexity: 13, fitness: -361.387451171875, equation: [5*y0 + 2*y1 + 2*y4 - 0.473*y7, y1 + y4]
# Complexity: 21, fitness: -361.86688232421875, equation: [10*y0 + 6*y1 + y3*y4 + 6*y4 + 4*y5, 2*y1 + 2*y4]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -12.504687309265137, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -217.96359252929688, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -291.0406494140625, equation: [y0 + y6 + sin(y0 + y6 + y7), y0 + y6 + y7]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -329.50750732421875, equation: [y0 + 0.242*y1 + sin(y4), 0.121*y1 + sin(y4)]
# Complexity: 9, fitness: -358.9577941894531, equation: [4*y0 + 2*y1 + 2*y4 + y5, y1 + y4]
# Complexity: 10, fitness: -360.72393798828125, equation: [5*y0 + y1 + y4 + sin(3*y0 + y1 + y4), y1 + y4]
# Complexity: 13, fitness: -361.387451171875, equation: [5*y0 + 2*y1 + 2*y4 - 0.473*y7, y1 + y4]
# Complexity: 15, fitness: -363.7863464355469, equation: [5*y0 + 3*y1 - y2 + 2*y4 + y5, y1 + y4]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -12.504687309265137, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -217.96359252929688, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -291.0406494140625, equation: [y0 + y6 + sin(y0 + y6 + y7), y0 + y6 + y7]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -329.50750732421875, equation: [y0 + 0.242*y1 + sin(y4), 0.121*y1 + sin(y4)]
# Complexity: 9, fitness: -358.9577941894531, equation: [4*y0 + 2*y1 + 2*y4 + y5, y1 + y4]
# Complexity: 10, fitness: -360.72393798828125, equation: [5*y0 + y1 + y4 + sin(3*y0 + y1 + y4), y1 + y4]
# Complexity: 13, fitness: -361.387451171875, equation: [5*y0 + 2*y1 + 2*y4 - 0.473*y7, y1 + y4]
# Complexity: 15, fitness: -363.7863464355469, equation: [5*y0 + 3*y1 - y2 + 2*y4 + y5, y1 + y4]
# Final pareto front:
# Complexity: 1, fitness: -12.504687309265137, equation: [y7, 0]
# Complexity: 3, fitness: -39.8231201171875, equation: [0, y1 + y5]
# Complexity: 5, fitness: -217.96359252929688, equation: [y0 + 2*y6, 2*y6]
# Complexity: 6, fitness: -291.0406494140625, equation: [y0 + y6 + sin(y0 + y6 + y7), y0 + y6 + y7]
# Complexity: 7, fitness: -293.7571716308594, equation: [y1 - y2 + y5 + y6, y1 + y6]
# Complexity: 8, fitness: -329.50750732421875, equation: [y0 + 0.242*y1 + sin(y4), 0.121*y1 + sin(y4)]
# Complexity: 9, fitness: -358.9577941894531, equation: [4*y0 + 2*y1 + 2*y4 + y5, y1 + y4]
# Complexity: 10, fitness: -360.72393798828125, equation: [5*y0 + y1 + y4 + sin(3*y0 + y1 + y4), y1 + y4]
# Complexity: 13, fitness: -361.387451171875, equation: [5*y0 + 2*y1 + 2*y4 - 0.473*y7, y1 + y4]
# Complexity: 15, fitness: -363.7863464355469, equation: [5*y0 + 3*y1 - y2 + 2*y4 + y5, y1 + y4]

# %%
brax_env = BraxGymnaxWrapper('hopper', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=3, max_nodes = 31)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated) 0.5 high
# Compiling code for evaluation and evolution...
# Finished compilation in 126.96 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: -212.62884521484375, equation: [0.639, 0, 0]
# Complexity: 2, fitness: -220.23825073242188, equation: [0, cos(y0), 0]
# Complexity: 4, fitness: -247.11436462402344, equation: [0.418*sin(y0), 0, 0]
# Complexity: 5, fitness: -310.4969787597656, equation: [0, y0*y1*y7 + y1*y7, 0]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -250.21145629882812, equation: [0, y4, 0]
# Complexity: 3, fitness: -283.03814697265625, equation: [0, y1*y7, 0]
# Complexity: 5, fitness: -326.7374267578125, equation: [y3*y7 + y4, y3*y7, 0]
# Complexity: 9, fitness: -418.9754638671875, equation: [y1*(-y10*y3 - y5 + y9), 0, -y5 + y9]
# Complexity: 17, fitness: -496.4168395996094, equation: [y7*(y10*y2*y4 + y3)*(y4 + y5 + y7*y8), y7*(y10*y2*y4 + y3), y10*y2 + y7*y8]
# Complexity: 20, fitness: -771.21728515625, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + sin(y6)) + 2*sin(y6), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -283.03814697265625, equation: [0, y1*y7, 0]
# Complexity: 5, fitness: -326.7374267578125, equation: [y3*y7 + y4, y3*y7, 0]
# Complexity: 7, fitness: -388.2273254394531, equation: [y1*(-y5 - y7 + y9), 0, -y5 + y9]
# Complexity: 9, fitness: -418.9801940917969, equation: [y1*(-y10*y3 - y5 + y9), 0, -y5 + y9]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 19, fitness: -771.76904296875, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + y10 + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + y10), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -308.7515869140625, equation: [0, y7*y8, 0]
# Complexity: 4, fitness: -334.9557189941406, equation: [cos(y1*y9), y1*y9, 0]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 9, fitness: -465.6339416503906, equation: [y0 + y10*y4*(-y0 + y6), 0, y10*y4*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 11, fitness: -515.0589599609375, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 18, fitness: -520.4366455078125, equation: [y1*(-y3*y5*y6 - y5 + y9), 2*y5*y6 + sin(y1*y4*y5*y6*(-y3*y5*y6 - y5 + y9)), -y5 + y9]
# Complexity: 19, fitness: -771.7740478515625, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + y10 + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + y10), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 24, fitness: -772.5056762695312, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + y2 + y5*(y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + sin(y6)) + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + sin(y6)) + 2*sin(y6), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -483.3055419921875, equation: [0, y4*(-y5 + y9) - y9, -y5 + y9]
# Complexity: 9, fitness: -512.1182861328125, equation: [y0 + y10*y4*(-y0 + y4), 0, y10*y4*(-y0 + y4) + y10*(-y0 + y4)]
# Complexity: 11, fitness: -515.0599365234375, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -521.9163818359375, equation: [y7*(-y5 + y9)*(y1 + y5 + y7*y8), y7*(-y5 + y9), -y5 + y7*y8 + y9]
# Complexity: 15, fitness: -629.2621459960938, equation: [y1*(-y10*y3 - y5 + y9), y7*y8, y1*y2*(-y10*y3 - y5 + y9) - y5 + y7*y8 + y9]
# Complexity: 17, fitness: -836.7462158203125, equation: [y1*(-y10 - y3 - y5 + y9), y1*y6*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y4*y6*y7*y8*(-y10 - y3 - y5 + y9) - y5 + y9]
# Complexity: 22, fitness: -844.18701171875, equation: [2*y0 + 2*y1*y10*(-y0 + y6) + y2 + y5*(y0*y1 + y3)*(y0 + y1*y10*(-y0 + y6) + sin(y6)) + (y0*y1 + y3)*(y0 + y1*y10*(-y0 + y6) + sin(y6)) + 2*sin(y6), y0*y1, y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 25, fitness: -910.3909301757812, equation: [y0*y10*y3*(-y0 + y6) + y0, sin(y1**2 + cos(y0*y10*y3*(-y0 + y6) + y0)), y0*y1*(-y0 + y9)*sin(y1**2 + cos(y0*y10*y3*(-y0 + y6) + y0)) + y0*y1*(-y0 + y9) + y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -595.8489990234375, equation: [0, y4*(-y5 + y7*y8) + y7*y8 - y9, -y5 + y7*y8]
# Complexity: 15, fitness: -629.2621459960938, equation: [y1*(-y10*y3 - y5 + y9), y7*y8, y1*y2*(-y10*y3 - y5 + y9) - y5 + y7*y8 + y9]
# Complexity: 17, fitness: -837.120849609375, equation: [y1*(-y10 - y3 - y5 + y9), y1*y6*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y4*y6*y7*y8*(-y10 - y3 - y5 + y9) - y5 + y9]
# Complexity: 22, fitness: -844.1883544921875, equation: [2*y0 + 2*y1*y10*(-y0 + y6) + y2 + y5*(y0*y1 + y3)*(y0 + y1*y10*(-y0 + y6) + sin(y6)) + (y0*y1 + y3)*(y0 + y1*y10*(-y0 + y6) + sin(y6)) + 2*sin(y6), y0*y1, y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 23, fitness: -910.6456298828125, equation: [y0*y10*y3*(-y0 + y6) + y0, sin(y10 + cos(y0*y10*y3*(-y0 + y6) + y0)), y0*y1*(-y0 + y9)*sin(y10 + cos(y0*y10*y3*(-y0 + y6) + y0)) + y0*y1*(-y0 + y9) + y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -595.8489990234375, equation: [0, y4*(-y5 + y7*y8) + y7*y8 - y9, -y5 + y7*y8]
# Complexity: 13, fitness: -858.9837036132812, equation: [2*y0*y1*y10*(-y0 + y6) + 2*y0 + y8, y0*y1, y0*y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 16, fitness: -986.694580078125, equation: [y6*y7*cos(y0 - y10*y7*(-y0 - 2.83*y7)), y10*y7*(-y0 - 2.83*y7) + y7*cos(y0 - y10*y7*(-y0 - 2.83*y7)) - 2.83*y7 + cos(y0 - y10*y7*(-y0 - 2.83*y7)), y10*(-y0 - 2.83*y7)]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -595.8489990234375, equation: [0, y4*(-y5 + y7*y8) + y7*y8 - y9, -y5 + y7*y8]
# Complexity: 13, fitness: -858.9837036132812, equation: [2*y0*y1*y10*(-y0 + y6) + 2*y0 + y8, y0*y1, y0*y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 15, fitness: -859.0145263671875, equation: [2*y0*y1*y10*(-y0 + y6) + 2*y0, y0*y1, y0*y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 16, fitness: -986.694580078125, equation: [y6*y7*cos(y0 - y10*y7*(-y0 - 2.83*y7)), y10*y7*(-y0 - 2.83*y7) + y7*cos(y0 - y10*y7*(-y0 - 2.83*y7)) - 2.83*y7 + cos(y0 - y10*y7*(-y0 - 2.83*y7)), y10*(-y0 - 2.83*y7)]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -595.8489990234375, equation: [0, y4*(-y5 + y7*y8) + y7*y8 - y9, -y5 + y7*y8]
# Complexity: 13, fitness: -858.9837036132812, equation: [2*y0*y1*y10*(-y0 + y6) + 2*y0 + y8, y0*y1, y0*y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 15, fitness: -859.0145263671875, equation: [2*y0*y1*y10*(-y0 + y6) + 2*y0, y0*y1, y0*y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 16, fitness: -986.694580078125, equation: [y6*y7*cos(y0 - y10*y7*(-y0 - 2.83*y7)), y10*y7*(-y0 - 2.83*y7) + y7*cos(y0 - y10*y7*(-y0 - 2.83*y7)) - 2.83*y7 + cos(y0 - y10*y7*(-y0 - 2.83*y7)), y10*(-y0 - 2.83*y7)]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -595.8489990234375, equation: [0, y4*(-y5 + y7*y8) + y7*y8 - y9, -y5 + y7*y8]
# Complexity: 13, fitness: -858.9837036132812, equation: [2*y0*y1*y10*(-y0 + y6) + 2*y0 + y8, y0*y1, y0*y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 15, fitness: -859.0145263671875, equation: [2*y0*y1*y10*(-y0 + y6) + 2*y0, y0*y1, y0*y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 16, fitness: -1024.4837646484375, equation: [y6*y7*cos(y0 - y10**2*(-y0 - 2.83*y7)), y7*cos(y0 - y10**2*(-y0 - 2.83*y7)) - 2.83*y7 + cos(y0 - y10**2*(-y0 - 2.83*y7)), y10**2*(-y0 - 2.83*y7) + y10*(-y0 - 2.83*y7)]
# Complexity: 31, fitness: -1025.7369384765625, equation: [y1*(y1*(-y10 - y3 - y5 + y9) - y10 - y3) + y1*(-y10 - y3 - y5 + y9), y1*y6*y7**2*y8**2*(y2 + y4)*(y1*(-y10 - y3 - y5 + y9) - y10 - y3) + y1*y6*y7*y8*(y1*(-y10 - y3 - y5 + y9) - y10 - y3) + 2*y7*y8, y1*y4*y6*y7**2*y8**2*(y2 + y4)*(y1*(-y10 - y3 - y5 + y9) - y10 - y3) - y5 + y9]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -595.8489990234375, equation: [0, y4*(-y5 + y7*y8) + y7*y8 - y9, -y5 + y7*y8]
# Complexity: 13, fitness: -858.9837036132812, equation: [2*y0*y1*y10*(-y0 + y6) + 2*y0 + y8, y0*y1, y0*y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 15, fitness: -859.0145263671875, equation: [2*y0*y1*y10*(-y0 + y6) + 2*y0, y0*y1, y0*y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 16, fitness: -1024.4837646484375, equation: [y6*y7*cos(y0 - y10**2*(-y0 - 2.83*y7)), y7*cos(y0 - y10**2*(-y0 - 2.83*y7)) - 2.83*y7 + cos(y0 - y10**2*(-y0 - 2.83*y7)), y10**2*(-y0 - 2.83*y7) + y10*(-y0 - 2.83*y7)]
# Complexity: 21, fitness: -1034.99951171875, equation: [y0**2*y10*y3*(-y0 - 2.83*y7) + y0 + y1*y6**2, -2.83*y7, y0**2*y10*y3*(-y0 - 2.83*y7) + y0*y10*(-y0 - 2.83*y7) + y1*y6**2 + y1*y6 + y10*(-y0 - 2.83*y7)]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -595.8489990234375, equation: [0, y4*(-y5 + y7*y8) + y7*y8 - y9, -y5 + y7*y8]
# Complexity: 11, fitness: -754.2227172851562, equation: [y10*(-y0 - 2.83*y7), -2.83*y7, y10*(-y0 - 2.83*y7)]
# Complexity: 13, fitness: -858.9837036132812, equation: [2*y0*y1*y10*(-y0 + y6) + 2*y0 + y8, y0*y1, y0*y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 15, fitness: -859.0145263671875, equation: [2*y0*y1*y10*(-y0 + y6) + 2*y0, y0*y1, y0*y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 16, fitness: -1024.4837646484375, equation: [y6*y7*cos(y0 - y10**2*(-y0 - 2.83*y7)), y7*cos(y0 - y10**2*(-y0 - 2.83*y7)) - 2.83*y7 + cos(y0 - y10**2*(-y0 - 2.83*y7)), y10**2*(-y0 - 2.83*y7) + y10*(-y0 - 2.83*y7)]
# Complexity: 21, fitness: -1034.99951171875, equation: [y0**2*y10*y3*(-y0 - 2.83*y7) + y0 + y1*y6**2, -2.83*y7, y0**2*y10*y3*(-y0 - 2.83*y7) + y0*y10*(-y0 - 2.83*y7) + y1*y6**2 + y1*y6 + y10*(-y0 - 2.83*y7)]
# Complexity: 22, fitness: -1058.605224609375, equation: [y0 + y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3), y1*(-y0 + y6), y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3) + y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y10*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3) + y10*cos(-y0 + y1*(-y0 + y6) + y3)]
# Complexity: 27, fitness: -1079.885498046875, equation: [y1*(-y10 - y3 - y5 + y9), y1*y2**2*y5*y6*y7*y8*(y2 + y4)*(-y10 - y3 - y5 + y9) + y1*y5*y6*y7*y8*(-y10 - y3 - y5 + y9) + y5*y6 + y7*y8, y1*y2**2*y4*y5*y6*y7*y8*(y2 + y4)*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -879.4063720703125, equation: [y0 + y10*(-y0 - 2.83*y7), -2.83*y7, y10*(-y0 - 2.83*y7)]
# Complexity: 16, fitness: -1024.4837646484375, equation: [y6*y7*cos(y0 - y10**2*(-y0 - 2.83*y7)), y7*cos(y0 - y10**2*(-y0 - 2.83*y7)) - 2.83*y7 + cos(y0 - y10**2*(-y0 - 2.83*y7)), y10**2*(-y0 - 2.83*y7) + y10*(-y0 - 2.83*y7)]
# Complexity: 21, fitness: -1043.0384521484375, equation: [y0**2*y10*y3*(-y0 - 2.83*y7) + y0 + y6*(-y0 + y6), -2.83*y7, y0**2*y10*y3*(-y0 - 2.83*y7) + y0*y10*(-y0 - 2.83*y7) + y10*(-y0 - 2.83*y7) + y6*(-y0 + y6)]
# Complexity: 22, fitness: -1058.605224609375, equation: [y0 + y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3), y1*(-y0 + y6), y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3) + y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y10*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3) + y10*cos(-y0 + y1*(-y0 + y6) + y3)]
# Complexity: 27, fitness: -1079.885498046875, equation: [y1*(-y10 - y3 - y5 + y9), y1*y2**2*y5*y6*y7*y8*(y2 + y4)*(-y10 - y3 - y5 + y9) + y1*y5*y6*y7*y8*(-y10 - y3 - y5 + y9) + y5*y6 + y7*y8, y1*y2**2*y4*y5*y6*y7*y8*(y2 + y4)*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -879.4063720703125, equation: [y0 + y10*(-y0 - 2.83*y7), -2.83*y7, y10*(-y0 - 2.83*y7)]
# Complexity: 16, fitness: -1024.4837646484375, equation: [y6*y7*cos(y0 - y10**2*(-y0 - 2.83*y7)), y7*cos(y0 - y10**2*(-y0 - 2.83*y7)) - 2.83*y7 + cos(y0 - y10**2*(-y0 - 2.83*y7)), y10**2*(-y0 - 2.83*y7) + y10*(-y0 - 2.83*y7)]
# Complexity: 21, fitness: -1043.0384521484375, equation: [y0**2*y10*y3*(-y0 - 2.83*y7) + y0 + y6*(-y0 + y6), -2.83*y7, y0**2*y10*y3*(-y0 - 2.83*y7) + y0*y10*(-y0 - 2.83*y7) + y10*(-y0 - 2.83*y7) + y6*(-y0 + y6)]
# Complexity: 22, fitness: -1058.802001953125, equation: [y0 + y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3), y1*(-y0 + y6), y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3) + y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y10*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3) + y10*cos(-y0 + y1*(-y0 + y6) + y3)]
# Complexity: 25, fitness: -1073.972900390625, equation: [y1*(-y10 - y3 - y5 + y9), y1*y2**2*y4*y5*y6*y7*y8*(-y10 - y3 - y5 + y9) + y1*y5*y6*y7*y8*(-y10 - y3 - y5 + y9) + y5*y6 + y7*y8, y1*y2**2*y4**2*y5*y6*y7*y8*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# Complexity: 27, fitness: -1079.885498046875, equation: [y1*(-y10 - y3 - y5 + y9), y1*y2**2*y5*y6*y7*y8*(y2 + y4)*(-y10 - y3 - y5 + y9) + y1*y5*y6*y7*y8*(-y10 - y3 - y5 + y9) + y5*y6 + y7*y8, y1*y2**2*y4*y5*y6*y7*y8*(y2 + y4)*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -879.4063720703125, equation: [y0 + y10*(-y0 - 2.83*y7), -2.83*y7, y10*(-y0 - 2.83*y7)]
# Complexity: 16, fitness: -1024.4837646484375, equation: [y6*y7*cos(y0 - y10**2*(-y0 - 2.83*y7)), y7*cos(y0 - y10**2*(-y0 - 2.83*y7)) - 2.83*y7 + cos(y0 - y10**2*(-y0 - 2.83*y7)), y10**2*(-y0 - 2.83*y7) + y10*(-y0 - 2.83*y7)]
# Complexity: 21, fitness: -1043.773681640625, equation: [y0**2*y10*y3*(-y0 - 2.83*y7) + y0 + y6*(-y0 + y6), -2.83*y7, y0**2*y10*y3*(-y0 - 2.83*y7) + y0*y10*(-y0 - 2.83*y7) + y10*(-y0 - 2.83*y7) + y6*(-y0 + y6)]
# Complexity: 22, fitness: -1058.802001953125, equation: [y0 + y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3), y1*(-y0 + y6), y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3) + y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y10*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3) + y10*cos(-y0 + y1*(-y0 + y6) + y3)]
# Complexity: 25, fitness: -1113.987060546875, equation: [y1*(-y10 - y3 - y5 + y9), y1*y2**3*y7*y8*(y2 + y4)*(-y10 - y3 - y5 + y9) + y1*y2*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y2**3*y4*y7*y8*(y2 + y4)*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -879.4063720703125, equation: [y0 + y10*(-y0 - 2.83*y7), -2.83*y7, y10*(-y0 - 2.83*y7)]
# Complexity: 15, fitness: -1038.5072021484375, equation: [y0 + y10*y4*(-y10*(-y0 - 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*(-y0 - 2.83*y7) + y3) + y10*(-y0 - 2.83*y7) + y10*(-y10*(-y0 - 2.83*y7) + y3)]
# Complexity: 21, fitness: -1043.773681640625, equation: [y0**2*y10*y3*(-y0 - 2.83*y7) + y0 + y6*(-y0 + y6), -2.83*y7, y0**2*y10*y3*(-y0 - 2.83*y7) + y0*y10*(-y0 - 2.83*y7) + y10*(-y0 - 2.83*y7) + y6*(-y0 + y6)]
# Complexity: 22, fitness: -1058.802001953125, equation: [y0 + y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3), y1*(-y0 + y6), y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3) + y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y10*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3) + y10*cos(-y0 + y1*(-y0 + y6) + y3)]
# Complexity: 24, fitness: -1066.5811767578125, equation: [y0 + y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y4*y7) + y3) + y3), y1*(-y0 + y4*y7), y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y4*y7) + y3) + y3) + y10*y5*cos(-y0 + y1*(-y0 + y4*y7) + y3) + y10*(-y10*y5*cos(-y0 + y1*(-y0 + y4*y7) + y3) + y3) + y10*cos(-y0 + y1*(-y0 + y4*y7) + y3)]
# Complexity: 25, fitness: -1113.987060546875, equation: [y1*(-y10 - y3 - y5 + y9), y1*y2**3*y7*y8*(y2 + y4)*(-y10 - y3 - y5 + y9) + y1*y2*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y2**3*y4*y7*y8*(y2 + y4)*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -879.4063720703125, equation: [y0 + y10*(-y0 - 2.83*y7), -2.83*y7, y10*(-y0 - 2.83*y7)]
# Complexity: 14, fitness: -1008.455322265625, equation: [0, y0*cos(-y0 + y10 + y6 + y7) + cos(-y0 + y10 + y6 + y7), -y10 - y6 - y7]
# Complexity: 15, fitness: -1038.5072021484375, equation: [y0 + y10*y4*(-y10*(-y0 - 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*(-y0 - 2.83*y7) + y3) + y10*(-y0 - 2.83*y7) + y10*(-y10*(-y0 - 2.83*y7) + y3)]
# Complexity: 21, fitness: -1043.773681640625, equation: [y0**2*y10*y3*(-y0 - 2.83*y7) + y0 + y6*(-y0 + y6), -2.83*y7, y0**2*y10*y3*(-y0 - 2.83*y7) + y0*y10*(-y0 - 2.83*y7) + y10*(-y0 - 2.83*y7) + y6*(-y0 + y6)]
# Complexity: 22, fitness: -1058.9281005859375, equation: [y0 + y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3), y1*(-y0 + y6), y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3) + y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y10*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3) + y10*cos(-y0 + y1*(-y0 + y6) + y3)]
# Complexity: 24, fitness: -1066.5811767578125, equation: [y0 + y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y4*y7) + y3) + y3), y1*(-y0 + y4*y7), y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y4*y7) + y3) + y3) + y10*y5*cos(-y0 + y1*(-y0 + y4*y7) + y3) + y10*(-y10*y5*cos(-y0 + y1*(-y0 + y4*y7) + y3) + y3) + y10*cos(-y0 + y1*(-y0 + y4*y7) + y3)]
# Complexity: 25, fitness: -1113.987060546875, equation: [y1*(-y10 - y3 - y5 + y9), y1*y2**3*y7*y8*(y2 + y4)*(-y10 - y3 - y5 + y9) + y1*y2*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y2**3*y4*y7*y8*(y2 + y4)*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -879.4063720703125, equation: [y0 + y10*(-y0 - 2.83*y7), -2.83*y7, y10*(-y0 - 2.83*y7)]
# Complexity: 14, fitness: -1008.455322265625, equation: [0, y0*cos(-y0 + y10 + y6 + y7) + cos(-y0 + y10 + y6 + y7), -y10 - y6 - y7]
# Complexity: 15, fitness: -1038.5072021484375, equation: [y0 + y10*y4*(-y10*(-y0 - 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*(-y0 - 2.83*y7) + y3) + y10*(-y0 - 2.83*y7) + y10*(-y10*(-y0 - 2.83*y7) + y3)]
# Complexity: 21, fitness: -1043.773681640625, equation: [y0**2*y10*y3*(-y0 - 2.83*y7) + y0 + y6*(-y0 + y6), -2.83*y7, y0**2*y10*y3*(-y0 - 2.83*y7) + y0*y10*(-y0 - 2.83*y7) + y10*(-y0 - 2.83*y7) + y6*(-y0 + y6)]
# Complexity: 22, fitness: -1058.9281005859375, equation: [y0 + y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3), y1*(-y0 + y6), y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3) + y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y10*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3) + y10*cos(-y0 + y1*(-y0 + y6) + y3)]
# Complexity: 24, fitness: -1066.5811767578125, equation: [y0 + y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y4*y7) + y3) + y3), y1*(-y0 + y4*y7), y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y4*y7) + y3) + y3) + y10*y5*cos(-y0 + y1*(-y0 + y4*y7) + y3) + y10*(-y10*y5*cos(-y0 + y1*(-y0 + y4*y7) + y3) + y3) + y10*cos(-y0 + y1*(-y0 + y4*y7) + y3)]
# Complexity: 25, fitness: -1113.987060546875, equation: [y1*(-y10 - y3 - y5 + y9), y1*y2**3*y7*y8*(y2 + y4)*(-y10 - y3 - y5 + y9) + y1*y2*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y2**3*y4*y7*y8*(y2 + y4)*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -879.4063720703125, equation: [y0 + y10*(-y0 - 2.83*y7), -2.83*y7, y10*(-y0 - 2.83*y7)]
# Complexity: 14, fitness: -1008.455322265625, equation: [0, y0*cos(-y0 + y10 + y6 + y7) + cos(-y0 + y10 + y6 + y7), -y10 - y6 - y7]
# Complexity: 15, fitness: -1038.5072021484375, equation: [y0 + y10*y4*(-y10*(-y0 - 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*(-y0 - 2.83*y7) + y3) + y10*(-y0 - 2.83*y7) + y10*(-y10*(-y0 - 2.83*y7) + y3)]
# Complexity: 21, fitness: -1043.773681640625, equation: [y0**2*y10*y3*(-y0 - 2.83*y7) + y0 + y6*(-y0 + y6), -2.83*y7, y0**2*y10*y3*(-y0 - 2.83*y7) + y0*y10*(-y0 - 2.83*y7) + y10*(-y0 - 2.83*y7) + y6*(-y0 + y6)]
# Complexity: 22, fitness: -1058.9281005859375, equation: [y0 + y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3), y1*(-y0 + y6), y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3) + y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y10*(-y10*y5*cos(-y0 + y1*(-y0 + y6) + y3) + y3) + y10*cos(-y0 + y1*(-y0 + y6) + y3)]
# Complexity: 23, fitness: -1111.587890625, equation: [y1*(-y10 - y3 - y5 + y9), y1*y2**3*y3*y7*y8*(-y10 - y3 - y5 + y9) + y1*y2*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y2**3*y3*y4*y7*y8*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# Complexity: 25, fitness: -1116.8912353515625, equation: [y1*(-y10 - y3 - y5 + y9), y1*y2**3*y7*y8*(y4 + y5)*(-y10 - y3 - y5 + y9) + y1*y2*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y2**3*y4*y7*y8*(y4 + y5)*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -879.4063720703125, equation: [y0 + y10*(-y0 - 2.83*y7), -2.83*y7, y10*(-y0 - 2.83*y7)]
# Complexity: 14, fitness: -1008.455322265625, equation: [0, y0*cos(-y0 + y10 + y6 + y7) + cos(-y0 + y10 + y6 + y7), -y10 - y6 - y7]
# Complexity: 15, fitness: -1038.5072021484375, equation: [y0 + y10*y4*(-y10*(-y0 - 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*(-y0 - 2.83*y7) + y3) + y10*(-y0 - 2.83*y7) + y10*(-y10*(-y0 - 2.83*y7) + y3)]
# Complexity: 20, fitness: -1041.865478515625, equation: [y0 + y10*y4*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3) + y10*y5*cos(y0 - y3 + 2.83*y7) + y10*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3) + y10*cos(y0 - y3 + 2.83*y7)]
# Complexity: 21, fitness: -1043.773681640625, equation: [y0**2*y10*y3*(-y0 - 2.83*y7) + y0 + y6*(-y0 + y6), -2.83*y7, y0**2*y10*y3*(-y0 - 2.83*y7) + y0*y10*(-y0 - 2.83*y7) + y10*(-y0 - 2.83*y7) + y6*(-y0 + y6)]
# Complexity: 22, fitness: -1064.289306640625, equation: [y0 + y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y7) + y3) + y3), y1*(-y0 + y7), y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y7) + y3) + y3) + y10*y5*cos(-y0 + y1*(-y0 + y7) + y3) + y10*(-y10*y5*cos(-y0 + y1*(-y0 + y7) + y3) + y3) + y10*cos(-y0 + y1*(-y0 + y7) + y3)]
# Complexity: 23, fitness: -1116.7205810546875, equation: [y1*(-y10 - y3 - y5 + y9), y1*y2**2*y4*y7*y8**2*(-y10 - y3 - y5 + y9) + y1*y4*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y2**2*y4**2*y7*y8**2*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# Complexity: 25, fitness: -1117.21826171875, equation: [y1*(-y10 - y3 - y5 + y9), y1*y2**3*y7*y8*(-y4 + y5)*(-y10 - y3 - y5 + y9) + y1*y2*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y2**3*y4*y7*y8*(-y4 + y5)*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -879.4063720703125, equation: [y0 + y10*(-y0 - 2.83*y7), -2.83*y7, y10*(-y0 - 2.83*y7)]
# Complexity: 14, fitness: -1008.455322265625, equation: [0, y0*cos(-y0 + y10 + y6 + y7) + cos(-y0 + y10 + y6 + y7), -y10 - y6 - y7]
# Complexity: 15, fitness: -1038.5072021484375, equation: [y0 + y10*y4*(-y10*(-y0 - 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*(-y0 - 2.83*y7) + y3) + y10*(-y0 - 2.83*y7) + y10*(-y10*(-y0 - 2.83*y7) + y3)]
# Complexity: 20, fitness: -1041.865478515625, equation: [y0 + y10*y4*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3) + y10*y5*cos(y0 - y3 + 2.83*y7) + y10*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3) + y10*cos(y0 - y3 + 2.83*y7)]
# Complexity: 21, fitness: -1043.773681640625, equation: [y0**2*y10*y3*(-y0 - 2.83*y7) + y0 + y6*(-y0 + y6), -2.83*y7, y0**2*y10*y3*(-y0 - 2.83*y7) + y0*y10*(-y0 - 2.83*y7) + y10*(-y0 - 2.83*y7) + y6*(-y0 + y6)]
# Complexity: 22, fitness: -1064.289306640625, equation: [y0 + y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y7) + y3) + y3), y1*(-y0 + y7), y10*y4*(-y10*y5*cos(-y0 + y1*(-y0 + y7) + y3) + y3) + y10*y5*cos(-y0 + y1*(-y0 + y7) + y3) + y10*(-y10*y5*cos(-y0 + y1*(-y0 + y7) + y3) + y3) + y10*cos(-y0 + y1*(-y0 + y7) + y3)]
# Complexity: 23, fitness: -1121.468994140625, equation: [y1*(-y10 - y3 - y5 + y9), y1*y10*y2**3*y7*y8*(-y10 - y3 - y5 + y9) + y1*y2*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y10*y2**3*y4*y7*y8*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# Complexity: 31, fitness: -1123.478515625, equation: [y1*(-2*y5 + y9), y2**2*y6*y7**2*y8*(y3 + 2*y4)*(-y1*(-2*y5 + y9) + y6**2) + y6**2 + y6*y7**2*y8*(-y1*(-2*y5 + y9) + y6**2) + y6*y7**2*y8 + y6*y7*y8 + y7*y8, y2**2*y4*y6*y7**2*y8*(y3 + 2*y4)*(-y1*(-2*y5 + y9) + y6**2) + y2**2 - y5 + y9]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -879.4063720703125, equation: [y0 + y10*(-y0 - 2.83*y7), -2.83*y7, y10*(-y0 - 2.83*y7)]
# Complexity: 14, fitness: -1008.455322265625, equation: [0, y0*cos(-y0 + y10 + y6 + y7) + cos(-y0 + y10 + y6 + y7), -y10 - y6 - y7]
# Complexity: 15, fitness: -1038.5072021484375, equation: [y0 + y10*y4*(-y10*(-y0 - 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*(-y0 - 2.83*y7) + y3) + y10*(-y0 - 2.83*y7) + y10*(-y10*(-y0 - 2.83*y7) + y3)]
# Complexity: 19, fitness: -1039.224365234375, equation: [y0 + y1*y10*y4**2*(3.83*y10*y7 + y3), y1*y10*y4*(3.83*y10*y7 + y3) - 2.83*y7, y1*y10*y4**2*(3.83*y10*y7 + y3) + y10*y4*(3.83*y10*y7 + y3) - 3.83*y10*y7 + y10*(3.83*y10*y7 + y3)]
# Complexity: 20, fitness: -1041.865478515625, equation: [y0 + y10*y4*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3) + y10*y5*cos(y0 - y3 + 2.83*y7) + y10*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3) + y10*cos(y0 - y3 + 2.83*y7)]
# Complexity: 21, fitness: -1083.82666015625, equation: [y1*(-y10 - y3 - y5 + y9), y1*y3*(-y10 - y3 - y5 + y9) + y2**2*(-y1*y3*(-y10 - y3 - y5 + y9) + y6 - y7**2) + 2*y7**2, y2**2 - y5 + y9]
# Complexity: 23, fitness: -1121.468994140625, equation: [y1*(-y10 - y3 - y5 + y9), y1*y10*y2**3*y7*y8*(-y10 - y3 - y5 + y9) + y1*y2*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y10*y2**3*y4*y7*y8*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# Complexity: 31, fitness: -1123.478515625, equation: [y1*(-2*y5 + y9), y2**2*y6*y7**2*y8*(y3 + 2*y4)*(-y1*(-2*y5 + y9) + y6**2) + y6**2 + y6*y7**2*y8*(-y1*(-2*y5 + y9) + y6**2) + y6*y7**2*y8 + y6*y7*y8 + y7*y8, y2**2*y4*y6*y7**2*y8*(y3 + 2*y4)*(-y1*(-2*y5 + y9) + y6**2) + y2**2 - y5 + y9]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -879.4063720703125, equation: [y0 + y10*(-y0 - 2.83*y7), -2.83*y7, y10*(-y0 - 2.83*y7)]
# Complexity: 14, fitness: -1008.455322265625, equation: [0, y0*cos(-y0 + y10 + y6 + y7) + cos(-y0 + y10 + y6 + y7), -y10 - y6 - y7]
# Complexity: 15, fitness: -1038.5072021484375, equation: [y0 + y10*y4*(-y10*(-y0 - 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*(-y0 - 2.83*y7) + y3) + y10*(-y0 - 2.83*y7) + y10*(-y10*(-y0 - 2.83*y7) + y3)]
# Complexity: 19, fitness: -1040.5877685546875, equation: [y0 + y1*y10**2*y4*(3.83*y10*y7 + y3), y1*y10*y4*(3.83*y10*y7 + y3) - 2.83*y7, y1*y10**2*y4*(3.83*y10*y7 + y3) + y10*y4*(3.83*y10*y7 + y3) - 3.83*y10*y7 + y10*(3.83*y10*y7 + y3)]
# Complexity: 20, fitness: -1041.865478515625, equation: [y0 + y10*y4*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3) + y10*y5*cos(y0 - y3 + 2.83*y7) + y10*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3) + y10*cos(y0 - y3 + 2.83*y7)]
# Complexity: 21, fitness: -1083.82666015625, equation: [y1*(-y10 - y3 - y5 + y9), y1*y3*(-y10 - y3 - y5 + y9) + y2**2*(-y1*y3*(-y10 - y3 - y5 + y9) + y6 - y7**2) + 2*y7**2, y2**2 - y5 + y9]
# Complexity: 23, fitness: -1121.468994140625, equation: [y1*(-y10 - y3 - y5 + y9), y1*y10*y2**3*y7*y8*(-y10 - y3 - y5 + y9) + y1*y2*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y10*y2**3*y4*y7*y8*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# Complexity: 31, fitness: -1123.478515625, equation: [y1*(-2*y5 + y9), y2**2*y6*y7**2*y8*(y3 + 2*y4)*(-y1*(-2*y5 + y9) + y6**2) + y6**2 + y6*y7**2*y8*(-y1*(-2*y5 + y9) + y6**2) + y6*y7**2*y8 + y6*y7*y8 + y7*y8, y2**2*y4*y6*y7**2*y8*(y3 + 2*y4)*(-y1*(-2*y5 + y9) + y6**2) + y2**2 - y5 + y9]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -879.4063720703125, equation: [y0 + y10*(-y0 - 2.83*y7), -2.83*y7, y10*(-y0 - 2.83*y7)]
# Complexity: 14, fitness: -1008.455322265625, equation: [0, y0*cos(-y0 + y10 + y6 + y7) + cos(-y0 + y10 + y6 + y7), -y10 - y6 - y7]
# Complexity: 15, fitness: -1038.5072021484375, equation: [y0 + y10*y4*(-y10*(-y0 - 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*(-y0 - 2.83*y7) + y3) + y10*(-y0 - 2.83*y7) + y10*(-y10*(-y0 - 2.83*y7) + y3)]
# Complexity: 19, fitness: -1040.5877685546875, equation: [y0 + y1*y10**2*y4*(3.83*y10*y7 + y3), y1*y10*y4*(3.83*y10*y7 + y3) - 2.83*y7, y1*y10**2*y4*(3.83*y10*y7 + y3) + y10*y4*(3.83*y10*y7 + y3) - 3.83*y10*y7 + y10*(3.83*y10*y7 + y3)]
# Complexity: 20, fitness: -1041.865478515625, equation: [y0 + y10*y4*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3) + y10*y5*cos(y0 - y3 + 2.83*y7) + y10*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3) + y10*cos(y0 - y3 + 2.83*y7)]
# Complexity: 21, fitness: -1083.82666015625, equation: [y1*(-y10 - y3 - y5 + y9), y1*y3*(-y10 - y3 - y5 + y9) + y2**2*(-y1*y3*(-y10 - y3 - y5 + y9) + y6 - y7**2) + 2*y7**2, y2**2 - y5 + y9]
# Complexity: 23, fitness: -1121.468994140625, equation: [y1*(-y10 - y3 - y5 + y9), y1*y10*y2**3*y7*y8*(-y10 - y3 - y5 + y9) + y1*y2*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y10*y2**3*y4*y7*y8*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# Complexity: 25, fitness: -1121.789794921875, equation: [y1*(-y10 - y3 - y5 + y9), y1*y2**3*y7*y8*(y7 + y8)*(-y10 - y3 - y5 + y9) + y1*y2*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y2**3*y4*y7*y8*(y7 + y8)*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# Complexity: 27, fitness: -1147.39892578125, equation: [y1*(-y10 - y3 - y5 + y9), 2*y1*y4*y6*y7*(-y10 - y3 - y5 + y9) + y10*y2**2*(y1*y4*y6*y7*(-y10 - y3 - y5 + y9) + y7**2) + y6*y7 + 2*y7**2, y10*y2**3*(y1*y4*y6*y7*(-y10 - y3 - y5 + y9) + y7**2) + y2**2 - y5 + y9]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -879.4063720703125, equation: [y0 + y10*(-y0 - 2.83*y7), -2.83*y7, y10*(-y0 - 2.83*y7)]
# Complexity: 14, fitness: -1008.455322265625, equation: [0, y0*cos(-y0 + y10 + y6 + y7) + cos(-y0 + y10 + y6 + y7), -y10 - y6 - y7]
# Complexity: 15, fitness: -1038.5072021484375, equation: [y0 + y10*y4*(-y10*(-y0 - 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*(-y0 - 2.83*y7) + y3) + y10*(-y0 - 2.83*y7) + y10*(-y10*(-y0 - 2.83*y7) + y3)]
# Complexity: 19, fitness: -1040.5877685546875, equation: [y0 + y1*y10**2*y4*(3.83*y10*y7 + y3), y1*y10*y4*(3.83*y10*y7 + y3) - 2.83*y7, y1*y10**2*y4*(3.83*y10*y7 + y3) + y10*y4*(3.83*y10*y7 + y3) - 3.83*y10*y7 + y10*(3.83*y10*y7 + y3)]
# Complexity: 20, fitness: -1041.865478515625, equation: [y0 + y10*y4*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3) + y10*y5*cos(y0 - y3 + 2.83*y7) + y10*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3) + y10*cos(y0 - y3 + 2.83*y7)]
# Complexity: 21, fitness: -1083.82666015625, equation: [y1*(-y10 - y3 - y5 + y9), y1*y3*(-y10 - y3 - y5 + y9) + y2**2*(-y1*y3*(-y10 - y3 - y5 + y9) + y6 - y7**2) + 2*y7**2, y2**2 - y5 + y9]
# Complexity: 23, fitness: -1121.800048828125, equation: [y1*(-y10 - y3 - y5 + y9), y1*y10*y2**3*y7*y8*(-y10 - y3 - y5 + y9) + y1*y2*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y10*y2**3*y4*y7*y8*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# Complexity: 25, fitness: -1122.3895263671875, equation: [y1*(-y10 - y3 - y5 + y9), y1*y2**3*y7*y8*(y4 + y8)*(-y10 - y3 - y5 + y9) + y1*y2*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y2**3*y3*y7*y8*(y4 + y8)*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# Complexity: 27, fitness: -1153.1966552734375, equation: [y1*(-y10 - y3 - y5 + y9), 2*y1*y4*y6*y7*(-y10 - y3 - y5 + y9) + y10*y2**2*(y1*y4*y6*y7*(-y10 - y3 - y5 + y9) + y7**2) + y6*y7 + 2*y7**2, y10*y2**3*(y1*y4*y6*y7*(-y10 - y3 - y5 + y9) + y7**2) + y2**2 - y5 + y9]
# Complexity: 29, fitness: -1169.7822265625, equation: [y1*(-y10 - y3 - y5 + y9), 2*y1*y4*y6*y7*(-y10 - y3 - y5 + y9) + y1*(-y10*y2**2*(y1*y4*y6*y7*(-y10 - y3 - y5 + y9) + y7**2) + y6) + y10*y2**2*(y1*y4*y6*y7*(-y10 - y3 - y5 + y9) + y7**2) + y6*y7 + 2*y7**2, y2**2 - y5 + y9]
# Final pareto front:
# Complexity: 1, fitness: -250.2145538330078, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.18701171875, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.2669677734375, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 7, fitness: -504.55731201171875, equation: [0, y4 - y5, -y5 + y9]
# Complexity: 9, fitness: -879.4063720703125, equation: [y0 + y10*(-y0 - 2.83*y7), -2.83*y7, y10*(-y0 - 2.83*y7)]
# Complexity: 14, fitness: -1008.455322265625, equation: [0, y0*cos(-y0 + y10 + y6 + y7) + cos(-y0 + y10 + y6 + y7), -y10 - y6 - y7]
# Complexity: 15, fitness: -1038.5072021484375, equation: [y0 + y10*y4*(-y10*(-y0 - 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*(-y0 - 2.83*y7) + y3) + y10*(-y0 - 2.83*y7) + y10*(-y10*(-y0 - 2.83*y7) + y3)]
# Complexity: 19, fitness: -1040.5877685546875, equation: [y0 + y1*y10**2*y4*(3.83*y10*y7 + y3), y1*y10*y4*(3.83*y10*y7 + y3) - 2.83*y7, y1*y10**2*y4*(3.83*y10*y7 + y3) + y10*y4*(3.83*y10*y7 + y3) - 3.83*y10*y7 + y10*(3.83*y10*y7 + y3)]
# Complexity: 20, fitness: -1041.865478515625, equation: [y0 + y10*y4*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3), -2.83*y7, y10*y4*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3) + y10*y5*cos(y0 - y3 + 2.83*y7) + y10*(-y10*y5*cos(y0 - y3 + 2.83*y7) + y3) + y10*cos(y0 - y3 + 2.83*y7)]
# Complexity: 21, fitness: -1083.82666015625, equation: [y1*(-y10 - y3 - y5 + y9), y1*y3*(-y10 - y3 - y5 + y9) + y2**2*(-y1*y3*(-y10 - y3 - y5 + y9) + y6 - y7**2) + 2*y7**2, y2**2 - y5 + y9]
# Complexity: 23, fitness: -1121.800048828125, equation: [y1*(-y10 - y3 - y5 + y9), y1*y10*y2**3*y7*y8*(-y10 - y3 - y5 + y9) + y1*y2*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y10*y2**3*y4*y7*y8*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# Complexity: 25, fitness: -1122.3895263671875, equation: [y1*(-y10 - y3 - y5 + y9), y1*y2**3*y7*y8*(y4 + y8)*(-y10 - y3 - y5 + y9) + y1*y2*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y2**3*y3*y7*y8*(y4 + y8)*(-y10 - y3 - y5 + y9) + y2**2 - y5 + y9]
# Complexity: 27, fitness: -1153.1966552734375, equation: [y1*(-y10 - y3 - y5 + y9), 2*y1*y4*y6*y7*(-y10 - y3 - y5 + y9) + y10*y2**2*(y1*y4*y6*y7*(-y10 - y3 - y5 + y9) + y7**2) + y6*y7 + 2*y7**2, y10*y2**3*(y1*y4*y6*y7*(-y10 - y3 - y5 + y9) + y7**2) + y2**2 - y5 + y9]
# Complexity: 29, fitness: -1169.7822265625, equation: [y1*(-y10 - y3 - y5 + y9), 2*y1*y4*y6*y7*(-y10 - y3 - y5 + y9) + y1*(-y10*y2**2*(y1*y4*y6*y7*(-y10 - y3 - y5 + y9) + y7**2) + y6) + y10*y2**2*(y1*y4*y6*y7*(-y10 - y3 - y5 + y9) + y7**2) + y6*y7 + 2*y7**2, y2**2 - y5 + y9]
