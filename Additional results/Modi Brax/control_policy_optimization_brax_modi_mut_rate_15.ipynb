# %%
from genetic_programming import GeneticProgramming
from fitness_functions.Gymnax_fitness_function import GymFitnessFunction

import jax
import jax.numpy as jnp
import jax.random as jr

import brax
from brax import envs
import matplotlib.pyplot as plt

class BraxGymnaxWrapper:
    def __init__(self, env_name, backend):
        self.env = envs.get_environment(env_name=env_name, backend=backend)
        self.observation_space = self.env.observation_size
        self.action_space = self.env.action_size

    # state, env_state = self.env.reset(subkey, self.env_params)

    def reset(self, key, params=None):
        #state consists of pipeline_state, obs, reward, done, metrics, info
        state = self.env.reset(key)
        return state.obs, state

     # next_state, next_env_state, reward, done, _ = self.env.step(
     #            subkey, env_state, action, self.env_params
     #        )

    def step(self, key, state, action, params=None):

      action = action.reshape(self.action_space)
      next_state = self.env.step(state, action)
      done = next_state.done

      # Freeze state after done
      obs = jnp.where(done, state.obs, next_state.obs)
      new_state = jax.tree.map(
          lambda new, old: jnp.where(done, old, new),
          next_state,
          state
      )

      reward = jnp.where(done, 0.0, next_state.reward)

      return obs, new_state, reward, done, {}
# Out:
# E0605 20:17:36.501745  197026 cuda_executor.cc:1526] Could not get kernel mode driver version: (INVALID_ARGUMENT: Version does not match the format X.Y.Z)
# E0605 20:17:36.518737  196918 cuda_executor.cc:1526] Could not get kernel mode driver version: (INVALID_ARGUMENT: Version does not match the format X.Y.Z)
# These device(s) are detected: [CudaDevice(id=0)]
# Failed to import warp: No module named 'warp'
# Failed to import mujoco_warp: No module named 'warp'

# %%
brax_env = BraxGymnaxWrapper('inverted_pendulum', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=1, max_nodes= 15)
# Out:
# /home/theun/yes/envs/modi_kozax/lib/python3.12/site-packages/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated)
# Compiling code for evaluation and evolution...
# Finished compilation in 107.36 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: -7.25, equation: [-0.0638]
# Complexity: 2, fitness: -93.875, equation: [sin(y3)]
# Complexity: 4, fitness: -233.375, equation: [y1 + sin(y1)]
# Complexity: 5, fitness: -252.8125, equation: [3.42*y1]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [y0*(y2 + y3) + y1]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [y0*(y2 + y3) + y1]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [y0*(y0 + y2) + y1]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [y0*(y0 + y2) + y1]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -281.3125, equation: [0.15*y0 + y1]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [y0*(y0 + y2) + y1]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -281.3125, equation: [0.15*y0 + y1]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -281.3125, equation: [0.15*y0 + y1]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# Final pareto front:
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]

# %%
brax_env = BraxGymnaxWrapper('inverted_double_pendulum', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=1, max_nodes= 15)
# Out:
# /home/theun/yes/envs/modi_kozax/lib/python3.12/site-packages/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated)
# Compiling code for evaluation and evolution...
# Finished compilation in 103.96 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: -184.10488891601562, equation: [-0.0638]
# Complexity: 2, fitness: -440.75897216796875, equation: [sin(y1)]
# Complexity: 3, fitness: -775.4652709960938, equation: [y2 - y7]
# Complexity: 7, fitness: -1006.9361572265625, equation: [0.486*y7*(y7 - 1.94)]
# Complexity: 9, fitness: -1246.233154296875, equation: [(y1 - 0.743)*(y2 + y4*y7)]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -424.4704895019531, equation: [y6]
# Complexity: 2, fitness: -440.75897216796875, equation: [sin(y1)]
# Complexity: 3, fitness: -815.1287231445312, equation: [y1 - y7]
# Complexity: 7, fitness: -1006.9361572265625, equation: [0.486*y7*(y7 - 1.94)]
# Complexity: 9, fitness: -1246.233154296875, equation: [(y1 - 0.743)*(y2 + y4*y7)]
# Complexity: 15, fitness: -2016.470703125, equation: [(y0**2 + y2)*(y3*y6 + 2*y5 - 1.76)]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -908.64208984375, equation: [y5 - y7]
# Complexity: 5, fitness: -7236.8759765625, equation: [y2*(y7 - 1.94)]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -908.64208984375, equation: [y5 - y7]
# Complexity: 4, fitness: -1091.970947265625, equation: [-sin(0.956*y7)]
# Complexity: 5, fitness: -7236.8759765625, equation: [y2*(y7 - 1.94)]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -908.64208984375, equation: [y5 - y7]
# Complexity: 4, fitness: -1091.970947265625, equation: [-sin(0.956*y7)]
# Complexity: 5, fitness: -7236.8759765625, equation: [y2*(y7 - 1.94)]
# Complexity: 7, fitness: -8323.716796875, equation: [y2*(y2 + y6 - 1.94)]
# Complexity: 9, fitness: -9356.68359375, equation: [y2*(y1*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -908.64208984375, equation: [y5 - y7]
# Complexity: 4, fitness: -1091.970947265625, equation: [-sin(0.956*y7)]
# Complexity: 5, fitness: -7236.8759765625, equation: [y2*(y7 - 1.94)]
# Complexity: 7, fitness: -9174.5078125, equation: [y2*(y2*y6 - 1.94)]
# Complexity: 9, fitness: -9356.68359375, equation: [y2*(y1*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -3001.00048828125, equation: [-3.88*y2]
# Complexity: 5, fitness: -7236.8759765625, equation: [y2*(y7 - 1.94)]
# Complexity: 7, fitness: -9174.5078125, equation: [y2*(y2*y6 - 1.94)]
# Complexity: 9, fitness: -9356.68359375, equation: [y2*(y1*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -3001.00048828125, equation: [-3.88*y2]
# Complexity: 4, fitness: -8868.197265625, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9356.68359375, equation: [y2*(y1*(y2 + y7) - 1.94)]
# Complexity: 13, fitness: -9356.697265625, equation: [y2*(y1*(y1*(y1 - 0.743) + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8708.32421875, equation: [-1.75*y2]
# Complexity: 4, fitness: -8868.197265625, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9356.68359375, equation: [y2*(y1*(y2 + y7) - 1.94)]
# Complexity: 11, fitness: -9356.6875, equation: [y2*(y1*(y2**2 + y7) - 1.94)]
# Complexity: 13, fitness: -9356.697265625, equation: [y2*(y1*(y1*(y1 - 0.743) + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8708.32421875, equation: [-1.75*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.083984375, equation: [y2*(y1*(y0 + y7) - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8708.32421875, equation: [-1.75*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9357.783203125, equation: [y2*(-4.12*y2*y7 - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9358.1240234375, equation: [y2*(-2.88*y0*y7 - 1.94)]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9358.1240234375, equation: [y2*(-2.88*y0*y7 - 1.94)]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9358.1240234375, equation: [y2*(-2.88*y0*y7 - 1.94)]
# Complexity: 13, fitness: -9358.2861328125, equation: [y2*(y7*(-3.88*y0 + y7**2) - 1.94)]
# Complexity: 15, fitness: -9358.505859375, equation: [y2*(2*y7*(-1.13*y0 + 2*y6) - 1.94)]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9358.1240234375, equation: [y2*(-2.88*y0*y7 - 1.94)]
# Complexity: 13, fitness: -9358.2861328125, equation: [y2*(y7*(-3.88*y0 + y7**2) - 1.94)]
# Complexity: 15, fitness: -9358.544921875, equation: [y2*(2*y7*(-3.88*y0 + 2*y6) - 1.94)]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9358.1240234375, equation: [y2*(-2.88*y0*y7 - 1.94)]
# Complexity: 13, fitness: -9358.2939453125, equation: [y2*(-4.12*y2*(y0 + y7) - 1.94)]
# Complexity: 15, fitness: -9358.544921875, equation: [y2*(2*y7*(-3.88*y0 + 2*y6) - 1.94)]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.7294921875, equation: [y2*(-1.94*y0*y7 - 1.94)]
# Complexity: 11, fitness: -9358.1240234375, equation: [y2*(-2.88*y0*y7 - 1.94)]
# Complexity: 13, fitness: -9358.412109375, equation: [y2*(-3.88*y0*y4*(y2 + y7) - 1.94)]
# Complexity: 15, fitness: -9358.544921875, equation: [y2*(2*y7*(-3.88*y0 + 2*y6) - 1.94)]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.7294921875, equation: [y2*(-1.94*y0*y7 - 1.94)]
# Complexity: 11, fitness: -9358.1240234375, equation: [y2*(-2.88*y0*y7 - 1.94)]
# Complexity: 13, fitness: -9358.412109375, equation: [y2*(-3.88*y0*y4*(y2 + y7) - 1.94)]
# Complexity: 15, fitness: -9358.677734375, equation: [y2*((y0 + y7)*(y5 + y6 - 1.94*y7) - 1.94)]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.7294921875, equation: [y2*(-1.94*y0*y7 - 1.94)]
# Complexity: 11, fitness: -9358.1240234375, equation: [y2*(-2.88*y0*y7 - 1.94)]
# Complexity: 13, fitness: -9358.466796875, equation: [y2*(y7*(-3.88*y0 + y1 + y6) - 1.94)]
# Complexity: 15, fitness: -9358.677734375, equation: [y2*((y0 + y7)*(y5 + y6 - 1.94*y7) - 1.94)]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9358.28125, equation: [y2*(-3.7*y0*y7 - 1.94)]
# Complexity: 13, fitness: -9358.466796875, equation: [y2*(y7*(-3.88*y0 + y1 + y6) - 1.94)]
# Complexity: 15, fitness: -9358.677734375, equation: [y2*((y0 + y7)*(y5 + y6 - 1.94*y7) - 1.94)]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9358.28125, equation: [y2*(-3.7*y0*y7 - 1.94)]
# Complexity: 13, fitness: -9358.466796875, equation: [y2*(y7*(-3.88*y0 + y1 + y6) - 1.94)]
# Complexity: 15, fitness: -9358.677734375, equation: [y2*((y0 + y7)*(y5 + y6 - 1.94*y7) - 1.94)]
# Final pareto front:
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.19921875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9358.28125, equation: [y2*(-3.7*y0*y7 - 1.94)]
# Complexity: 13, fitness: -9358.466796875, equation: [y2*(y7*(-3.88*y0 + y1 + y6) - 1.94)]
# Complexity: 15, fitness: -9358.677734375, equation: [y2*((y0 + y7)*(y5 + y6 - 1.94*y7) - 1.94)]

# %%
brax_env = BraxGymnaxWrapper('reacher', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=2, max_nodes= 15)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated)
# Compiling code for evaluation and evolution...
# Finished compilation in 80.81 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: 530.9840698242188, equation: [0, 0.639]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 4, fitness: 112.74169921875, equation: [0, -sin(y6 - y8)]
# Complexity: 9, fitness: 107.21183013916016, equation: [0, y5*(y0*y8 - y6 + y7)]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 4, fitness: 112.7186050415039, equation: [0, sin(y0*y8)]
# Complexity: 5, fitness: 93.0948257446289, equation: [y0*y8*y9, y0*y8]
# Complexity: 9, fitness: 80.26565551757812, equation: [0, y5*(y0*y8 + y6*y7)]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 7, fitness: 80.15457153320312, equation: [0, 0.157*y5*y8**2 + y5*y8]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 7, fitness: 77.84796142578125, equation: [0, y5*(y0*y8 + y8)]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 7, fitness: 77.84796142578125, equation: [0, y5*(y0*y8 + y8)]
# Complexity: 9, fitness: 77.84739685058594, equation: [0, y5*(y0*y8 + y6 + y8)]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 79.76844787597656, equation: [0, 1.16*y5*y8]
# Complexity: 7, fitness: 77.84796142578125, equation: [0, y5*(y0*y8 + y8)]
# Complexity: 9, fitness: 77.84739685058594, equation: [0, y5*(y0*y8 + y6 + y8)]
# Complexity: 11, fitness: 76.91390991210938, equation: [0, y5*y8 + y5*(y0*y8 + y5*y8 + y8)]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 79.76844787597656, equation: [0, 1.16*y5*y8]
# Complexity: 7, fitness: 77.84796142578125, equation: [0, y5*(y0*y8 + y8)]
# Complexity: 9, fitness: 77.49557495117188, equation: [0, y0*y8*(y5*y8 + y5) + y5*y8]
# Complexity: 11, fitness: 76.91390991210938, equation: [0, y5*y8 + y5*(y0*y8 + y5*y8 + y8)]
# Complexity: 13, fitness: 76.84577941894531, equation: [0, y5**2*(y0*y8 + y5*y8 + y8) + y5*y8 + y5*(y0*y8 + y5*y8 + y8)]
# Complexity: 15, fitness: 76.77259826660156, equation: [0, 0.0495*y5*y8**3 + 0.157*y5*y8**2 + 3*y5*y8]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 77.89115905761719, equation: [0, 2*y8*sin(y5)]
# Complexity: 7, fitness: 77.84796142578125, equation: [0, y5*(y0*y8 + y8)]
# Complexity: 9, fitness: 76.90570831298828, equation: [0, y5*y8 + y5*(y5*y8 + 2*y8)]
# Complexity: 11, fitness: 76.89031982421875, equation: [0, 0.315*y5*y8**2 + 3*y5*y8]
# Complexity: 13, fitness: 76.392333984375, equation: [0, y5*y8 + y5*(y0*y8 + y5*y8 + 2*y8)]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 11, fitness: 76.2818374633789, equation: [0, y5*y8 + y5*(y2 + y5*y8 + 2*y8)]
# Complexity: 15, fitness: 76.26962280273438, equation: [0, 2*y5*y8 + (y5*y8 + y5)*(y0*y8 + y5*y8 + y8)]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 10, fitness: 76.19766998291016, equation: [0, y5*y8 + y5*(y5*y8 + 2*y8) + sin(y5*(y5*y8 + 2*y8))]
# Complexity: 12, fitness: 76.07217407226562, equation: [0, y5*(y10 + 3*y8) + y8*sin(y5*(y10 + 3*y8)) + sin(y5*(y10 + 3*y8))]
# Complexity: 13, fitness: 74.62725830078125, equation: [0, y0*y5*(y3*y9 + y8) + y5*(y3*y9 + y8)]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 9, fitness: 76.13151550292969, equation: [0, y10 + 6*y5*y8]
# Complexity: 12, fitness: 75.82405090332031, equation: [0, y5*(y5*y9 + 3*y8) + sin(y5*(y5*y9 + 3*y8))]
# Complexity: 13, fitness: 74.62725830078125, equation: [0, y0*y5*(y3*y9 + y8) + y5*(y3*y9 + y8)]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 8, fitness: 76.27621459960938, equation: [0, 2*y5*y8 + y8*sin(2*y5*y8) + sin(2*y5*y8)]
# Complexity: 9, fitness: 76.13151550292969, equation: [0, y10 + 6*y5*y8]
# Complexity: 10, fitness: 76.07099914550781, equation: [0, y5*(y5*y9 + 2*y8) + sin(y5*(y5*y9 + 2*y8))]
# Complexity: 11, fitness: 74.26559448242188, equation: [0, y0*y5*y8*(y3*y9 + y8) + y0*y5*(y3*y9 + y8) + y5*(y3*y9 + y8)]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 8, fitness: 76.13581848144531, equation: [0, 3*y5*y8 + sin(3*y5*y8)]
# Complexity: 9, fitness: 76.13151550292969, equation: [0, y10 + 6*y5*y8]
# Complexity: 10, fitness: 74.18986511230469, equation: [0, y5*(y3*y9 + y8) + y8*sin(y5*(y3*y9 + y8)) + sin(y5*(y3*y9 + y8))]
# Complexity: 15, fitness: 73.46846008300781, equation: [0, y0*(y5*(y3*y9 + y8) + y6) + 2*y5*(y3*y9 + y8) + y6]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 8, fitness: 76.13581848144531, equation: [0, 3*y5*y8 + sin(3*y5*y8)]
# Complexity: 9, fitness: 76.13151550292969, equation: [0, y10 + 6*y5*y8]
# Complexity: 10, fitness: 74.18986511230469, equation: [0, y5*(y3*y9 + y8) + y8*sin(y5*(y3*y9 + y8)) + sin(y5*(y3*y9 + y8))]
# Complexity: 13, fitness: 73.32453918457031, equation: [0, y0*y8*(y5*(y3*y9 + y8) + y6) + y0*(y5*(y3*y9 + y8) + y6) + 2*y5*(y3*y9 + y8) + y6]
# Complexity: 15, fitness: 73.0279541015625, equation: [0, 2*y0*(y5*(y3*y9 + y8) + y6) + 2*y5*(y3*y9 + y8) + y6]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 8, fitness: 76.13581848144531, equation: [0, 3*y5*y8 + sin(3*y5*y8)]
# Complexity: 9, fitness: 75.41658782958984, equation: [0, 1.48*y5*(y3*y9 + y8)]
# Complexity: 10, fitness: 74.18986511230469, equation: [0, y5*(y3*y9 + y8) + y8*sin(y5*(y3*y9 + y8)) + sin(y5*(y3*y9 + y8))]
# Complexity: 11, fitness: 73.46846008300781, equation: [0, y0*(y5*(y3*y9 + y8) + y6) + 2*y5*(y3*y9 + y8) + y6]
# Complexity: 12, fitness: 71.93646240234375, equation: [0, y4*y8*sin(y5*(y3*y9 + y8)) + y4*y8 + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 8, fitness: 76.13581848144531, equation: [0, 3*y5*y8 + sin(3*y5*y8)]
# Complexity: 9, fitness: 74.58551025390625, equation: [0, 2*y5*(y3*y9 + y8) + y6]
# Complexity: 10, fitness: 74.18986511230469, equation: [0, y5*(y3*y9 + y8) + y8*sin(y5*(y3*y9 + y8)) + sin(y5*(y3*y9 + y8))]
# Complexity: 11, fitness: 73.33013153076172, equation: [0, y5*(y3*y9 + y8) + y8*sin(sin(y5*(y3*y9 + y8))) + sin(y5*(y3*y9 + y8)) + sin(sin(y5*(y3*y9 + y8)))]
# Complexity: 12, fitness: 71.93646240234375, equation: [0, y4*y8*sin(y5*(y3*y9 + y8)) + y4*y8 + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 8, fitness: 76.13581848144531, equation: [0, 3*y5*y8 + sin(3*y5*y8)]
# Complexity: 9, fitness: 74.58551025390625, equation: [0, 2*y5*(y3*y9 + y8) + y6]
# Complexity: 10, fitness: 74.18986511230469, equation: [0, y5*(y3*y9 + y8) + y8*sin(y5*(y3*y9 + y8)) + sin(y5*(y3*y9 + y8))]
# Complexity: 11, fitness: 73.33013153076172, equation: [0, y5*(y3*y9 + y8) + y8*sin(sin(y5*(y3*y9 + y8))) + sin(y5*(y3*y9 + y8)) + sin(sin(y5*(y3*y9 + y8)))]
# Complexity: 12, fitness: 71.93646240234375, equation: [0, y4*y8*sin(y5*(y3*y9 + y8)) + y4*y8 + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# Complexity: 14, fitness: 71.9364013671875, equation: [0, y4*(y6 + y8)*sin(y5*(y3*y9 + y8)) + y4*(y6 + y8) + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 8, fitness: 76.13581848144531, equation: [0, 3*y5*y8 + sin(3*y5*y8)]
# Complexity: 9, fitness: 74.58551025390625, equation: [0, 2*y5*(y3*y9 + y8) + y6]
# Complexity: 10, fitness: 74.18986511230469, equation: [0, y5*(y3*y9 + y8) + y8*sin(y5*(y3*y9 + y8)) + sin(y5*(y3*y9 + y8))]
# Complexity: 11, fitness: 73.33013153076172, equation: [0, y5*(y3*y9 + y8) + y8*sin(sin(y5*(y3*y9 + y8))) + sin(y5*(y3*y9 + y8)) + sin(sin(y5*(y3*y9 + y8)))]
# Complexity: 12, fitness: 71.93646240234375, equation: [0, y4*y8*sin(y5*(y3*y9 + y8)) + y4*y8 + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# Complexity: 14, fitness: 71.9364013671875, equation: [0, y4*(y6 + y8)*sin(y5*(y3*y9 + y8)) + y4*(y6 + y8) + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 8, fitness: 76.13581848144531, equation: [0, 3*y5*y8 + sin(3*y5*y8)]
# Complexity: 9, fitness: 74.58551025390625, equation: [0, 2*y5*(y3*y9 + y8) + y6]
# Complexity: 10, fitness: 74.18986511230469, equation: [0, y5*(y3*y9 + y8) + y8*sin(y5*(y3*y9 + y8)) + sin(y5*(y3*y9 + y8))]
# Complexity: 11, fitness: 73.33013153076172, equation: [0, y5*(y3*y9 + y8) + y8*sin(sin(y5*(y3*y9 + y8))) + sin(y5*(y3*y9 + y8)) + sin(sin(y5*(y3*y9 + y8)))]
# Complexity: 12, fitness: 71.93646240234375, equation: [0, y4*y8*sin(y5*(y3*y9 + y8)) + y4*y8 + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# Complexity: 14, fitness: 71.9364013671875, equation: [0, y4*(y6 + y8)*sin(y5*(y3*y9 + y8)) + y4*(y6 + y8) + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 8, fitness: 76.13581848144531, equation: [0, 3*y5*y8 + sin(3*y5*y8)]
# Complexity: 9, fitness: 74.58551025390625, equation: [0, 2*y5*(y3*y9 + y8) + y6]
# Complexity: 10, fitness: 74.09478759765625, equation: [0, y1*sin(y5*(y3*y9 + y8)) + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# Complexity: 11, fitness: 73.33013153076172, equation: [0, y5*(y3*y9 + y8) + y8*sin(sin(y5*(y3*y9 + y8))) + sin(y5*(y3*y9 + y8)) + sin(sin(y5*(y3*y9 + y8)))]
# Complexity: 12, fitness: 71.93646240234375, equation: [0, y4*y8*sin(y5*(y3*y9 + y8)) + y4*y8 + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# Complexity: 14, fitness: 71.13693237304688, equation: [0, y4*y8*sin(y5*(y3*y9 + y8) + y6) + y4*y8 + 2*y5*(y3*y9 + y8) + y6 + sin(y5*(y3*y9 + y8) + y6)]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.84796142578125, equation: [0, y0*y5*y8 + y5*y8]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 8, fitness: 76.13581848144531, equation: [0, 3*y5*y8 + sin(3*y5*y8)]
# Complexity: 9, fitness: 74.58551025390625, equation: [0, 2*y5*(y3*y9 + y8) + y6]
# Complexity: 10, fitness: 74.09478759765625, equation: [0, y1*sin(y5*(y3*y9 + y8)) + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# Complexity: 11, fitness: 73.33013153076172, equation: [0, y5*(y3*y9 + y8) + y8*sin(sin(y5*(y3*y9 + y8))) + sin(y5*(y3*y9 + y8)) + sin(sin(y5*(y3*y9 + y8)))]
# Complexity: 12, fitness: 71.93646240234375, equation: [0, y4*y8*sin(y5*(y3*y9 + y8)) + y4*y8 + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# Complexity: 13, fitness: 71.93352508544922, equation: [0, y4*y8*(y5*(y3*y9 + y8) + y6) + y4*y8 + 2*y5*(y3*y9 + y8) + y6]
# Complexity: 14, fitness: 71.13693237304688, equation: [0, y4*y8*sin(y5*(y3*y9 + y8) + y6) + y4*y8 + 2*y5*(y3*y9 + y8) + y6 + sin(y5*(y3*y9 + y8) + y6)]
# Complexity: 15, fitness: 70.86410522460938, equation: [0, y4*y8*sin(sin(y5*(y3*y9 + y8) + y6)) + y4*y8 + 2*y5*(y3*y9 + y8) + y6 + sin(y5*(y3*y9 + y8) + y6) + sin(sin(y5*(y3*y9 + y8) + y6))]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.46229553222656, equation: [0, 2.32*y5*y8]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 8, fitness: 76.13581848144531, equation: [0, 3*y5*y8 + sin(3*y5*y8)]
# Complexity: 9, fitness: 74.58551025390625, equation: [0, 2*y5*(y3*y9 + y8) + y6]
# Complexity: 10, fitness: 74.09478759765625, equation: [0, y1*sin(y5*(y3*y9 + y8)) + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# Complexity: 11, fitness: 73.33013153076172, equation: [0, y5*(y3*y9 + y8) + y8*sin(sin(y5*(y3*y9 + y8))) + sin(y5*(y3*y9 + y8)) + sin(sin(y5*(y3*y9 + y8)))]
# Complexity: 12, fitness: 71.93646240234375, equation: [0, y4*y8*sin(y5*(y3*y9 + y8)) + y4*y8 + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# Complexity: 13, fitness: 71.93352508544922, equation: [0, y4*y8*(y5*(y3*y9 + y8) + y6) + y4*y8 + 2*y5*(y3*y9 + y8) + y6]
# Complexity: 14, fitness: 71.13693237304688, equation: [0, y4*y8*sin(y5*(y3*y9 + y8) + y6) + y4*y8 + 2*y5*(y3*y9 + y8) + y6 + sin(y5*(y3*y9 + y8) + y6)]
# Complexity: 15, fitness: 70.86410522460938, equation: [0, y4*y8*sin(sin(y5*(y3*y9 + y8) + y6)) + y4*y8 + 2*y5*(y3*y9 + y8) + y6 + sin(y5*(y3*y9 + y8) + y6) + sin(sin(y5*(y3*y9 + y8) + y6))]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.46229553222656, equation: [0, 2.32*y5*y8]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 8, fitness: 76.13581848144531, equation: [0, 3*y5*y8 + sin(3*y5*y8)]
# Complexity: 9, fitness: 74.58551025390625, equation: [0, 2*y5*(y3*y9 + y8) + y6]
# Complexity: 10, fitness: 73.48805236816406, equation: [0, 2*y5*(y3*y9 + y8) + y6 + sin(y5*(y3*y9 + y8) + y6)]
# Complexity: 11, fitness: 73.33013153076172, equation: [0, y5*(y3*y9 + y8) + y8*sin(sin(y5*(y3*y9 + y8))) + sin(y5*(y3*y9 + y8)) + sin(sin(y5*(y3*y9 + y8)))]
# Complexity: 12, fitness: 71.93646240234375, equation: [0, y4*y8*sin(y5*(y3*y9 + y8)) + y4*y8 + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# Complexity: 13, fitness: 71.93352508544922, equation: [0, y4*y8*(y5*(y3*y9 + y8) + y6) + y4*y8 + 2*y5*(y3*y9 + y8) + y6]
# Complexity: 14, fitness: 71.13693237304688, equation: [0, y4*y8*sin(y5*(y3*y9 + y8) + y6) + y4*y8 + 2*y5*(y3*y9 + y8) + y6 + sin(y5*(y3*y9 + y8) + y6)]
# Complexity: 15, fitness: 70.86410522460938, equation: [0, y4*y8*sin(sin(y5*(y3*y9 + y8) + y6)) + y4*y8 + 2*y5*(y3*y9 + y8) + y6 + sin(y5*(y3*y9 + y8) + y6) + sin(sin(y5*(y3*y9 + y8) + y6))]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.42357635498047, equation: [0, 2.42*y5*y8]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 8, fitness: 76.13581848144531, equation: [0, 3*y5*y8 + sin(3*y5*y8)]
# Complexity: 9, fitness: 74.58551025390625, equation: [0, 2*y5*(y3*y9 + y8) + y6]
# Complexity: 10, fitness: 73.48805236816406, equation: [0, 2*y5*(y3*y9 + y8) + y6 + sin(y5*(y3*y9 + y8) + y6)]
# Complexity: 11, fitness: 73.33013153076172, equation: [0, y5*(y3*y9 + y8) + y8*sin(sin(y5*(y3*y9 + y8))) + sin(y5*(y3*y9 + y8)) + sin(sin(y5*(y3*y9 + y8)))]
# Complexity: 12, fitness: 71.93646240234375, equation: [0, y4*y8*sin(y5*(y3*y9 + y8)) + y4*y8 + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# Complexity: 13, fitness: 71.93352508544922, equation: [0, y4*y8*(y5*(y3*y9 + y8) + y6) + y4*y8 + 2*y5*(y3*y9 + y8) + y6]
# Complexity: 14, fitness: 70.86555480957031, equation: [0, y4*y8*sin(sin(sin(y5*(y3*y9 + y8)))) + y4*y8 + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8)) + sin(sin(y5*(y3*y9 + y8))) + sin(sin(sin(y5*(y3*y9 + y8))))]
# Complexity: 15, fitness: 70.86410522460938, equation: [0, y4*y8*sin(sin(y5*(y3*y9 + y8) + y6)) + y4*y8 + 2*y5*(y3*y9 + y8) + y6 + sin(y5*(y3*y9 + y8) + y6) + sin(sin(y5*(y3*y9 + y8) + y6))]
# Final pareto front:
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 4, fitness: 77.93618774414062, equation: [0, y5*y8 + sin(y5*y8)]
# Complexity: 5, fitness: 77.42357635498047, equation: [0, 2.42*y5*y8]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 8, fitness: 76.13581848144531, equation: [0, 3*y5*y8 + sin(3*y5*y8)]
# Complexity: 9, fitness: 74.58551025390625, equation: [0, 2*y5*(y3*y9 + y8) + y6]
# Complexity: 10, fitness: 73.48805236816406, equation: [0, 2*y5*(y3*y9 + y8) + y6 + sin(y5*(y3*y9 + y8) + y6)]
# Complexity: 11, fitness: 73.33013153076172, equation: [0, y5*(y3*y9 + y8) + y8*sin(sin(y5*(y3*y9 + y8))) + sin(y5*(y3*y9 + y8)) + sin(sin(y5*(y3*y9 + y8)))]
# Complexity: 12, fitness: 71.93646240234375, equation: [0, y4*y8*sin(y5*(y3*y9 + y8)) + y4*y8 + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8))]
# Complexity: 13, fitness: 71.93352508544922, equation: [0, y4*y8*(y5*(y3*y9 + y8) + y6) + y4*y8 + 2*y5*(y3*y9 + y8) + y6]
# Complexity: 14, fitness: 70.86555480957031, equation: [0, y4*y8*sin(sin(sin(y5*(y3*y9 + y8)))) + y4*y8 + y5*(y3*y9 + y8) + sin(y5*(y3*y9 + y8)) + sin(sin(y5*(y3*y9 + y8))) + sin(sin(sin(y5*(y3*y9 + y8))))]
# Complexity: 15, fitness: 70.86410522460938, equation: [0, y4*y8*sin(sin(y5*(y3*y9 + y8) + y6)) + y4*y8 + 2*y5*(y3*y9 + y8) + y6 + sin(y5*(y3*y9 + y8) + y6) + sin(sin(y5*(y3*y9 + y8) + y6))]

# %%
brax_env = BraxGymnaxWrapper('swimmer', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=2, max_nodes= 15)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated)
# Compiling code for evaluation and evolution...
# Finished compilation in 81.42 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: 5.379508972167969, equation: [-0.0638, 0]
# Complexity: 2, fitness: -11.424619674682617, equation: [0, sin(y6)]
# Complexity: 3, fitness: -23.38439178466797, equation: [0, y6 + y7]
# Complexity: 5, fitness: -27.639122009277344, equation: [cos(y4), sin(y3*cos(y4))]
# Complexity: 6, fitness: -42.69431686401367, equation: [y6 + 0.596, -y4 + sin(y6 + 0.596)]
# Complexity: 7, fitness: -71.54219818115234, equation: [y2*y7 + y4, y2*y7 + y4 + y5]
# Complexity: 8, fitness: -79.88739776611328, equation: [cos(y1 + y5), y1*y2 + cos(y1 + y5)]
# Complexity: 9, fitness: -101.94956970214844, equation: [y0 + y1 + y3, y0 + y1]
# Complexity: 12, fitness: -154.68130493164062, equation: [y6 + y7, -0.572*y0 + y1 + y6 + y7 + sin(y6)]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -11.617633819580078, equation: [0, y4]
# Complexity: 3, fitness: -23.38439178466797, equation: [0, y6 + y7]
# Complexity: 5, fitness: -28.993017196655273, equation: [1.01*y1, 1.01*y1 + y4]
# Complexity: 6, fitness: -86.6681137084961, equation: [y3 + y4, y3 + y4 + sin(y7)]
# Complexity: 7, fitness: -94.85042572021484, equation: [y6*sin(y4) + sin(y6), sin(y4)]
# Complexity: 9, fitness: -101.94956970214844, equation: [y0 + y1 + y3, y0 + y1]
# Complexity: 11, fitness: -157.048583984375, equation: [y6 + y7, -0.572*y0 + y1 + y4 + y6 + y7]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -37.07846450805664, equation: [0, y1 - y4]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.82307434082031, equation: [0, y1 + y5]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.82307434082031, equation: [0, y1 + y5]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 10, fitness: -274.31671142578125, equation: [y0 + y6, y0*sin(y7) + y0 + y1 + y6]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.82307434082031, equation: [0, y1 + y5]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 7, fitness: -287.9432678222656, equation: [2*y0 + y1 + y4, y1 + y4]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.82307434082031, equation: [0, y1 + y5]
# Complexity: 4, fitness: -45.147682189941406, equation: [cos(y6), y4*cos(y6)]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 7, fitness: -287.9432678222656, equation: [2*y0 + y1 + y4, y1 + y4]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.82307434082031, equation: [0, y1 + y5]
# Complexity: 4, fitness: -45.147682189941406, equation: [cos(y6), y4*cos(y6)]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 7, fitness: -287.9432678222656, equation: [2*y0 + y1 + y4, y1 + y4]
# Complexity: 11, fitness: -340.45819091796875, equation: [4*y0 + 2*y1 + 1.29*y6, y1 + 0.647*y6]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.82307434082031, equation: [0, y1 + y5]
# Complexity: 4, fitness: -45.147682189941406, equation: [cos(y6), y4*cos(y6)]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 7, fitness: -287.9433288574219, equation: [2*y0 + y1 + y4, y1 + y4]
# Complexity: 9, fitness: -359.3166198730469, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.82307434082031, equation: [0, y1 + y5]
# Complexity: 4, fitness: -45.147682189941406, equation: [cos(y6), y4*cos(y6)]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 7, fitness: -324.7623291015625, equation: [2*y0 + y1 + y6, y1 + y6]
# Complexity: 9, fitness: -359.3166198730469, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.82307434082031, equation: [0, y1 + y5]
# Complexity: 4, fitness: -45.147682189941406, equation: [cos(y6), y4*cos(y6)]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 7, fitness: -324.7625427246094, equation: [2*y0 + y1 + y6, y1 + y6]
# Complexity: 9, fitness: -359.34320068359375, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# Complexity: 15, fitness: -359.4286804199219, equation: [2*y0 - 0.503*y1*y3 + y1 - 0.503*y2 + y4, 0.497*y1*y3 + y1 - 0.503*y2 + y4]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.82307434082031, equation: [0, y1 + y5]
# Complexity: 4, fitness: -45.147682189941406, equation: [cos(y6), y4*cos(y6)]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 7, fitness: -324.7625427246094, equation: [2*y0 + y1 + y6, y1 + y6]
# Complexity: 9, fitness: -359.34320068359375, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# Complexity: 15, fitness: -359.4287109375, equation: [2*y0 - 0.503*y1*y3 + y1 - 0.503*y2 + y4, 0.497*y1*y3 + y1 - 0.503*y2 + y4]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -144.25289916992188, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 7, fitness: -340.33514404296875, equation: [2*y0 + y1 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -359.34320068359375, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# Complexity: 15, fitness: -359.4287109375, equation: [2*y0 - 0.503*y1*y3 + y1 - 0.503*y2 + y4, 0.497*y1*y3 + y1 - 0.503*y2 + y4]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -144.25289916992188, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -319.5538330078125, equation: [y0 + sin(y1 + y4), y1 + y4]
# Complexity: 7, fitness: -340.33514404296875, equation: [2*y0 + y1 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -359.34320068359375, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# Complexity: 15, fitness: -359.4287414550781, equation: [2*y0 - 0.503*y1*y3 + y1 - 0.503*y2 + y4, 0.497*y1*y3 + y1 - 0.503*y2 + y4]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -144.25289916992188, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -322.8556213378906, equation: [y0 + sin(y1 + y6), y1 + y6]
# Complexity: 7, fitness: -340.33514404296875, equation: [2*y0 + y1 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -359.3763427734375, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# Complexity: 15, fitness: -362.1526184082031, equation: [2*y0 + y1 - 0.503*y2 - 0.503*y3*y4 + y4, y1 - 0.503*y2 + 0.497*y3*y4 + y4]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -144.25289916992188, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -322.8556213378906, equation: [y0 + sin(y1 + y6), y1 + y6]
# Complexity: 7, fitness: -340.33514404296875, equation: [2*y0 + y1 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -359.3763427734375, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# Complexity: 15, fitness: -362.1526184082031, equation: [2*y0 + y1 - 0.503*y2 - 0.503*y3*y4 + y4, y1 - 0.503*y2 + 0.497*y3*y4 + y4]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -144.25289916992188, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -322.8556213378906, equation: [y0 + sin(y1 + y6), y1 + y6]
# Complexity: 7, fitness: -340.33514404296875, equation: [2*y0 + y1 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -359.3763427734375, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# Complexity: 15, fitness: -362.1526184082031, equation: [2*y0 + y1 - 0.503*y2 - 0.503*y3*y4 + y4, y1 - 0.503*y2 + 0.497*y3*y4 + y4]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -144.25289916992188, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -322.8556213378906, equation: [y0 + sin(y1 + y6), y1 + y6]
# Complexity: 7, fitness: -340.33514404296875, equation: [2*y0 + y1 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -359.3763427734375, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# Complexity: 10, fitness: -360.33380126953125, equation: [3*y0 + y1 + y4 + y5 + 2*sin(y0 + y1 + y4), y1 + y4 + sin(y0 + y1 + y4)]
# Complexity: 15, fitness: -362.1526184082031, equation: [2*y0 + y1 - 0.503*y2 - 0.503*y3*y4 + y4, y1 - 0.503*y2 + 0.497*y3*y4 + y4]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -144.25289916992188, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -322.8556213378906, equation: [y0 + sin(y1 + y6), y1 + y6]
# Complexity: 7, fitness: -340.33514404296875, equation: [2*y0 + y1 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -359.3763427734375, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# Complexity: 10, fitness: -360.3338623046875, equation: [3*y0 + y1 + y4 + y5 + 2*sin(y0 + y1 + y4), y1 + y4 + sin(y0 + y1 + y4)]
# Complexity: 15, fitness: -362.1526184082031, equation: [2*y0 + y1 - 0.503*y2 - 0.503*y3*y4 + y4, y1 - 0.503*y2 + 0.497*y3*y4 + y4]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -144.25289916992188, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -322.8556213378906, equation: [y0 + sin(y1 + y6), y1 + y6]
# Complexity: 7, fitness: -340.33514404296875, equation: [2*y0 + y1 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -359.3763427734375, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# Complexity: 10, fitness: -360.3338623046875, equation: [3*y0 + y1 + y4 + y5 + 2*sin(y0 + y1 + y4), y1 + y4 + sin(y0 + y1 + y4)]
# Complexity: 11, fitness: -361.8644104003906, equation: [2*y0 + y1 + 0.497*y6, y1 + 0.497*y6]
# Complexity: 15, fitness: -362.1526794433594, equation: [2*y0 + y1 - 0.503*y2 - 0.503*y3*y4 + y4, y1 - 0.503*y2 + 0.497*y3*y4 + y4]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -144.25289916992188, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -322.8556213378906, equation: [y0 + sin(y1 + y6), y1 + y6]
# Complexity: 7, fitness: -340.33514404296875, equation: [2*y0 + y1 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -359.3763427734375, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# Complexity: 10, fitness: -360.3338623046875, equation: [3*y0 + y1 + y4 + y5 + 2*sin(y0 + y1 + y4), y1 + y4 + sin(y0 + y1 + y4)]
# Complexity: 11, fitness: -361.8644104003906, equation: [2*y0 + y1 + 0.497*y6, y1 + 0.497*y6]
# Complexity: 15, fitness: -362.1527099609375, equation: [2*y0 + y1 - 0.503*y2 - 0.503*y3*y4 + y4, y1 - 0.503*y2 + 0.497*y3*y4 + y4]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -144.25289916992188, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -322.8556213378906, equation: [y0 + sin(y1 + y6), y1 + y6]
# Complexity: 7, fitness: -340.33514404296875, equation: [2*y0 + y1 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -359.3763427734375, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# Complexity: 10, fitness: -360.3338623046875, equation: [3*y0 + y1 + y4 + y5 + 2*sin(y0 + y1 + y4), y1 + y4 + sin(y0 + y1 + y4)]
# Complexity: 11, fitness: -361.8644104003906, equation: [2*y0 + y1 + 0.497*y6, y1 + 0.497*y6]
# Complexity: 15, fitness: -362.1527099609375, equation: [2*y0 + y1 - 0.503*y2 - 0.503*y3*y4 + y4, y1 - 0.503*y2 + 0.497*y3*y4 + y4]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -144.25289916992188, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -322.8556213378906, equation: [y0 + sin(y1 + y6), y1 + y6]
# Complexity: 7, fitness: -340.33514404296875, equation: [2*y0 + y1 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -359.3763427734375, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# Complexity: 10, fitness: -360.3338623046875, equation: [3*y0 + y1 + y4 + y5 + 2*sin(y0 + y1 + y4), y1 + y4 + sin(y0 + y1 + y4)]
# Complexity: 11, fitness: -361.8644104003906, equation: [2*y0 + y1 + 0.497*y6, y1 + 0.497*y6]
# Complexity: 15, fitness: -362.1527099609375, equation: [2*y0 + y1 - 0.503*y2 - 0.503*y3*y4 + y4, y1 - 0.503*y2 + 0.497*y3*y4 + y4]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -144.25289916992188, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -322.8556213378906, equation: [y0 + sin(y1 + y6), y1 + y6]
# Complexity: 7, fitness: -349.1854248046875, equation: [2*y0 + y1 + 2*y4 + y5, y0 + y1 + y4]
# Complexity: 9, fitness: -359.3763427734375, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# Complexity: 10, fitness: -360.3338623046875, equation: [3*y0 + y1 + y4 + y5 + 2*sin(y0 + y1 + y4), y1 + y4 + sin(y0 + y1 + y4)]
# Complexity: 11, fitness: -361.86444091796875, equation: [2*y0 + y1 + 0.497*y6, y1 + 0.497*y6]
# Complexity: 12, fitness: -363.282958984375, equation: [3*y4 + 3*y5 + 3*sin(y0 + y1 + y4), y1 + y4 + sin(y0 + y1 + y4)]
# Complexity: 15, fitness: -363.7976989746094, equation: [5*y0 - 0.509*y3*y7 + 3.49*y4, 0.497*y3*y7 + 0.497*y4]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -144.25289916992188, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -322.8556213378906, equation: [y0 + sin(y1 + y6), y1 + y6]
# Complexity: 7, fitness: -349.1854248046875, equation: [2*y0 + y1 + 2*y4 + y5, y0 + y1 + y4]
# Complexity: 9, fitness: -359.3763427734375, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# Complexity: 10, fitness: -360.3338623046875, equation: [3*y0 + y1 + y4 + y5 + 2*sin(y0 + y1 + y4), y1 + y4 + sin(y0 + y1 + y4)]
# Complexity: 11, fitness: -361.86444091796875, equation: [2*y0 + y1 + 0.497*y6, y1 + 0.497*y6]
# Complexity: 12, fitness: -363.282958984375, equation: [3*y4 + 3*y5 + 3*sin(y0 + y1 + y4), y1 + y4 + sin(y0 + y1 + y4)]
# Complexity: 15, fitness: -363.7977600097656, equation: [5*y0 - 0.509*y3*y7 + 3.49*y4, 0.497*y3*y7 + 0.497*y4]
# Final pareto front:
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 2, fitness: -26.858558654785156, equation: [0, sin(y7)]
# Complexity: 3, fitness: -144.25289916992188, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -233.14161682128906, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -322.8556213378906, equation: [y0 + sin(y1 + y6), y1 + y6]
# Complexity: 7, fitness: -349.1854248046875, equation: [2*y0 + y1 + 2*y4 + y5, y0 + y1 + y4]
# Complexity: 9, fitness: -359.3763427734375, equation: [2*y0 + 2*y1 + y5 + 1.29*y6, y1 + 0.647*y6]
# Complexity: 10, fitness: -360.3338623046875, equation: [3*y0 + y1 + y4 + y5 + 2*sin(y0 + y1 + y4), y1 + y4 + sin(y0 + y1 + y4)]
# Complexity: 11, fitness: -361.86444091796875, equation: [2*y0 + y1 + 0.497*y6, y1 + 0.497*y6]
# Complexity: 12, fitness: -363.282958984375, equation: [3*y4 + 3*y5 + 3*sin(y0 + y1 + y4), y1 + y4 + sin(y0 + y1 + y4)]
# Complexity: 15, fitness: -363.7977600097656, equation: [5*y0 - 0.509*y3*y7 + 3.49*y4, 0.497*y3*y7 + 0.497*y4]

# %%
brax_env = BraxGymnaxWrapper('hopper', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=3, max_nodes = 15)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated)
# Compiling code for evaluation and evolution...
# Finished compilation in 114.76 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: -220.33328247070312, equation: [0, 0.639, 0]
# Complexity: 3, fitness: -226.26095581054688, equation: [0, y0*y10, 0]
# Complexity: 6, fitness: -368.7633056640625, equation: [0, cos(y10 - y4*y5), -y10 + y4*y5]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -250.21890258789062, equation: [0, y4, 0]
# Complexity: 3, fitness: -275.40057373046875, equation: [0, y3*y8, 0]
# Complexity: 6, fitness: -409.53472900390625, equation: [0, cos(y10 - y4*y8), -y10 + y4*y8]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -250.21890258789062, equation: [0, y4, 0]
# Complexity: 3, fitness: -292.82208251953125, equation: [0, y3*y7, 0]
# Complexity: 6, fitness: -409.53472900390625, equation: [0, cos(y10 - y4*y8), -y10 + y4*y8]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -250.21890258789062, equation: [0, y4, 0]
# Complexity: 3, fitness: -308.75323486328125, equation: [0, y7*y8, 0]
# Complexity: 5, fitness: -331.2342529296875, equation: [y0*y3*y7, y3*y7, 0]
# Complexity: 6, fitness: -414.296142578125, equation: [0, cos(y10*y4 - y10), y10*y4 - y10]
# Complexity: 7, fitness: -447.398193359375, equation: [0, cos(y1*y6 - y10) + cos(cos(y1*y6 - y10)), 2*y1*y6 - y10]
# Complexity: 8, fitness: -619.91650390625, equation: [0, cos(y10 - y8*(y1 + 0.502)), -y10 + y8*(y1 + 0.502)]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 3, fitness: -327.817138671875, equation: [0, -0.337*y7, 0]
# Complexity: 5, fitness: -331.2351989746094, equation: [y0*y3*y7, y3*y7, 0]
# Complexity: 6, fitness: -434.26422119140625, equation: [0, cos(y10 - y6*y8), -y10 + y6*y8]
# Complexity: 7, fitness: -447.398193359375, equation: [0, cos(y1*y6 - y10) + cos(cos(y1*y6 - y10)), 2*y1*y6 - y10]
# Complexity: 8, fitness: -622.97509765625, equation: [0, cos(y10 - y8*(y1 + 0.502)), -y10 + y8*(y1 + 0.502)]
# Complexity: 10, fitness: -1026.56640625, equation: [0, -y1 - y7 + sin(y2*y5), -y1 + y3 - y7 + sin(y2*y5)]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 3, fitness: -327.8214416503906, equation: [0, -0.337*y7, 0]
# Complexity: 5, fitness: -331.2351989746094, equation: [y0*y3*y7, y3*y7, 0]
# Complexity: 6, fitness: -434.26422119140625, equation: [0, cos(y10 - y6*y8), -y10 + y6*y8]
# Complexity: 7, fitness: -749.047119140625, equation: [0, -y1 + y3 - y7, -y1 + 2*y3 - y7]
# Complexity: 10, fitness: -1026.56640625, equation: [0, -y1 - y7 + sin(y2*y5), -y1 + y3 - y7 + sin(y2*y5)]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 3, fitness: -327.82672119140625, equation: [0, -0.337*y7, 0]
# Complexity: 4, fitness: -585.8042602539062, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 7, fitness: -879.6864013671875, equation: [0, sin(cos(y10*y4 - y5)), y10*y4 - y5]
# Complexity: 9, fitness: -1007.0245361328125, equation: [0, -y1 + 2*y2*y6 - y7, -y1 + y2*y6 - y7 + y9]
# Complexity: 10, fitness: -1026.56640625, equation: [0, -y1 - y7 + sin(y2*y5), -y1 + y3 - y7 + sin(y2*y5)]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 6, fitness: -614.5505981445312, equation: [0, cos(y10 - 0.502*y8), -y10 + 0.502*y8]
# Complexity: 7, fitness: -1010.6849365234375, equation: [0, sin(cos(0.771*y10 + y5)), -0.771*y10 - y5]
# Complexity: 10, fitness: -1026.56640625, equation: [0, -y1 - y7 + sin(y2*y5), -y1 + y3 - y7 + sin(y2*y5)]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 6, fitness: -614.5505981445312, equation: [0, cos(y10 - 0.502*y8), -y10 + 0.502*y8]
# Complexity: 7, fitness: -1010.6849365234375, equation: [0, sin(cos(0.771*y10 + y5)), -0.771*y10 - y5]
# Complexity: 10, fitness: -1026.56640625, equation: [0, -y1 - y7 + sin(y2*y5), -y1 + y3 - y7 + sin(y2*y5)]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 6, fitness: -614.5505981445312, equation: [0, cos(y10 - 0.502*y8), -y10 + 0.502*y8]
# Complexity: 7, fitness: -1010.6849365234375, equation: [0, sin(cos(0.771*y10 + y5)), -0.771*y10 - y5]
# Complexity: 9, fitness: -1019.6868896484375, equation: [0, sin(cos(0.771*y10 + y4 + y7)), -0.771*y10 - y4 - y7]
# Complexity: 10, fitness: -1026.56640625, equation: [0, -y1 - y7 + sin(y2*y5), -y1 + y3 - y7 + sin(y2*y5)]
# Complexity: 12, fitness: -1037.60986328125, equation: [0, -y2*y7 + 2*y3*sin(y6) - y7, y3*sin(y6) - y7 + y9]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 5, fitness: -730.8284301757812, equation: [0, y3 - y7, y3 - y7 + y9]
# Complexity: 7, fitness: -1049.197998046875, equation: [0, -y7, -y7 + y9]
# Complexity: 14, fitness: -1049.3365478515625, equation: [0, -y1*y10*y7 + 2*y2*sin(y6) - y7, -y1*y10*y7 + y1*y7 + y2*sin(y6) - y7 + y9]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 5, fitness: -730.8284301757812, equation: [0, y3 - y7, y3 - y7 + y9]
# Complexity: 6, fitness: -867.20947265625, equation: [0, sin(cos(cos(y2 - y5))), y2 - y5]
# Complexity: 7, fitness: -1049.197998046875, equation: [0, -y7, -y7 + y9]
# Complexity: 14, fitness: -1051.9368896484375, equation: [0, -y1*y10*y7 + 2*y2*sin(y6) - y7, -y1*y10*y7 + y1*y7 + y2*sin(y6) - y7 + y9]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.250732421875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 5, fitness: -890.7545166015625, equation: [0, sin(cos(y5 - y8)), -y5 + y8]
# Complexity: 7, fitness: -1049.197998046875, equation: [0, -y7, -y7 + y9]
# Complexity: 13, fitness: -1049.97705078125, equation: [0, 2*y2*y6*(y1 - y10*y7) - y7, y2*y6*(y1 - y10*y7) - y7 + y9]
# Complexity: 14, fitness: -1051.9368896484375, equation: [0, -y1*y10*y7 + 2*y2*sin(y6) - y7, -y1*y10*y7 + y1*y7 + y2*sin(y6) - y7 + y9]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.250732421875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 5, fitness: -890.7545166015625, equation: [0, sin(cos(y5 - y8)), -y5 + y8]
# Complexity: 7, fitness: -1049.197998046875, equation: [0, -y7, -y7 + y9]
# Complexity: 13, fitness: -1049.97705078125, equation: [0, 2*y2*y6*(y1 - y10*y7) - y7, y2*y6*(y1 - y10*y7) - y7 + y9]
# Complexity: 14, fitness: -1068.6741943359375, equation: [0, -y1*y10*y2 + 2*y2*sin(y6) - y7, -y1*y10*y2 + y1*y2 + y2*sin(y6) - y7 + y9]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.250732421875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 5, fitness: -890.7545166015625, equation: [0, sin(cos(y5 - y8)), -y5 + y8]
# Complexity: 7, fitness: -1049.197998046875, equation: [0, -y7, -y7 + y9]
# Complexity: 13, fitness: -1049.97705078125, equation: [0, 2*y2*y6*(y1 - y10*y7) - y7, y2*y6*(y1 - y10*y7) - y7 + y9]
# Complexity: 14, fitness: -1068.6741943359375, equation: [0, -y1*y10*y2 + 2*y2*sin(y6) - y7, -y1*y10*y2 + y1*y2 + y2*sin(y6) - y7 + y9]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.250732421875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 5, fitness: -890.7545166015625, equation: [0, sin(cos(y5 - y8)), -y5 + y8]
# Complexity: 7, fitness: -1049.197998046875, equation: [0, -y7, -y7 + y9]
# Complexity: 12, fitness: -1050.0794677734375, equation: [0, -y1*y10 + 2*y6*sin(y6) - y7, -y1*y10 + y6*sin(y6) - y7 + y9]
# Complexity: 13, fitness: -1053.6812744140625, equation: [0, -y1*y10**2 + 2*y2*y6 - y7, -y1*y10**2 + y1*y10 + y2*y6 - y7 + y9]
# Complexity: 14, fitness: -1068.6741943359375, equation: [0, -y1*y10*y2 + 2*y2*sin(y6) - y7, -y1*y10*y2 + y1*y2 + y2*sin(y6) - y7 + y9]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.250732421875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 5, fitness: -890.7545776367188, equation: [0, sin(cos(y5 - y8)), -y5 + y8]
# Complexity: 7, fitness: -1049.197998046875, equation: [0, -y7, -y7 + y9]
# Complexity: 11, fitness: -1049.630859375, equation: [0, 4*y10*y7**2 - y7, 2*y10*y7**2 - y7 + y9]
# Complexity: 12, fitness: -1050.0794677734375, equation: [0, -y1*y10 + 2*y6*sin(y6) - y7, -y1*y10 + y6*sin(y6) - y7 + y9]
# Complexity: 13, fitness: -1059.491455078125, equation: [0, -y1*y10**2 + 2*y2*y6 - y7, -y1*y10**2 + y1*y10 + y2*y6 - y7 + y9]
# Complexity: 14, fitness: -1071.202392578125, equation: [0, 2*y2*sin(y6) - y7, -y1*(y1 - y10) + y2*sin(y6) - y7 + y9]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.250732421875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 5, fitness: -890.7545776367188, equation: [0, sin(cos(y5 - y8)), -y5 + y8]
# Complexity: 7, fitness: -1066.255615234375, equation: [0, y1*y10 - y7, y1*y10 - y7 + y9]
# Complexity: 14, fitness: -1094.38525390625, equation: [0, 2*y2*sin(y6) - y7, -y1*(y1 - y10) + y2*sin(y6) - y7 + y9]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.250732421875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 5, fitness: -890.7545776367188, equation: [0, sin(cos(y5 - y8)), -y5 + y8]
# Complexity: 7, fitness: -1077.8297119140625, equation: [0, y1*y10 - y7, y1*y10 - y7 + y9]
# Complexity: 14, fitness: -1094.38525390625, equation: [0, 2*y2*sin(y6) - y7, -y1*(y1 - y10) + y2*sin(y6) - y7 + y9]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.250732421875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 5, fitness: -890.7545776367188, equation: [0, sin(cos(y5 - y8)), -y5 + y8]
# Complexity: 7, fitness: -1077.8297119140625, equation: [0, y1*y10 - y7, y1*y10 - y7 + y9]
# Complexity: 14, fitness: -1094.38525390625, equation: [0, 2*y2*sin(y6) - y7, -y1*(y1 - y10) + y2*sin(y6) - y7 + y9]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.250732421875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 5, fitness: -1019.672119140625, equation: [0, -1.32*y7, -1.32*y7 + y9]
# Complexity: 7, fitness: -1077.8297119140625, equation: [0, y1*y10 - y7, y1*y10 - y7 + y9]
# Complexity: 14, fitness: -1094.38525390625, equation: [0, 2*y2*sin(y6) - y7, -y1*(y1 - y10) + y2*sin(y6) - y7 + y9]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.250732421875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 5, fitness: -1019.672119140625, equation: [0, -1.32*y7, -1.32*y7 + y9]
# Complexity: 7, fitness: -1077.8297119140625, equation: [0, y1*y10 - y7, y1*y10 - y7 + y9]
# Complexity: 14, fitness: -1094.38525390625, equation: [0, 2*y2*sin(y6) - y7, -y1*(y1 - y10) + y2*sin(y6) - y7 + y9]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.250732421875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 5, fitness: -1019.672119140625, equation: [0, -1.32*y7, -1.32*y7 + y9]
# Complexity: 7, fitness: -1077.8297119140625, equation: [0, y1*y10 - y7, y1*y10 - y7 + y9]
# Complexity: 14, fitness: -1094.38525390625, equation: [0, 2*y2*sin(y6) - y7, -y1*(y1 - y10) + y2*sin(y6) - y7 + y9]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.250732421875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 5, fitness: -1019.672119140625, equation: [0, -1.32*y7, -1.32*y7 + y9]
# Complexity: 7, fitness: -1077.8297119140625, equation: [0, y1*y10 - y7, y1*y10 - y7 + y9]
# Complexity: 14, fitness: -1094.38525390625, equation: [0, 2*y2*sin(y6) - y7, -y1*(y1 - y10) + y2*sin(y6) - y7 + y9]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.250732421875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 5, fitness: -1019.672119140625, equation: [0, -1.32*y7, -1.32*y7 + y9]
# Complexity: 7, fitness: -1077.8297119140625, equation: [0, y1*y10 - y7, y1*y10 - y7 + y9]
# Complexity: 14, fitness: -1094.38525390625, equation: [0, 2*y2*sin(y6) - y7, -y1*(y1 - y10) + y2*sin(y6) - y7 + y9]
# Final pareto front:
# Complexity: 1, fitness: -250.2201690673828, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.250732421875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.0909729003906, equation: [0, -0.859*y7, 0]
# Complexity: 4, fitness: -586.1187744140625, equation: [0, cos(y10 - y6), -y10 + y6]
# Complexity: 5, fitness: -1019.672119140625, equation: [0, -1.32*y7, -1.32*y7 + y9]
# Complexity: 7, fitness: -1077.8297119140625, equation: [0, y1*y10 - y7, y1*y10 - y7 + y9]
# Complexity: 14, fitness: -1094.38525390625, equation: [0, 2*y2*sin(y6) - y7, -y1*(y1 - y10) + y2*sin(y6) - y7 + y9]
