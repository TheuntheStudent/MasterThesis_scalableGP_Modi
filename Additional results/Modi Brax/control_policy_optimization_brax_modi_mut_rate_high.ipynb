# %%
from genetic_programming import GeneticProgramming
from fitness_functions.Gymnax_fitness_function import GymFitnessFunction

import jax
import jax.numpy as jnp
import jax.random as jr

import brax
from brax import envs
import matplotlib.pyplot as plt

class BraxGymnaxWrapper:
    def __init__(self, env_name, backend):
        self.env = envs.get_environment(env_name=env_name, backend=backend)
        self.observation_space = self.env.observation_size
        self.action_space = self.env.action_size

    # state, env_state = self.env.reset(subkey, self.env_params)

    def reset(self, key, params=None):
        #state consists of pipeline_state, obs, reward, done, metrics, info
        state = self.env.reset(key)
        return state.obs, state

     # next_state, next_env_state, reward, done, _ = self.env.step(
     #            subkey, env_state, action, self.env_params
     #        )

    def step(self, key, state, action, params=None):

      action = action.reshape(self.action_space)
      next_state = self.env.step(state, action)
      done = next_state.done

      # Freeze state after done
      obs = jnp.where(done, state.obs, next_state.obs)
      new_state = jax.tree.map(
          lambda new, old: jnp.where(done, old, new),
          next_state,
          state
      )

      reward = jnp.where(done, 0.0, next_state.reward)

      return obs, new_state, reward, done, {}
# Out:
# E0606 14:07:16.018596  303860 cuda_executor.cc:1526] Could not get kernel mode driver version: (INVALID_ARGUMENT: Version does not match the format X.Y.Z)
# E0606 14:07:16.030356  303752 cuda_executor.cc:1526] Could not get kernel mode driver version: (INVALID_ARGUMENT: Version does not match the format X.Y.Z)
# These device(s) are detected: [CudaDevice(id=0)]
# Failed to import warp: No module named 'warp'
# Failed to import mujoco_warp: No module named 'warp'

# %%
brax_env = BraxGymnaxWrapper('inverted_pendulum', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=1, max_nodes= 15)
# Out:
# /home/theun/yes/envs/modi_kozax/lib/python3.12/site-packages/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated) 0.5
# Compiling code for evaluation and evolution...
# Finished compilation in 77.72 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: -7.25, equation: [-0.0638]
# Complexity: 2, fitness: -93.875, equation: [sin(y3)]
# Complexity: 4, fitness: -233.375, equation: [y1 + sin(y1)]
# Complexity: 5, fitness: -252.8125, equation: [3.42*y1]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [y0*(y2 + y3) + y1]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [y0*(y2 + y3) + y1]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [y0*(y0 + y2) + y1]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [y0*(y0 + y2) + y1]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -281.3125, equation: [0.15*y0 + y1]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [y0*(y0 + y2) + y1]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -281.3125, equation: [0.15*y0 + y1]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -281.3125, equation: [0.15*y0 + y1]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# Final pareto front:
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]

# %%
brax_env = BraxGymnaxWrapper('inverted_double_pendulum', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=1, max_nodes= 15)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated) 0.5
# Compiling code for evaluation and evolution...
# Finished compilation in 110.49 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: -184.10488891601562, equation: [-0.0638]
# Complexity: 2, fitness: -440.75897216796875, equation: [sin(y1)]
# Complexity: 3, fitness: -775.4652709960938, equation: [y2 - y7]
# Complexity: 7, fitness: -1006.9361572265625, equation: [0.486*y7*(y7 - 1.94)]
# Complexity: 9, fitness: -1246.233154296875, equation: [(y1 - 0.743)*(y2 + y4*y7)]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -424.4704895019531, equation: [y6]
# Complexity: 2, fitness: -440.75897216796875, equation: [sin(y1)]
# Complexity: 3, fitness: -815.1287231445312, equation: [y1 - y7]
# Complexity: 7, fitness: -1006.9361572265625, equation: [0.486*y7*(y7 - 1.94)]
# Complexity: 9, fitness: -1246.233154296875, equation: [(y1 - 0.743)*(y2 + y4*y7)]
# Complexity: 15, fitness: -2016.470703125, equation: [(y0**2 + y2)*(y3*y6 + 2*y5 - 1.76)]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -908.64208984375, equation: [y5 - y7]
# Complexity: 5, fitness: -7236.8759765625, equation: [y2*(y7 - 1.94)]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -908.64208984375, equation: [y5 - y7]
# Complexity: 4, fitness: -1091.970947265625, equation: [-sin(0.956*y7)]
# Complexity: 5, fitness: -7236.8759765625, equation: [y2*(y7 - 1.94)]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -908.64208984375, equation: [y5 - y7]
# Complexity: 4, fitness: -1091.970947265625, equation: [-sin(0.956*y7)]
# Complexity: 5, fitness: -7236.8759765625, equation: [y2*(y7 - 1.94)]
# Complexity: 7, fitness: -8323.716796875, equation: [y2*(y2 + y6 - 1.94)]
# Complexity: 9, fitness: -9356.68359375, equation: [y2*(y1*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -908.64208984375, equation: [y5 - y7]
# Complexity: 4, fitness: -1091.970947265625, equation: [-sin(0.956*y7)]
# Complexity: 5, fitness: -7236.8759765625, equation: [y2*(y7 - 1.94)]
# Complexity: 7, fitness: -9174.5078125, equation: [y2*(y2*y6 - 1.94)]
# Complexity: 9, fitness: -9356.68359375, equation: [y2*(y1*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -3001.00048828125, equation: [-3.88*y2]
# Complexity: 5, fitness: -7236.8759765625, equation: [y2*(y7 - 1.94)]
# Complexity: 7, fitness: -9174.5078125, equation: [y2*(y2*y6 - 1.94)]
# Complexity: 9, fitness: -9356.68359375, equation: [y2*(y1*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -3001.00048828125, equation: [-3.88*y2]
# Complexity: 4, fitness: -8868.197265625, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9356.68359375, equation: [y2*(y1*(y2 + y7) - 1.94)]
# Complexity: 13, fitness: -9356.697265625, equation: [y2*(y1*(y1*(y1 - 0.743) + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8708.32421875, equation: [-1.75*y2]
# Complexity: 4, fitness: -8868.197265625, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9356.68359375, equation: [y2*(y1*(y2 + y7) - 1.94)]
# Complexity: 11, fitness: -9356.6875, equation: [y2*(y1*(y2**2 + y7) - 1.94)]
# Complexity: 13, fitness: -9356.697265625, equation: [y2*(y1*(y1*(y1 - 0.743) + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8708.32421875, equation: [-1.75*y2]
# Complexity: 4, fitness: -8868.197265625, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.083984375, equation: [y2*(y1*(y0 + y7) - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8708.32421875, equation: [-1.75*y2]
# Complexity: 4, fitness: -8868.197265625, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9357.783203125, equation: [y2*(-4.12*y2*y7 - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8708.32421875, equation: [-1.75*y2]
# Complexity: 4, fitness: -8868.197265625, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9357.783203125, equation: [y2*(-4.12*y2*y7 - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.197265625, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9357.783203125, equation: [y2*(-4.12*y2*y7 - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9357.783203125, equation: [y2*(-4.12*y2*y7 - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9357.783203125, equation: [y2*(-4.12*y2*y7 - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9358.1240234375, equation: [y2*(-2.88*y0*y7 - 1.94)]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9358.1240234375, equation: [y2*(-2.88*y0*y7 - 1.94)]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9358.1240234375, equation: [y2*(-2.88*y0*y7 - 1.94)]
# Complexity: 13, fitness: -9358.2861328125, equation: [y2*(y7*(-3.88*y0 + y7**2) - 1.94)]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9358.142578125, equation: [y2*(y7*(-3.88*y0 + y2) - 1.94)]
# Complexity: 13, fitness: -9358.2861328125, equation: [y2*(y7*(-3.88*y0 + y7**2) - 1.94)]
# Complexity: 14, fitness: -9358.287109375, equation: [(y7*(-3.88*y0 + y7**2) - 1.94)*sin(y2)]
# Complexity: 15, fitness: -9358.3232421875, equation: [y2*(y7*(-3.88*y0 + y6*y7**2) - 1.94)]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9358.142578125, equation: [y2*(y7*(-3.88*y0 + y2) - 1.94)]
# Complexity: 13, fitness: -9358.2939453125, equation: [y2*(y7*(-3.88*y0 + y2*y5) - 1.94)]
# Complexity: 14, fitness: -9358.400390625, equation: [(y7*(-3.88*y0 - 1.76*y2) - 1.94)*sin(y2)]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9358.142578125, equation: [y2*(y7*(-3.88*y0 + y2) - 1.94)]
# Complexity: 13, fitness: -9358.2998046875, equation: [y2*(y7*(-3.88*y0 + y2**2) - 1.94)]
# Complexity: 14, fitness: -9358.4033203125, equation: [(y7*(-3.88*y0 - 1.94*y2) - 1.94)*sin(y2)]
# Complexity: 15, fitness: -9358.814453125, equation: [y2*((y0 + y7)*(-4.12*y2 - 4.12*y7) - 1.94)]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9358.142578125, equation: [y2*(y7*(-3.88*y0 + y2) - 1.94)]
# Complexity: 13, fitness: -9358.5830078125, equation: [y2*(y7*(-3.88*y0 - 1.94*y7) - 1.94)]
# Complexity: 15, fitness: -9358.814453125, equation: [y2*((y0 + y7)*(-4.12*y2 - 4.12*y7) - 1.94)]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.9423828125, equation: [y2*(-2.35*y0*y7 - 1.94)]
# Complexity: 11, fitness: -9358.142578125, equation: [y2*(y7*(-3.88*y0 + y2) - 1.94)]
# Complexity: 13, fitness: -9358.5830078125, equation: [y2*(y7*(-3.88*y0 - 1.94*y7) - 1.94)]
# Complexity: 15, fitness: -9358.814453125, equation: [y2*((y0 + y7)*(-4.12*y2 - 4.12*y7) - 1.94)]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.9423828125, equation: [y2*(-2.35*y0*y7 - 1.94)]
# Complexity: 11, fitness: -9358.142578125, equation: [y2*(y7*(-3.88*y0 + y2) - 1.94)]
# Complexity: 13, fitness: -9358.5830078125, equation: [y2*(y7*(-3.88*y0 - 1.94*y7) - 1.94)]
# Complexity: 15, fitness: -9358.814453125, equation: [y2*((y0 + y7)*(-4.12*y2 - 4.12*y7) - 1.94)]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.9423828125, equation: [y2*(-2.35*y0*y7 - 1.94)]
# Complexity: 11, fitness: -9358.3671875, equation: [y2*(y7*(-3.88*y0 + y1) - 1.94)]
# Complexity: 13, fitness: -9358.7275390625, equation: [y2*(y7*(-3.88*y0 - 3.88*y7) - 1.94)]
# Complexity: 15, fitness: -9358.814453125, equation: [y2*((y0 + y7)*(-4.12*y2 - 4.12*y7) - 1.94)]
# Final pareto front:
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.9423828125, equation: [y2*(-2.35*y0*y7 - 1.94)]
# Complexity: 11, fitness: -9358.3671875, equation: [y2*(y7*(-3.88*y0 + y1) - 1.94)]
# Complexity: 13, fitness: -9358.7275390625, equation: [y2*(y7*(-3.88*y0 - 3.88*y7) - 1.94)]
# Complexity: 15, fitness: -9358.814453125, equation: [y2*((y0 + y7)*(-4.12*y2 - 4.12*y7) - 1.94)]

# %%
brax_env = BraxGymnaxWrapper('reacher', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=2, max_nodes= 30)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated) 0.5
# Compiling code for evaluation and evolution...
# Finished compilation in 171.60 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: 530.9840698242188, equation: [0, 0.639]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 7, fitness: 110.91987609863281, equation: [0, y8*(y1*y10 + 0.599)]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 111.21009826660156, equation: [0, 0.247*y8]
# Complexity: 5, fitness: 88.23331451416016, equation: [0, y5*(y2 + y8)]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 105.35753631591797, equation: [0, -y8 + y9]
# Complexity: 5, fitness: 80.22433471679688, equation: [0, y5*(y6 + y8)]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 7, fitness: 77.66867065429688, equation: [0, 2.25*y5*y8]
# Complexity: 9, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 22, fitness: 75.30567932128906, equation: [y0*y4*y8*y9 + y0*y8*y9 + y0*y8*(y0*y4*y8*y9*sin(y9**3) + y6*y9) + sin(y9**3), y0*y4*y8*y9*sin(y9**3) + 2*y0*y8 + y6*y9 + y9**2]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 7, fitness: 77.28008270263672, equation: [0, 2.49*y5*y8]
# Complexity: 9, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 22, fitness: 75.30567932128906, equation: [y0*y4*y8*y9 + y0*y8*y9 + y0*y8*(y0*y4*y8*y9*sin(y9**3) + y6*y9) + sin(y9**3), y0*y4*y8*y9*sin(y9**3) + 2*y0*y8 + y6*y9 + y9**2]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 14, fitness: 76.12671661376953, equation: [0, 2*y5*y8 + 1.24*y5*(y8 + y9*sin(2*y5*y8)) + y9*sin(2*y5*y8) + sin(2*y5*y8)]
# Complexity: 22, fitness: 75.30567932128906, equation: [y0*y4*y8*y9 + y0*y8*y9 + y0*y8*(y0*y4*y8*y9*sin(y9**3) + y6*y9) + sin(y9**3), y0*y4*y8*y9*sin(y9**3) + 2*y0*y8 + y6*y9 + y9**2]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, y10 + 2*y5*y8]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 13, fitness: 76.13917541503906, equation: [0, 4*y5*y8**2 + 4*y5*y8]
# Complexity: 14, fitness: 76.12671661376953, equation: [0, 2*y5*y8 + 1.24*y5*(y8 + y9*sin(2*y5*y8)) + y9*sin(2*y5*y8) + sin(2*y5*y8)]
# Complexity: 21, fitness: 75.92579650878906, equation: [0, 4*y5*y8*(y1*y8 + y8)*(y6*y9 + y8) + 4*y5*y8*(y6*y9 + y8) + 4*y5*y8]
# Complexity: 22, fitness: 74.09739685058594, equation: [y0*y5*y8*y9 + y0*y8*y9 + y0*y8*(y0*y5*y8*y9*sin(y9**3) + y6*y9) + sin(y9**3), y0*y5*y8*y9*sin(y9**3) + 2*y0*y8 + y6*y9 + y9**2]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.418006896972656, equation: [y5*(y1*y5 + y8), y1*y5]
# Complexity: 22, fitness: 57.75319290161133, equation: [y0*y5*y8*y9 + y0*y8*y9 + sin(y9**3), y0*y5*y8*y9*sin(y9**3) + y0*y8 + y6*y9 + y9**2 + (y4 - 0.325)*(y0*y5*y8*y9*sin(y9**3) + y6*y9)]
# Complexity: 24, fitness: 56.96827697753906, equation: [y0*y5*y8*y9 + y0*y8*y9 + y2*y6*y8*(y0*y5*y8*y9*sin(y9**3) + y6*y9) + sin(y9**3), y0*y5*y8*y9*sin(y9**3) + y0*y8 + y2*y6*y8 + y6*y9 + y9**2]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.418006896972656, equation: [y5*(y1*y5 + y8), y1*y5]
# Complexity: 22, fitness: 57.75319290161133, equation: [y0*y5*y8*y9 + y0*y8*y9 + sin(y9**3), y0*y5*y8*y9*sin(y9**3) + y0*y8 + y6*y9 + y9**2 + (y4 - 0.325)*(y0*y5*y8*y9*sin(y9**3) + y6*y9)]
# Complexity: 24, fitness: 56.96827697753906, equation: [y0*y5*y8*y9 + y0*y8*y9 + y2*y6*y8*(y0*y5*y8*y9*sin(y9**3) + y6*y9) + sin(y9**3), y0*y5*y8*y9*sin(y9**3) + y0*y8 + y2*y6*y8 + y6*y9 + y9**2]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.1634635925293, equation: [y5*(-y1*y5 + y8), y1*y5]
# Complexity: 22, fitness: 57.75319290161133, equation: [y0*y5*y8*y9 + y0*y8*y9 + sin(y9**3), y0*y5*y8*y9*sin(y9**3) + y0*y8 + y6*y9 + y9**2 + (y4 - 0.325)*(y0*y5*y8*y9*sin(y9**3) + y6*y9)]
# Complexity: 24, fitness: 56.96827697753906, equation: [y0*y5*y8*y9 + y0*y8*y9 + y2*y6*y8*(y0*y5*y8*y9*sin(y9**3) + y6*y9) + sin(y9**3), y0*y5*y8*y9*sin(y9**3) + y0*y8 + y2*y6*y8 + y6*y9 + y9**2]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.1634635925293, equation: [y5*(-y1*y5 + y8), y1*y5]
# Complexity: 22, fitness: 57.75319290161133, equation: [y0*y5*y8*y9 + y0*y8*y9 + sin(y9**3), y0*y5*y8*y9*sin(y9**3) + y0*y8 + y6*y9 + y9**2 + (y4 - 0.325)*(y0*y5*y8*y9*sin(y9**3) + y6*y9)]
# Complexity: 24, fitness: 56.96827697753906, equation: [y0*y5*y8*y9 + y0*y8*y9 + y2*y6*y8*(y0*y5*y8*y9*sin(y9**3) + y6*y9) + sin(y9**3), y0*y5*y8*y9*sin(y9**3) + y0*y8 + y2*y6*y8 + y6*y9 + y9**2]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.1634635925293, equation: [y5*(-y1*y5 + y8), y1*y5]
# Complexity: 22, fitness: 57.75319290161133, equation: [y0*y5*y8*y9 + y0*y8*y9 + sin(y9**3), y0*y5*y8*y9*sin(y9**3) + y0*y8 + y6*y9 + y9**2 + (y4 - 0.325)*(y0*y5*y8*y9*sin(y9**3) + y6*y9)]
# Complexity: 24, fitness: 55.907814025878906, equation: [-0.681*y0*y2*y6**2*y8**2*y9**3*sin(y8*y9) + 0.319*y0*y8*y9 + sin(y8*y9), -0.681*y0*y6*y8*y9**3*sin(y8*y9) + y0*y8 + y2*y6*y8 + y9**2]
# Complexity: 28, fitness: 55.77574157714844, equation: [y0*y5*y8*y9 + y0*y8*y9 + sin(y9**3), y0*y5*y8*y9*sin(y9**3) + y0*y8 + y10*(y0 - 0.325)*(y5 + y9)*(y0*y5*y8*y9*sin(y9**3) + y6*y9) + y10*(y0 - 0.325)*(y0*y5*y8*y9*sin(y9**3) + y6*y9) + y6*y9 + y9**2 + (y0 - 0.325)*(y0*y5*y8*y9*sin(y9**3) + y6*y9)]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.1634635925293, equation: [y5*(-y1*y5 + y8), y1*y5]
# Complexity: 22, fitness: 57.75319290161133, equation: [y0*y5*y8*y9 + y0*y8*y9 + sin(y9**3), y0*y5*y8*y9*sin(y9**3) + y0*y8 + y6*y9 + y9**2 + (y4 - 0.325)*(y0*y5*y8*y9*sin(y9**3) + y6*y9)]
# Complexity: 24, fitness: 51.67253112792969, equation: [-0.681*y0*y6*y8*y9**3*sin(y8*y9) + 0.319*y0*y8*y9 + y2*y6*y8 + sin(y8*y9), -0.681*y0*y6*y8*y9**3*sin(y8*y9) + y0*y8 + y2*y6*y8 + y9**2]
# Complexity: 26, fitness: 47.426963806152344, equation: [y0*y4*y5**4*y8 + y0*y4*y5**3*y8 + y0*y4*y5**2*y8 + y10*(y0*y4*y5**4*y8*sin(y8*y9) + y6*y9**2) + sin(y8*y9), y0*y4*y5**4*y8*sin(y8*y9) + y0*y8 + y4*y5**2 + y4*y5 + y6*y9**2 + y9**2]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.1634635925293, equation: [y5*(-y1*y5 + y8), y1*y5]
# Complexity: 20, fitness: 57.763397216796875, equation: [y5*y6*sin(y8*(y10 + y5*y8)) + y5*(y1*y5**2*y6*sin(y8*(y10 + y5*y8)) + y8) + y8*(y10 + y5*y8), y1*y5 + y5*y6 + y5*y8]
# Complexity: 22, fitness: 56.05704116821289, equation: [0.319*y0*y8*y9 + y10*y8*(-0.681*y0*y8*y9*sin(y8*y9) + y6*y9**2) + sin(y8*y9), -0.681*y0*y8*y9*sin(y8*y9) + y0*y8 + y10*y8 + y6*y9**2 + y9**2]
# Complexity: 24, fitness: 51.67253112792969, equation: [-0.681*y0*y6*y8*y9**3*sin(y8*y9) + 0.319*y0*y8*y9 + y2*y6*y8 + sin(y8*y9), -0.681*y0*y6*y8*y9**3*sin(y8*y9) + y0*y8 + y2*y6*y8 + y9**2]
# Complexity: 26, fitness: 47.426963806152344, equation: [y0*y4*y5**4*y8 + y0*y4*y5**3*y8 + y0*y4*y5**2*y8 + y10*(y0*y4*y5**4*y8*sin(y8*y9) + y6*y9**2) + sin(y8*y9), y0*y4*y5**4*y8*sin(y8*y9) + y0*y8 + y4*y5**2 + y4*y5 + y6*y9**2 + y9**2]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.1634635925293, equation: [y5*(-y1*y5 + y8), y1*y5]
# Complexity: 18, fitness: 57.763397216796875, equation: [y5*y6*sin(y5*y8**2) + y5*y8**2 + y5*(y1*y5**2*y6*sin(y5*y8**2) + y8), y1*y5 + y5*y6 + y5*y8]
# Complexity: 20, fitness: 56.03770446777344, equation: [0.319*y0*y8*y9 + y4*(-0.681*y0*y8*y9*sin(y8*y9) + y6*y9**2) + sin(y8*y9), -0.681*y0*y8*y9*sin(y8*y9) + y0*y8 + y6*y9**2 + y9**2]
# Complexity: 24, fitness: 51.67253112792969, equation: [-0.681*y0*y6*y8*y9**3*sin(y8*y9) + 0.319*y0*y8*y9 + y2*y6*y8 + sin(y8*y9), -0.681*y0*y6*y8*y9**3*sin(y8*y9) + y0*y8 + y2*y6*y8 + y9**2]
# Complexity: 26, fitness: 47.40273666381836, equation: [0.675*y0*y4*y5**3*y8 + y0*y4*y5**2*y8 + y10*(-0.325*y0*y4*y5**3*y8*sin(y8*y9) + y6*y9**2) + sin(y8*y9), -0.325*y0*y4*y5**3*y8*sin(y8*y9) + y0*y8 + y4*y5**2 + y4*y5 + y6*y9**2 + y9**2]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.1634635925293, equation: [y5*(-y1*y5 + y8), y1*y5]
# Complexity: 18, fitness: 57.763397216796875, equation: [y5*y6*sin(y5*y8**2) + y5*y8**2 + y5*(y1*y5**2*y6*sin(y5*y8**2) + y8), y1*y5 + y5*y6 + y5*y8]
# Complexity: 20, fitness: 54.288421630859375, equation: [-0.681*y0**2*y6**2*y8*y9**2*sin(y8*y9) + 0.319*y0*y6*y8 + sin(y8*y9), -0.681*y0*y6**2*y8*y9**2*sin(y8*y9) + y0*y8 + y9**2]
# Complexity: 24, fitness: 51.67253112792969, equation: [-0.681*y0*y6*y8*y9**3*sin(y8*y9) + 0.319*y0*y8*y9 + y2*y6*y8 + sin(y8*y9), -0.681*y0*y6*y8*y9**3*sin(y8*y9) + y0*y8 + y2*y6*y8 + y9**2]
# Complexity: 26, fitness: 47.40273666381836, equation: [0.675*y0*y4*y5**3*y8 + y0*y4*y5**2*y8 + y10*(-0.325*y0*y4*y5**3*y8*sin(y8*y9) + y6*y9**2) + sin(y8*y9), -0.325*y0*y4*y5**3*y8*sin(y8*y9) + y0*y8 + y4*y5**2 + y4*y5 + y6*y9**2 + y9**2]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.1634635925293, equation: [y5*(-y1*y5 + y8), y1*y5]
# Complexity: 18, fitness: 57.763397216796875, equation: [y5*y6*sin(y5*y8**2) + y5*y8**2 + y5*(y1*y5**2*y6*sin(y5*y8**2) + y8), y1*y5 + y5*y6 + y5*y8]
# Complexity: 19, fitness: 57.05525588989258, equation: [3*y10*y5*y8**2 + y5*(3*y1*y10*y5**2*y8**2 + y8), y1*y5 + 3*y5*y8**2 + 3*y5*y8]
# Complexity: 20, fitness: 54.288421630859375, equation: [-0.681*y0**2*y6**2*y8*y9**2*sin(y8*y9) + 0.319*y0*y6*y8 + sin(y8*y9), -0.681*y0*y6**2*y8*y9**2*sin(y8*y9) + y0*y8 + y9**2]
# Complexity: 24, fitness: 51.67253112792969, equation: [-0.681*y0*y6*y8*y9**3*sin(y8*y9) + 0.319*y0*y8*y9 + y2*y6*y8 + sin(y8*y9), -0.681*y0*y6*y8*y9**3*sin(y8*y9) + y0*y8 + y2*y6*y8 + y9**2]
# Complexity: 26, fitness: 47.40273666381836, equation: [0.675*y0*y4*y5**3*y8 + y0*y4*y5**2*y8 + y10*(-0.325*y0*y4*y5**3*y8*sin(y8*y9) + y6*y9**2) + sin(y8*y9), -0.325*y0*y4*y5**3*y8*sin(y8*y9) + y0*y8 + y4*y5**2 + y4*y5 + y6*y9**2 + y9**2]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.1634635925293, equation: [y5*(-y1*y5 + y8), y1*y5]
# Complexity: 18, fitness: 57.763397216796875, equation: [y5*y6*sin(y5*y8**2) + y5*y8**2 + y5*(y1*y5**2*y6*sin(y5*y8**2) + y8), y1*y5 + y5*y6 + y5*y8]
# Complexity: 19, fitness: 57.05525588989258, equation: [3*y10*y5*y8**2 + y5*(3*y1*y10*y5**2*y8**2 + y8), y1*y5 + 3*y5*y8**2 + 3*y5*y8]
# Complexity: 20, fitness: 54.288421630859375, equation: [-0.681*y0**2*y6**2*y8*y9**2*sin(y8*y9) + 0.319*y0*y6*y8 + sin(y8*y9), -0.681*y0*y6**2*y8*y9**2*sin(y8*y9) + y0*y8 + y9**2]
# Complexity: 24, fitness: 51.67253112792969, equation: [-0.681*y0*y6*y8*y9**3*sin(y8*y9) + 0.319*y0*y8*y9 + y2*y6*y8 + sin(y8*y9), -0.681*y0*y6*y8*y9**3*sin(y8*y9) + y0*y8 + y2*y6*y8 + y9**2]
# Complexity: 26, fitness: 47.40273666381836, equation: [0.675*y0*y4*y5**3*y8 + y0*y4*y5**2*y8 + y10*(-0.325*y0*y4*y5**3*y8*sin(y8*y9) + y6*y9**2) + sin(y8*y9), -0.325*y0*y4*y5**3*y8*sin(y8*y9) + y0*y8 + y4*y5**2 + y4*y5 + y6*y9**2 + y9**2]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.1634635925293, equation: [y5*(-y1*y5 + y8), y1*y5]
# Complexity: 18, fitness: 57.763397216796875, equation: [y5*y6*sin(y5*y8**2) + y5*y8**2 + y5*(y1*y5**2*y6*sin(y5*y8**2) + y8), y1*y5 + y5*y6 + y5*y8]
# Complexity: 19, fitness: 57.05525588989258, equation: [3*y10*y5*y8**2 + y5*(3*y1*y10*y5**2*y8**2 + y8), y1*y5 + 3*y5*y8**2 + 3*y5*y8]
# Complexity: 20, fitness: 54.288421630859375, equation: [-0.681*y0**2*y6**2*y8*y9**2*sin(y8*y9) + 0.319*y0*y6*y8 + sin(y8*y9), -0.681*y0*y6**2*y8*y9**2*sin(y8*y9) + y0*y8 + y9**2]
# Complexity: 24, fitness: 51.67253112792969, equation: [-0.681*y0*y6*y8*y9**3*sin(y8*y9) + 0.319*y0*y8*y9 + y2*y6*y8 + sin(y8*y9), -0.681*y0*y6*y8*y9**3*sin(y8*y9) + y0*y8 + y2*y6*y8 + y9**2]
# Complexity: 26, fitness: 47.40273666381836, equation: [0.675*y0*y4*y5**3*y8 + y0*y4*y5**2*y8 + y10*(-0.325*y0*y4*y5**3*y8*sin(y8*y9) + y6*y9**2) + sin(y8*y9), -0.325*y0*y4*y5**3*y8*sin(y8*y9) + y0*y8 + y4*y5**2 + y4*y5 + y6*y9**2 + y9**2]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.1634635925293, equation: [y5*(-y1*y5 + y8), y1*y5]
# Complexity: 18, fitness: 57.763397216796875, equation: [y5*y6*sin(y5*y8**2) + y5*y8**2 + y5*(y1*y5**2*y6*sin(y5*y8**2) + y8), y1*y5 + y5*y6 + y5*y8]
# Complexity: 19, fitness: 57.05525588989258, equation: [3*y10*y5*y8**2 + y5*(3*y1*y10*y5**2*y8**2 + y8), y1*y5 + 3*y5*y8**2 + 3*y5*y8]
# Complexity: 20, fitness: 54.288421630859375, equation: [-0.681*y0**2*y6**2*y8*y9**2*sin(y8*y9) + 0.319*y0*y6*y8 + sin(y8*y9), -0.681*y0*y6**2*y8*y9**2*sin(y8*y9) + y0*y8 + y9**2]
# Complexity: 22, fitness: 53.02763366699219, equation: [y0*y10*y8*y9 + y0*y8*y9 + sin(y9**3), y0*y10*y8*y9*sin(y9**3) + y0*y8 + 2*y9**2 + (y0 - 0.325)*(y0*y10*y8*y9*sin(y9**3) + y9**2)]
# Complexity: 24, fitness: 51.67253112792969, equation: [-0.681*y0*y6*y8*y9**3*sin(y8*y9) + 0.319*y0*y8*y9 + y2*y6*y8 + sin(y8*y9), -0.681*y0*y6*y8*y9**3*sin(y8*y9) + y0*y8 + y2*y6*y8 + y9**2]
# Complexity: 26, fitness: 45.78123474121094, equation: [0.675*y0*y4*y5**3*y8 + y0*y4*y5**2*y8 + y10*(-0.325*y0*y4*y5**3*y8*sin(y8*y9) + y0*y9**2) + sin(y8*y9), -0.325*y0*y4*y5**3*y8*sin(y8*y9) + y0*y8 + y0*y9**2 + y4*y5**2 + y4*y5 + y9**2]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.1634635925293, equation: [y5*(-y1*y5 + y8), y1*y5]
# Complexity: 18, fitness: 57.763397216796875, equation: [y5*y6*sin(y5*y8**2) + y5*y8**2 + y5*(y1*y5**2*y6*sin(y5*y8**2) + y8), y1*y5 + y5*y6 + y5*y8]
# Complexity: 19, fitness: 57.05525588989258, equation: [3*y10*y5*y8**2 + y5*(3*y1*y10*y5**2*y8**2 + y8), y1*y5 + 3*y5*y8**2 + 3*y5*y8]
# Complexity: 20, fitness: 54.288421630859375, equation: [-0.681*y0**2*y6**2*y8*y9**2*sin(y8*y9) + 0.319*y0*y6*y8 + sin(y8*y9), -0.681*y0*y6**2*y8*y9**2*sin(y8*y9) + y0*y8 + y9**2]
# Complexity: 22, fitness: 53.02763366699219, equation: [y0*y10*y8*y9 + y0*y8*y9 + sin(y9**3), y0*y10*y8*y9*sin(y9**3) + y0*y8 + 2*y9**2 + (y0 - 0.325)*(y0*y10*y8*y9*sin(y9**3) + y9**2)]
# Complexity: 24, fitness: 48.70196533203125, equation: [0.236*y0*y4*y5**2*y8*sin(y8*y9) + 0.675*y0*y4*y5**2*y8 + y0*y4*y5*y8 - 0.728*y10*y9**2 + sin(y8*y9), -0.325*y0*y4*y5**2*y8*sin(y8*y9) + y0*y8 + y10*y9**2 + y4*y5 + y9**2]
# Complexity: 26, fitness: 45.78123474121094, equation: [0.675*y0*y4*y5**3*y8 + y0*y4*y5**2*y8 + y10*(-0.325*y0*y4*y5**3*y8*sin(y8*y9) + y0*y9**2) + sin(y8*y9), -0.325*y0*y4*y5**3*y8*sin(y8*y9) + y0*y8 + y0*y9**2 + y4*y5**2 + y4*y5 + y9**2]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.1634635925293, equation: [y5*(-y1*y5 + y8), y1*y5]
# Complexity: 17, fitness: 50.05205535888672, equation: [y10*(-y1*y5 + y5) + y5*(0.247*y10*y5*y8*(-y1*y5 + y5) + y8), y1*y5 + 0.247*y5*y8 + 0.247*y5]
# Complexity: 22, fitness: 45.13395690917969, equation: [0.149*y0*y5*y8 + 0.221*y0*y8 + y8*(-0.0717*y0*y5*y8*sin(y8*y9) + y6*y9**2) + sin(y8*y9), -0.0717*y0*y5*y8*sin(y8*y9) + y0*y8 + y6*y9**2 + y9**2]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.1634635925293, equation: [y5*(-y1*y5 + y8), y1*y5]
# Complexity: 17, fitness: 50.05205535888672, equation: [y10*(y1*y5 + y5) + y5*(0.247*y10*y5*y8*(y1*y5 + y5) + y8), y1*y5 + 0.247*y5*y8 + 0.247*y5]
# Complexity: 22, fitness: 45.13395690917969, equation: [0.149*y0*y5*y8 + 0.221*y0*y8 + y8*(-0.0717*y0*y5*y8*sin(y8*y9) + y6*y9**2) + sin(y8*y9), -0.0717*y0*y5*y8*sin(y8*y9) + y0*y8 + y6*y9**2 + y9**2]
# Complexity: 23, fitness: 45.06372833251953, equation: [0.149*y5*sin(y0*y8) + y8*(-0.0717*y5*sin(y0*y8)*sin(y8*y9) + y6*y9**2) + 0.221*sin(y0*y8) + sin(y8*y9), y0*y8 - 0.0717*y5*sin(y0*y8)*sin(y8*y9) + y6*y9**2 + y9**2]
# Complexity: 24, fitness: 41.68659973144531, equation: [y5*(-y5*y8 + y8), y1*y5**3*(-y5*y8 + y8)*(2*y5*y8 + y8)*sin(y9) + y1*y5**3*(-y5*y8 + y8)*sin(y9) + y1*y5**3*(-y5*y8 + y8) + y1*y5 + 2*y5*y8 + sin(y9)]
# Final pareto front:
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93360137939453, equation: [0, 2*y5*y8 + y6]
# Complexity: 6, fitness: 76.37594604492188, equation: [0, 2*y5*y8 + sin(2*y5*y8)]
# Complexity: 7, fitness: 58.1634635925293, equation: [y5*(-y1*y5 + y8), y1*y5]
# Complexity: 17, fitness: 50.05205535888672, equation: [y10*(y1*y5 + y5) + y5*(0.247*y10*y5*y8*(y1*y5 + y5) + y8), y1*y5 + 0.247*y5*y8 + 0.247*y5]
# Complexity: 22, fitness: 45.13395690917969, equation: [0.149*y0*y5*y8 + 0.221*y0*y8 + y8*(-0.0717*y0*y5*y8*sin(y8*y9) + y6*y9**2) + sin(y8*y9), -0.0717*y0*y5*y8*sin(y8*y9) + y0*y8 + y6*y9**2 + y9**2]
# Complexity: 23, fitness: 45.06372833251953, equation: [0.149*y5*sin(y0*y8) + y8*(-0.0717*y5*sin(y0*y8)*sin(y8*y9) + y6*y9**2) + 0.221*sin(y0*y8) + sin(y8*y9), y0*y8 - 0.0717*y5*sin(y0*y8)*sin(y8*y9) + y6*y9**2 + y9**2]
# Complexity: 24, fitness: 41.68659973144531, equation: [y5*(-y5*y8 + y8), y1*y5**3*(-y5*y8 + y8)*(2*y5*y8 + y8)*sin(y9) + y1*y5**3*(-y5*y8 + y8)*sin(y9) + y1*y5**3*(-y5*y8 + y8) + y1*y5 + 2*y5*y8 + sin(y9)]

# %%
brax_env = BraxGymnaxWrapper('swimmer', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=2, max_nodes= 30)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated) 0.5
# Compiling code for evaluation and evolution...
# Finished compilation in 91.68 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: 7.4527268409729, equation: [0.839, 0]
# Complexity: 2, fitness: -11.4246187210083, equation: [0, sin(y6)]
# Complexity: 3, fitness: -23.575965881347656, equation: [0, y6 + y7]
# Complexity: 5, fitness: -43.92849349975586, equation: [0.334*y4 - 0.724, 0.334*y4]
# Complexity: 6, fitness: -87.59139251708984, equation: [y0 + y1 + y3, y1 + y3 + sin(y0 + y1 + y3)]
# Complexity: 7, fitness: -217.22744750976562, equation: [y0 - y5 - 0.216, y0 - y5 + y7 - 0.216]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -23.575965881347656, equation: [0, y6 + y7]
# Complexity: 4, fitness: -33.95392608642578, equation: [y3 - 0.0415, sin(y3 - 0.0415)]
# Complexity: 5, fitness: -43.92849349975586, equation: [0.334*y4 - 0.724, 0.334*y4]
# Complexity: 6, fitness: -87.59139251708984, equation: [y0 + y1 + y3, y1 + y3 + sin(y0 + y1 + y3)]
# Complexity: 7, fitness: -217.2301025390625, equation: [y0 - y5 - 0.216, y0 - y5 + y7 - 0.216]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -23.583654403686523, equation: [0, y6 + y7]
# Complexity: 4, fitness: -36.07283020019531, equation: [0, sin(y1 + y5)]
# Complexity: 5, fitness: -43.92849349975586, equation: [0.334*y4 - 0.724, 0.334*y4]
# Complexity: 6, fitness: -87.59139251708984, equation: [y0 + y1 + y3, y1 + y3 + sin(y0 + y1 + y3)]
# Complexity: 7, fitness: -330.21868896484375, equation: [y0 + y4, y0 + y4 + y6 + y7]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -23.849319458007812, equation: [0, y6 + y7]
# Complexity: 4, fitness: -36.07283020019531, equation: [0, sin(y1 + y5)]
# Complexity: 5, fitness: -213.96221923828125, equation: [y0 - y5, y0 - y5 + y7]
# Complexity: 7, fitness: -330.21868896484375, equation: [y0 + y4, y0 + y4 + y6 + y7]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.8814392089844, equation: [y0 + y4, y0 + y1 + y4]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.8814392089844, equation: [y0 + y4, y0 + y1 + y4]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.8814392089844, equation: [y0 + y4, y0 + y1 + y4]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.8814697265625, equation: [y0 + y4, y0 + y1 + y4]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82310485839844, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.8814697265625, equation: [y0 + y4, y0 + y1 + y4]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.8814697265625, equation: [y0 + y4, y0 + y1 + y4]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.8814697265625, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 11, fitness: -356.6577453613281, equation: [3.93*y0 + y1 + y4, y1 + y4]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.8814697265625, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 11, fitness: -356.6577453613281, equation: [3.93*y0 + y1 + y4, y1 + y4]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.88153076171875, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 11, fitness: -356.6577453613281, equation: [3.93*y0 + y1 + y4, y1 + y4]
# Complexity: 13, fitness: -358.724365234375, equation: [y0*y1**2 + 2.62*y0 + y1 + y4, -y0*y1**2 + 1.31*y0 + y1 + y4]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 5, fitness: -348.88153076171875, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 11, fitness: -356.6577453613281, equation: [3.93*y0 + y1 + y4, y1 + y4]
# Complexity: 13, fitness: -362.55548095703125, equation: [2.62*y0 + y1 + y4, 1.31*y0 + 2*y1 - 0.767*y2 + y4]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 4, fitness: -69.41749572753906, equation: [y4 + y7, cos(y4 + y7)]
# Complexity: 5, fitness: -348.88153076171875, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -353.4582824707031, equation: [y0 + y4, 2*y0 + 2*y1 + y4]
# Complexity: 11, fitness: -356.6577453613281, equation: [3.93*y0 + y1 + y4, y1 + y4]
# Complexity: 13, fitness: -362.5556335449219, equation: [2.62*y0 + y1 + y4, 1.31*y0 + 2*y1 - 0.767*y2 + y4]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 4, fitness: -69.41749572753906, equation: [y4 + y7, cos(y4 + y7)]
# Complexity: 5, fitness: -348.88153076171875, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -353.4582824707031, equation: [y0 + y4, 2*y0 + 2*y1 + y4]
# Complexity: 11, fitness: -356.6577453613281, equation: [3.93*y0 + y1 + y4, y1 + y4]
# Complexity: 13, fitness: -362.5556335449219, equation: [2.62*y0 + y1 + y4, 1.31*y0 + 2*y1 - 0.767*y2 + y4]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 4, fitness: -69.41749572753906, equation: [y4 + y7, cos(y4 + y7)]
# Complexity: 5, fitness: -348.88153076171875, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -353.4582824707031, equation: [y0 + y4, 2*y0 + 2*y1 + y4]
# Complexity: 11, fitness: -356.6577453613281, equation: [3.93*y0 + y1 + y4, y1 + y4]
# Complexity: 13, fitness: -362.5556335449219, equation: [2.62*y0 + y1 + y4, 1.31*y0 + 2*y1 - 0.767*y2 + y4]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 4, fitness: -69.41749572753906, equation: [y4 + y7, cos(y4 + y7)]
# Complexity: 5, fitness: -348.88153076171875, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -353.4582824707031, equation: [y0 + y4, 2*y0 + 2*y1 + y4]
# Complexity: 11, fitness: -356.6577453613281, equation: [3.93*y0 + y1 + y4, y1 + y4]
# Complexity: 13, fitness: -362.5556335449219, equation: [2.62*y0 + y1 + y4, 1.31*y0 + 2*y1 - 0.767*y2 + y4]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 4, fitness: -69.41749572753906, equation: [y4 + y7, cos(y4 + y7)]
# Complexity: 5, fitness: -348.88153076171875, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -353.4582824707031, equation: [y0 + y4, 2*y0 + 2*y1 + y4]
# Complexity: 11, fitness: -356.6577453613281, equation: [3.93*y0 + y1 + y4, y1 + y4]
# Complexity: 13, fitness: -362.5556335449219, equation: [2.62*y0 + y1 + y4, 1.31*y0 + 2*y1 - 0.767*y2 + y4]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 4, fitness: -69.41749572753906, equation: [y4 + y7, cos(y4 + y7)]
# Complexity: 5, fitness: -348.88153076171875, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -353.4582824707031, equation: [y0 + y4, 2*y0 + 2*y1 + y4]
# Complexity: 11, fitness: -356.6577453613281, equation: [3.93*y0 + y1 + y4, y1 + y4]
# Complexity: 13, fitness: -362.5556335449219, equation: [2.62*y0 + y1 + y4, 1.31*y0 + 2*y1 - 0.767*y2 + y4]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 4, fitness: -69.41749572753906, equation: [y4 + y7, cos(y4 + y7)]
# Complexity: 5, fitness: -348.88153076171875, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -353.4582824707031, equation: [y0 + y4, 2*y0 + 2*y1 + y4]
# Complexity: 11, fitness: -356.6577453613281, equation: [3.93*y0 + y1 + y4, y1 + y4]
# Complexity: 13, fitness: -362.5556335449219, equation: [2.62*y0 + y1 + y4, 1.31*y0 + 2*y1 - 0.767*y2 + y4]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 4, fitness: -69.41749572753906, equation: [y4 + y7, cos(y4 + y7)]
# Complexity: 5, fitness: -348.88153076171875, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -353.4582824707031, equation: [y0 + y4, 2*y0 + 2*y1 + y4]
# Complexity: 11, fitness: -356.6577453613281, equation: [3.93*y0 + y1 + y4, y1 + y4]
# Complexity: 13, fitness: -362.5556335449219, equation: [2.62*y0 + y1 + y4, 1.31*y0 + 2*y1 - 0.767*y2 + y4]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 4, fitness: -69.41749572753906, equation: [y4 + y7, cos(y4 + y7)]
# Complexity: 5, fitness: -348.88153076171875, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -353.4582824707031, equation: [y0 + y4, 2*y0 + 2*y1 + y4]
# Complexity: 11, fitness: -356.6577453613281, equation: [3.93*y0 + y1 + y4, y1 + y4]
# Complexity: 13, fitness: -362.5556335449219, equation: [2.62*y0 + y1 + y4, 1.31*y0 + 2*y1 - 0.767*y2 + y4]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 4, fitness: -69.41749572753906, equation: [y4 + y7, cos(y4 + y7)]
# Complexity: 5, fitness: -348.88153076171875, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -353.4582824707031, equation: [y0 + y4, 2*y0 + 2*y1 + y4]
# Complexity: 11, fitness: -356.6578369140625, equation: [3.93*y0 + y1 + y4, y1 + y4]
# Complexity: 13, fitness: -362.5556335449219, equation: [2.62*y0 + y1 + y4, 1.31*y0 + 2*y1 - 0.767*y2 + y4]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 4, fitness: -69.41749572753906, equation: [y4 + y7, cos(y4 + y7)]
# Complexity: 5, fitness: -348.88153076171875, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -357.2806396484375, equation: [2.62*y0 + y1 + y4, 0.31*y0 + y1 + y4]
# Complexity: 13, fitness: -362.5556335449219, equation: [2.62*y0 + y1 + y4, 1.31*y0 + 2*y1 - 0.767*y2 + y4]
# Complexity: 16, fitness: -365.98846435546875, equation: [3*y0 + y1 - 1.53*y2 + y4 + cos(y7 + 1.12), y1 - 0.767*y2 + y4]
# Final pareto front:
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -39.82312774658203, equation: [0, y1 + y5]
# Complexity: 4, fitness: -69.41749572753906, equation: [y4 + y7, cos(y4 + y7)]
# Complexity: 5, fitness: -348.88153076171875, equation: [y0 + y4, y0 + y1 + y4]
# Complexity: 9, fitness: -357.2806396484375, equation: [2.62*y0 + y1 + y4, 0.31*y0 + y1 + y4]
# Complexity: 13, fitness: -362.5556335449219, equation: [2.62*y0 + y1 + y4, 1.31*y0 + 2*y1 - 0.767*y2 + y4]
# Complexity: 16, fitness: -365.98846435546875, equation: [3*y0 + y1 - 1.53*y2 + y4 + cos(y7 + 1.12), y1 - 0.767*y2 + y4]

# %%
brax_env = BraxGymnaxWrapper('hopper', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=3, max_nodes = 31)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated) 0.5
# Compiling code for evaluation and evolution...
# Finished compilation in 229.88 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: -212.6290283203125, equation: [0.639, 0, 0]
# Complexity: 2, fitness: -220.23828125, equation: [0, cos(y0), 0]
# Complexity: 4, fitness: -247.114501953125, equation: [0.418*sin(y0), 0, 0]
# Complexity: 5, fitness: -311.21728515625, equation: [0, y0*y1*y7 + y1*y7, 0]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -250.21961975097656, equation: [0, y4, 0]
# Complexity: 3, fitness: -283.03802490234375, equation: [0, y1*y7, 0]
# Complexity: 5, fitness: -326.82562255859375, equation: [y3*y7 + y4, y3*y7, 0]
# Complexity: 9, fitness: -418.9886779785156, equation: [y1*(-y10*y3 - y5 + y9), 0, -y5 + y9]
# Complexity: 17, fitness: -496.83721923828125, equation: [y7*(y10*y2*y4 + y3)*(y4 + y5 + y7*y8), y7*(y10*y2*y4 + y3), y10*y2 + y7*y8]
# Complexity: 20, fitness: -772.399658203125, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + sin(y6)) + 2*sin(y6), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -283.03802490234375, equation: [0, y1*y7, 0]
# Complexity: 5, fitness: -326.82562255859375, equation: [y3*y7 + y4, y3*y7, 0]
# Complexity: 7, fitness: -387.85198974609375, equation: [y1*(-y5 - y7 + y9), 0, -y5 + y9]
# Complexity: 9, fitness: -418.9886779785156, equation: [y1*(-y10*y3 - y5 + y9), 0, -y5 + y9]
# Complexity: 11, fitness: -515.0579833984375, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 19, fitness: -771.7730712890625, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + y10 + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + y10), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 20, fitness: -772.399658203125, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + sin(y6)) + 2*sin(y6), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -308.7515869140625, equation: [0, y7*y8, 0]
# Complexity: 4, fitness: -334.9556884765625, equation: [cos(y1*y9), y1*y9, 0]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 9, fitness: -465.6321716308594, equation: [y0 + y10*y4*(-y0 + y6), 0, y10*y4*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 11, fitness: -515.0594482421875, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 18, fitness: -520.448974609375, equation: [y1*(-y3*y5*y6 - y5 + y9), 2*y5*y6 + sin(y1*y4*y5*y6*(-y3*y5*y6 - y5 + y9)), -y5 + y9]
# Complexity: 19, fitness: -771.7730712890625, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + y10 + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + y10), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 20, fitness: -772.399658203125, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + sin(y6)) + 2*sin(y6), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 24, fitness: -772.505126953125, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + y2 + y5*(y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + sin(y6)) + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + sin(y6)) + 2*sin(y6), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 9, fitness: -512.1176147460938, equation: [y0 + y10*y4*(-y0 + y4), 0, y10*y4*(-y0 + y4) + y10*(-y0 + y4)]
# Complexity: 11, fitness: -515.0621337890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -577.6000366210938, equation: [y0*y10*y3*(-y0 + y1*y7) + y0, y1*y7, y0*y10*y3*(-y0 + y1*y7) + y10*(-y0 + y1*y7)]
# Complexity: 15, fitness: -639.577392578125, equation: [y1*(-y10*y3 - y5 + y9), y7*y8, y1*y2*(-y10*y3 - y5 + y9) - y5 + y7*y8 + y9]
# Complexity: 17, fitness: -837.1851806640625, equation: [y1*(-y10 - y3 - y5 + y9), y1*y6*y7*y8*(-y10 - y3 - y5 + y9) + y7*y8, y1*y4*y6*y7*y8*(-y10 - y3 - y5 + y9) - y5 + y9]
# Complexity: 22, fitness: -844.1870727539062, equation: [2*y0 + 2*y1*y10*(-y0 + y6) + y2 + y5*(y0*y1 + y3)*(y0 + y1*y10*(-y0 + y6) + sin(y6)) + (y0*y1 + y3)*(y0 + y1*y10*(-y0 + y6) + sin(y6)) + 2*sin(y6), y0*y1, y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -630.7437133789062, equation: [0, y7*(y3 - y5 + y9), -y5 + y7*(y3 - y5 + y9) - y7 + y9]
# Complexity: 10, fitness: -989.6425170898438, equation: [cos(y1*(y1 - y2 - y9 - 0.875)), y1*(y1 - y2 - y9 - 0.875), y2 + y9]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -630.7437133789062, equation: [0, y7*(y3 - y5 + y9), -y5 + y7*(y3 - y5 + y9) - y7 + y9]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 17, fitness: -998.4660034179688, equation: [0, y0*(y5 + y7*(-y0 + y2 - y4 + y8) + 0.157) + y4, y7*(-y0 + y2 - y4 + y8)]
# Complexity: 26, fitness: -1020.2431640625, equation: [y1*(-y10 - y4 - y5 + y9 - sin(y10*y3*y5*y6)), y1*y6*y7*y8*(-y10 - y4 - y5 + y9 - sin(y10*y3*y5*y6)) + y4 + y5*y6 + y7*y8 + 2*sin(y10*y3*y5*y6), y1*y4*y6*y7*y8*(-y10 - y4 - y5 + y9 - sin(y10*y3*y5*y6)) - y5 + y9]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -630.7437133789062, equation: [0, y7*(y3 - y5 + y9), -y5 + y7*(y3 - y5 + y9) - y7 + y9]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 17, fitness: -998.4660034179688, equation: [0, y0*(y5 + y7*(-y0 + y2 - y4 + y8) + 0.157) + y4, y7*(-y0 + y2 - y4 + y8)]
# Complexity: 22, fitness: -1017.31591796875, equation: [y1*(-y10 - y4 - y5 + y9 - sin(y10*y3*y5*y6)), y4 + y5*y6 + 2*sin(y10*y3*y5*y6), y1*y4*y6*(-y10 - y4 - y5 + y9 - sin(y10*y3*y5*y6)) - y5 + y9]
# Complexity: 26, fitness: -1020.7809448242188, equation: [y1*(-y10 - y4 - y5 + y9 + sin(0.771*y10*y5*y6)), y1*y6*y7*y8*(-y10 - y4 - y5 + y9 + sin(0.771*y10*y5*y6)) + y4 + y5*y6 + y7*y8 - 2*sin(0.771*y10*y5*y6), y1*y4*y6*y7*y8*(-y10 - y4 - y5 + y9 + sin(0.771*y10*y5*y6)) - y5 + y9]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -630.7437133789062, equation: [0, y7*(y3 - y5 + y9), -y5 + y7*(y3 - y5 + y9) - y7 + y9]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 17, fitness: -998.4660034179688, equation: [0, y0*(y5 + y7*(-y0 + y2 - y4 + y8) + 0.157) + y4, y7*(-y0 + y2 - y4 + y8)]
# Complexity: 22, fitness: -1017.31591796875, equation: [y1*(-y10 - y4 - y5 + y9 - sin(y10*y3*y5*y6)), y4 + y5*y6 + 2*sin(y10*y3*y5*y6), y1*y4*y6*(-y10 - y4 - y5 + y9 - sin(y10*y3*y5*y6)) - y5 + y9]
# Complexity: 26, fitness: -1026.87841796875, equation: [y1*(-y10*sin(y3) - y10 + 1.6*y3 - y4 - y5 + y9), y1*y6*y7*y8*(-y10*sin(y3) - y10 + 1.6*y3 - y4 - y5 + y9) - 3.2*y3 + y4 + y7*y8, y1*y4*y6*y7*y8*(-y10*sin(y3) - y10 + 1.6*y3 - y4 - y5 + y9) - y5 + y9]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -630.7437133789062, equation: [0, y7*(y3 - y5 + y9), -y5 + y7*(y3 - y5 + y9) - y7 + y9]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 17, fitness: -998.4660034179688, equation: [0, y0*(y5 + y7*(-y0 + y2 - y4 + y8) + 0.157) + y4, y7*(-y0 + y2 - y4 + y8)]
# Complexity: 18, fitness: -1008.671630859375, equation: [y1*(-y10 - y4 - y5 + y9 - sin(y7**2)), y4 + 2*sin(y7**2), y1*y4*y6*(-y10 - y4 - y5 + y9 - sin(y7**2)) - y5 + y9]
# Complexity: 22, fitness: -1017.31591796875, equation: [y1*(-y10 - y4 - y5 + y9 - sin(y10*y3*y5*y6)), y4 + y5*y6 + 2*sin(y10*y3*y5*y6), y1*y4*y6*(-y10 - y4 - y5 + y9 - sin(y10*y3*y5*y6)) - y5 + y9]
# Complexity: 26, fitness: -1029.729736328125, equation: [y1*(-y10*sin(y4) - y10 + 1.6*y3 - y4 - y5 + y9), y1*y6*y7*y8*(-y10*sin(y4) - y10 + 1.6*y3 - y4 - y5 + y9) - 3.2*y3 + y4 + y7*y8, y1*y4*y6*y7*y8*(-y10*sin(y4) - y10 + 1.6*y3 - y4 - y5 + y9) - y5 + y9]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -630.7437133789062, equation: [0, y7*(y3 - y5 + y9), -y5 + y7*(y3 - y5 + y9) - y7 + y9]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 15, fitness: -995.5604858398438, equation: [0, y0*(y5 + y7*(-y0 + y2 - y4 + y8)) + y4, y7*(-y0 + y2 - y4 + y8)]
# Complexity: 17, fitness: -998.4660034179688, equation: [0, y0*(y5 + y7*(-y0 + y2 - y4 + y8) + 0.157) + y4, y7*(-y0 + y2 - y4 + y8)]
# Complexity: 18, fitness: -1008.671630859375, equation: [y1*(-y10 - y4 - y5 + y9 - sin(y7**2)), y4 + 2*sin(y7**2), y1*y4*y6*(-y10 - y4 - y5 + y9 - sin(y7**2)) - y5 + y9]
# Complexity: 21, fitness: -1026.625244140625, equation: [y1*(-y10 + 1.6*y3 - y4 - y5 + y9), y1*y3*y7*y8*(-y10 + 1.6*y3 - y4 - y5 + y9) - 3.2*y3 + y4 + y7*y8, y1*y3*y4*y7*y8*(-y10 + 1.6*y3 - y4 - y5 + y9) - y5 + y9]
# Complexity: 22, fitness: -1026.9517822265625, equation: [y1*(-y0*(y4 + y5) - y5 + y9), y4 + y5*y6 + 2*sin(y1*y4*y5*y6*y9*(-y0*(y4 + y5) - y5 + y9)), -y5 + y9]
# Complexity: 25, fitness: -1031.557373046875, equation: [y1*(-y10*y7 - y10 + 1.6*y3 - y4 - y5 + y9), y1*y6*y7*y8*(-y10*y7 - y10 + 1.6*y3 - y4 - y5 + y9) - 3.2*y3 + y4 + y7*y8, y1*y4*y6*y7*y8*(-y10*y7 - y10 + 1.6*y3 - y4 - y5 + y9) - y5 + y9]
# Complexity: 26, fitness: -1033.8642578125, equation: [y1*(-y10*sin(y3) - y10 + 2.6*y3 - y4 - y5), -3.2*y3 + y4 + y7*y8*(y1*(-y10*sin(y3) - y10 + 2.6*y3 - y4 - y5) + y6) + y7*y8, y3 + y4*y7*y8*(y1*(-y10*sin(y3) - y10 + 2.6*y3 - y4 - y5) + y6) - y5]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -630.7437133789062, equation: [0, y7*(y3 - y5 + y9), -y5 + y7*(y3 - y5 + y9) - y7 + y9]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 15, fitness: -995.5604858398438, equation: [0, y0*(y5 + y7*(-y0 + y2 - y4 + y8)) + y4, y7*(-y0 + y2 - y4 + y8)]
# Complexity: 17, fitness: -1001.4931640625, equation: [0, y0*(0.157*y5 + y7*(-y0 + y2 - y4 + y8)) + y4, y7*(-y0 + y2 - y4 + y8)]
# Complexity: 18, fitness: -1008.671630859375, equation: [y1*(-y10 - y4 - y5 + y9 - sin(y7**2)), y4 + 2*sin(y7**2), y1*y4*y6*(-y10 - y4 - y5 + y9 - sin(y7**2)) - y5 + y9]
# Complexity: 21, fitness: -1030.61083984375, equation: [y1*(1.6*y3 - y4), y1*y6*y7*(1.6*y3 - y4)*(-y5 + y9) - 3.2*y3 + y4 + y7*(-y5 + y9), y1*y4*y6*y7*(1.6*y3 - y4)*(-y5 + y9) - y5 + y9]
# Complexity: 25, fitness: -1031.65673828125, equation: [y1*(-y10*y7 - y10 + 1.6*y3 - y4 - y5 + y9), y1*y6*y7*y8*(-y10*y7 - y10 + 1.6*y3 - y4 - y5 + y9) - 3.2*y3 + y4 + y7*y8, y1*y4*y6*y7*y8*(-y10*y7 - y10 + 1.6*y3 - y4 - y5 + y9) - y5 + y9]
# Complexity: 26, fitness: -1036.0638427734375, equation: [y1*(-y10*sin(y2) - y10 + 2.6*y3 - y4 - y5), -3.2*y3 + y4 + y7*y8*(y1*(-y10*sin(y2) - y10 + 2.6*y3 - y4 - y5) + y6) + y7*y8, y3 + y4*y7*y8*(y1*(-y10*sin(y2) - y10 + 2.6*y3 - y4 - y5) + y6) - y5]
# Complexity: 29, fitness: -1041.8387451171875, equation: [y1*(-y10*sin(y3) - y10 - y4*sin(y10*y7*y8) - y5 + y9), y1*y5*y7*y8*(-y10*sin(y3) - y10 - y4*sin(y10*y7*y8) - y5 + y9) + y4*sin(y10*y7*y8) + y7*y8 + sin(y10*y7*y8), y1*y4*y5*y7*y8*(-y10*sin(y3) - y10 - y4*sin(y10*y7*y8) - y5 + y9) - y5 + y7*y8 + y9]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -823.4652709960938, equation: [0, y5 + y7*(-y0 + y2 + y8), y7*(-y0 + y2 + y8)]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 15, fitness: -995.5604858398438, equation: [0, y0*(y5 + y7*(-y0 + y2 - y4 + y8)) + y4, y7*(-y0 + y2 - y4 + y8)]
# Complexity: 17, fitness: -1001.4931640625, equation: [0, y0*(0.157*y5 + y7*(-y0 + y2 - y4 + y8)) + y4, y7*(-y0 + y2 - y4 + y8)]
# Complexity: 18, fitness: -1008.671630859375, equation: [y1*(-y10 - y4 - y5 + y9 - sin(y7**2)), y4 + 2*sin(y7**2), y1*y4*y6*(-y10 - y4 - y5 + y9 - sin(y7**2)) - y5 + y9]
# Complexity: 21, fitness: -1030.61083984375, equation: [y1*(1.6*y3 - y4), y1*y6*y7*(1.6*y3 - y4)*(-y5 + y9) - 3.2*y3 + y4 + y7*(-y5 + y9), y1*y4*y6*y7*(1.6*y3 - y4)*(-y5 + y9) - y5 + y9]
# Complexity: 23, fitness: -1033.62158203125, equation: [y1*(-y10 + 1.6*y3 - y4 - y5), -3.2*y3 + y4 + y7*y8*(y1*(-y10 + 1.6*y3 - y4 - y5) + y6) + y7*y8, y3 + y4*y7*y8*(y1*(-y10 + 1.6*y3 - y4 - y5) + y6) - y5]
# Complexity: 26, fitness: -1036.1873779296875, equation: [y1*(-y10*sin(y2) - y10 + 2.6*y3 - y4 - y5), -3.2*y3 + y4 + y7*y8*(y1*(-y10*sin(y2) - y10 + 2.6*y3 - y4 - y5) + y6) + y7*y8, y3 + y4*y7*y8*(y1*(-y10*sin(y2) - y10 + 2.6*y3 - y4 - y5) + y6) - y5]
# Complexity: 29, fitness: -1041.8387451171875, equation: [y1*(-y10*sin(y3) - y10 - y4*sin(y10*y7*y8) - y5 + y9), y1*y5*y7*y8*(-y10*sin(y3) - y10 - y4*sin(y10*y7*y8) - y5 + y9) + y4*sin(y10*y7*y8) + y7*y8 + sin(y10*y7*y8), y1*y4*y5*y7*y8*(-y10*sin(y3) - y10 - y4*sin(y10*y7*y8) - y5 + y9) - y5 + y7*y8 + y9]
# Complexity: 30, fitness: -1042.128173828125, equation: [y1*(-y10*y7 - y10 - y4 - y5 + y9 - sin(y5**2*y7*y8)), y1**2*y6*y7*(-y10*y7 - y10 - y4 - y5 + y9 - sin(y5**2*y7*y8)) + y1*y7 + y4 + y5**2 + 2*sin(y5**2*y7*y8), y1**2*y4*y6*y7*(-y10*y7 - y10 - y4 - y5 + y9 - sin(y5**2*y7*y8)) - y5 + y7*y8 + y9]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -823.4652709960938, equation: [0, y5 + y7*(-y0 + y2 + y8), y7*(-y0 + y2 + y8)]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 15, fitness: -995.5604858398438, equation: [0, y0*(y5 + y7*(-y0 + y2 - y4 + y8)) + y4, y7*(-y0 + y2 - y4 + y8)]
# Complexity: 17, fitness: -1016.2225341796875, equation: [0, y0*(0.157*y5 + y7*(-y0 + y10 + y2 - y4)) + y4, y7*(-y0 + y10 + y2 - y4)]
# Complexity: 19, fitness: -1039.7984619140625, equation: [0, y0*y7*(-y0 + y10 + y2 + y3*y8 - y4 + y9) + y4, y3*y8 + y7*(-y0 + y10 + y2 + y3*y8 - y4 + y9)]
# Complexity: 29, fitness: -1041.8387451171875, equation: [y1*(-y10*sin(y3) - y10 - y4*sin(y10*y7*y8) - y5 + y9), y1*y5*y7*y8*(-y10*sin(y3) - y10 - y4*sin(y10*y7*y8) - y5 + y9) + y4*sin(y10*y7*y8) + y7*y8 + sin(y10*y7*y8), y1*y4*y5*y7*y8*(-y10*sin(y3) - y10 - y4*sin(y10*y7*y8) - y5 + y9) - y5 + y7*y8 + y9]
# Complexity: 30, fitness: -1042.128173828125, equation: [y1*(-y10*y7 - y10 - y4 - y5 + y9 - sin(y5**2*y7*y8)), y1**2*y6*y7*(-y10*y7 - y10 - y4 - y5 + y9 - sin(y5**2*y7*y8)) + y1*y7 + y4 + y5**2 + 2*sin(y5**2*y7*y8), y1**2*y4*y6*y7*(-y10*y7 - y10 - y4 - y5 + y9 - sin(y5**2*y7*y8)) - y5 + y7*y8 + y9]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -823.4652709960938, equation: [0, y5 + y7*(-y0 + y2 + y8), y7*(-y0 + y2 + y8)]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 13, fitness: -1003.4210815429688, equation: [0, y0*(y5 + y7*(y1*y9 - 1.9)) + y4, y7*(y1*y9 - 1.9)]
# Complexity: 17, fitness: -1016.2225341796875, equation: [0, y0*(0.157*y5 + y7*(-y0 + y10 + y2 - y4)) + y4, y7*(-y0 + y10 + y2 - y4)]
# Complexity: 19, fitness: -1039.7984619140625, equation: [0, y0*y7*(-y0 + y10 + y2 + y3*y8 - y4 + y9) + y4, y3*y8 + y7*(-y0 + y10 + y2 + y3*y8 - y4 + y9)]
# Complexity: 27, fitness: -1050.9210205078125, equation: [y1**2*(-y10*y7 - y10 + 1.6*y3 - y5 + y9 - 0.118) + y1*(-y10*y7 - y10 + 1.6*y3 - y5 + y9 - 0.118), y1**2*y5*y7*y8*(-y10*y7 - y10 + 1.6*y3 - y5 + y9 - 0.118) - 3.2*y3 + y7*y8 + 0.118, y1**2*y4*y5*y7*y8*(-y10*y7 - y10 + 1.6*y3 - y5 + y9 - 0.118) - y5 + y9]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -823.4652709960938, equation: [0, y5 + y7*(-y0 + y2 + y8), y7*(-y0 + y2 + y8)]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 13, fitness: -1003.4210815429688, equation: [0, y0*(y5 + y7*(y1*y9 - 1.9)) + y4, y7*(y1*y9 - 1.9)]
# Complexity: 15, fitness: -1015.226318359375, equation: [0, y0*(0.157*y5 + y7*(-y0 + y10 - y4)) + y4, y7*(-y0 + y10 - y4)]
# Complexity: 17, fitness: -1026.508056640625, equation: [y1*(-y10 - 2*y5 + y9), y1*y6*y7*y8*(-y10 - 2*y5 + y9) + y7*y8, y1*y6*y7*y8*y9*(-y10 - 2*y5 + y9) - y5 + y9]
# Complexity: 19, fitness: -1039.7984619140625, equation: [0, y0*y7*(-y0 + y10 + y2 + y3*y8 - y4 + y9) + y4, y3*y8 + y7*(-y0 + y10 + y2 + y3*y8 - y4 + y9)]
# Complexity: 23, fitness: -1044.826904296875, equation: [0, y0*y7*(-y0 + y10 + y2 + y3*(y3*y4 - y9) - y4 + y9) + 2*y3*y4 + y4 - y9, y3*(y3*y4 - y9) + y7*(-y0 + y10 + y2 + y3*(y3*y4 - y9) - y4 + y9)]
# Complexity: 27, fitness: -1050.971435546875, equation: [y1**2*(-y10*y7 - y10 + 1.6*y3 - y5 + y9 - 0.118) + y1*(-y10*y7 - y10 + 1.6*y3 - y5 + y9 - 0.118), y1**2*y5*y7*y8*(-y10*y7 - y10 + 1.6*y3 - y5 + y9 - 0.118) - 3.2*y3 + y7*y8 + 0.118, y1**2*y4*y5*y7*y8*(-y10*y7 - y10 + 1.6*y3 - y5 + y9 - 0.118) - y5 + y9]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -823.4652709960938, equation: [0, y5 + y7*(-y0 + y2 + y8), y7*(-y0 + y2 + y8)]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 13, fitness: -1003.4210815429688, equation: [0, y0*(y5 + y7*(y1*y9 - 1.9)) + y4, y7*(y1*y9 - 1.9)]
# Complexity: 15, fitness: -1015.226318359375, equation: [0, y0*(0.157*y5 + y7*(-y0 + y10 - y4)) + y4, y7*(-y0 + y10 - y4)]
# Complexity: 17, fitness: -1044.6129150390625, equation: [0, y0*(-0.286*y6 + y7*(y2 - y3 + y6 - 1.9)) + y4, y7*(y2 - y3 + y6 - 1.9)]
# Complexity: 23, fitness: -1044.826904296875, equation: [0, y0*y7*(-y0 + y10 + y2 + y3*(y3*y4 - y9) - y4 + y9) + 2*y3*y4 + y4 - y9, y3*(y3*y4 - y9) + y7*(-y0 + y10 + y2 + y3*(y3*y4 - y9) - y4 + y9)]
# Complexity: 27, fitness: -1050.971435546875, equation: [y1**2*(-y10*y7 - y10 + 1.6*y3 - y5 + y9 - 0.118) + y1*(-y10*y7 - y10 + 1.6*y3 - y5 + y9 - 0.118), y1**2*y5*y7*y8*(-y10*y7 - y10 + 1.6*y3 - y5 + y9 - 0.118) - 3.2*y3 + y7*y8 + 0.118, y1**2*y4*y5*y7*y8*(-y10*y7 - y10 + 1.6*y3 - y5 + y9 - 0.118) - y5 + y9]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -823.4652709960938, equation: [0, y5 + y7*(-y0 + y2 + y8), y7*(-y0 + y2 + y8)]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 13, fitness: -1003.4210815429688, equation: [0, y0*(y5 + y7*(y1*y9 - 1.9)) + y4, y7*(y1*y9 - 1.9)]
# Complexity: 15, fitness: -1015.226318359375, equation: [0, y0*(0.157*y5 + y7*(-y0 + y10 - y4)) + y4, y7*(-y0 + y10 - y4)]
# Complexity: 17, fitness: -1044.6129150390625, equation: [0, y0*(-0.286*y6 + y7*(y2 - y3 + y6 - 1.9)) + y4, y7*(y2 - y3 + y6 - 1.9)]
# Complexity: 21, fitness: -1060.06005859375, equation: [0, y0*y7*(-y0 + y3*y8 - y4 + y5*y6 - y7*y8) + y4, y3*y8 + y5*y6 + y7*(-y0 + y3*y8 - y4 + y5*y6 - y7*y8)]
# Complexity: 30, fitness: -1061.5477294921875, equation: [y1*(-y10 - y5 - y7*y8*(-1.6*y3 + y4)*sin(y3)), -3.2*y3 + y4*y7*(y1*(-y10 - y5 - y7*y8*(-1.6*y3 + y4)*sin(y3)) + y6) + y4*y7 + y4, y3 + y4**2*y7*(y1*(-y10 - y5 - y7*y8*(-1.6*y3 + y4)*sin(y3)) + y6) - y5 + y7*y8]
# Complexity: 31, fitness: -1086.753662109375, equation: [y1*(1.6*y0*y3 + y8) + y1*(-y10*y7 - y5**2 - y5 - y7**2 + y9), y1**2*y6*(1.6*y0*y3 + y8)*(-y10*y7 - y5**2 - y5 - y7**2 + y9) - 1.6*y3 + y5**2, y1**2*y4*y6*(1.6*y0*y3 + y8)*(-y10*y7 - y5**2 - y5 - y7**2 + y9) - y5 + y7**2 + y9]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -823.4652709960938, equation: [0, y5 + y7*(-y0 + y2 + y8), y7*(-y0 + y2 + y8)]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 13, fitness: -1003.4210815429688, equation: [0, y0*(y5 + y7*(y1*y9 - 1.9)) + y4, y7*(y1*y9 - 1.9)]
# Complexity: 15, fitness: -1015.226318359375, equation: [0, y0*(0.157*y5 + y7*(-y0 + y10 - y4)) + y4, y7*(-y0 + y10 - y4)]
# Complexity: 17, fitness: -1044.6129150390625, equation: [0, y0*(-0.286*y6 + y7*(y2 - y3 + y6 - 1.9)) + y4, y7*(y2 - y3 + y6 - 1.9)]
# Complexity: 21, fitness: -1063.6820068359375, equation: [0, y0*y7*(-y0 + y3*y8 - y4 + y5*y6 - y7*y8) + y4, y3*y8 + y5*y6 + y7*(-y0 + y3*y8 - y4 + y5*y6 - y7*y8)]
# Complexity: 31, fitness: -1086.753662109375, equation: [y1*(1.6*y0*y3 + y8) + y1*(-y10*y7 - y5**2 - y5 - y7**2 + y9), y1**2*y6*(1.6*y0*y3 + y8)*(-y10*y7 - y5**2 - y5 - y7**2 + y9) - 1.6*y3 + y5**2, y1**2*y4*y6*(1.6*y0*y3 + y8)*(-y10*y7 - y5**2 - y5 - y7**2 + y9) - y5 + y7**2 + y9]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -823.4652709960938, equation: [0, y5 + y7*(-y0 + y2 + y8), y7*(-y0 + y2 + y8)]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 13, fitness: -1003.4210815429688, equation: [0, y0*(y5 + y7*(y1*y9 - 1.9)) + y4, y7*(y1*y9 - 1.9)]
# Complexity: 15, fitness: -1015.226318359375, equation: [0, y0*(0.157*y5 + y7*(-y0 + y10 - y4)) + y4, y7*(-y0 + y10 - y4)]
# Complexity: 17, fitness: -1044.6129150390625, equation: [0, y0*(-0.286*y6 + y7*(y2 - y3 + y6 - 1.9)) + y4, y7*(y2 - y3 + y6 - 1.9)]
# Complexity: 21, fitness: -1063.6820068359375, equation: [0, y0*y7*(-y0 + y3*y8 - y4 + y5*y6 - y7*y8) + y4, y3*y8 + y5*y6 + y7*(-y0 + y3*y8 - y4 + y5*y6 - y7*y8)]
# Complexity: 23, fitness: -1078.8433837890625, equation: [y1*y10*(-y10 + 2.6*y3 - y5 - 0.118) + y1*(-y10 + 2.6*y3 - y5 - 0.118), y1*y10*y5*y7*y8*(-y10 + 2.6*y3 - y5 - 0.118) - 3.2*y3 + y7*y8 + 0.118, y1*y10*y4*y5*y7*y8*(-y10 + 2.6*y3 - y5 - 0.118) + y3 - y5]
# Complexity: 25, fitness: -1087.462646484375, equation: [y1*y10*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118) + y1*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118), y1*y10*y5*y7*y8*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118) + y3 + y7*y8 + 0.118, y1*y10*y4*y5*y7*y8*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118) - y5 + y9]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -823.4652709960938, equation: [0, y5 + y7*(-y0 + y2 + y8), y7*(-y0 + y2 + y8)]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 13, fitness: -1003.4210815429688, equation: [0, y0*(y5 + y7*(y1*y9 - 1.9)) + y4, y7*(y1*y9 - 1.9)]
# Complexity: 15, fitness: -1015.226318359375, equation: [0, y0*(0.157*y5 + y7*(-y0 + y10 - y4)) + y4, y7*(-y0 + y10 - y4)]
# Complexity: 17, fitness: -1044.6129150390625, equation: [0, y0*(-0.286*y6 + y7*(y2 - y3 + y6 - 1.9)) + y4, y7*(y2 - y3 + y6 - 1.9)]
# Complexity: 21, fitness: -1063.6820068359375, equation: [0, y0*y7*(-y0 + y3*y8 - y4 + y5*y6 - y7*y8) + y4, y3*y8 + y5*y6 + y7*(-y0 + y3*y8 - y4 + y5*y6 - y7*y8)]
# Complexity: 23, fitness: -1078.8433837890625, equation: [y1*y10*(-y10 + 2.6*y3 - y5 - 0.118) + y1*(-y10 + 2.6*y3 - y5 - 0.118), y1*y10*y5*y7*y8*(-y10 + 2.6*y3 - y5 - 0.118) - 3.2*y3 + y7*y8 + 0.118, y1*y10*y4*y5*y7*y8*(-y10 + 2.6*y3 - y5 - 0.118) + y3 - y5]
# Complexity: 25, fitness: -1089.8709716796875, equation: [y1*y10*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118) + y1*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118), y1*y10*y5*y7*y8*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118) + y3 + y7*y8 + 0.118, y1*y10*y4*y5*y7*y8*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118) - y5 + y9]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -823.4652709960938, equation: [0, y5 + y7*(-y0 + y2 + y8), y7*(-y0 + y2 + y8)]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 13, fitness: -1003.4210815429688, equation: [0, y0*(y5 + y7*(y1*y9 - 1.9)) + y4, y7*(y1*y9 - 1.9)]
# Complexity: 15, fitness: -1015.226318359375, equation: [0, y0*(0.157*y5 + y7*(-y0 + y10 - y4)) + y4, y7*(-y0 + y10 - y4)]
# Complexity: 17, fitness: -1044.6129150390625, equation: [0, y0*(-0.286*y6 + y7*(y2 - y3 + y6 - 1.9)) + y4, y7*(y2 - y3 + y6 - 1.9)]
# Complexity: 21, fitness: -1063.6820068359375, equation: [0, y0*y7*(-y0 + y3*y8 - y4 + y5*y6 - y7*y8) + y4, y3*y8 + y5*y6 + y7*(-y0 + y3*y8 - y4 + y5*y6 - y7*y8)]
# Complexity: 23, fitness: -1078.8433837890625, equation: [y1*y10*(-y10 + 2.6*y3 - y5 - 0.118) + y1*(-y10 + 2.6*y3 - y5 - 0.118), y1*y10*y5*y7*y8*(-y10 + 2.6*y3 - y5 - 0.118) - 3.2*y3 + y7*y8 + 0.118, y1*y10*y4*y5*y7*y8*(-y10 + 2.6*y3 - y5 - 0.118) + y3 - y5]
# Complexity: 25, fitness: -1098.68505859375, equation: [y1*y10*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118) + y1*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118), y1*y10*y5*y7*y8*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118) + y3 + y7*y8 + 0.118, y1*y10*y4*y5*y7*y8*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118) - y5 + y9]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -823.4652709960938, equation: [0, y5 + y7*(-y0 + y2 + y8), y7*(-y0 + y2 + y8)]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 13, fitness: -1005.5557861328125, equation: [0, y4 + y7*(-2*y0 + y3 - y4 + y8), y7*(-2*y0 + y3 - y4 + y8)]
# Complexity: 15, fitness: -1015.226318359375, equation: [0, y0*(0.157*y5 + y7*(-y0 + y10 - y4)) + y4, y7*(-y0 + y10 - y4)]
# Complexity: 17, fitness: -1044.6129150390625, equation: [0, y0*(-0.286*y6 + y7*(y2 - y3 + y6 - 1.9)) + y4, y7*(y2 - y3 + y6 - 1.9)]
# Complexity: 21, fitness: -1063.6820068359375, equation: [0, y0*y7*(-y0 + y3*y8 - y4 + y5*y6 - y7*y8) + y4, y3*y8 + y5*y6 + y7*(-y0 + y3*y8 - y4 + y5*y6 - y7*y8)]
# Complexity: 23, fitness: -1078.8433837890625, equation: [y1*y10*(-y10 + 2.6*y3 - y5 - 0.118) + y1*(-y10 + 2.6*y3 - y5 - 0.118), y1*y10*y5*y7*y8*(-y10 + 2.6*y3 - y5 - 0.118) - 3.2*y3 + y7*y8 + 0.118, y1*y10*y4*y5*y7*y8*(-y10 + 2.6*y3 - y5 - 0.118) + y3 - y5]
# Complexity: 25, fitness: -1101.9124755859375, equation: [y1*y10*(y10*y7 - y3 - y5 - y6 + y9 - 0.118) + y1*(y10*y7 - y3 - y5 - y6 + y9 - 0.118), y1*y10*y5*y7*y8*(y10*y7 - y3 - y5 - y6 + y9 - 0.118) + y3 + y7*y8 + 0.118, y1*y10*y4*y5*y7*y8*(y10*y7 - y3 - y5 - y6 + y9 - 0.118) - y5 + y9]
# Complexity: 27, fitness: -1121.068603515625, equation: [y1**2*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) + y1*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118), 2*y0*y3 + y1**2*y5*y7*y8*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) + y7*y8 + 0.118, y1**2*y5*y6*y7*y8*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) - y5 + y9]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -823.4652709960938, equation: [0, y5 + y7*(-y0 + y2 + y8), y7*(-y0 + y2 + y8)]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 13, fitness: -1005.5557861328125, equation: [0, y4 + y7*(-2*y0 + y3 - y4 + y8), y7*(-2*y0 + y3 - y4 + y8)]
# Complexity: 15, fitness: -1015.226318359375, equation: [0, y0*(0.157*y5 + y7*(-y0 + y10 - y4)) + y4, y7*(-y0 + y10 - y4)]
# Complexity: 17, fitness: -1044.6129150390625, equation: [0, y0*(-0.286*y6 + y7*(y2 - y3 + y6 - 1.9)) + y4, y7*(y2 - y3 + y6 - 1.9)]
# Complexity: 21, fitness: -1117.75390625, equation: [y1*y10*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118) + y1*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118), y3 + 0.118, y1*y10*y4*y5*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118) - y5 + y9]
# Complexity: 27, fitness: -1121.068603515625, equation: [y1**2*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) + y1*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118), 2*y0*y3 + y1**2*y5*y7*y8*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) + y7*y8 + 0.118, y1**2*y5*y6*y7*y8*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) - y5 + y9]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -823.4652709960938, equation: [0, y5 + y7*(-y0 + y2 + y8), y7*(-y0 + y2 + y8)]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 13, fitness: -1005.5557861328125, equation: [0, y4 + y7*(-2*y0 + y3 - y4 + y8), y7*(-2*y0 + y3 - y4 + y8)]
# Complexity: 15, fitness: -1015.226318359375, equation: [0, y0*(0.157*y5 + y7*(-y0 + y10 - y4)) + y4, y7*(-y0 + y10 - y4)]
# Complexity: 17, fitness: -1044.6129150390625, equation: [0, y0*(-0.286*y6 + y7*(y2 - y3 + y6 - 1.9)) + y4, y7*(y2 - y3 + y6 - 1.9)]
# Complexity: 21, fitness: -1119.190185546875, equation: [y1*y10*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118) + y1*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118), y3 + 0.118, y1*y10*y4*y8*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118) - y5 + y9]
# Complexity: 25, fitness: -1135.3309326171875, equation: [y1**2*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) + y1*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118), 2*y0*y3 + y1**2*y5**2*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) + 0.118, y1**2*y5**2*y6*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) - y5 + y9]
# Complexity: 27, fitness: -1135.3564453125, equation: [y1**2*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) + y1*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118), 2*y0*y3 + y1**2*y3*y5**2*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) + 0.118, y1**2*y3*y5**2*y6*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) - y5 + y9]
# Final pareto front:
# Complexity: 1, fitness: -250.22027587890625, equation: [0, y4, 0]
# Complexity: 3, fitness: -411.11865234375, equation: [0, 0, -y5 + y9]
# Complexity: 5, fitness: -464.270263671875, equation: [0, 0, -2*y5 - y7 + 2*y9]
# Complexity: 8, fitness: -477.6687316894531, equation: [0, y5*y6 + sin(y5*y6*(-y5 + y9)), -y5 + y9]
# Complexity: 9, fitness: -823.4652709960938, equation: [0, y5 + y7*(-y0 + y2 + y8), y7*(-y0 + y2 + y8)]
# Complexity: 10, fitness: -990.1773071289062, equation: [cos(y1*(-y2 + y3 - y9 - 0.875)), y1*(-y2 + y3 - y9 - 0.875), y2 + y9]
# Complexity: 13, fitness: -1005.5557861328125, equation: [0, y4 + y7*(-2*y0 + y3 - y4 + y8), y7*(-2*y0 + y3 - y4 + y8)]
# Complexity: 15, fitness: -1015.226318359375, equation: [0, y0*(0.157*y5 + y7*(-y0 + y10 - y4)) + y4, y7*(-y0 + y10 - y4)]
# Complexity: 17, fitness: -1044.6129150390625, equation: [0, y0*(-0.286*y6 + y7*(y2 - y3 + y6 - 1.9)) + y4, y7*(y2 - y3 + y6 - 1.9)]
# Complexity: 21, fitness: -1119.190185546875, equation: [y1*y10*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118) + y1*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118), y3 + 0.118, y1*y10*y4*y8*(-y10*y7 - y10 - y3 - y5 + y9 - 0.118) - y5 + y9]
# Complexity: 25, fitness: -1135.3309326171875, equation: [y1**2*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) + y1*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118), 2*y0*y3 + y1**2*y5**2*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) + 0.118, y1**2*y5**2*y6*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) - y5 + y9]
# Complexity: 27, fitness: -1135.3564453125, equation: [y1**2*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) + y1*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118), 2*y0*y3 + y1**2*y3*y5**2*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) + 0.118, y1**2*y3*y5**2*y6*(-y0*y3 - y10**2 - y10 - y5 + y9 - 0.118) - y5 + y9]
