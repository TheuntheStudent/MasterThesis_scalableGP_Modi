# %%
from genetic_programming import GeneticProgramming
from fitness_functions.Gymnax_fitness_function import GymFitnessFunction

import jax
import jax.numpy as jnp
import jax.random as jr

import brax
from brax import envs
import matplotlib.pyplot as plt

class BraxGymnaxWrapper:
    def __init__(self, env_name, backend):
        self.env = envs.get_environment(env_name=env_name, backend=backend)
        self.observation_space = self.env.observation_size
        self.action_space = self.env.action_size

    # state, env_state = self.env.reset(subkey, self.env_params)

    def reset(self, key, params=None):
        #state consists of pipeline_state, obs, reward, done, metrics, info
        state = self.env.reset(key)
        return state.obs, state

     # next_state, next_env_state, reward, done, _ = self.env.step(
     #            subkey, env_state, action, self.env_params
     #        )

    def step(self, key, state, action, params=None):

      action = action.reshape(self.action_space)
      next_state = self.env.step(state, action)
      done = next_state.done

      # Freeze state after done
      obs = jnp.where(done, state.obs, next_state.obs)
      new_state = jax.tree.map(
          lambda new, old: jnp.where(done, old, new),
          next_state,
          state
      )

      reward = jnp.where(done, 0.0, next_state.reward)

      return obs, new_state, reward, done, {}
# Out:
# E0606 11:40:48.498806  272823 cuda_executor.cc:1526] Could not get kernel mode driver version: (INVALID_ARGUMENT: Version does not match the format X.Y.Z)
# E0606 11:40:48.517159  272715 cuda_executor.cc:1526] Could not get kernel mode driver version: (INVALID_ARGUMENT: Version does not match the format X.Y.Z)
# These device(s) are detected: [CudaDevice(id=0)]
# Failed to import warp: No module named 'warp'
# Failed to import mujoco_warp: No module named 'warp'

# %%
brax_env = BraxGymnaxWrapper('inverted_pendulum', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=1, max_nodes= 15)
# Out:
# /home/theun/yes/envs/modi_kozax/lib/python3.12/site-packages/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated) 0.1
# Compiling code for evaluation and evolution...
# Finished compilation in 88.80 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: -7.25, equation: [-0.0638]
# Complexity: 2, fitness: -93.875, equation: [sin(y3)]
# Complexity: 4, fitness: -233.375, equation: [y1 + sin(y1)]
# Complexity: 5, fitness: -252.8125, equation: [3.42*y1]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [y0*(y2 + y3) + y1]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [y0*(y2 + y3) + y1]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [y0*(y0 + y2) + y1]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [y0*(y0 + y2) + y1]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -281.3125, equation: [0.15*y0 + y1]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [y0*(y0 + y2) + y1]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -281.3125, equation: [0.15*y0 + y1]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -281.3125, equation: [0.15*y0 + y1]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# Final pareto front:
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]

# %%
brax_env = BraxGymnaxWrapper('inverted_double_pendulum', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=1, max_nodes= 15)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated) 0.1
# Compiling code for evaluation and evolution...
# Finished compilation in 90.53 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: -184.10488891601562, equation: [-0.0638]
# Complexity: 2, fitness: -440.75897216796875, equation: [sin(y1)]
# Complexity: 3, fitness: -775.4652709960938, equation: [y2 - y7]
# Complexity: 7, fitness: -1006.9361572265625, equation: [0.486*y7*(y7 - 1.94)]
# Complexity: 9, fitness: -1246.233154296875, equation: [(y1 - 0.743)*(y2 + y4*y7)]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -424.4704895019531, equation: [y6]
# Complexity: 2, fitness: -440.75897216796875, equation: [sin(y1)]
# Complexity: 3, fitness: -815.1287231445312, equation: [y1 - y7]
# Complexity: 7, fitness: -1006.9361572265625, equation: [0.486*y7*(y7 - 1.94)]
# Complexity: 9, fitness: -1246.233154296875, equation: [(y1 - 0.743)*(y2 + y4*y7)]
# Complexity: 15, fitness: -2016.470703125, equation: [(y0**2 + y2)*(y3*y6 + 2*y5 - 1.76)]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -908.64208984375, equation: [y5 - y7]
# Complexity: 5, fitness: -7236.8759765625, equation: [y2*(y7 - 1.94)]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -908.64208984375, equation: [y5 - y7]
# Complexity: 4, fitness: -1091.970947265625, equation: [-sin(0.956*y7)]
# Complexity: 5, fitness: -7236.8759765625, equation: [y2*(y7 - 1.94)]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -1002.267578125, equation: [-0.956*y7]
# Complexity: 4, fitness: -1091.970947265625, equation: [-sin(0.956*y7)]
# Complexity: 5, fitness: -7236.8759765625, equation: [y2*(y7 - 1.94)]
# Complexity: 7, fitness: -8323.716796875, equation: [y2*(y2 + y6 - 1.94)]
# Complexity: 9, fitness: -9356.68359375, equation: [y2*(y1*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -1002.267578125, equation: [-0.956*y7]
# Complexity: 4, fitness: -1091.970947265625, equation: [-sin(0.956*y7)]
# Complexity: 5, fitness: -7236.8759765625, equation: [y2*(y7 - 1.94)]
# Complexity: 7, fitness: -9174.5078125, equation: [y2*(y2*y6 - 1.94)]
# Complexity: 9, fitness: -9356.68359375, equation: [y2*(y1*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -3001.00048828125, equation: [-3.88*y2]
# Complexity: 5, fitness: -7236.8759765625, equation: [y2*(y7 - 1.94)]
# Complexity: 7, fitness: -9174.5078125, equation: [y2*(y2*y6 - 1.94)]
# Complexity: 9, fitness: -9356.68359375, equation: [y2*(y1*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -3001.00048828125, equation: [-3.88*y2]
# Complexity: 4, fitness: -8868.197265625, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9356.68359375, equation: [y2*(y1*(y2 + y7) - 1.94)]
# Complexity: 13, fitness: -9356.697265625, equation: [y2*(y1*(y1*(y1 - 0.743) + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8708.32421875, equation: [-1.75*y2]
# Complexity: 4, fitness: -8868.197265625, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9356.68359375, equation: [y2*(y1*(y2 + y7) - 1.94)]
# Complexity: 11, fitness: -9356.6875, equation: [y2*(y1*(y2**2 + y7) - 1.94)]
# Complexity: 13, fitness: -9356.697265625, equation: [y2*(y1*(y1*(y1 - 0.743) + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8708.32421875, equation: [-1.75*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.083984375, equation: [y2*(y1*(y0 + y7) - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8708.32421875, equation: [-1.75*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# Complexity: 15, fitness: -9358.4716796875, equation: [y2*((-4.12*y2 - 4.12*y7)*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# Complexity: 15, fitness: -9358.4716796875, equation: [y2*((-4.12*y2 - 4.12*y7)*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 13, fitness: -9357.81640625, equation: [y2*(-4.12*y2*(y2 + y7) - 1.94)]
# Complexity: 15, fitness: -9358.51953125, equation: [y2*(-8.24*y7*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 13, fitness: -9358.34765625, equation: [y2*(-4.12*y7*(y2 + y7) - 1.94)]
# Complexity: 15, fitness: -9358.51953125, equation: [y2*(-8.24*y7*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9358.1240234375, equation: [y2*(-2.88*y0*y7 - 1.94)]
# Complexity: 13, fitness: -9358.34765625, equation: [y2*(-4.12*y7*(y2 + y7) - 1.94)]
# Complexity: 15, fitness: -9358.521484375, equation: [y2*(-7.76*y3*y7*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.544921875, equation: [y2*(2*y1*y7 - 1.94)]
# Complexity: 11, fitness: -9358.1240234375, equation: [y2*(-2.88*y0*y7 - 1.94)]
# Complexity: 13, fitness: -9358.34765625, equation: [y2*(-4.12*y7*(y2 + y7) - 1.94)]
# Complexity: 15, fitness: -9358.814453125, equation: [y2*((-4.12*y0 - 4.12*y7)*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.958984375, equation: [y2*(-5.46*y2*y7 - 1.94)]
# Complexity: 11, fitness: -9358.2177734375, equation: [y2*(y7*(y1 - 3.7*y7) - 1.94)]
# Complexity: 13, fitness: -9358.34765625, equation: [y2*(-4.12*y7*(y2 + y7) - 1.94)]
# Complexity: 15, fitness: -9358.814453125, equation: [y2*((-4.12*y0 - 4.12*y7)*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.958984375, equation: [y2*(-5.46*y2*y7 - 1.94)]
# Complexity: 11, fitness: -9358.310546875, equation: [y2*(-3.7*y7*(y2 + y7) - 1.94)]
# Complexity: 13, fitness: -9358.34765625, equation: [y2*(-4.12*y7*(y2 + y7) - 1.94)]
# Complexity: 15, fitness: -9358.814453125, equation: [y2*((-4.12*y0 - 4.12*y7)*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.958984375, equation: [y2*(-5.46*y2*y7 - 1.94)]
# Complexity: 11, fitness: -9358.7255859375, equation: [y2*(-3.7*y7*(y0 + y7) - 1.94)]
# Complexity: 15, fitness: -9358.814453125, equation: [y2*((-4.12*y0 - 4.12*y7)*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.958984375, equation: [y2*(-5.46*y2*y7 - 1.94)]
# Complexity: 11, fitness: -9358.7255859375, equation: [y2*(-3.7*y7*(y0 + y7) - 1.94)]
# Complexity: 13, fitness: -9358.7265625, equation: [y2*(y7*(-4.12*y0 - 4.12*y7) - 1.94)]
# Complexity: 15, fitness: -9358.814453125, equation: [y2*((-4.12*y0 - 4.12*y7)*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.958984375, equation: [y2*(-5.46*y2*y7 - 1.94)]
# Complexity: 10, fitness: -9358.2998046875, equation: [(-3.88*y0*y7 - 1.94)*sin(y2)]
# Complexity: 11, fitness: -9358.7255859375, equation: [y2*(-3.7*y7*(y0 + y7) - 1.94)]
# Complexity: 13, fitness: -9358.7265625, equation: [y2*(y7*(-4.12*y0 - 4.12*y7) - 1.94)]
# Complexity: 15, fitness: -9358.830078125, equation: [y2*(y3*(-3.88*y0 - 3.88*y7)*(y2 + y7) - 1.94)]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.958984375, equation: [y2*(-5.46*y2*y7 - 1.94)]
# Complexity: 10, fitness: -9358.2998046875, equation: [(-3.88*y0*y7 - 1.94)*sin(y2)]
# Complexity: 11, fitness: -9358.7255859375, equation: [y2*(-3.7*y7*(y0 + y7) - 1.94)]
# Complexity: 13, fitness: -9358.7265625, equation: [y2*(y7*(-4.12*y0 - 4.12*y7) - 1.94)]
# Complexity: 15, fitness: -9358.8681640625, equation: [y2*(-3.88*y7*(y0*y3 + 2*y7) - 1.94)]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9357.958984375, equation: [y2*(-5.46*y2*y7 - 1.94)]
# Complexity: 10, fitness: -9358.2998046875, equation: [(-3.88*y0*y7 - 1.94)*sin(y2)]
# Complexity: 11, fitness: -9358.7255859375, equation: [y2*(-3.7*y7*(y0 + y7) - 1.94)]
# Complexity: 13, fitness: -9358.728515625, equation: [y2*(-3.88*y7*(y0*y3 + y7) - 1.94)]
# Complexity: 15, fitness: -9358.8681640625, equation: [y2*(-3.88*y7*(y0*y3 + 2*y7) - 1.94)]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9358.30078125, equation: [y2*(-3.88*y0*y7 - 1.94)]
# Complexity: 11, fitness: -9358.7255859375, equation: [y2*(-3.7*y7*(y0 + y7) - 1.94)]
# Complexity: 13, fitness: -9358.7890625, equation: [y2*(y7*(-3.88*y0 + y5 - 3.88*y7) - 1.94)]
# Complexity: 15, fitness: -9358.8681640625, equation: [y2*(-3.88*y7*(y0*y3 + 2*y7) - 1.94)]
# Final pareto front:
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 4, fitness: -8868.1982421875, equation: [-1.76*sin(y2)]
# Complexity: 7, fitness: -9356.677734375, equation: [y2*(y1*y7 - 1.94)]
# Complexity: 9, fitness: -9358.30078125, equation: [y2*(-3.88*y0*y7 - 1.94)]
# Complexity: 11, fitness: -9358.7255859375, equation: [y2*(-3.7*y7*(y0 + y7) - 1.94)]
# Complexity: 13, fitness: -9358.7890625, equation: [y2*(y7*(-3.88*y0 + y5 - 3.88*y7) - 1.94)]
# Complexity: 15, fitness: -9358.8681640625, equation: [y2*(-3.88*y7*(y0*y3 + 2*y7) - 1.94)]

# %%
brax_env = BraxGymnaxWrapper('reacher', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=2, max_nodes= 30)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated) 0.1
# Compiling code for evaluation and evolution...
# Finished compilation in 193.32 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: 530.9840698242188, equation: [0, 0.639]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 5, fitness: 109.94471740722656, equation: [0, y1*y5 + y4]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 5, fitness: 88.23331451416016, equation: [0, y5*(y2 + y8)]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 112.55796813964844, equation: [0, 0.97*y8]
# Complexity: 5, fitness: 80.22433471679688, equation: [0, y5*(y6 + y8)]
# Complexity: 6, fitness: 77.90614318847656, equation: [0, y5*(y8 + sin(y8))]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 112.55796813964844, equation: [0, 0.97*y8]
# Complexity: 5, fitness: 80.22433471679688, equation: [0, y5*(y6 + y8)]
# Complexity: 6, fitness: 77.90614318847656, equation: [0, y5*(y8 + sin(y8))]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.90614318847656, equation: [0, y5*(y8 + sin(y8))]
# Complexity: 8, fitness: 77.90591430664062, equation: [0, y5*(y6 + y8 + sin(y8))]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.90614318847656, equation: [0, y5*(y8 + sin(y8))]
# Complexity: 8, fitness: 76.93787384033203, equation: [0, y5*(2*y8 + sin(y8))]
# Complexity: 11, fitness: 76.86323547363281, equation: [0, y5*(y6 + 2*y8) + y5*(y5*(y6 + 2*y8) + y8)]
# Complexity: 14, fitness: 76.42280578613281, equation: [0, y5*(y6 + 2*y8) + y5*(y5*(y6 + 2*y8) + y8 + sin(y8))]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.90614318847656, equation: [0, y5*(y8 + sin(y8))]
# Complexity: 7, fitness: 77.3086929321289, equation: [0, 2*y5*y8**2 + 2*y5*y8]
# Complexity: 8, fitness: 76.93787384033203, equation: [0, y5*(2*y8 + sin(y8))]
# Complexity: 10, fitness: 76.40482330322266, equation: [0, y5*(3*y8 + sin(y8))]
# Complexity: 15, fitness: 76.1158447265625, equation: [0, y5*(y6 + 4*y8) + y5*(y5*(y6 + 4*y8) + y8)]
# Complexity: 18, fitness: 76.05670166015625, equation: [0, y5*(y6 + 2*y8) + y5*(y5*(y6 + 2*y8) + y8 + sin(y2 + y6 + y8))]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.90614318847656, equation: [0, y5*(y8 + sin(y8))]
# Complexity: 7, fitness: 77.3086929321289, equation: [0, 2*y5*y8**2 + 2*y5*y8]
# Complexity: 8, fitness: 76.93787384033203, equation: [0, y5*(2*y8 + sin(y8))]
# Complexity: 9, fitness: 76.86331939697266, equation: [0, 2*y5*y8 + y5*(2*y5*y8 + y8)]
# Complexity: 10, fitness: 76.40482330322266, equation: [0, y5*(3*y8 + sin(y8))]
# Complexity: 12, fitness: 76.25621795654297, equation: [0, y5*(3*y8 + sin(2*y8))]
# Complexity: 15, fitness: 76.1158447265625, equation: [0, y5*(y6 + 4*y8) + y5*(y5*(y6 + 4*y8) + y8)]
# Complexity: 18, fitness: 76.05670166015625, equation: [0, y5*(y6 + 2*y8) + y5*(y5*(y6 + 2*y8) + y8 + sin(y2 + y6 + y8))]
# Complexity: 29, fitness: 75.92817687988281, equation: [0, y5*(y6 + 4*y8)*(y5*(y6 + 4*y8) + y8) + y5*(y6 + 4*y8) + y5*(y5*(y6 + 4*y8) + y8) + y5*(y5*(y6 + 4*y8)*(y5*(y6 + 4*y8) + y8) + y8)]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.90614318847656, equation: [0, y5*(y8 + sin(y8))]
# Complexity: 7, fitness: 77.3086929321289, equation: [0, 2*y5*y8**2 + 2*y5*y8]
# Complexity: 8, fitness: 76.93787384033203, equation: [0, y5*(2*y8 + sin(y8))]
# Complexity: 9, fitness: 76.86331939697266, equation: [0, 2*y5*y8 + y5*(2*y5*y8 + y8)]
# Complexity: 10, fitness: 76.3529281616211, equation: [0, y5*(y2 + 2*y8 + sin(y8))]
# Complexity: 12, fitness: 76.25621795654297, equation: [0, y5*(3*y8 + sin(2*y8))]
# Complexity: 14, fitness: 76.18025207519531, equation: [0, y5*(y6 + 4*y8 + sin(y8))]
# Complexity: 15, fitness: 76.1158447265625, equation: [0, y5*(y6 + 4*y8) + y5*(y5*(y6 + 4*y8) + y8)]
# Complexity: 18, fitness: 76.03959655761719, equation: [0, y5*(y6 + 3*y8) + y5*(y5*(y6 + 3*y8) + 2*y8 + sin(y8))]
# Complexity: 22, fitness: 76.02339172363281, equation: [0, y5*y8 + y5*(y6 + 4*y8) + y5*(y5*y8 + 2*y8 + sin(y5*(y6 + 4*y8)))]
# Complexity: 24, fitness: 76.01225280761719, equation: [0, y5*(y6 + 2*y8) + y5*(3*y8 + sin(y5*(y8*(y5*(y6 + 2*y8) + y6) + y8))) + y5*(y8*(y5*(y6 + 2*y8) + y6) + y8) + y8*(y5*(y6 + 2*y8) + y6)]
# Complexity: 26, fitness: 73.98463439941406, equation: [y5*y8, y4*y5*y8 + y5*(y6 + 2*y8) + y5*(y5*(y4*y5*y8 + y5*(y6 + 2*y8) + y8) + y8 + sin(y2*y9)) + y5*(y4*y5*y8 + y5*(y6 + 2*y8) + y8)]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.89115905761719, equation: [0, 2*y8*sin(y5)]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.86331939697266, equation: [0, 2*y5*y8 + y5*(2*y5*y8 + y8)]
# Complexity: 10, fitness: 76.3529281616211, equation: [0, y5*(y2 + 2*y8 + sin(y8))]
# Complexity: 11, fitness: 76.17454528808594, equation: [0, 5*y5*y8]
# Complexity: 12, fitness: 76.17264556884766, equation: [0, y5*(4*y8 + sin(y8))]
# Complexity: 15, fitness: 76.1158447265625, equation: [0, y5*(y6 + 4*y8) + y5*(y5*(y6 + 4*y8) + y8)]
# Complexity: 18, fitness: 76.03959655761719, equation: [0, y5*(y6 + 3*y8) + y5*(y5*(y6 + 3*y8) + 2*y8 + sin(y8))]
# Complexity: 20, fitness: 75.19647979736328, equation: [y5*y8, y4*y5*y8 + y5*(y4*y5*y8 + 2*y8) + y5*(y5*(y4*y5*y8 + 2*y8) + y8 + sin(y2*y9))]
# Complexity: 26, fitness: 73.98463439941406, equation: [y5*y8, y4*y5*y8 + y5*(y6 + 2*y8) + y5*(y5*(y4*y5*y8 + y5*(y6 + 2*y8) + y8) + y8 + sin(y2*y9)) + y5*(y4*y5*y8 + y5*(y6 + 2*y8) + y8)]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.89115905761719, equation: [0, 2*y8*sin(y5)]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 10, fitness: 76.3529281616211, equation: [0, y5*(y2 + 2*y8 + sin(y8))]
# Complexity: 11, fitness: 76.17454528808594, equation: [0, 5*y5*y8]
# Complexity: 12, fitness: 76.10393524169922, equation: [0, 2*y5*y8**2 + 2*y5*y8 + y8*(2*y5*y8**2 + y5) + sin(y8*(2*y5*y8**2 + y5))]
# Complexity: 18, fitness: 72.61135864257812, equation: [y5*y8, y4*y5*y8 + y5*(y4*y5*y8 + y8) + y5*(y5*(y4*y5*y8 + y8) + y8 + sin(y2*y9))]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.89115905761719, equation: [0, 2*y8*sin(y5)]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 10, fitness: 76.3529281616211, equation: [0, y5*(y2 + 2*y8 + sin(y8))]
# Complexity: 11, fitness: 76.17454528808594, equation: [0, 5*y5*y8]
# Complexity: 12, fitness: 76.10393524169922, equation: [0, 2*y5*y8**2 + 2*y5*y8 + y8*(2*y5*y8**2 + y5) + sin(y8*(2*y5*y8**2 + y5))]
# Complexity: 16, fitness: 76.08102416992188, equation: [0, y5*y8 + y5*(y8 + sin(y5*(y5*y8 + 3*y8))) + y5*(y5*y8 + 3*y8)]
# Complexity: 18, fitness: 72.61135864257812, equation: [y5*y8, y4*y5*y8 + y5*(y4*y5*y8 + y8) + y5*(y5*(y4*y5*y8 + y8) + y8 + sin(y2*y9))]
# Complexity: 26, fitness: 55.07978057861328, equation: [y5*y8, y4*y5*y8 + y5*(y1 + y6 + y8) + y5*(y5*(y4*y5*y8 + y5*(y1 + y6 + y8) + y8) + y8 + sin(y2*y9)) + y5*(y4*y5*y8 + y5*(y1 + y6 + y8) + y8)]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.89115905761719, equation: [0, 2*y8*sin(y5)]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 10, fitness: 76.3529281616211, equation: [0, y5*(y2 + 2*y8 + sin(y8))]
# Complexity: 11, fitness: 76.17454528808594, equation: [0, 5*y5*y8]
# Complexity: 12, fitness: 76.10393524169922, equation: [0, 2*y5*y8**2 + 2*y5*y8 + y8*(2*y5*y8**2 + y5) + sin(y8*(2*y5*y8**2 + y5))]
# Complexity: 16, fitness: 75.90669250488281, equation: [0, y5*(y6 + 3*y8) + y5*(y5*(y6 + 3*y8) + y8 + sin(y2))]
# Complexity: 18, fitness: 72.61135864257812, equation: [y5*y8, y4*y5*y8 + y5*(y4*y5*y8 + y8) + y5*(y5*(y4*y5*y8 + y8) + y8 + sin(y2*y9))]
# Complexity: 22, fitness: 63.64822006225586, equation: [y5*y8, y4*y5*y8 + y5*y6 + y5*(y5*(y4*y5*y8 + y5*y6 + y8) + y8 + sin(y2*y9)) + y5*(y4*y5*y8 + y5*y6 + y8)]
# Complexity: 26, fitness: 55.07978057861328, equation: [y5*y8, y4*y5*y8 + y5*(y1 + y6 + y8) + y5*(y5*(y4*y5*y8 + y5*(y1 + y6 + y8) + y8) + y8 + sin(y2*y9)) + y5*(y4*y5*y8 + y5*(y1 + y6 + y8) + y8)]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.89115905761719, equation: [0, 2*y8*sin(y5)]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.37298583984375, equation: [0, 4*y5*y8]
# Complexity: 10, fitness: 76.3529281616211, equation: [0, y5*(y2 + 2*y8 + sin(y8))]
# Complexity: 11, fitness: 76.17454528808594, equation: [0, 5*y5*y8]
# Complexity: 12, fitness: 76.10393524169922, equation: [0, 2*y5*y8**2 + 2*y5*y8 + y8*(2*y5*y8**2 + y5) + sin(y8*(2*y5*y8**2 + y5))]
# Complexity: 16, fitness: 75.90669250488281, equation: [0, y5*(y6 + 3*y8) + y5*(y5*(y6 + 3*y8) + y8 + sin(y2))]
# Complexity: 18, fitness: 61.99211883544922, equation: [y5*y8, y4*y5*y8 + y5*(y4*y5*y8 + y8) + y5*
equation: [y5*y8, y4*y5*y8 + y5*(y1 + y8 + 0.197) + y5*(y5*(y4*y5*y8 + y5*(y1 + y8 + 0.197) + y8) + 2*y5 + y8) + y5*(y4*y5*y8 + y5*(y1 + y8 + 0.197) + y8)]
# Complexity: 26, fitness: 47.46894073486328, equation: [y5*y8, y4*y5*y8 + y5*(y1 + y8 + 0.197) + y5*(y5*(y4*y5*y8 + y5*(y1 + y8 + 0.197) + y8) + y8 + sin(y2*y9)) + y5*(y4*y5*y8 + y5*(y1 + y8 + 0.197) + y8)]
# Complexity: 30, fitness: 39.31462097167969, equation: [y5*y8, y0*y5*y8 - y5*y8*(y0*y5*y8 + y5*(y1 + 3*y8) + 2*y8) + y5*(y1 + 3*y8) + y5*(y0*y5*y8 + y5*(y1 + 3*y8) + 2*y8) + y9 - sin(y10*y8)]

# %%
brax_env = BraxGymnaxWrapper('swimmer', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=2, max_nodes= 30)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated) 0.1
# Compiling code for evaluation and evolution...
# Finished compilation in 77.70 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: 7.4525465965271, equation: [0.839, 0]
# Complexity: 2, fitness: -11.424619674682617, equation: [0, sin(y6)]
# Complexity: 3, fitness: -24.159893035888672, equation: [0, y6 + y7]
# Complexity: 5, fitness: -27.818269729614258, equation: [0.47*y1, 0.47*y1*y3]
# Complexity: 6, fitness: -30.676727294921875, equation: [y3*y6, y3*y6 + y5 + sin(y3*y6 + y5)]
# Complexity: 7, fitness: -217.24343872070312, equation: [y0 - y5 - 0.216, y0 - y5 + y7 - 0.216]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -24.159893035888672, equation: [0, y6 + y7]
# Complexity: 5, fitness: -27.818269729614258, equation: [0.47*y1, 0.47*y1*y3]
# Complexity: 6, fitness: -30.833141326904297, equation: [y3*y6, y3*y6 + y5 + sin(y3*y6 + y5)]
# Complexity: 7, fitness: -217.24343872070312, equation: [y0 - y5 - 0.216, y0 - y5 + y7 - 0.216]
# Complexity: 12, fitness: -247.23614501953125, equation: [-y1 - 0.24*y2 + y3 + 0.24*y4 + 2*sin(y4), -0.24*y2 + 0.24*y4]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -26.66438865661621, equation: [0, y1 + y7]
# Complexity: 5, fitness: -27.818269729614258, equation: [0.47*y1, 0.47*y1*y3]
# Complexity: 6, fitness: -32.94548797607422, equation: [0, (y1 + y7)*cos(y4)]
# Complexity: 7, fitness: -217.24343872070312, equation: [y0 - y5 - 0.216, y0 - y5 + y7 - 0.216]
# Complexity: 10, fitness: -221.62034606933594, equation: [-1.24*y2 + 0.24*y4 + 2*sin(y4), -0.24*y2 + 0.24*y4]
# Complexity: 12, fitness: -247.29241943359375, equation: [-y1 - 0.24*y2 + y3 + 0.24*y4 + 2*sin(y4), -0.24*y2 + 0.24*y4]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -26.66438865661621, equation: [0, y1 + y7]
# Complexity: 5, fitness: -30.504390716552734, equation: [0, 2*y1 + y5]
# Complexity: 6, fitness: -32.94548797607422, equation: [0, (y1 + y7)*cos(y4)]
# Complexity: 7, fitness: -220.10977172851562, equation: [-1.24*y2 + 0.24*y4, -0.24*y2 + 0.24*y4]
# Complexity: 10, fitness: -221.62034606933594, equation: [-1.24*y2 + 0.24*y4 + 2*sin(y4), -0.24*y2 + 0.24*y4]
# Complexity: 12, fitness: -247.29257202148438, equation: [-y1 - 0.24*y2 + y3 + 0.24*y4 + 2*sin(y4), -0.24*y2 + 0.24*y4]
# Complexity: 13, fitness: -292.4090270996094, equation: [-y1 + y3 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -26.66438865661621, equation: [0, y1 + y7]
# Complexity: 5, fitness: -30.504390716552734, equation: [0, 2*y1 + y5]
# Complexity: 6, fitness: -73.52070617675781, equation: [sin(y6), y1 + y3 + sin(y6)]
# Complexity: 7, fitness: -220.10977172851562, equation: [-1.24*y2 + 0.24*y4, -0.24*y2 + 0.24*y4]
# Complexity: 10, fitness: -221.62034606933594, equation: [-1.24*y2 + 0.24*y4 + 2*sin(y4), -0.24*y2 + 0.24*y4]
# Complexity: 12, fitness: -247.29257202148438, equation: [-y1 - 0.24*y2 + y3 + 0.24*y4 + 2*sin(y4), -0.24*y2 + 0.24*y4]
# Complexity: 13, fitness: -292.4090270996094, equation: [-y1 + y3 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -78.53044128417969, equation: [y0 + y6 - y7, y0 + y6]
# Complexity: 7, fitness: -220.10977172851562, equation: [-1.24*y2 + 0.24*y4, -0.24*y2 + 0.24*y4]
# Complexity: 10, fitness: -227.23126220703125, equation: [sin(y4), y1*sin(y4) + y2 + y6 + y7]
# Complexity: 11, fitness: -340.8056335449219, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -78.53044128417969, equation: [y0 + y6 - y7, y0 + y6]
# Complexity: 6, fitness: -120.53032684326172, equation: [y0 + y6 - y7, y0 + y6 + sin(y0 + y6 - y7)]
# Complexity: 7, fitness: -220.10977172851562, equation: [-1.24*y2 + 0.24*y4, -0.24*y2 + 0.24*y4]
# Complexity: 9, fitness: -229.60638427734375, equation: [y0 - 0.24*y2 + 0.24*y4 - y5, -0.24*y2 + 0.24*y4]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -79.41110229492188, equation: [y0 + y6 - y7, y0 + y6]
# Complexity: 6, fitness: -120.53032684326172, equation: [y0 + y6 - y7, y0 + y6 + sin(y0 + y6 - y7)]
# Complexity: 7, fitness: -220.10977172851562, equation: [-1.24*y2 + 0.24*y4, -0.24*y2 + 0.24*y4]
# Complexity: 9, fitness: -229.60638427734375, equation: [y0 - 0.24*y2 + 0.24*y4 - y5, -0.24*y2 + 0.24*y4]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 18, fitness: -341.30865478515625, equation: [2*y0 - 2*y1 - y7 + 2*(y2 - y4)*cos(y5) + 5*sin(y4), (y2 - y4)*cos(y5)]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 7, fitness: -220.10977172851562, equation: [-1.24*y2 + 0.24*y4, -0.24*y2 + 0.24*y4]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 18, fitness: -341.30987548828125, equation: [2*y0 - 2*y1 - y7 + 2*(y2 - y4)*cos(y5) + 5*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 21, fitness: -341.7412414550781, equation: [2*y0 - 2*y1 - y7 + 2*(y2 - y4)*cos(y5) + 3*sin(y4) + 2*sin(y4 + cos(y7)), (y2 - y4)*cos(y5)]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 18, fitness: -341.30987548828125, equation: [2*y0 - 2*y1 - y7 + 2*(y2 - y4)*cos(y5) + 5*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 21, fitness: -341.7412414550781, equation: [2*y0 - 2*y1 - y7 + 2*(y2 - y4)*cos(y5) + 3*sin(y4) + 2*sin(y4 + cos(y7)), (y2 - y4)*cos(y5)]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 18, fitness: -341.30987548828125, equation: [2*y0 - 2*y1 - y7 + 2*(y2 - y4)*cos(y5) + 5*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 21, fitness: -341.7421875, equation: [2*y0 - 2*y1 - y7 + 2*(y2 - y4)*cos(y5) + 3*sin(y4) + 2*sin(y4 + cos(y7)), (y2 - y4)*cos(y5)]
# Complexity: 22, fitness: -342.0738525390625, equation: [y0 + y4, y0*y3*(y0 + y4)*sin(y5) + 2*y3 + 2*y4 + (y0 + y7)*(y0*y3*(y0 + y4)*sin(y5) + y3)]
# Complexity: 25, fitness: -343.3836975097656, equation: [y0 + y4, 3*y4 - 0.484*(y0 + y4)*sin(y5) + (y0 + y7)*(y3 - 0.484*(y0 + y4)*sin(y5)) + sin(y5)]
# Complexity: 27, fitness: -353.3277587890625, equation: [0.48*y2 - 1.48*y4 - y7 + 2*(y2 - y4)*cos(y5) + 2*sin(y4) - 3*sin(0.24*y5), -0.24*y2 + 0.24*y4 - 0.24*y5 + (y2 - y4)*cos(y5)]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 18, fitness: -341.30987548828125, equation: [2*y0 - 2*y1 - y7 + 2*(y2 - y4)*cos(y5) + 5*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 21, fitness: -341.7421875, equation: [2*y0 - 2*y1 - y7 + 2*(y2 - y4)*cos(y5) + 3*sin(y4) + 2*sin(y4 + cos(y7)), (y2 - y4)*cos(y5)]
# Complexity: 22, fitness: -342.0829162597656, equation: [y0 + y4, y0*y3*(y0 + y4)*sin(y5) + 2*y3 + 2*y4 + (y0 + y7)*(y0*y3*(y0 + y4)*sin(y5) + y3)]
# Complexity: 25, fitness: -343.3838195800781, equation: [y0 + y4, 3*y4 - 0.484*(y0 + y4)*sin(y5) + (y0 + y7)*(y3 - 0.484*(y0 + y4)*sin(y5)) + sin(y5)]
# Complexity: 27, fitness: -353.3277587890625, equation: [0.48*y2 - 1.48*y4 - y7 + 2*(y2 - y4)*cos(y5) + 2*sin(y4) - 3*sin(0.24*y5), -0.24*y2 + 0.24*y4 - 0.24*y5 + (y2 - y4)*cos(y5)]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 18, fitness: -341.30987548828125, equation: [2*y0 - 2*y1 - y7 + 2*(y2 - y4)*cos(y5) + 5*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 21, fitness: -346.394287109375, equation: [-y7 + 2*(y2 - y4)*cos(y5) + sin(y4) - 3*sin(0.24*y2 - 0.24*y4), -0.24*y2 + 0.24*y4 + (y2 - y4)*cos(y5)]
# Complexity: 26, fitness: -350.3768310546875, equation: [-y4 - y7 + 2*(y2 - y4)*cos(y5) + 2*sin(y4) - 2*sin(0.24*y5), -0.48*y5 + (y2 - y4)*cos(y5)]
# Complexity: 27, fitness: -353.3277587890625, equation: [0.48*y2 - 1.48*y4 - y7 + 2*(y2 - y4)*cos(y5) + 2*sin(y4) - 3*sin(0.24*y5), -0.24*y2 + 0.24*y4 - 0.24*y5 + (y2 - y4)*cos(y5)]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 16, fitness: -341.7864990234375, equation: [2*y0 + y4 - y7 + 2*(y2 - y4)*cos(y5), (y2 - y4)*cos(y5)]
# Complexity: 18, fitness: -344.8939208984375, equation: [-2*y1 - y7 + 2*(y2 - y4)*cos(y5) + 2*sin(y4) - 3*sin(0.24*y5), -0.24*y5 + (y2 - y4)*cos(y5)]
# Complexity: 20, fitness: -346.60498046875, equation: [2*y0 - y7 + 2*(y2 - y4)*cos(y5) + sin(y1) + 2*sin(y4 + sin(y1)), (y2 - y4)*cos(y5)]
# Complexity: 23, fitness: -348.6405334472656, equation: [y0 + y4, 0.325*y0*y3*(y0 + y4) + y3 + 1.53*y4 + (y0 + y7)*(0.325*y0*y3*(y0 + y4) + y3)]
# Complexity: 24, fitness: -350.29913330078125, equation: [-y4 - y7 + 2*(y2 - y4)*cos(y5) + sin(y4) - 3*sin(0.24*y5), -0.24*y5 + (y2 - y4)*cos(y5)]
# Complexity: 26, fitness: -350.3768310546875, equation: [-y4 - y7 + 2*(y2 - y4)*cos(y5) + 2*sin(y4) - 2*sin(0.24*y5), -0.48*y5 + (y2 - y4)*cos(y5)]
# Complexity: 27, fitness: -353.3277587890625, equation: [0.48*y2 - 1.48*y4 - y7 + 2*(y2 - y4)*cos(y5) + 2*sin(y4) - 3*sin(0.24*y5), -0.24*y2 + 0.24*y4 - 0.24*y5 + (y2 - y4)*cos(y5)]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 16, fitness: -341.7864990234375, equation: [2*y0 + y4 - y7 + 2*(y2 - y4)*cos(y5), (y2 - y4)*cos(y5)]
# Complexity: 18, fitness: -344.8939208984375, equation: [-2*y1 - y7 + 2*(y2 - y4)*cos(y5) + 2*sin(y4) - 3*sin(0.24*y5), -0.24*y5 + (y2 - y4)*cos(y5)]
# Complexity: 19, fitness: -346.05010986328125, equation: [2*y0 - y7 + 2*(y2 - y4)*cos(y5) - 2*sin(y0 - y1), (y2 - y4)*cos(y5)]
# Complexity: 20, fitness: -346.60498046875, equation: [2*y0 - y7 + 2*(y2 - y4)*cos(y5) + sin(y1) + 2*sin(y4 + sin(y1)), (y2 - y4)*cos(y5)]
# Complexity: 22, fitness: -351.8484191894531, equation: [y0 + y4, y0*y3*(y0 + y4)*sin(y5) + y3 + 2*y4 + y5 + (y0 + y7)*(y0*y3*(y0 + y4)*sin(y5) + y3)]
# Complexity: 27, fitness: -353.3277587890625, equation: [0.48*y2 - 1.48*y4 - y7 + 2*(y2 - y4)*cos(y5) + 2*sin(y4) - 3*sin(0.24*y5), -0.24*y2 + 0.24*y4 - 0.24*y5 + (y2 - y4)*cos(y5)]
# Complexity: 30, fitness: -354.6650390625, equation: [0.48*y1 - 1.48*y4 - y7 + 2*(y2 - y4)*cos(y5) + 2*sin(y4) - 3*sin(0.24*y5), -0.24*y1 + 0.24*y4 - 0.24*y5 + (y2 - y4)*cos(y5)]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 16, fitness: -341.7864990234375, equation: [2*y0 + y4 - y7 + 2*(y2 - y4)*cos(y5), (y2 - y4)*cos(y5)]
# Complexity: 18, fitness: -344.8939208984375, equation: [-2*y1 - y7 + 2*(y2 - y4)*cos(y5) + 2*sin(y4) - 3*sin(0.24*y5), -0.24*y5 + (y2 - y4)*cos(y5)]
# Complexity: 19, fitness: -346.05010986328125, equation: [2*y0 - y7 + 2*(y2 - y4)*cos(y5) - 2*sin(y0 - y1), (y2 - y4)*cos(y5)]
# Complexity: 20, fitness: -346.60498046875, equation: [2*y0 - y7 + 2*(y2 - y4)*cos(y5) + sin(y1) + 2*sin(y4 + sin(y1)), (y2 - y4)*cos(y5)]
# Complexity: 22, fitness: -351.84844970703125, equation: [y0 + y4, y0*y3*(y0 + y4)*sin(y5) + y3 + 2*y4 + y5 + (y0 + y7)*(y0*y3*(y0 + y4)*sin(y5) + y3)]
# Complexity: 23, fitness: -352.5198059082031, equation: [y0 + y4, y0*y3*(y0 + y4)*sin(sin(y5)) + y3 + 2*y4 + y5 + (y0 + y7)*(y0*y3*(y0 + y4)*sin(sin(y5)) + y3)]
# Complexity: 26, fitness: -353.09552001953125, equation: [2.53*y0 + y4, 0.74*y0*sin(0.484*y0 + 0.484*y4) + y3 + 2*y4 + (y0 + y7)*(0.74*y0*sin(0.484*y0 + 0.484*y4) + y3) - 0.24]
# Complexity: 27, fitness: -354.882080078125, equation: [0.48*y1 - 1.48*y4 - y7 + 2*(y2 - y4)*cos(y5) + 2*sin(y4) - 3*sin(0.24*y5), -0.24*y1 + 0.24*y4 - 0.24*y5 + (y2 - y4)*cos(y5)]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 16, fitness: -341.7864990234375, equation: [2*y0 + y4 - y7 + 2*(y2 - y4)*cos(y5), (y2 - y4)*cos(y5)]
# Complexity: 18, fitness: -344.8939208984375, equation: [-2*y1 - y7 + 2*(y2 - y4)*cos(y5) + 2*sin(y4) - 3*sin(0.24*y5), -0.24*y5 + (y2 - y4)*cos(y5)]
# Complexity: 19, fitness: -346.05010986328125, equation: [2*y0 - y7 + 2*(y2 - y4)*cos(y5) - 2*sin(y0 - y1), (y2 - y4)*cos(y5)]
# Complexity: 20, fitness: -346.60498046875, equation: [2*y0 - y7 + 2*(y2 - y4)*cos(y5) + sin(y1) + 2*sin(y4 + sin(y1)), (y2 - y4)*cos(y5)]
# Complexity: 22, fitness: -351.84844970703125, equation: [y0 + y4, y0*y3*(y0 + y4)*sin(y5) + y3 + 2*y4 + y5 + (y0 + y7)*(y0*y3*(y0 + y4)*sin(y5) + y3)]
# Complexity: 23, fitness: -352.51983642578125, equation: [y0 + y4, y0*y3*(y0 + y4)*sin(sin(y5)) + y3 + 2*y4 + y5 + (y0 + y7)*(y0*y3*(y0 + y4)*sin(sin(y5)) + y3)]
# Complexity: 26, fitness: -353.09552001953125, equation: [2.53*y0 + y4, 0.74*y0*sin(0.484*y0 + 0.484*y4) + y3 + 2*y4 + (y0 + y7)*(0.74*y0*sin(0.484*y0 + 0.484*y4) + y3) - 0.24]
# Complexity: 27, fitness: -354.882080078125, equation: [0.48*y1 - 1.48*y4 - y7 + 2*(y2 - y4)*cos(y5) + 2*sin(y4) - 3*sin(0.24*y5), -0.24*y1 + 0.24*y4 - 0.24*y5 + (y2 - y4)*cos(y5)]
# Complexity: 30, fitness: -357.22454833984375, equation: [y0 + y4, 3*y4 + y5 + 0.484*(y0 + y4)*sin(0.484*sin(y0)) + (y0 + y7)*(y3 + 0.484*(y0 + y4)*sin(0.484*sin(y0))) + sin(y5)]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 16, fitness: -341.7864990234375, equation: [2*y0 + y4 - y7 + 2*(y2 - y4)*cos(y5), (y2 - y4)*cos(y5)]
# Complexity: 18, fitness: -344.8939208984375, equation: [-2*y1 - y7 + 2*(y2 - y4)*cos(y5) + 2*sin(y4) - 3*sin(0.24*y5), -0.24*y5 + (y2 - y4)*cos(y5)]
# Complexity: 19, fitness: -346.05010986328125, equation: [2*y0 - y7 + 2*(y2 - y4)*cos(y5) - 2*sin(y0 - y1), (y2 - y4)*cos(y5)]
# Complexity: 20, fitness: -346.60498046875, equation: [2*y0 - y7 + 2*(y2 - y4)*cos(y5) + sin(y1) + 2*sin(y4 + sin(y1)), (y2 - y4)*cos(y5)]
# Complexity: 22, fitness: -351.84844970703125, equation: [y0 + y4, y0*y3*(y0 + y4)*sin(y5) + y3 + 2*y4 + y5 + (y0 + y7)*(y0*y3*(y0 + y4)*sin(y5) + y3)]
# Complexity: 23, fitness: -352.51983642578125, equation: [y0 + y4, y0*y3*(y0 + y4)*sin(sin(y5)) + y3 + 2*y4 + y5 + (y0 + y7)*(y0*y3*(y0 + y4)*sin(sin(y5)) + y3)]
# Complexity: 24, fitness: -355.00433349609375, equation: [y0 - 0.484*y5, y0**2*(y0 - 0.484*y5)*sin(y5) + y3 + 2*y4 + y5 + (y0 + y7)*(y0**2*(y0 - 0.484*y5)*sin(y5) + y3)]
# Complexity: 30, fitness: -357.22454833984375, equation: [y0 + y4, 3*y4 + y5 + 0.484*(y0 + y4)*sin(0.484*sin(y0)) + (y0 + y7)*(y3 + 0.484*(y0 + y4)*sin(0.484*sin(y0))) + sin(y5)]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 16, fitness: -341.7864990234375, equation: [2*y0 + y4 - y7 + 2*(y2 - y4)*cos(y5), (y2 - y4)*cos(y5)]
# Complexity: 18, fitness: -344.8939208984375, equation: [-2*y1 - y7 + 2*(y2 - y4)*cos(y5) + 2*sin(y4) - 3*sin(0.24*y5), -0.24*y5 + (y2 - y4)*cos(y5)]
# Complexity: 19, fitness: -355.47845458984375, equation: [y0 + y4, 0.0531*y0 + y1 + y3 + 2.05*y4 + (y0 + y7)*(0.0531*y0 + y3 + 0.0531*y4) + 0.472]
# Complexity: 23, fitness: -357.67230224609375, equation: [y0 - 0.484*y5, y3 + 2*y4 + y5 + (y0 - 0.484*y5)*sin(y5)**2 + (y0 + y7)*(y3 + (y0 - 0.484*y5)*sin(y5)**2)]
# Complexity: 26, fitness: -358.1106262207031, equation: [y0 + y4, y0*y3*(y0 + y4) + 3*y4 + y5 + (y0 + y7)*(y0*y3*(y0 + y4) + y3) + sin(y5)]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 16, fitness: -341.7864990234375, equation: [2*y0 + y4 - y7 + 2*(y2 - y4)*cos(y5), (y2 - y4)*cos(y5)]
# Complexity: 17, fitness: -354.1675109863281, equation: [y0 + y4, -0.157*y0*(y0 + y4) + y3 + y4 + (y3 + y7)*(-0.157*y0*(y0 + y4) + y3)]
# Complexity: 19, fitness: -355.47845458984375, equation: [y0 + y4, 0.0531*y0 + y1 + y3 + 2.05*y4 + (y0 + y7)*(0.0531*y0 + y3 + 0.0531*y4) + 0.472]
# Complexity: 21, fitness: -356.26312255859375, equation: [y0 + y4, 0.325*y0*y3*(y0 + y4) + y3 + 2*y4 + y5 + (y7 + 0.231)*(0.325*y0*y3*(y0 + y4) + y3)]
# Complexity: 23, fitness: -357.67230224609375, equation: [y0 - 0.484*y5, y3 + 2*y4 + y5 + (y0 - 0.484*y5)*sin(y5)**2 + (y0 + y7)*(y3 + (y0 - 0.484*y5)*sin(y5)**2)]
# Complexity: 26, fitness: -358.1106262207031, equation: [y0 + y4, y0*y3*(y0 + y4) + 3*y4 + y5 + (y0 + y7)*(y0*y3*(y0 + y4) + y3) + sin(y5)]
# Complexity: 28, fitness: -358.8720703125, equation: [y0 + y4, y0 + y3*(y0 + y4)*(y4 + y5) + y3 + 2*y4 + y7*(y3*(y0 + y4)*(y4 + y5) + y3) + sin(y5 + y7)]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 16, fitness: -341.7864990234375, equation: [2*y0 + y4 - y7 + 2*(y2 - y4)*cos(y5), (y2 - y4)*cos(y5)]
# Complexity: 17, fitness: -354.1675109863281, equation: [y0 + y4, -0.157*y0*(y0 + y4) + y3 + y4 + (y3 + y7)*(-0.157*y0*(y0 + y4) + y3)]
# Complexity: 19, fitness: -355.47845458984375, equation: [y0 + y4, 0.0531*y0 + y1 + y3 + 2.05*y4 + (y0 + y7)*(0.0531*y0 + y3 + 0.0531*y4) + 0.472]
# Complexity: 21, fitness: -356.26617431640625, equation: [y0 + y4, 0.325*y0*y3*(y0 + y4) + y3 + 2*y4 + y5 + (y7 + 0.231)*(0.325*y0*y3*(y0 + y4) + y3)]
# Complexity: 23, fitness: -357.67230224609375, equation: [y0 - 0.484*y5, y3 + 2*y4 + y5 + (y0 - 0.484*y5)*sin(y5)**2 + (y0 + y7)*(y3 + (y0 - 0.484*y5)*sin(y5)**2)]
# Complexity: 26, fitness: -358.11065673828125, equation: [y0 + y4, y0*y3*(y0 + y4) + 3*y4 + y5 + (y0 + y7)*(y0*y3*(y0 + y4) + y3) + sin(y5)]
# Complexity: 28, fitness: -360.24951171875, equation: [y0 + y4, y0 + 2*y4 + (y0 + y4)*(0.325*y4 + 0.325*y5) + (y3 + (y0 + y4)*(0.325*y4 + 0.325*y5))*(y5 + y7) + sin(y5 + y7)]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 15, fitness: -351.05303955078125, equation: [y0 + y4, 0.0531*y0 + 2*y3 + 1.05*y4 + (y0 + y7)*(0.0531*y0 + y3 + 0.0531*y4)]
# Complexity: 17, fitness: -354.1675109863281, equation: [y0 + y4, -0.157*y0*(y0 + y4) + y3 + y4 + (y3 + y7)*(-0.157*y0*(y0 + y4) + y3)]
# Complexity: 19, fitness: -355.47845458984375, equation: [y0 + y4, 0.0531*y0 + y1 + y3 + 2.05*y4 + (y0 + y7)*(0.0531*y0 + y3 + 0.0531*y4) + 0.472]
# Complexity: 21, fitness: -356.26617431640625, equation: [y0 + y4, 0.325*y0*y3*(y0 + y4) + y3 + 2*y4 + y5 + (y7 + 0.231)*(0.325*y0*y3*(y0 + y4) + y3)]
# Complexity: 23, fitness: -357.67230224609375, equation: [y0 - 0.484*y5, y3 + 2*y4 + y5 + (y0 - 0.484*y5)*sin(y5)**2 + (y0 + y7)*(y3 + (y0 - 0.484*y5)*sin(y5)**2)]
# Complexity: 25, fitness: -357.824951171875, equation: [y0 + y4, 0.325*y0*y3*(y0 + y4) - y2 + y3 + 2*y4 + y5 + (y7 + 0.231)*(0.325*y0*y3*(y0 + y4) + y3) - 0.251]
# Complexity: 26, fitness: -358.11065673828125, equation: [y0 + y4, y0*y3*(y0 + y4) + 3*y4 + y5 + (y0 + y7)*(y0*y3*(y0 + y4) + y3) + sin(y5)]
# Complexity: 28, fitness: -360.24957275390625, equation: [y0 + y4, y0 + 2*y4 + (y0 + y4)*(0.325*y4 + 0.325*y5) + (y3 + (y0 + y4)*(0.325*y4 + 0.325*y5))*(y5 + y7) + sin(y5 + y7)]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 15, fitness: -351.05303955078125, equation: [y0 + y4, 0.0531*y0 + 2*y3 + 1.05*y4 + (y0 + y7)*(0.0531*y0 + y3 + 0.0531*y4)]
# Complexity: 17, fitness: -358.6156921386719, equation: [2*y0 + y4, 0.106*y0 + 2*y3 + 1.05*y4 + (y0 + y7)*(0.106*y0 + y3 + 0.0531*y4)]
# Complexity: 28, fitness: -360.24957275390625, equation: [y0 + y4, y0 + 2*y4 + (y0 + y4)*(0.325*y4 + 0.325*y5) + (y3 + (y0 + y4)*(0.325*y4 + 0.325*y5))*(y5 + y7) + sin(y5 + y7)]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 15, fitness: -351.05303955078125, equation: [y0 + y4, 0.0531*y0 + 2*y3 + 1.05*y4 + (y0 + y7)*(0.0531*y0 + y3 + 0.0531*y4)]
# Complexity: 17, fitness: -358.6156921386719, equation: [2*y0 + y4, 0.106*y0 + 2*y3 + 1.05*y4 + (y0 + y7)*(0.106*y0 + y3 + 0.0531*y4)]
# Complexity: 27, fitness: -358.6387939453125, equation: [y0 + y4 + sin(y0), y0*y3*(y0 + y4) + y1 + y3 + 2*y4 + y5 + (y0 + y7)*(y0*y3*(y0 + y4) + y3) + sin(y0) + sin(y5)]
# Complexity: 28, fitness: -360.24957275390625, equation: [y0 + y4, y0 + 2*y4 + (y0 + y4)*(0.325*y4 + 0.325*y5) + (y3 + (y0 + y4)*(0.325*y4 + 0.325*y5))*(y5 + y7) + sin(y5 + y7)]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 15, fitness: -351.05303955078125, equation: [y0 + y4, 0.0531*y0 + 2*y3 + 1.05*y4 + (y0 + y7)*(0.0531*y0 + y3 + 0.0531*y4)]
# Complexity: 17, fitness: -358.6158447265625, equation: [2*y0 + y4, 0.106*y0 + 2*y3 + 1.05*y4 + (y0 + y7)*(0.106*y0 + y3 + 0.0531*y4)]
# Complexity: 18, fitness: -359.01727294921875, equation: [3*y0 + 2*y4, 1.11*y0 + y3 + 1.05*y4 + (y7 + cos(y2))*(0.106*y0 + y3 + 0.0531*y4)]
# Complexity: 24, fitness: -360.98193359375, equation: [y0 + y4, 0.24*y0*sin(0.484*y0 + 0.484*y4) - 0.48*y2 + y3 + y4 + (y5 + y7)*(0.24*y0*sin(0.484*y0 + 0.484*y4) + y3) - 0.24]
# Final pareto front:
# Complexity: 1, fitness: -12.504690170288086, equation: [y7, 0]
# Complexity: 2, fitness: -27.77018928527832, equation: [0, sin(y7)]
# Complexity: 3, fitness: -39.823097229003906, equation: [0, y1 + y5]
# Complexity: 5, fitness: -199.35733032226562, equation: [-y2 - 0.24*y5, -0.24*y5]
# Complexity: 6, fitness: -229.4313201904297, equation: [sin(y6), y1 + y4 + sin(y6)]
# Complexity: 9, fitness: -324.47222900390625, equation: [y5*cos(y5) - y7 + 2*sin(y4), y5*cos(y5)]
# Complexity: 11, fitness: -340.8056640625, equation: [-y7 + (y2 - y4)*cos(y5) + 2*sin(y4), (y2 - y4)*cos(y5)]
# Complexity: 15, fitness: -351.05303955078125, equation: [y0 + y4, 0.0531*y0 + 2*y3 + 1.05*y4 + (y0 + y7)*(0.0531*y0 + y3 + 0.0531*y4)]
# Complexity: 17, fitness: -358.6158447265625, equation: [2*y0 + y4, 0.106*y0 + 2*y3 + 1.05*y4 + (y0 + y7)*(0.106*y0 + y3 + 0.0531*y4)]
# Complexity: 18, fitness: -359.01727294921875, equation: [3*y0 + 2*y4, 1.11*y0 + y3 + 1.05*y4 + (y7 + cos(y2))*(0.106*y0 + y3 + 0.0531*y4)]
# Complexity: 24, fitness: -360.98193359375, equation: [y0 + y4, 0.24*y0*sin(0.484*y0 + 0.484*y4) - 0.48*y2 + y3 + y4 + (y5 + y7)*(0.24*y0*sin(0.484*y0 + 0.484*y4) + y3) - 0.24]

# %%
brax_env = BraxGymnaxWrapper('hopper', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=3, max_nodes = 31)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated) 0.1
# Compiling code for evaluation and evolution...
# Finished compilation in 241.20 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: -212.62896728515625, equation: [0.639, 0, 0]
# Complexity: 2, fitness: -220.23822021484375, equation: [0, cos(y0), 0]
# Complexity: 5, fitness: -295.34417724609375, equation: [0, y0*y1*y7, 0]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -238.04168701171875, equation: [0, y10, 0]
# Complexity: 3, fitness: -283.03814697265625, equation: [0, y1*y7, 0]
# Complexity: 5, fitness: -295.34417724609375, equation: [0, y0*y1*y7, 0]
# Complexity: 10, fitness: -306.42138671875, equation: [0, y1*y7 + y1*(y1*y7 + y6 + sin(y8)), 0]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -250.2135009765625, equation: [0, y4, 0]
# Complexity: 3, fitness: -283.0382080078125, equation: [0, y1*y7, 0]
# Complexity: 5, fitness: -313.4730224609375, equation: [0, y7*(y1 + y8), 0]
# Complexity: 19, fitness: -430.13427734375, equation: [0, y0 + y7 + (y1 - y2*y8 - 0.66)*(y0 - y10 + 2*y2 + y7 + y8), -y10 + y2]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -250.21783447265625, equation: [0, y4, 0]
# Complexity: 3, fitness: -283.0382080078125, equation: [0, y1*y7, 0]
# Complexity: 5, fitness: -313.47381591796875, equation: [0, y7*(y1 + y8), 0]
# Complexity: 6, fitness: -313.7469177246094, equation: [0, y7*sin(y1 + y8), 0]
# Complexity: 8, fitness: -352.7289733886719, equation: [cos(y10*(-0.92*y1 - 0.92*y2)), y10*(-0.92*y1 - 0.92*y2), 0]
# Complexity: 17, fitness: -415.302734375, equation: [0, y0 + y7 + (y1 - y2*y8 - 0.66)*(y0 - y10 + y2 + y7 + y9), -y10 + y2]
# Complexity: 19, fitness: -430.13433837890625, equation: [0, y0 + y7 + (y1 - y2*y8 - 0.66)*(y0 - y10 + 2*y2 + y7 + y8), -y10 + y2]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -250.21783447265625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 8, fitness: -352.7308654785156, equation: [cos(y10*(-0.92*y1 - 0.92*y2)), y10*(-0.92*y1 - 0.92*y2), 0]
# Complexity: 14, fitness: -494.15301513671875, equation: [cos(y0*(y0 - y10 + 2*y2 + y7 + y8)), y0 + y7, -y10 + y2]
# Complexity: 15, fitness: -531.0408935546875, equation: [0, y0 + y7 + (y10*y4 - 0.66)*(y0 - y10 + y2 + y7 + y9), -y10 + y2]
# Complexity: 23, fitness: -553.4837036132812, equation: [0, y0 + y7 + (y2*y9*(y1 - y2*y8) - 0.66)*(y0 - y10 + 2*y2 + y7 + y8), -y10 + y2]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 8, fitness: -352.7308654785156, equation: [cos(y10*(-0.92*y1 - 0.92*y2)), y10*(-0.92*y1 - 0.92*y2), 0]
# Complexity: 12, fitness: -357.9837646484375, equation: [-y1 - y8 + cos(y10*(-0.92*y1 - 0.92*y2)), y10*(-0.92*y1 - 0.92*y2), 0]
# Complexity: 14, fitness: -494.15301513671875, equation: [cos(y0*(y0 - y10 + 2*y2 + y7 + y8)), y0 + y7, -y10 + y2]
# Complexity: 15, fitness: -531.0408935546875, equation: [0, y0 + y7 + (y10*y4 - 0.66)*(y0 - y10 + y2 + y7 + y9), -y10 + y2]
# Complexity: 17, fitness: -979.8330078125, equation: [cos(y0*(y0 - y10 + y2*(-y9 + cos(y10)) + y2 + y7)), y0 + y7 - y9 + cos(y10), -y10 + y2]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 8, fitness: -352.7308654785156, equation: [cos(y10*(-0.92*y1 - 0.92*y2)), y10*(-0.92*y1 - 0.92*y2), 0]
# Complexity: 12, fitness: -361.4336853027344, equation: [sin(y6 + 1.15), (y3 - 0.24)*(y7*sin(y6 + 1.15) + y8), 0]
# Complexity: 13, fitness: -365.68402099609375, equation: [0, y0 + y7 + (y6 - 0.66)*(y0 - y10 + y2 + y7 + y9), -y10 + y2]
# Complexity: 14, fitness: -982.5616455078125, equation: [cos(y0*(y0 - y10 + y2*y7 + y2 + y7)), y0 + y7, -y10 + y2]
# Complexity: 16, fitness: -1012.2232666015625, equation: [cos(y0*(y0 - y10 + y2*(y8 - y9) + y2 + y7)), y0 + y7 + y8 - y9, -y10 + y2]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 8, fitness: -365.0895080566406, equation: [0, y7*y8**2 + sin(y10), y7*y8]
# Complexity: 13, fitness: -365.68402099609375, equation: [0, y0 + y7 + (y6 - 0.66)*(y0 - y10 + y2 + y7 + y9), -y10 + y2]
# Complexity: 14, fitness: -1002.518310546875, equation: [cos(y0*(y0*y2 + y0 - y10 + y2 + y7)), y0 + y7, -y10 + y2]
# Complexity: 16, fitness: -1012.4780883789062, equation: [cos(y0*(y0 - y10 + y2*(y8 - y9) + y2 + y7)), y0 + y7 + y8 - y9, -y10 + y2]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 7, fitness: -347.569580078125, equation: [0, 2*y1*y7 - 2*y7, 0]
# Complexity: 8, fitness: -365.0895080566406, equation: [0, y7*y8**2 + sin(y10), y7*y8]
# Complexity: 12, fitness: -366.78839111328125, equation: [0, y7*y8**2 + (y0 + y7)*sin(y10), y7*y8]
# Complexity: 13, fitness: -574.883056640625, equation: [0, y0 + y1*(y0 - y10 + y2 + y7 + 2*y8) + y7, -y10 + y8]
# Complexity: 14, fitness: -1002.518310546875, equation: [cos(y0*(y0*y2 + y0 - y10 + y2 + y7)), y0 + y7, -y10 + y2]
# Complexity: 16, fitness: -1012.4780883789062, equation: [cos(y0*(y0 - y10 + y2*(y8 - y9) + y2 + y7)), y0 + y7 + y8 - y9, -y10 + y2]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 7, fitness: -347.569580078125, equation: [0, 2*y1*y7 - 2*y7, 0]
# Complexity: 8, fitness: -365.0895080566406, equation: [0, y7*y8**2 + sin(y10), y7*y8]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 14, fitness: -1009.9445190429688, equation: [cos(y0*(y0*y1 + y0 - y10 + y2 + y6)), y0 + y6, -y10 + y2]
# Complexity: 16, fitness: -1021.7398681640625, equation: [cos(y0*(y0 + y1*y3 - y10 + y2 + 2*y7)), y0 + y7, -y10 + y2]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 7, fitness: -347.569580078125, equation: [0, 2*y1*y7 - 2*y7, 0]
# Complexity: 8, fitness: -395.6473693847656, equation: [cos(y0*(-y10 + y2 + y8)), 0, -y10 + y8]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 14, fitness: -1009.9445190429688, equation: [cos(y0*(y0*y1 + y0 - y10 + y2 + y6)), y0 + y6, -y10 + y2]
# Complexity: 16, fitness: -1021.8695068359375, equation: [cos(y0*(y0 + y1*y3 - y10 + y2 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 20, fitness: -1022.82177734375, equation: [-y5 - y6 + cos(y0*(y0 - y10 + y2*(y8 - y9) + y2 + y7)), y0 + y7 + y8 - y9, -y10 + y2]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 7, fitness: -347.569580078125, equation: [0, 2*y1*y7 - 2*y7, 0]
# Complexity: 8, fitness: -395.6473693847656, equation: [cos(y0*(-y10 + y2 + y8)), 0, -y10 + y8]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 14, fitness: -1009.9445190429688, equation: [cos(y0*(y0*y1 + y0 - y10 + y2 + y6)), y0 + y6, -y10 + y2]
# Complexity: 16, fitness: -1021.8695068359375, equation: [cos(y0*(y0 + y1*y3 - y10 + y2 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 20, fitness: -1022.82177734375, equation: [-y5 - y6 + cos(y0*(y0 - y10 + y2*(y8 - y9) + y2 + y7)), y0 + y7 + y8 - y9, -y10 + y2]
# Complexity: 23, fitness: -1027.819091796875, equation: [(y0 - 1.16)*(y10*y7*cos(y0*(y0 - y10 + y2 + 2*y7)) + sin(y7)) + cos(y0*(y0 - y10 + y2 + 2*y7)), y0 + y7, -y10 + y2]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 4, fitness: -927.4193115234375, equation: [cos(y2 - y4), 0, y2 - y4]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 14, fitness: -1009.9445190429688, equation: [cos(y0*(y0*y1 + y0 - y10 + y2 + y6)), y0 + y6, -y10 + y2]
# Complexity: 16, fitness: -1021.8695068359375, equation: [cos(y0*(y0 + y1*y3 - y10 + y2 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 20, fitness: -1022.82177734375, equation: [-y5 - y6 + cos(y0*(y0 - y10 + y2*(y8 - y9) + y2 + y7)), y0 + y7 + y8 - y9, -y10 + y2]
# Complexity: 23, fitness: -1027.819091796875, equation: [(y0 - 1.16)*(y10*y7*cos(y0*(y0 - y10 + y2 + 2*y7)) + sin(y7)) + cos(y0*(y0 - y10 + y2 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 28, fitness: -1029.86083984375, equation: [cos(y0*(y0 - y1*y3 + y2*sin(cos(y5)) + y3*(y0*y4 - 0.0775*y8) - y4 + y7)), y0 + y7 - 0.0775*y8 + sin(cos(y5)), -y1*y3 + y3*(y0*y4 - 0.0775*y8) - y4]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 4, fitness: -927.4193115234375, equation: [cos(y2 - y4), 0, y2 - y4]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 14, fitness: -1009.9445190429688, equation: [cos(y0*(y0*y1 + y0 - y10 + y2 + y6)), y0 + y6, -y10 + y2]
# Complexity: 16, fitness: -1021.8695068359375, equation: [cos(y0*(y0 + y1*y3 - y10 + y2 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 20, fitness: -1022.82177734375, equation: [-y5 - y6 + cos(y0*(y0 - y10 + y2*(y8 - y9) + y2 + y7)), y0 + y7 + y8 - y9, -y10 + y2]
# Complexity: 23, fitness: -1027.819091796875, equation: [(y0 - 1.16)*(y10*y7*cos(y0*(y0 - y10 + y2 + 2*y7)) + sin(y7)) + cos(y0*(y0 - y10 + y2 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 28, fitness: -1030.05078125, equation: [cos(y0*(y0 - y1*y3 + y2*sin(cos(y5)) + y3*(y0*y4 - 0.0775*y8) - y4 + y7)), y0 + y7 - 0.0775*y8 + sin(cos(y5)), -y1*y3 + y3*(y0*y4 - 0.0775*y8) - y4]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 4, fitness: -927.4193115234375, equation: [cos(y2 - y4), 0, y2 - y4]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 14, fitness: -1009.9445190429688, equation: [cos(y0*(y0*y1 + y0 - y10 + y2 + y6)), y0 + y6, -y10 + y2]
# Complexity: 16, fitness: -1021.8695068359375, equation: [cos(y0*(y0 + y1*y3 - y10 + y2 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 20, fitness: -1022.82177734375, equation: [-y5 - y6 + cos(y0*(y0 - y10 + y2*(y8 - y9) + y2 + y7)), y0 + y7 + y8 - y9, -y10 + y2]
# Complexity: 23, fitness: -1027.819091796875, equation: [(y0 - 1.16)*(y10*y7*cos(y0*(y0 - y10 + y2 + 2*y7)) + sin(y7)) + cos(y0*(y0 - y10 + y2 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 28, fitness: -1030.05078125, equation: [cos(y0*(y0 - y1*y3 + y2*sin(cos(y5)) + y3*(y0*y4 - 0.0775*y8) - y4 + y7)), y0 + y7 - 0.0775*y8 + sin(cos(y5)), -y1*y3 + y3*(y0*y4 - 0.0775*y8) - y4]
# Complexity: 29, fitness: -1031.371826171875, equation: [cos(y0*(y0 - y1*y3 + y2*sin(cos(y5)) + y3*(y0*y4 + y8*sin(y3)) - y4 + y7)), y0 + y7 + y8*sin(y3) + sin(y3) + sin(cos(y5)), -y1*y3 + y3*(y0*y4 + y8*sin(y3)) - y4]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 4, fitness: -927.4193115234375, equation: [cos(y2 - y4), 0, y2 - y4]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 14, fitness: -1009.9445190429688, equation: [cos(y0*(y0*y1 + y0 - y10 + y2 + y6)), y0 + y6, -y10 + y2]
# Complexity: 16, fitness: -1022.8372802734375, equation: [cos(y0*(y0*y10 + y0 + y10 - y2 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 20, fitness: -1037.892822265625, equation: [cos(y2*(y0*y2 - y10 + y2*(-2*y1 + y10) + 0.479*y5)), -2*y1 + y10, y0*y2 - y10]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 4, fitness: -927.4193115234375, equation: [cos(y2 - y4), 0, y2 - y4]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 12, fitness: -1010.0900268554688, equation: [cos(y0*(y0 + y1 + y10 - y2 + y7)), y0 + y7, -y10 + y2]
# Complexity: 16, fitness: -1022.8372802734375, equation: [cos(y0*(y0*y10 + y0 + y10 - y2 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 20, fitness: -1038.87548828125, equation: [cos(y2*(y0*y2 - y10 + y2*(-2*y1 + y10) + 0.479*y5)), -2*y1 + y10, y0*y2 - y10]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 4, fitness: -927.4193115234375, equation: [cos(y2 - y4), 0, y2 - y4]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 12, fitness: -1010.0900268554688, equation: [cos(y0*(y0 + y1 + y10 - y2 + y7)), y0 + y7, -y10 + y2]
# Complexity: 16, fitness: -1022.8372802734375, equation: [cos(y0*(y0*y10 + y0 + y10 - y2 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 20, fitness: -1038.87548828125, equation: [cos(y2*(y0*y2 - y10 + y2*(-2*y1 + y10) + 0.479*y5)), -2*y1 + y10, y0*y2 - y10]
# Complexity: 26, fitness: -1051.09619140625, equation: [cos(y2*(y0*y2 - y10 + y2*(-y1 + y10 - y2*(-2*y1 + y10)) + 0.479*y5)), -3*y1 + 2*y10 - y2*(-2*y1 + y10), y0*y2 - y10]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 4, fitness: -927.4193115234375, equation: [cos(y2 - y4), 0, y2 - y4]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 12, fitness: -1010.0900268554688, equation: [cos(y0*(y0 + y1 + y10 - y2 + y7)), y0 + y7, -y10 + y2]
# Complexity: 14, fitness: -1027.5576171875, equation: [cos(y0*(y0 + y10 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 20, fitness: -1038.87548828125, equation: [cos(y2*(y0*y2 - y10 + y2*(-2*y1 + y10) + 0.479*y5)), -2*y1 + y10, y0*y2 - y10]
# Complexity: 23, fitness: -1041.91650390625, equation: [cos(y0*(-y10 + y2 + (y1*y3 - y7)*(y1*sin(y1*y3) - y2 - y9))), y1*y3 + y1*sin(y1*y3) - y2 - y7 - y9, -y10 + y2]
# Complexity: 26, fitness: -1051.46484375, equation: [cos(y2*(y0*y2 - y10 + y2*(-y1 + y10 - y2*(-2*y1 + y10)) + 0.479*y5)), -3*y1 + 2*y10 - y2*(-2*y1 + y10), y0*y2 - y10]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 4, fitness: -927.4193115234375, equation: [cos(y2 - y4), 0, y2 - y4]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 12, fitness: -1010.0900268554688, equation: [cos(y0*(y0 + y1 + y10 - y2 + y7)), y0 + y7, -y10 + y2]
# Complexity: 14, fitness: -1027.5576171875, equation: [cos(y0*(y0 + y10 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 17, fitness: -1044.408447265625, equation: [cos(y0*(-y10 + y2)*(y1*sin(y2) + y2 - 2*y7)), y1*sin(y2) + y2 - 2*y7, -y10 + y2]
# Complexity: 24, fitness: -1051.4176025390625, equation: [cos(y2*(y0*y2 - y10 + y2*(-y1 + y10 - y2*(-2*y1 + y10)) + y3)), -3*y1 + 2*y10 - y2*(-2*y1 + y10), y0*y2 - y10]
# Complexity: 26, fitness: -1051.630859375, equation: [cos(y2*(y0*y2 - y10 + y2*(-y1 + y10 - y2*(-2*y1 + y10)) + 0.479*y5)), -3*y1 + 2*y10 - y2*(-2*y1 + y10), y0*y2 - y10]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 4, fitness: -927.4193115234375, equation: [cos(y2 - y4), 0, y2 - y4]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 12, fitness: -1010.0900268554688, equation: [cos(y0*(y0 + y1 + y10 - y2 + y7)), y0 + y7, -y10 + y2]
# Complexity: 14, fitness: -1027.5576171875, equation: [cos(y0*(y0 + y10 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 17, fitness: -1044.408447265625, equation: [cos(y0*(-y10 + y2)*(y1*sin(y2) + y2 - 2*y7)), y1*sin(y2) + y2 - 2*y7, -y10 + y2]
# Complexity: 24, fitness: -1051.591064453125, equation: [cos(y2*(y0*y2 - y10 + y2*(-y1*(-2*y1 + y10) - y1 + y10) + y7)), -y1*(-2*y1 + y10) - 3*y1 + 2*y10, y0*y2 - y10]
# Complexity: 26, fitness: -1051.630859375, equation: [cos(y2*(y0*y2 - y10 + y2*(-y1 + y10 - y2*(-2*y1 + y10)) + 0.479*y5)), -3*y1 + 2*y10 - y2*(-2*y1 + y10), y0*y2 - y10]
# Complexity: 28, fitness: -1052.4599609375, equation: [cos(y2*(y0*y2 - y1*(-2*y1 + y10) - y1 + y2 + 0.479*y5 + 0.479*y6)), -y1*(-2*y1 + y10) - 3*y1 + 2*y10, y0*y2 - y10]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 4, fitness: -927.4193115234375, equation: [cos(y2 - y4), 0, y2 - y4]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 12, fitness: -1010.0900268554688, equation: [cos(y0*(y0 + y1 + y10 - y2 + y7)), y0 + y7, -y10 + y2]
# Complexity: 14, fitness: -1027.5576171875, equation: [cos(y0*(y0 + y10 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 17, fitness: -1044.408447265625, equation: [cos(y0*(-y10 + y2)*(y1*sin(y2) + y2 - 2*y7)), y1*sin(y2) + y2 - 2*y7, -y10 + y2]
# Complexity: 22, fitness: -1045.019775390625, equation: [cos(y0*y2 - y10 + y2*(-y1 + y10 - y2*(-2*y1 + y10)) + y2), -3*y1 + 2*y10 - y2*(-2*y1 + y10), y0*y2 - y10]
# Complexity: 24, fitness: -1051.591064453125, equation: [cos(y2*(y0*y2 - y10 + y2*(-y1*(-2*y1 + y10) - y1 + y10) + y7)), -y1*(-2*y1 + y10) - 3*y1 + 2*y10, y0*y2 - y10]
# Complexity: 26, fitness: -1051.630859375, equation: [cos(y2*(y0*y2 - y10 + y2*(-y1 + y10 - y2*(-2*y1 + y10)) + 0.479*y5)), -3*y1 + 2*y10 - y2*(-2*y1 + y10), y0*y2 - y10]
# Complexity: 28, fitness: -1052.4599609375, equation: [cos(y2*(y0*y2 - y1*(-2*y1 + y10) - y1 + y2 + 0.479*y5 + 0.479*y6)), -y1*(-2*y1 + y10) - 3*y1 + 2*y10, y0*y2 - y10]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 4, fitness: -927.4193115234375, equation: [cos(y2 - y4), 0, y2 - y4]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 12, fitness: -1010.0900268554688, equation: [cos(y0*(y0 + y1 + y10 - y2 + y7)), y0 + y7, -y10 + y2]
# Complexity: 14, fitness: -1027.5576171875, equation: [cos(y0*(y0 + y10 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 17, fitness: -1044.408447265625, equation: [cos(y0*(-y10 + y2)*(y1*sin(y2) + y2 - 2*y7)), y1*sin(y2) + y2 - 2*y7, -y10 + y2]
# Complexity: 22, fitness: -1045.019775390625, equation: [cos(y0*y2 - y10 + y2*(-y1 + y10 - y2*(-2*y1 + y10)) + y2), -3*y1 + 2*y10 - y2*(-2*y1 + y10), y0*y2 - y10]
# Complexity: 24, fitness: -1052.88037109375, equation: [cos(y2*(y0*y2 - y10 + y2*(-y1 + y10 - y8*(-2*y1 + y10)) + y3)), -3*y1 + 2*y10 - y8*(-2*y1 + y10), y0*y2 - y10]
# Complexity: 28, fitness: -1055.2921142578125, equation: [cos(y0*y2 + y0*(y5 + y6) - y1*(-2*y1 + y10) - y1 + 2*y2), -y1*(-2*y1 + y10) - 3*y1 + 2*y10, y0*y2 - y10]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 4, fitness: -927.4193115234375, equation: [cos(y2 - y4), 0, y2 - y4]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 12, fitness: -1010.0900268554688, equation: [cos(y0*(y0 + y1 + y10 - y2 + y7)), y0 + y7, -y10 + y2]
# Complexity: 14, fitness: -1027.5576171875, equation: [cos(y0*(y0 + y10 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 17, fitness: -1044.408447265625, equation: [cos(y0*(-y10 + y2)*(y1*sin(y2) + y2 - 2*y7)), y1*sin(y2) + y2 - 2*y7, -y10 + y2]
# Complexity: 22, fitness: -1056.0986328125, equation: [cos(y0*(y1*y3 + y1*sin(sin(y7)) - y10 - y7 - y9)), y1*y3 + y1*sin(sin(y7)) - y2 - y7 - y9, -y10 + y2]
# Complexity: 24, fitness: -1062.30712890625, equation: [cos(y2*(y0*y2 + y1 - y10 + y2*(-3*y1 + 2*y10 - y2))), -5*y1 + 3*y10 - y2, y0*y2 - y10]
# Complexity: 25, fitness: -1063.863525390625, equation: [cos(y1*(y0*y2 + y2*(y2*sin(y2) + y2 - 2*y7) + y7)), y2*sin(y2) + y2 - 2*y7, y0*y2 - y10]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 4, fitness: -927.4193115234375, equation: [cos(y2 - y4), 0, y2 - y4]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 12, fitness: -1010.0900268554688, equation: [cos(y0*(y0 + y1 + y10 - y2 + y7)), y0 + y7, -y10 + y2]
# Complexity: 14, fitness: -1027.5576171875, equation: [cos(y0*(y0 + y10 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 17, fitness: -1044.408447265625, equation: [cos(y0*(-y10 + y2)*(y1*sin(y2) + y2 - 2*y7)), y1*sin(y2) + y2 - 2*y7, -y10 + y2]
# Complexity: 22, fitness: -1056.0986328125, equation: [cos(y0*(y1*y3 + y1*sin(sin(y7)) - y10 - y7 - y9)), y1*y3 + y1*sin(sin(y7)) - y2 - y7 - y9, -y10 + y2]
# Complexity: 24, fitness: -1062.459716796875, equation: [cos(y2*(y0*y2 + y1 - y10 + y2*(-3*y1 + 2*y10 - y2))), -5*y1 + 3*y10 - y2, y0*y2 - y10]
# Complexity: 25, fitness: -1065.03759765625, equation: [cos(y1*(y0*y2 + y1 - y10 + y2*(y2*sin(y2) + y2 - 2*y7) + y3)), y2*sin(y2) + y2 - 2*y7, y0*y2 - y10]
# Final pareto front:
# Complexity: 1, fitness: -250.21832275390625, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25759887695312, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -344.741943359375, equation: [0, -0.875*y7, 0]
# Complexity: 4, fitness: -927.4193115234375, equation: [cos(y2 - y4), 0, y2 - y4]
# Complexity: 10, fitness: -1003.8106689453125, equation: [cos(y0*(-y10 + y2 - 1.23*y7)), -1.23*y7, -y10 + y2]
# Complexity: 12, fitness: -1010.0900268554688, equation: [cos(y0*(y0 + y1 + y10 - y2 + y7)), y0 + y7, -y10 + y2]
# Complexity: 14, fitness: -1027.5576171875, equation: [cos(y0*(y0 + y10 + 2*y7)), y0 + y7, -y10 + y2]
# Complexity: 17, fitness: -1044.408447265625, equation: [cos(y0*(-y10 + y2)*(y1*sin(y2) + y2 - 2*y7)), y1*sin(y2) + y2 - 2*y7, -y10 + y2]
# Complexity: 22, fitness: -1056.0986328125, equation: [cos(y0*(y1*y3 + y1*sin(sin(y7)) - y10 - y7 - y9)), y1*y3 + y1*sin(sin(y7)) - y2 - y7 - y9, -y10 + y2]
# Complexity: 24, fitness: -1062.459716796875, equation: [cos(y2*(y0*y2 + y1 - y10 + y2*(-3*y1 + 2*y10 - y2))), -5*y1 + 3*y10 - y2, y0*y2 - y10]
# Complexity: 25, fitness: -1065.03759765625, equation: [cos(y1*(y0*y2 + y1 - y10 + y2*(y2*sin(y2) + y2 - 2*y7) + y3)), y2*sin(y2) + y2 - 2*y7, y0*y2 - y10]
