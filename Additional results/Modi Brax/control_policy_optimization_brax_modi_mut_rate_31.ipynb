# %%
from genetic_programming import GeneticProgramming
from fitness_functions.Gymnax_fitness_function import GymFitnessFunction

import jax
import jax.numpy as jnp
import jax.random as jr

import brax
from brax import envs
import matplotlib.pyplot as plt

class BraxGymnaxWrapper:
    def __init__(self, env_name, backend):
        self.env = envs.get_environment(env_name=env_name, backend=backend)
        self.observation_space = self.env.observation_size
        self.action_space = self.env.action_size

    # state, env_state = self.env.reset(subkey, self.env_params)

    def reset(self, key, params=None):
        #state consists of pipeline_state, obs, reward, done, metrics, info
        state = self.env.reset(key)
        return state.obs, state

     # next_state, next_env_state, reward, done, _ = self.env.step(
     #            subkey, env_state, action, self.env_params
     #        )

    def step(self, key, state, action, params=None):

      action = action.reshape(self.action_space)
      next_state = self.env.step(state, action)
      done = next_state.done

      # Freeze state after done
      obs = jnp.where(done, state.obs, next_state.obs)
      new_state = jax.tree.map(
          lambda new, old: jnp.where(done, old, new),
          next_state,
          state
      )

      reward = jnp.where(done, 0.0, next_state.reward)

      return obs, new_state, reward, done, {}
# Out:
# E0606 10:38:23.122638  245270 cuda_executor.cc:1526] Could not get kernel mode driver version: (INVALID_ARGUMENT: Version does not match the format X.Y.Z)
# E0606 10:38:23.139223  245088 cuda_executor.cc:1526] Could not get kernel mode driver version: (INVALID_ARGUMENT: Version does not match the format X.Y.Z)
# These device(s) are detected: [CudaDevice(id=0)]
# Failed to import warp: No module named 'warp'
# Failed to import mujoco_warp: No module named 'warp'

# %%
brax_env = BraxGymnaxWrapper('inverted_pendulum', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=1, max_nodes=31)
# Out:
# /home/theun/yes/envs/modi_kozax/lib/python3.12/site-packages/brax/io/mjcf.py:480: UserWarning: Brax System, piplines and environments are not actively being maintained. Please see MJX for a well maintained JAX-based physics engine: https://github.com/google-deepmind/mujoco/tree/main/mjx. For a host of environments that use MJX, see: https://github.com/google-deepmind/mujoco_playground.
#   warnings.warn(
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated)
# Compiling code for evaluation and evolution...
# Finished compilation in 149.25 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: -7.25, equation: [-0.0638]
# Complexity: 2, fitness: -93.875, equation: [sin(y3)]
# Complexity: 4, fitness: -233.375, equation: [y1 + sin(y1)]
# Complexity: 5, fitness: -252.8125, equation: [3.42*y1]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2**2]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [2*y1 + y2 + y3]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -257.625, equation: [y1 + y2 + y3]
# Complexity: 6, fitness: -554.375, equation: [y0 + y1 - sin(y0)]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]
# Final pareto front:
# Complexity: 1, fitness: -181.9375, equation: [y1]
# Complexity: 3, fitness: -241.3125, equation: [2.42*y1]
# Complexity: 5, fitness: -977.0, equation: [y1 + y2**2]
# Complexity: 7, fitness: -1000.0, equation: [1.6*y1 + y2**2]

# %%
brax_env = BraxGymnaxWrapper('inverted_double_pendulum', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=1, max_nodes=31)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated)
# Compiling code for evaluation and evolution...
# Finished compilation in 96.04 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: -184.10488891601562, equation: [-0.0638]
# Complexity: 2, fitness: -440.75897216796875, equation: [sin(y1)]
# Complexity: 3, fitness: -775.4652709960938, equation: [y2 - y7]
# Complexity: 7, fitness: -1006.9361572265625, equation: [0.486*y7*(y7 - 1.94)]
# Complexity: 9, fitness: -1246.233154296875, equation: [(y1 - 0.743)*(y2 + y4*y7)]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -424.4704895019531, equation: [y6]
# Complexity: 2, fitness: -440.75897216796875, equation: [sin(y1)]
# Complexity: 3, fitness: -815.1287231445312, equation: [y1 - y7]
# Complexity: 7, fitness: -1006.9361572265625, equation: [0.486*y7*(y7 - 1.94)]
# Complexity: 9, fitness: -1246.233154296875, equation: [(y1 - 0.743)*(y2 + y4*y7)]
# Complexity: 15, fitness: -2016.470703125, equation: [(y0**2 + y2)*(y3*y6 + 2*y5 - 1.76)]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -908.64208984375, equation: [y5 - y7]
# Complexity: 7, fitness: -1006.9361572265625, equation: [0.486*y7*(y7 - 1.94)]
# Complexity: 9, fitness: -1246.233154296875, equation: [(y1 - 0.743)*(y2 + y4*y7)]
# Complexity: 12, fitness: -6038.86962890625, equation: [-y2*(y3 + 1.25) + sin(y2*y7)]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -908.64208984375, equation: [y5 - y7]
# Complexity: 4, fitness: -908.6424560546875, equation: [sin(y5 - y7)]
# Complexity: 7, fitness: -1080.20654296875, equation: [y5*y7**2 - y7]
# Complexity: 9, fitness: -1246.233154296875, equation: [(y1 - 0.743)*(y2 + y4*y7)]
# Complexity: 11, fitness: -3549.811279296875, equation: [y2*(y3*y6 + 2*y5 - 1.76)]
# Complexity: 12, fitness: -6038.86962890625, equation: [-y2*(y3 + 1.25) + sin(y2*y7)]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -908.64208984375, equation: [y5 - y7]
# Complexity: 4, fitness: -908.6424560546875, equation: [sin(y5 - y7)]
# Complexity: 5, fitness: -1047.342041015625, equation: [y7*(y1 - 0.743)]
# Complexity: 7, fitness: -4066.927978515625, equation: [y2*(y1 + y5 - 1.76)]
# Complexity: 11, fitness: -6638.68798828125, equation: [y2*(y3*y6 + y5 + y6 - 1.76)]
# Complexity: 15, fitness: -7006.37158203125, equation: [(y2*y5 + y2)*(y3*y6 + 2*y5 - 1.76)]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 14, fitness: -9210.853515625, equation: [-y2*(y4 + 1.25) + sin(y6*y7**2)]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 14, fitness: -9210.853515625, equation: [-y2*(y4 + 1.25) + sin(y6*y7**2)]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 14, fitness: -9210.853515625, equation: [-y2*(y4 + 1.25) + sin(y6*y7**2)]
# Complexity: 15, fitness: -9210.859375, equation: [-y2*(y4 + 1.25) + sin(y6*y7*sin(y7))]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 14, fitness: -9317.79296875, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 14, fitness: -9317.7939453125, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 18, fitness: -9318.369140625, equation: [-y2*(y4 + 1.44) + sin(y7*(y1*y2 + y6*y7))]
# Complexity: 22, fitness: -9355.9814453125, equation: [-y2*(y0*y7 + y3 + 1.01) + sin(y1*y2**2*y7**2)]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -8875.0625, equation: [y2*(y2*y6 - 1.76)]
# Complexity: 14, fitness: -9317.7939453125, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 18, fitness: -9318.369140625, equation: [-y2*(y4 + 1.44) + sin(y7*(y1*y2 + y6*y7))]
# Complexity: 22, fitness: -9355.9814453125, equation: [-y2*(y0*y7 + y3 + 1.01) + sin(y1*y2**2*y7**2)]
# Complexity: 24, fitness: -9356.76171875, equation: [-y2*(y0*y7 + y3 + 0.897) + sin(y1*y2**2*y4*y5*y7)]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -8875.0625, equation: [y2*(y2*y6 - 1.76)]
# Complexity: 13, fitness: -9149.3125, equation: [y2*y3*(y1*y7 + y6*y7 - 1.76)]
# Complexity: 14, fitness: -9317.7939453125, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 18, fitness: -9357.0048828125, equation: [-y2*(y0*y7 + 1.91) - sin(0.0741*y2**2*y7)]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 13, fitness: -9149.3125, equation: [y2*y3*(y1*y7 + y6*y7 - 1.76)]
# Complexity: 14, fitness: -9317.7939453125, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 18, fitness: -9357.0048828125, equation: [-y2*(y0*y7 + 1.91) - sin(0.0741*y2**2*y7)]
# Complexity: 28, fitness: -9357.517578125, equation: [-y2*y3*(y4 + 1.24)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y5 + y7))]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 13, fitness: -9149.3125, equation: [y2*y3*(y1*y7 + y6*y7 - 1.76)]
# Complexity: 14, fitness: -9317.7939453125, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 28, fitness: -9357.517578125, equation: [-y2*y3*(y4 + 1.24)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y5 + y7))]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 11, fitness: -9145.24609375, equation: [y2*(y1**2 + y6*y7 - 1.76)]
# Complexity: 13, fitness: -9149.3125, equation: [y2*y3*(y1*y7 + y6*y7 - 1.76)]
# Complexity: 14, fitness: -9317.7939453125, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 24, fitness: -9357.6669921875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*(-0.0741*y2*y3 - 0.968*y2))]
# Complexity: 26, fitness: -9358.19140625, equation: [-y2*y3*(y3 + 0.388)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y5 + y7))]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 11, fitness: -9145.24609375, equation: [y2*(y1**2 + y6*y7 - 1.76)]
# Complexity: 13, fitness: -9149.3125, equation: [y2*y3*(y1*y7 + y6*y7 - 1.76)]
# Complexity: 14, fitness: -9317.7939453125, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 23, fitness: -9357.6123046875, equation: [-y2*(y0*y7 + y3 + 1.01) + sin(y1*y7*(y2 + y7)*cos(y6))]
# Complexity: 24, fitness: -9357.8818359375, equation: [-y2*(y3 + y7*(y0 + y5) + 0.85) + sin(y1*y4*y7**2*(y2 + 1.05))]
# Complexity: 26, fitness: -9358.19140625, equation: [-y2*y3*(y3 + 0.388)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y5 + y7))]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9145.24609375, equation: [y2*(y1**2 + y6*y7 - 1.76)]
# Complexity: 13, fitness: -9149.3125, equation: [y2*y3*(y1*y7 + y6*y7 - 1.76)]
# Complexity: 14, fitness: -9317.7939453125, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 24, fitness: -9358.189453125, equation: [-y2*(y0*y7 + sin(y3) + 1.01) + sin(y1*y7*(y2 + y7)*cos(y6))]
# Complexity: 26, fitness: -9358.19140625, equation: [-y2*y3*(y3 + 0.388)*(y0*y7 + y3 + 1.65) + sin(y6*y7*(y5 + y7))]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9145.24609375, equation: [y2*(y1**2 + y6*y7 - 1.76)]
# Complexity: 13, fitness: -9149.3125, equation: [y2*y3*(y1*y7 + y6*y7 - 1.76)]
# Complexity: 14, fitness: -9317.7939453125, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 22, fitness: -9357.84765625, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*(y0*y1 - 0.968*y7))]
# Complexity: 24, fitness: -9358.189453125, equation: [-y2*(y0*y7 + sin(y3) + 1.01) + sin(y1*y7*(y2 + y7)*cos(y6))]
# Complexity: 26, fitness: -9358.208984375, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*(-0.0741*y0*y3 - 0.968*y0 - 0.968*y7))]
# Complexity: 27, fitness: -9358.46484375, equation: [-y2*(y0*y7 + y3 + 1.01) + sin(y1*y7*(y2 + y7)*(y3 + 0.85))*cos(y5)]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9145.24609375, equation: [y2*(y1**2 + y6*y7 - 1.76)]
# Complexity: 13, fitness: -9149.3125, equation: [y2*y3*(y1*y7 + y6*y7 - 1.76)]
# Complexity: 14, fitness: -9317.7939453125, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 22, fitness: -9357.84765625, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*(y0*y1 - 0.968*y7))]
# Complexity: 24, fitness: -9358.189453125, equation: [-y2*(y0*y7 + sin(y3) + 1.01) + sin(y1*y7*(y2 + y7)*cos(y6))]
# Complexity: 26, fitness: -9358.208984375, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*(-0.0741*y0*y3 - 0.968*y0 - 0.968*y7))]
# Complexity: 27, fitness: -9358.525390625, equation: [-y2*(y0*y7 + y3 + 1.01) + sin(y1*y7*(y2 + y7)*(y3 + y4))*cos(y5)]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9145.24609375, equation: [y2*(y1**2 + y6*y7 - 1.76)]
# Complexity: 13, fitness: -9149.3125, equation: [y2*y3*(y1*y7 + y6*y7 - 1.76)]
# Complexity: 14, fitness: -9317.7939453125, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 15, fitness: -9354.64453125, equation: [-y2*(y0*y7 + y3 + 0.897) - 0.201*y2]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 22, fitness: -9358.087890625, equation: [-y2*(y3 + 1.43)*(y0*y7 + 0.797) + sin(y2*y6*y7**3)]
# Complexity: 24, fitness: -9358.189453125, equation: [-y2*(y0*y7 + sin(y3) + 1.01) + sin(y1*y7*(y2 + y7)*cos(y6))]
# Complexity: 26, fitness: -9358.208984375, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*(-0.0741*y0*y3 - 0.968*y0 - 0.968*y7))]
# Complexity: 27, fitness: -9358.525390625, equation: [-y2*(y0*y7 + y3 + 1.01) + sin(y1*y7*(y2 + y7)*(y3 + y4))*cos(y5)]
# Complexity: 29, fitness: -9358.681640625, equation: [-y2*(y0*y7 + y3 + 1.01) + sin(y1*y7*(2*y2 + y7)*(y3 + 0.85))*cos(y5)]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9145.24609375, equation: [y2*(y1**2 + y6*y7 - 1.76)]
# Complexity: 13, fitness: -9149.3125, equation: [y2*y3*(y1*y7 + y6*y7 - 1.76)]
# Complexity: 14, fitness: -9317.7939453125, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 15, fitness: -9356.5634765625, equation: [y2*(y1*(y0 + y2) + y6*y7 - 1.96)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 21, fitness: -9357.935546875, equation: [-y2*(y3 + 1.43)*(y0*y7 + 0.797) + sin(y1*y2*y7*sin(y5))]
# Complexity: 22, fitness: -9358.087890625, equation: [-y2*(y3 + 1.43)*(y0*y7 + 0.797) + sin(y2*y6*y7**3)]
# Complexity: 24, fitness: -9358.189453125, equation: [-y2*(y0*y7 + sin(y3) + 1.01) + sin(y1*y7*(y2 + y7)*cos(y6))]
# Complexity: 25, fitness: -9358.34375, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*(-0.968*y0 + y3*sin(y1) - 0.968*y7))]
# Complexity: 27, fitness: -9358.525390625, equation: [-y2*(y0*y7 + y3 + 1.01) + sin(y1*y7*(y2 + y7)*(y3 + y4))*cos(y5)]
# Complexity: 29, fitness: -9358.681640625, equation: [-y2*(y0*y7 + y3 + 1.01) + sin(y1*y7*(2*y2 + y7)*(y3 + 0.85))*cos(y5)]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9145.24609375, equation: [y2*(y1**2 + y6*y7 - 1.76)]
# Complexity: 13, fitness: -9149.3125, equation: [y2*y3*(y1*y7 + y6*y7 - 1.76)]
# Complexity: 14, fitness: -9317.7939453125, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 15, fitness: -9356.5634765625, equation: [y2*(y1*(y0 + y2) + y6*y7 - 1.96)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 20, fitness: -9358.251953125, equation: [-y2*(y3 + 1.43)*(y0*y7 + 0.797) + sin(y1*y2*y4*y7)]
# Complexity: 25, fitness: -9358.34375, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*(-0.968*y0 + y3*sin(y1) - 0.968*y7))]
# Complexity: 27, fitness: -9358.54296875, equation: [-y2*(y3 + 1.43)*(y0*y7 + 0.797) + sin(y1*y7*(y2 + y7)*(y3 + 0.85))*cos(y3)]
# Complexity: 29, fitness: -9358.681640625, equation: [-y2*(y0*y7 + y3 + 1.01) + sin(y1*y7*(2*y2 + y7)*(y3 + 0.85))*cos(y5)]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9145.24609375, equation: [y2*(y1**2 + y6*y7 - 1.76)]
# Complexity: 13, fitness: -9149.3125, equation: [y2*y3*(y1*y7 + y6*y7 - 1.76)]
# Complexity: 14, fitness: -9317.7939453125, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 15, fitness: -9356.5634765625, equation: [y2*(y1*(y0 + y2) + y6*y7 - 1.96)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 20, fitness: -9358.251953125, equation: [-y2*(y3 + 1.43)*(y0*y7 + 0.797) + sin(y1*y2*y4*y7)]
# Complexity: 25, fitness: -9358.34375, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*(-0.968*y0 + y3*sin(y1) - 0.968*y7))]
# Complexity: 27, fitness: -9358.54296875, equation: [-y2*(y3 + 1.43)*(y0*y7 + 0.797) + sin(y1*y7*(y2 + y7)*(y3 + 0.85))*cos(y3)]
# Complexity: 29, fitness: -9358.681640625, equation: [-y2*(y0*y7 + y3 + 1.01) + sin(y1*y7*(2*y2 + y7)*(y3 + 0.85))*cos(y5)]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9145.24609375, equation: [y2*(y1**2 + y6*y7 - 1.76)]
# Complexity: 13, fitness: -9149.3125, equation: [y2*y3*(y1*y7 + y6*y7 - 1.76)]
# Complexity: 14, fitness: -9317.7939453125, equation: [-y2*(y4 + 1.44) + sin(y6*y7**2)]
# Complexity: 15, fitness: -9356.5634765625, equation: [y2*(y1*(y0 + y2) + y6*y7 - 1.96)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 20, fitness: -9358.251953125, equation: [-y2*(y3 + 1.43)*(y0*y7 + 0.797) + sin(y1*y2*y4*y7)]
# Complexity: 25, fitness: -9358.34375, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*(-0.968*y0 + y3*sin(y1) - 0.968*y7))]
# Complexity: 26, fitness: -9358.697265625, equation: [-y2*(y0*y7 + y3 + 1.01) + sin(y1*y7*(2*y2 + y7)*(y3 + 0.85))]
# Complexity: 31, fitness: -9358.75, equation: [-y2*(y3 + 1.43)*(y0*y7 + 0.797) + sin((y0*y7 + 2.23)*sin(y1*y3*y7*(y2 + y7)))]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9145.24609375, equation: [y2*(y1**2 + y6*y7 - 1.76)]
# Complexity: 13, fitness: -9149.3125, equation: [y2*y3*(y1*y7 + y6*y7 - 1.76)]
# Complexity: 14, fitness: -9352.462890625, equation: [-y2*(y0*y7 + y3 + 2.23) + sin(y2)]
# Complexity: 15, fitness: -9356.5634765625, equation: [y2*(y1*(y0 + y2) + y6*y7 - 1.96)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 20, fitness: -9358.251953125, equation: [-y2*(y3 + 1.43)*(y0*y7 + 0.797) + sin(y1*y2*y4*y7)]
# Complexity: 25, fitness: -9358.34375, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*(-0.968*y0 + y3*sin(y1) - 0.968*y7))]
# Complexity: 26, fitness: -9358.697265625, equation: [-y2*(y0*y7 + y3 + 1.01) + sin(y1*y7*(2*y2 + y7)*(y3 + 0.85))]
# Complexity: 31, fitness: -9358.75, equation: [-y2*(y3 + 1.43)*(y0*y7 + 0.797) + sin((y0*y7 + 2.23)*sin(y1*y3*y7*(y2 + y7)))]
# Final pareto front:
# Complexity: 1, fitness: -440.75927734375, equation: [y1]
# Complexity: 3, fitness: -8841.658203125, equation: [-1.76*y2]
# Complexity: 7, fitness: -9005.8544921875, equation: [y2*(y0*y1 - 1.76)]
# Complexity: 9, fitness: -9005.9287109375, equation: [y2*(-1.76*y0*y2 - 1.76)]
# Complexity: 11, fitness: -9145.24609375, equation: [y2*(y1**2 + y6*y7 - 1.76)]
# Complexity: 13, fitness: -9149.3125, equation: [y2*y3*(y1*y7 + y6*y7 - 1.76)]
# Complexity: 14, fitness: -9352.462890625, equation: [-y2*(y0*y7 + y3 + 2.23) + sin(y2)]
# Complexity: 15, fitness: -9356.5634765625, equation: [y2*(y1*(y0 + y2) + y6*y7 - 1.96)]
# Complexity: 16, fitness: -9357.2421875, equation: [-y2*(y0*y7 + y1 + y4 + 0.85) + sin(y1*y2)]
# Complexity: 17, fitness: -9357.7998046875, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*sin(y1))]
# Complexity: 20, fitness: -9358.251953125, equation: [-y2*(y3 + 1.43)*(y0*y7 + 0.797) + sin(y1*y2*y4*y7)]
# Complexity: 25, fitness: -9358.34375, equation: [-y2*(y0*y7 + 1.91) + sin(y2*y7*(-0.968*y0 + y3*sin(y1) - 0.968*y7))]
# Complexity: 26, fitness: -9358.697265625, equation: [-y2*(y0*y7 + y3 + 1.01) + sin(y1*y7*(2*y2 + y7)*(y3 + 0.85))]
# Complexity: 31, fitness: -9358.75, equation: [-y2*(y3 + 1.43)*(y0*y7 + 0.797) + sin((y0*y7 + 2.23)*sin(y1*y3*y7*(y2 + y7)))]

# %%
brax_env = BraxGymnaxWrapper('reacher', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=2, max_nodes=31)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated)
# Compiling code for evaluation and evolution...
# Finished compilation in 82.80 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: 637.1117553710938, equation: [0.639, 0]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 4, fitness: 112.74169921875, equation: [0, -sin(y6 - y8)]
# Complexity: 5, fitness: 111.38760375976562, equation: [0, 2*y1*y5 + y4]
# Complexity: 7, fitness: 110.91987609863281, equation: [0, y8*(y1*y10 + 0.599)]
# Complexity: 9, fitness: 107.21183013916016, equation: [0, y5*(y0*y8 - y6 + y7)]
# Complexity: 11, fitness: 106.92889404296875, equation: [y3*y5*(y0 + y3)*(y10 + y8), (y0 + y3)*(y10 + y8)]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 4, fitness: 112.74169921875, equation: [0, -sin(y6 - y8)]
# Complexity: 5, fitness: 111.38760375976562, equation: [0, 2*y1*y5 + y4]
# Complexity: 7, fitness: 110.43020629882812, equation: [0, y8*(y1*y8 + 0.599)]
# Complexity: 9, fitness: 99.90740966796875, equation: [0, y5*(y0*y8 + y4 - y6)]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 4, fitness: 112.39454650878906, equation: [0, y5*sin(y8) + sin(y8)]
# Complexity: 5, fitness: 110.76173400878906, equation: [0, y8*(y5 + 0.599)]
# Complexity: 7, fitness: 107.62448120117188, equation: [0, y5*(y0*y8 + y5)]
# Complexity: 8, fitness: 80.25741577148438, equation: [0, y5*(y0*y8 + sin(y6)) + sin(y6)]
# Complexity: 10, fitness: 79.65605926513672, equation: [0, y8*(y5 + y6)*(sin(y2) + 1.15)]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 4, fitness: 112.39454650878906, equation: [0, y5*sin(y8) + sin(y8)]
# Complexity: 5, fitness: 110.76173400878906, equation: [0, y8*(y5 + 0.599)]
# Complexity: 6, fitness: 110.03948211669922, equation: [0, (y1 + y2)*sin(y8) + sin(y8)]
# Complexity: 7, fitness: 107.54022216796875, equation: [0, y5*(y10 + y5 + y8)]
# Complexity: 8, fitness: 80.25741577148438, equation: [0, y5*(y0*y8 + sin(y6)) + sin(y6)]
# Complexity: 10, fitness: 79.65605926513672, equation: [0, y8*(y5 + y6)*(sin(y2) + 1.15)]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 7, fitness: 78.45408630371094, equation: [0, 1.75*y8*(y5 + y6)]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 7, fitness: 77.84796142578125, equation: [0, y5*(y0*y8 + y8)]
# Complexity: 11, fitness: 76.93065643310547, equation: [0, y5*(y10 + y3*(y10 + y9) + y8)]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 7, fitness: 77.84796142578125, equation: [0, y5*(y0*y8 + y8)]
# Complexity: 11, fitness: 76.93065643310547, equation: [0, y5*(y10 + y3*(y10 + y9) + y8)]
# Complexity: 18, fitness: 76.27822875976562, equation: [y3**2*y5**2*y8**2*(y10 + y5) + y3*y5*y8*(y10 + y5), y3*y5*y8**2*(y10 + y5) + y8*(y10 + y5) + sin(y3**2*y5**2*y8**2*(y10 + y5) - y6)]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 77.84796142578125, equation: [0, y5*(y0*y8 + y8)]
# Complexity: 10, fitness: 76.38148498535156, equation: [0, y8*(3*y5 + sin(y5))]
# Complexity: 18, fitness: 76.27822875976562, equation: [y3**2*y5**2*y8**2*(y10 + y5) + y3*y5*y8*(y10 + y5), y3*y5*y8**2*(y10 + y5) + y8*(y10 + y5) + sin(y3**2*y5**2*y8**2*(y10 + y5) - y6)]
# Complexity: 24, fitness: 73.65738677978516, equation: [y3*y5*y8*sin(y5*y8*(y10 + y5)*(y10 + sin(y3)) - y6) + y5*y8*(y10 + y5)*(y10 + sin(y3)), y8*(y10 + y5) + y8*sin(y5*y8*(y10 + y5)*(y10 + sin(y3)) - y6) + sin(y3*y5*y8*sin(y5*y8*(y10 + y5)*(y10 + sin(y3)) - y6) - y6)]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 10, fitness: 76.38148498535156, equation: [0, y8*(3*y5 + sin(y5))]
# Complexity: 14, fitness: 76.0207290649414, equation: [0, y8*(y5 + y8*(3*y5 + sin(y5))) + y8*(3*y5 + sin(y5))]
# Complexity: 24, fitness: 73.65738677978516, equation: [y3*y5*y8*sin(y5*y8*(y10 + y5)*(y10 + sin(y3)) - y6) + y5*y8*(y10 + y5)*(y10 + sin(y3)), y8*(y10 + y5) + y8*sin(y5*y8*(y10 + y5)*(y10 + sin(y3)) - y6) + sin(y3*y5*y8*sin(y5*y8*(y10 + y5)*(y10 + sin(y3)) - y6) - y6)]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 14, fitness: 76.0207290649414, equation: [0, y8*(y5 + y8*(3*y5 + sin(y5))) + y8*(3*y5 + sin(y5))]
# Complexity: 16, fitness: 74.53953552246094, equation: [0, y5*(y10*y8 + y3*(y10 + y9) + y8) + sin(y5*(y10*y8 + y3*(y10 + y9) + y8) - y6)]
# Complexity: 24, fitness: 68.49810791015625, equation: [y3*y5**2*(y3*y5*y8*(y0 + y8)*(y10 + y5) + y8) + y3*y5*y8*(y0 + y8)*(y10 + y5), y5*(y3*y5*y8*(y0 + y8)*(y10 + y5) + y8) + y8*(y0 + y8)*(y10 + y5) + y8*(y10 + y5) + sin(y3*y5**2*(y3*y5*y8*(y0 + y8)*(y10 + y5) + y8) - y6)]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 12, fitness: 73.24398040771484, equation: [y3*y5*y8*sin(sin(y5)), y8*sin(sin(y5)) + sin(y3*y5*y8*sin(sin(y5)) - y6)]
# Complexity: 22, fitness: 68.18736267089844, equation: [y9*(y0 + y3)*(y10 + y8), y4*(y10*(y3 + y8*sin(y5)) - y6 + y9*(y0 + y3)*(y10 + y8)) - y6 + y8*sin(y5) + y9*(y0 + y3)*(y10 + y8) + (y0 + y3)*(y10 + y8)]
# Complexity: 24, fitness: 67.47990417480469, equation: [y3*y5**2*(y8*(y0 + y8)*(y10 + y5)*(y10 + y8) + y8) + y8*(y0 + y8)*(y10 + y5)*(y10 + y8), y5*(y8*(y0 + y8)*(y10 + y5)*(y10 + y8) + y8) + y8*(y0 + y8)*(y10 + y5) + y8*(y10 + y5) + sin(y3*y5**2*(y8*(y0 + y8)*(y10 + y5)*(y10 + y8) + y8) - y6)]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 12, fitness: 73.24398040771484, equation: [y3*y5*y8*sin(sin(y5)), y8*sin(sin(y5)) + sin(y3*y5*y8*sin(sin(y5)) - y6)]
# Complexity: 22, fitness: 68.18736267089844, equation: [y9*(y0 + y3)*(y10 + y8), y4*(y10*(y3 + y8*sin(y5)) - y6 + y9*(y0 + y3)*(y10 + y8)) - y6 + y8*sin(y5) + y9*(y0 + y3)*(y10 + y8) + (y0 + y3)*(y10 + y8)]
# Complexity: 24, fitness: 67.47990417480469, equation: [y3*y5**2*(y8*(y0 + y8)*(y10 + y5)*(y10 + y8) + y8) + y8*(y0 + y8)*(y10 + y5)*(y10 + y8), y5*(y8*(y0 + y8)*(y10 + y5)*(y10 + y8) + y8) + y8*(y0 + y8)*(y10 + y5) + y8*(y10 + y5) + sin(y3*y5**2*(y8*(y0 + y8)*(y10 + y5)*(y10 + y8) + y8) - y6)]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 12, fitness: 73.24398040771484, equation: [y3*y5*y8*sin(sin(y5)), y8*sin(sin(y5)) + sin(y3*y5*y8*sin(sin(y5)) - y6)]
# Complexity: 20, fitness: 73.16818237304688, equation: [y10*y5**2*(y3*y5*y8*(y10 + y5) - y6) + y3*y5*y8*(y10 + y5), y5*(y3*y5*y8*(y10 + y5) - y6) + y8*(y10 + y5) + sin(y10*y5**2*(y3*y5*y8*(y10 + y5) - y6) - y6)]
# Complexity: 21, fitness: 68.17881774902344, equation: [y9*(y0 + y3)*(y10 + y8), y4*(y10*(y3 + y5*y8) - y6 + y9*(y0 + y3)*(y10 + y8)) + y5*y8 - y6 + y9*(y0 + y3)*(y10 + y8) + (y0 + y3)*(y10 + y8)]
# Complexity: 22, fitness: 67.47990417480469, equation: [y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + y5*y8*(y0 + y8)*(y10 + y8), y5*y8*(y0 + y8) + y5*y8 + y5*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)]
# Complexity: 24, fitness: 66.07141876220703, equation: [y3*y5**2*(y8*(y0 + y5)*(y10 + y5)*(y10 + y8) + y8) + y8*(y0 + y5)*(y10 + y5)*(y10 + y8), y5*(y8*(y0 + y5)*(y10 + y5)*(y10 + y8) + y8) + y8*(y0 + y5)*(y10 + y5) + y8*(y10 + y5) + sin(y3*y5**2*(y8*(y0 + y5)*(y10 + y5)*(y10 + y8) + y8) - y6)]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 12, fitness: 73.24398040771484, equation: [y3*y5*y8*sin(sin(y5)), y8*sin(sin(y5)) + sin(y3*y5*y8*sin(sin(y5)) - y6)]
# Complexity: 20, fitness: 73.16818237304688, equation: [y10*y5**2*(y3*y5*y8*(y10 + y5) - y6) + y3*y5*y8*(y10 + y5), y5*(y3*y5*y8*(y10 + y5) - y6) + y8*(y10 + y5) + sin(y10*y5**2*(y3*y5*y8*(y10 + y5) - y6) - y6)]
# Complexity: 21, fitness: 68.17881774902344, equation: [y9*(y0 + y3)*(y10 + y8), y4*(y10*(y3 + y5*y8) - y6 + y9*(y0 + y3)*(y10 + y8)) + y5*y8 - y6 + y9*(y0 + y3)*(y10 + y8) + (y0 + y3)*(y10 + y8)]
# Complexity: 22, fitness: 67.47990417480469, equation: [y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + y5*y8*(y0 + y8)*(y10 + y8), y5*y8*(y0 + y8) + y5*y8 + y5*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)]
# Complexity: 24, fitness: 66.07141876220703, equation: [y3*y5**2*(y8*(y0 + y5)*(y10 + y5)*(y10 + y8) + y8) + y8*(y0 + y5)*(y10 + y5)*(y10 + y8), y5*(y8*(y0 + y5)*(y10 + y5)*(y10 + y8) + y8) + y8*(y0 + y5)*(y10 + y5) + y8*(y10 + y5) + sin(y3*y5**2*(y8*(y0 + y5)*(y10 + y5)*(y10 + y8) + y8) - y6)]
# Complexity: 30, fitness: 55.382755279541016, equation: [y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + y5*y8*(y0 + y8)*(y10 + y8), y5*y8*(y0 + y8) + y5*y8 + y5*(y3*(y10 + y9) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)) + y5*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 12, fitness: 73.24398040771484, equation: [y3*y5*y8*sin(sin(y5)), y8*sin(sin(y5)) + sin(y3*y5*y8*sin(sin(y5)) - y6)]
# Complexity: 19, fitness: 67.53359985351562, equation: [y7*y9*(y10 + y8), y4*(y10*(y3 + y5*y8) - y6 + y7*y9*(y10 + y8)) + y5*y8 - y6 + y7*y9*(y10 + y8) + y7*(y10 + y8)]
# Complexity: 22, fitness: 65.6898193359375, equation: [y9*(y10 + y8)*(y3 + y5), y5*y8 - y6 + y9*(y10 + y8)*(y3 + y5) + (y10 + y8)*(y3 + y5) + (y10*(y3 + y5*y8) - y6 + y9*(y10 + y8)*(y3 + y5))*cos(y10)]
# Complexity: 30, fitness: 55.382755279541016, equation: [y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + y5*y8*(y0 + y8)*(y10 + y8), y5*y8*(y0 + y8) + y5*y8 + y5*(y3*(y10 + y9) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)) + y5*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 12, fitness: 73.24398040771484, equation: [y3*y5*y8*sin(sin(y5)), y8*sin(sin(y5)) + sin(y3*y5*y8*sin(sin(y5)) - y6)]
# Complexity: 17, fitness: 65.07942199707031, equation: [y7*y9*(y10 + y8), y4*(y3*y5*y8 - y6 + y7*y9*(y10 + y8)) + y5*y8 - y6 + y7*y9*(y10 + y8) + y7*(y10 + y8)]
# Complexity: 28, fitness: 59.43510437011719, equation: [y9**2*(y10 + y8)*(y0 + y3 + y8*sin(y5)) + y9*(y10 + y8)*(y0 + y3 + y8*sin(y5)), y4*(y10*y3*y5*y8 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y8*sin(y5))) + y5*y8 - y6 + y8*sin(y5) + y9**2*(y10 + y8)*(y0 + y3 + y8*sin(y5)) + (y10 + y8)*(y0 + y3 + y8*sin(y5))]
# Complexity: 30, fitness: 55.382755279541016, equation: [y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + y5*y8*(y0 + y8)*(y10 + y8), y5*y8*(y0 + y8) + y5*y8 + y5*(y3*(y10 + y9) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)) + y5*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 12, fitness: 73.24398040771484, equation: [y3*y5*y8*sin(sin(y5)), y8*sin(sin(y5)) + sin(y3*y5*y8*sin(sin(y5)) - y6)]
# Complexity: 17, fitness: 65.07942199707031, equation: [y7*y9*(y10 + y8), y4*(y3*y5*y8 - y6 + y7*y9*(y10 + y8)) + y5*y8 - y6 + y7*y9*(y10 + y8) + y7*(y10 + y8)]
# Complexity: 26, fitness: 60.36079406738281, equation: [y9**2*(y10 + y8)*(y0 + y3 + sin(y5)) + y9*(y10 + y8)*(y0 + y3 + sin(y5)), y4*(y10*y3*y5*y8 - y6 + y9**2*(y10 + y8)*(y0 + y3 + sin(y5))) + y5*y8 - y6 + y9**2*(y10 + y8)*(y0 + y3 + sin(y5)) + (y10 + y8)*(y0 + y3 + sin(y5))]
# Complexity: 28, fitness: 59.43510437011719, equation: [y9**2*(y10 + y8)*(y0 + y3 + y8*sin(y5)) + y9*(y10 + y8)*(y0 + y3 + y8*sin(y5)), y4*(y10*y3*y5*y8 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y8*sin(y5))) + y5*y8 - y6 + y8*sin(y5) + y9**2*(y10 + y8)*(y0 + y3 + y8*sin(y5)) + (y10 + y8)*(y0 + y3 + y8*sin(y5))]
# Complexity: 30, fitness: 55.382755279541016, equation: [y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + y5*y8*(y0 + y8)*(y10 + y8), y5*y8*(y0 + y8) + y5*y8 + y5*(y3*(y10 + y9) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)) + y5*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 12, fitness: 73.24398040771484, equation: [y3*y5*y8*sin(sin(y5)), y8*sin(sin(y5)) + sin(y3*y5*y8*sin(sin(y5)) - y6)]
# Complexity: 17, fitness: 65.07942199707031, equation: [y7*y9*(y10 + y8), y4*(y3*y5*y8 - y6 + y7*y9*(y10 + y8)) + y5*y8 - y6 + y7*y9*(y10 + y8) + y7*(y10 + y8)]
# Complexity: 26, fitness: 60.36079406738281, equation: [y9**2*(y10 + y8)*(y0 + y3 + sin(y5)) + y9*(y10 + y8)*(y0 + y3 + sin(y5)), y4*(y10*y3*y5*y8 - y6 + y9**2*(y10 + y8)*(y0 + y3 + sin(y5))) + y5*y8 - y6 + y9**2*(y10 + y8)*(y0 + y3 + sin(y5)) + (y10 + y8)*(y0 + y3 + sin(y5))]
# Complexity: 27, fitness: 59.363037109375, equation: [y9**2*(y10 + y8)*(y0 + y3 + y5 + y6) + y9*(y10 + y8)*(y0 + y3 + y5 + y6), y4*(y10*y3*y5*y8 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y5 + y6)) + y5*y8 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y5 + y6) + (y10 + y8)*(y0 + y3 + y5 + y6)]
# Complexity: 30, fitness: 55.382755279541016, equation: [y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + y5*y8*(y0 + y8)*(y10 + y8), y5*y8*(y0 + y8) + y5*y8 + y5*(y3*(y10 + y9) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)) + y5*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 12, fitness: 73.24398040771484, equation: [y3*y5*y8*sin(sin(y5)), y8*sin(sin(y5)) + sin(y3*y5*y8*sin(sin(y5)) - y6)]
# Complexity: 17, fitness: 65.07942199707031, equation: [y7*y9*(y10 + y8), y4*(y3*y5*y8 - y6 + y7*y9*(y10 + y8)) + y5*y8 - y6 + y7*y9*(y10 + y8) + y7*(y10 + y8)]
# Complexity: 23, fitness: 64.54312896728516, equation: [y9**2*(y0 + y3)*(y10 + y8) + y9*(y0 + y3)*(y10 + y8), y4*(y10*y3*y5*y8 - y6 + y9**2*(y0 + y3)*(y10 + y8)) + y5*y8 - y6 + y9**2*(y0 + y3)*(y10 + y8) + (y0 + y3)*(y10 + y8)]
# Complexity: 25, fitness: 57.902034759521484, equation: [y9**2*(y10 + y8)*(y0 + y3 + y6) + y9*(y10 + y8)*(y0 + y3 + y6), y4*(y10*(y3 + y5*y8) - y6 + y9**2*(y10 + y8)*(y0 + y3 + y6)) + y5*y8 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y6) + (y10 + y8)*(y0 + y3 + y6)]
# Complexity: 30, fitness: 55.382755279541016, equation: [y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + y5*y8*(y0 + y8)*(y10 + y8), y5*y8*(y0 + y8) + y5*y8 + y5*(y3*(y10 + y9) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)) + y5*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 12, fitness: 73.24398040771484, equation: [y3*y5*y8*sin(sin(y5)), y8*sin(sin(y5)) + sin(y3*y5*y8*sin(sin(y5)) - y6)]
# Complexity: 15, fitness: 71.15267944335938, equation: [y8*y9*(y3 + y5), y4*(-y6 + y8*y9*(y3 + y5))*cos(cos(y7)) - y6 + y8*y9*(y3 + y5) + y8*(y3 + y5)]
# Complexity: 17, fitness: 65.07942199707031, equation: [y7*y9*(y10 + y8), y4*(y3*y5*y8 - y6 + y7*y9*(y10 + y8)) + y5*y8 - y6 + y7*y9*(y10 + y8) + y7*(y10 + y8)]
# Complexity: 21, fitness: 64.16283416748047, equation: [y9**2*(y10 + y8)*(y0 + y3 + y5 + y6) + y9*(y10 + y8)*(y0 + y3 + y5 + y6), y4*y9**2*(y10 + y8)*(y0 + y3 + y5 + y6) - y6 + y9**2*(y10 + y8)*(y0 + y3 + y5 + y6) + (y10 + y8)*(y0 + y3 + y5 + y6)]
# Complexity: 23, fitness: 62.951438903808594, equation: [y9**2*(y10 + y8)*(y0 + y3 + y6) + y9*(y10 + y8)*(y0 + y3 + y6), y4*(y10*(y3 + y5) - y6 + y9**2*(y10 + y8)*(y0 + y3 + y6)) - y6 + y9**2*(y10 + y8)*(y0 + y3 + y6) + (y10 + y8)*(y0 + y3 + y6)]
# Complexity: 24, fitness: 62.39288330078125, equation: [y9**2*(y10 + y8)*(y0 + y3 + y8*sin(y5)) + y9*(y10 + y8)*(y0 + y3 + y8*sin(y5)), y10*y3*y4*(-y6 + y9**2*(y10 + y8)*(y0 + y3 + y8*sin(y5))) - y6 + y8*sin(y5) + y9**2*(y10 + y8)*(y0 + y3 + y8*sin(y5)) + (y10 + y8)*(y0 + y3 + y8*sin(y5))]
# Complexity: 25, fitness: 57.902034759521484, equation: [y9**2*(y10 + y8)*(y0 + y3 + y6) + y9*(y10 + y8)*(y0 + y3 + y6), y4*(y10*(y3 + y5*y8) - y6 + y9**2*(y10 + y8)*(y0 + y3 + y6)) + y5*y8 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y6) + (y10 + y8)*(y0 + y3 + y6)]
# Complexity: 28, fitness: 57.84349822998047, equation: [y9**2*(y10 + y8)*(y0 + y3 + y6 + y8*sin(y5)) + y9*(y10 + y8)*(y0 + y3 + y6 + y8*sin(y5)), y4*(y10*(y3 + y7) - y6 + y9**2*(y10 + y8)*(y0 + y3 + y6 + y8*sin(y5))) - y6 + y8*sin(y5) + y9**2*(y10 + y8)*(y0 + y3 + y6 + y8*sin(y5)) + (y10 + y8)*(y0 + y3 + y6 + y8*sin(y5))]
# Complexity: 30, fitness: 55.382755279541016, equation: [y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + y5*y8*(y0 + y8)*(y10 + y8), y5*y8*(y0 + y8) + y5*y8 + y5*(y3*(y10 + y9) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)) + y5*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 12, fitness: 73.24398040771484, equation: [y3*y5*y8*sin(sin(y5)), y8*sin(sin(y5)) + sin(y3*y5*y8*sin(sin(y5)) - y6)]
# Complexity: 15, fitness: 71.14636993408203, equation: [y8*y9*(y3 + y5), y10*y4*y6*(-y6 + y8*y9*(y3 + y5)) - y6 + y8*y9*(y3 + y5) + y8*(y3 + y5)]
# Complexity: 17, fitness: 65.07942199707031, equation: [y7*y9*(y10 + y8), y4*(y3*y5*y8 - y6 + y7*y9*(y10 + y8)) + y5*y8 - y6 + y7*y9*(y10 + y8) + y7*(y10 + y8)]
# Complexity: 21, fitness: 64.16283416748047, equation: [y9**2*(y10 + y8)*(y0 + y3 + y5 + y6) + y9*(y10 + y8)*(y0 + y3 + y5 + y6), y4*y9**2*(y10 + y8)*(y0 + y3 + y5 + y6) - y6 + y9**2*(y10 + y8)*(y0 + y3 + y5 + y6) + (y10 + y8)*(y0 + y3 + y5 + y6)]
# Complexity: 22, fitness: 62.975189208984375, equation: [y9**2*(y10 + y8)*(y0 + y3 + y6) + y9*(y10 + y8)*(y0 + y3 + y6), y4*(-y6 + y8*sin(y5) + y9**2*(y10 + y8)*(y0 + y3 + y6)) - y6 + y9**2*(y10 + y8)*(y0 + y3 + y6) + (y10 + y8)*(y0 + y3 + y6)]
# Complexity: 23, fitness: 59.23359680175781, equation: [y9**2*(y10 + y8)*(y0 + y3 + y4) + y9*(y10 + y8)*(y0 + y3 + y4), y4*(y10*y3*y4 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4)) - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4) + (y10 + y8)*(y0 + y3 + y4)]
# Complexity: 25, fitness: 55.66487121582031, equation: [y9**2*(y10 + y8)*(y0 + y3 + y4) + y9*(y10 + y8)*(y0 + y3 + y4), y10*(-0.14*y10*y3*y8 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4)) - y6 - 0.14*y8 + y9**2*(y10 + y8)*(y0 + y3 + y4) + (y10 + y8)*(y0 + y3 + y4)]
# Complexity: 30, fitness: 55.382755279541016, equation: [y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + y5*y8*(y0 + y8)*(y10 + y8), y5*y8*(y0 + y8) + y5*y8 + y5*(y3*(y10 + y9) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)) + y5*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 12, fitness: 73.24398040771484, equation: [y3*y5*y8*sin(sin(y5)), y8*sin(sin(y5)) + sin(y3*y5*y8*sin(sin(y5)) - y6)]
# Complexity: 15, fitness: 71.14636993408203, equation: [y8*y9*(y3 + y5), y10*y4*y6*(-y6 + y8*y9*(y3 + y5)) - y6 + y8*y9*(y3 + y5) + y8*(y3 + y5)]
# Complexity: 17, fitness: 65.07942199707031, equation: [y7*y9*(y10 + y8), y4*(y3*y5*y8 - y6 + y7*y9*(y10 + y8)) + y5*y8 - y6 + y7*y9*(y10 + y8) + y7*(y10 + y8)]
# Complexity: 21, fitness: 64.16283416748047, equation: [y9**2*(y10 + y8)*(y0 + y3 + y5 + y6) + y9*(y10 + y8)*(y0 + y3 + y5 + y6), y4*y9**2*(y10 + y8)*(y0 + y3 + y5 + y6) - y6 + y9**2*(y10 + y8)*(y0 + y3 + y5 + y6) + (y10 + y8)*(y0 + y3 + y5 + y6)]
# Complexity: 22, fitness: 62.975189208984375, equation: [y9**2*(y10 + y8)*(y0 + y3 + y6) + y9*(y10 + y8)*(y0 + y3 + y6), y4*(-y6 + y8*sin(y5) + y9**2*(y10 + y8)*(y0 + y3 + y6)) - y6 + y9**2*(y10 + y8)*(y0 + y3 + y6) + (y10 + y8)*(y0 + y3 + y6)]
# Complexity: 23, fitness: 59.23359680175781, equation: [y9**2*(y10 + y8)*(y0 + y3 + y4) + y9*(y10 + y8)*(y0 + y3 + y4), y4*(y10*y3*y4 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4)) - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4) + (y10 + y8)*(y0 + y3 + y4)]
# Complexity: 25, fitness: 55.66487121582031, equation: [y9**2*(y10 + y8)*(y0 + y3 + y4) + y9*(y10 + y8)*(y0 + y3 + y4), y10*(-0.14*y10*y3*y8 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4)) - y6 - 0.14*y8 + y9**2*(y10 + y8)*(y0 + y3 + y4) + (y10 + y8)*(y0 + y3 + y4)]
# Complexity: 30, fitness: 55.382755279541016, equation: [y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + y5*y8*(y0 + y8)*(y10 + y8), y5*y8*(y0 + y8) + y5*y8 + y5*(y3*(y10 + y9) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)) + y5*(y5*y8*(y0 + y8)*(y10 + y8) + y8) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y10 + y8) + y8) - y6)]
# Complexity: 31, fitness: 54.98284912109375, equation: [y3*y5**2*(y8*(y0 + y8)*(y10 + y8)*sin(y5) + y8) + y8*(y0 + y8)*(y10 + y8)*sin(y5), y5*(y3*(y10 + y9) + sin(y3*y5**2*(y8*(y0 + y8)*(y10 + y8)*sin(y5) + y8) - y6)) + y5*(y8*(y0 + y8)*(y10 + y8)*sin(y5) + y8) + y8*(y0 + y8)*sin(y5) + y8*sin(y5) + sin(y3*y5**2*(y8*(y0 + y8)*(y10 + y8)*sin(y5) + y8) - y6)]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 12, fitness: 73.24398040771484, equation: [y3*y5*y8*sin(sin(y5)), y8*sin(sin(y5)) + sin(y3*y5*y8*sin(sin(y5)) - y6)]
# Complexity: 13, fitness: 68.2580795288086, equation: [y8*y9*(y5 + y7), y2*y4*(-y6 + y8*y9*(y5 + y7)) - y6 + y8*y9*(y5 + y7) + y8*(y5 + y7)]
# Complexity: 17, fitness: 65.07942199707031, equation: [y7*y9*(y10 + y8), y4*(y3*y5*y8 - y6 + y7*y9*(y10 + y8)) + y5*y8 - y6 + y7*y9*(y10 + y8) + y7*(y10 + y8)]
# Complexity: 20, fitness: 61.61962127685547, equation: [2*y3*y5**2*y8, 2*y5*y8 + y5*(y3*(y10 + y9) + sin(2*y3*y5**2*y8 - y6)) + sin(2*y3*y5**2*y8 - y6)]
# Complexity: 23, fitness: 59.23359680175781, equation: [y9**2*(y10 + y8)*(y0 + y3 + y4) + y9*(y10 + y8)*(y0 + y3 + y4), y4*(y10*y3*y4 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4)) - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4) + (y10 + y8)*(y0 + y3 + y4)]
# Complexity: 25, fitness: 55.66487121582031, equation: [y9**2*(y10 + y8)*(y0 + y3 + y4) + y9*(y10 + y8)*(y0 + y3 + y4), y10*(-0.14*y10*y3*y8 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4)) - y6 - 0.14*y8 + y9**2*(y10 + y8)*(y0 + y3 + y4) + (y10 + y8)*(y0 + y3 + y4)]
# Complexity: 29, fitness: 54.78150939941406, equation: [y9**2*(y10 + y8)*(y0 + y3 + y4) + y9*(y10 + y8)*(y0 + y3 + y4), y4*(y3 - 0.108*y8)*(y10*y3*y4 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4)) - y6 - 0.108*y8 + y9**2*(y10 + y8)*(y0 + y3 + y4) + (y10 + y8)*(y0 + y3 + y4)]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 12, fitness: 73.24398040771484, equation: [y3*y5*y8*sin(sin(y5)), y8*sin(sin(y5)) + sin(y3*y5*y8*sin(sin(y5)) - y6)]
# Complexity: 13, fitness: 68.2580795288086, equation: [y8*y9*(y5 + y7), y2*y4*(-y6 + y8*y9*(y5 + y7)) - y6 + y8*y9*(y5 + y7) + y8*(y5 + y7)]
# Complexity: 17, fitness: 65.07942199707031, equation: [y7*y9*(y10 + y8), y4*(y3*y5*y8 - y6 + y7*y9*(y10 + y8)) + y5*y8 - y6 + y7*y9*(y10 + y8) + y7*(y10 + y8)]
# Complexity: 20, fitness: 61.61962127685547, equation: [2*y3*y5**2*y8, 2*y5*y8 + y5*(y3*(y10 + y9) + sin(2*y3*y5**2*y8 - y6)) + sin(2*y3*y5**2*y8 - y6)]
# Complexity: 23, fitness: 59.23359680175781, equation: [y9**2*(y10 + y8)*(y0 + y3 + y4) + y9*(y10 + y8)*(y0 + y3 + y4), y4*(y10*y3*y4 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4)) - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4) + (y10 + y8)*(y0 + y3 + y4)]
# Complexity: 25, fitness: 55.66487121582031, equation: [y9**2*(y10 + y8)*(y0 + y3 + y4) + y9*(y10 + y8)*(y0 + y3 + y4), y10*(-0.14*y10*y3*y8 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4)) - y6 - 0.14*y8 + y9**2*(y10 + y8)*(y0 + y3 + y4) + (y10 + y8)*(y0 + y3 + y4)]
# Complexity: 29, fitness: 54.78150939941406, equation: [y9**2*(y10 + y8)*(y0 + y3 + y4) + y9*(y10 + y8)*(y0 + y3 + y4), y4*(y3 - 0.108*y8)*(y10*y3*y4 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4)) - y6 - 0.108*y8 + y9**2*(y10 + y8)*(y0 + y3 + y4) + (y10 + y8)*(y0 + y3 + y4)]
# Complexity: 30, fitness: 53.90058517456055, equation: [y3*y5**2*(y5*y8*(y0 + y8)*(y8 + y9) + y8) + y5*y8*(y0 + y8)*(y8 + y9), y5*y8*(y0 + y8) + y5*y8 + y5*(y3*(y10 + y9) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y8 + y9) + y8) - y6)) + y5*(y5*y8*(y0 + y8)*(y8 + y9) + y8) + sin(y3*y5**2*(y5*y8*(y0 + y8)*(y8 + y9) + y8) - y6)]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 12, fitness: 73.24398040771484, equation: [y3*y5*y8*sin(sin(y5)), y8*sin(sin(y5)) + sin(y3*y5*y8*sin(sin(y5)) - y6)]
# Complexity: 13, fitness: 68.2580795288086, equation: [y8*y9*(y5 + y7), y2*y4*(-y6 + y8*y9*(y5 + y7)) - y6 + y8*y9*(y5 + y7) + y8*(y5 + y7)]
# Complexity: 17, fitness: 65.07942199707031, equation: [y7*y9*(y10 + y8), y4*(y3*y5*y8 - y6 + y7*y9*(y10 + y8)) + y5*y8 - y6 + y7*y9*(y10 + y8) + y7*(y10 + y8)]
# Complexity: 20, fitness: 61.61962127685547, equation: [2*y3*y5**2*y8, 2*y5*y8 + y5*(y3*(y10 + y9) + sin(2*y3*y5**2*y8 - y6)) + sin(2*y3*y5**2*y8 - y6)]
# Complexity: 23, fitness: 59.23359680175781, equation: [y9**2*(y10 + y8)*(y0 + y3 + y4) + y9*(y10 + y8)*(y0 + y3 + y4), y4*(y10*y3*y4 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4)) - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4) + (y10 + y8)*(y0 + y3 + y4)]
# Complexity: 24, fitness: 58.29265594482422, equation: [y9**2*(y10 + y8)*(y0 + y3 + y6 + y8*sin(y5)) + y9*(y10 + y8)*(y0 + y3 + y6 + y8*sin(y5)), y4*y9**2*(y10 + y8)*(y0 + y3 + y6 + y8*sin(y5)) - y6 + y8*sin(y5) + y9**2*(y10 + y8)*(y0 + y3 + y6 + y8*sin(y5)) + (y10 + y8)*(y0 + y3 + y6 + y8*sin(y5))]
# Complexity: 25, fitness: 55.66487121582031, equation: [y9**2*(y10 + y8)*(y0 + y3 + y4) + y9*(y10 + y8)*(y0 + y3 + y4), y10*(-0.14*y10*y3*y8 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4)) - y6 - 0.14*y8 + y9**2*(y10 + y8)*(y0 + y3 + y4) + (y10 + y8)*(y0 + y3 + y4)]
# Complexity: 28, fitness: 53.33940887451172, equation: [y3*y5**2*(y8*(y10 + y5)*(y8 + y9) + y8) + y8*(y10 + y5)*(y8 + y9), y5*(y3*(y10 + y9) + sin(y3*y5**2*(y8*(y10 + y5)*(y8 + y9) + y8) - y6)) + y5*(y8*(y10 + y5)*(y8 + y9) + y8) + y8*(y10 + y5) + sin(y3*y5**2*(y8*(y10 + y5)*(y8 + y9) + y8) - y6)]
# Final pareto front:
# Complexity: 1, fitness: 112.77143859863281, equation: [0, y8]
# Complexity: 2, fitness: 112.74197387695312, equation: [0, sin(y8)]
# Complexity: 3, fitness: 80.22518920898438, equation: [0, y5*y8]
# Complexity: 5, fitness: 77.93533325195312, equation: [0, 2*y5*y8]
# Complexity: 6, fitness: 77.86361694335938, equation: [0, y8*(y5 + sin(y5))]
# Complexity: 7, fitness: 76.90232849121094, equation: [0, 3*y5*y8]
# Complexity: 9, fitness: 76.02590942382812, equation: [0, y8*(y3 + 3*y5)]
# Complexity: 12, fitness: 73.24398040771484, equation: [y3*y5*y8*sin(sin(y5)), y8*sin(sin(y5)) + sin(y3*y5*y8*sin(sin(y5)) - y6)]
# Complexity: 13, fitness: 68.2580795288086, equation: [y8*y9*(y5 + y7), y2*y4*(-y6 + y8*y9*(y5 + y7)) - y6 + y8*y9*(y5 + y7) + y8*(y5 + y7)]
# Complexity: 17, fitness: 65.07942199707031, equation: [y7*y9*(y10 + y8), y4*(y3*y5*y8 - y6 + y7*y9*(y10 + y8)) + y5*y8 - y6 + y7*y9*(y10 + y8) + y7*(y10 + y8)]
# Complexity: 20, fitness: 61.61962127685547, equation: [2*y3*y5**2*y8, 2*y5*y8 + y5*(y3*(y10 + y9) + sin(2*y3*y5**2*y8 - y6)) + sin(2*y3*y5**2*y8 - y6)]
# Complexity: 23, fitness: 59.23359680175781, equation: [y9**2*(y10 + y8)*(y0 + y3 + y4) + y9*(y10 + y8)*(y0 + y3 + y4), y4*(y10*y3*y4 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4)) - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4) + (y10 + y8)*(y0 + y3 + y4)]
# Complexity: 24, fitness: 58.29265594482422, equation: [y9**2*(y10 + y8)*(y0 + y3 + y6 + y8*sin(y5)) + y9*(y10 + y8)*(y0 + y3 + y6 + y8*sin(y5)), y4*y9**2*(y10 + y8)*(y0 + y3 + y6 + y8*sin(y5)) - y6 + y8*sin(y5) + y9**2*(y10 + y8)*(y0 + y3 + y6 + y8*sin(y5)) + (y10 + y8)*(y0 + y3 + y6 + y8*sin(y5))]
# Complexity: 25, fitness: 55.66487121582031, equation: [y9**2*(y10 + y8)*(y0 + y3 + y4) + y9*(y10 + y8)*(y0 + y3 + y4), y10*(-0.14*y10*y3*y8 - y6 + y9**2*(y10 + y8)*(y0 + y3 + y4)) - y6 - 0.14*y8 + y9**2*(y10 + y8)*(y0 + y3 + y4) + (y10 + y8)*(y0 + y3 + y4)]
# Complexity: 28, fitness: 53.33940887451172, equation: [y3*y5**2*(y8*(y10 + y5)*(y8 + y9) + y8) + y8*(y10 + y5)*(y8 + y9), y5*(y3*(y10 + y9) + sin(y3*y5**2*(y8*(y10 + y5)*(y8 + y9) + y8) - y6)) + y5*(y8*(y10 + y5)*(y8 + y9) + y8) + y8*(y10 + y5) + sin(y3*y5**2*(y8*(y10 + y5)*(y8 + y9) + y8) - y6)]

# %%
brax_env = BraxGymnaxWrapper('swimmer', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=2, max_nodes=31)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated)
# Compiling code for evaluation and evolution...
# Finished compilation in 168.49 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: 7.452517032623291, equation: [0.839, 0]
# Complexity: 2, fitness: -11.4246187210083, equation: [0, sin(y6)]
# Complexity: 3, fitness: -23.89447021484375, equation: [0, y6 + y7]
# Complexity: 5, fitness: -32.4927978515625, equation: [0, y0 + y1 + y5]
# Complexity: 7, fitness: -109.45574951171875, equation: [y0 + y6, y1*y6*(y0 + y6)]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -12.50468635559082, equation: [y7, 0]
# Complexity: 3, fitness: -23.89447021484375, equation: [0, y6 + y7]
# Complexity: 5, fitness: -89.42616271972656, equation: [sin(2*y6), sin(sin(2*y6))]
# Complexity: 7, fitness: -109.45574951171875, equation: [y0 + y6, y1*y6*(y0 + y6)]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -12.504688262939453, equation: [y7, 0]
# Complexity: 3, fitness: -23.89447021484375, equation: [0, y6 + y7]
# Complexity: 4, fitness: -24.791994094848633, equation: [y2 + y7, sin(y2 + y7)]
# Complexity: 5, fitness: -125.77400970458984, equation: [sin(y4 + y6), sin(sin(y4 + y6))]
# Complexity: 11, fitness: -193.75169372558594, equation: [y0 - y3 + y5 + y7 + (y6 + 0.432)*(y0 - y3 + y5 + y7), y6 + 0.432]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -25.654922485351562, equation: [sin(y4), sin(sin(y4))]
# Complexity: 4, fitness: -27.52064323425293, equation: [sin(y4), sin(sin(sin(y4)))]
# Complexity: 5, fitness: -125.77400970458984, equation: [sin(y4 + y6), sin(sin(y4 + y6))]
# Complexity: 6, fitness: -235.24655151367188, equation: [y4 + y6 + sin(y0), y4 + y6]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 6, fitness: -235.3868408203125, equation: [y4 + y6 + sin(y0), y4 + y6]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -228.42230224609375, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -239.44235229492188, equation: [y4 + y6 + sin(y0), y4 + y6]
# Complexity: 9, fitness: -255.6162109375, equation: [y0 + y6, y0 + y2 + 2*y6 + y7]
# Complexity: 13, fitness: -330.5955810546875, equation: [2*y0 + y4, y0*y1*(2*y0 + y4) + y2 + y6]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -228.42230224609375, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -239.44235229492188, equation: [y4 + y6 + sin(y0), y4 + y6]
# Complexity: 9, fitness: -255.6162109375, equation: [y0 + y6, y0 + y2 + 2*y6 + y7]
# Complexity: 11, fitness: -284.4933166503906, equation: [y0 + y4 + y6, y0 + y2 + y4 + 2*y6 + y7]
# Complexity: 13, fitness: -330.5955810546875, equation: [2*y0 + y4, y0*y1*(2*y0 + y4) + y2 + y6]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -228.42230224609375, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -239.44235229492188, equation: [y4 + y6 + sin(y0), y4 + y6]
# Complexity: 9, fitness: -288.4349365234375, equation: [y0 + y4 + y6, y0 + y4 + 2*y6 + y7]
# Complexity: 13, fitness: -330.5955810546875, equation: [2*y0 + y4, y0*y1*(2*y0 + y4) + y2 + y6]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -228.42230224609375, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -239.44235229492188, equation: [y4 + y6 + sin(y0), y4 + y6]
# Complexity: 7, fitness: -261.70684814453125, equation: [y1 + y5 + y6, 2*y1 + y5 + y6]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 13, fitness: -330.5955810546875, equation: [2*y0 + y4, y0*y1*(2*y0 + y4) + y2 + y6]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -228.42230224609375, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -252.21360778808594, equation: [2*y0 + y7, sin(2*y0 + y7)]
# Complexity: 7, fitness: -261.70697021484375, equation: [y1 + y5 + y6, 2*y1 + y5 + y6]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 13, fitness: -330.5955810546875, equation: [2*y0 + y4, y0*y1*(2*y0 + y4) + y2 + y6]
# Complexity: 14, fitness: -346.0029296875, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y2 + y6]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -228.42230224609375, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -252.21360778808594, equation: [2*y0 + y7, sin(2*y0 + y7)]
# Complexity: 7, fitness: -279.0177917480469, equation: [y0 + y4 + y6, y0 + y4 + y6 + y7]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 13, fitness: -330.59564208984375, equation: [2*y0 + y4, y0*y1*(2*y0 + y4) + y2 + y6]
# Complexity: 14, fitness: -346.0030822753906, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y2 + y6]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -228.42230224609375, equation: [y0 + y4 + y6, y4 + y6]
# Complexity: 6, fitness: -252.21360778808594, equation: [2*y0 + y7, sin(2*y0 + y7)]
# Complexity: 7, fitness: -279.0177917480469, equation: [y0 + y4 + y6, y0 + y4 + y6 + y7]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 13, fitness: -330.59564208984375, equation: [2*y0 + y4, y0*y1*(2*y0 + y4) + y2 + y6]
# Complexity: 14, fitness: -346.0030822753906, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y2 + y6]
# Complexity: 21, fitness: -355.3551025390625, equation: [2*y0 + y4, y0*(y1 - 0.237*y2)*(2*y0 + y1 - 0.237*y2 + y4 + y6) + 2*y0 + 3*y1 - 0.712*y2 + y4 + y6]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -271.05316162109375, equation: [y0 + y6, y0 + y6 + y7]
# Complexity: 7, fitness: -279.0177917480469, equation: [y0 + y4 + y6, y0 + y4 + y6 + y7]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 13, fitness: -330.59564208984375, equation: [2*y0 + y4, y0*y1*(2*y0 + y4) + y2 + y6]
# Complexity: 14, fitness: -352.0947265625, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y4 + y6]
# Complexity: 21, fitness: -355.3551025390625, equation: [2*y0 + y4, y0*(y1 - 0.237*y2)*(2*y0 + y1 - 0.237*y2 + y4 + y6) + 2*y0 + 3*y1 - 0.712*y2 + y4 + y6]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -271.05316162109375, equation: [y0 + y6, y0 + y6 + y7]
# Complexity: 7, fitness: -279.0177917480469, equation: [y0 + y4 + y6, y0 + y4 + y6 + y7]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 13, fitness: -330.59564208984375, equation: [2*y0 + y4, y0*y1*(2*y0 + y4) + y2 + y6]
# Complexity: 14, fitness: -352.0947265625, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y4 + y6]
# Complexity: 16, fitness: -355.38665771484375, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y2 + y4 + y6]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -271.05316162109375, equation: [y0 + y6, y0 + y6 + y7]
# Complexity: 7, fitness: -279.0177917480469, equation: [y0 + y4 + y6, y0 + y4 + y6 + y7]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 12, fitness: -333.91473388671875, equation: [y0 + y4*cos(y3) + y4, y0 + y4*cos(y3) + y4 + y6 + y7]
# Complexity: 14, fitness: -352.0947265625, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y4 + y6]
# Complexity: 16, fitness: -355.4464111328125, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y2 + y4 + y6]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -271.05316162109375, equation: [y0 + y6, y0 + y6 + y7]
# Complexity: 7, fitness: -279.0177917480469, equation: [y0 + y4 + y6, y0 + y4 + y6 + y7]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 12, fitness: -333.91473388671875, equation: [y0 + y4*cos(y3) + y4, y0 + y4*cos(y3) + y4 + y6 + y7]
# Complexity: 13, fitness: -336.14593505859375, equation: [7*y0 + 2*y4 + 2*y6, 4*y0 + y4 + y6 + y7]
# Complexity: 14, fitness: -352.0947265625, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y4 + y6]
# Complexity: 16, fitness: -355.4464111328125, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y2 + y4 + y6]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -271.05316162109375, equation: [y0 + y6, y0 + y6 + y7]
# Complexity: 7, fitness: -279.0177917480469, equation: [y0 + y4 + y6, y0 + y4 + y6 + y7]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 12, fitness: -333.91473388671875, equation: [y0 + y4*cos(y3) + y4, y0 + y4*cos(y3) + y4 + y6 + y7]
# Complexity: 13, fitness: -336.14593505859375, equation: [7*y0 + 2*y4 + 2*y6, 4*y0 + y4 + y6 + y7]
# Complexity: 14, fitness: -352.0947265625, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y4 + y6]
# Complexity: 16, fitness: -355.4464111328125, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y2 + y4 + y6]
# Complexity: 26, fitness: -360.607421875, equation: [2*y0 + 0.362*y3*y7 + y4 + y6 + (2*y0 + sin(y6)*cos(y1 - y5))*cos(-y1 + 0.0782*y3*y7 + 0.432*y4 + 0.432*y6) + sin(y6)*cos(y1 - y5), 2*y1 - 0.0782*y3*y7 + 0.568*y4 - y5 + 0.568*y6 + cos(y1 - y5) + cos(-y1 + 0.0782*y3*y7 + 0.432*y4 + 0.432*y6)]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -271.05316162109375, equation: [y0 + y6, y0 + y6 + y7]
# Complexity: 7, fitness: -279.0177917480469, equation: [y0 + y4 + y6, y0 + y4 + y6 + y7]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 12, fitness: -333.91473388671875, equation: [y0 + y4*cos(y3) + y4, y0 + y4*cos(y3) + y4 + y6 + y7]
# Complexity: 13, fitness: -351.2760009765625, equation: [2*y0 + y4 + 0.241, 2*y0 + 2*y1 - 0.475*y2 + y4 + 0.241]
# Complexity: 14, fitness: -352.0947265625, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y4 + y6]
# Complexity: 16, fitness: -355.4464111328125, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y2 + y4 + y6]
# Complexity: 26, fitness: -360.607421875, equation: [2*y0 + 0.362*y3*y7 + y4 + y6 + (2*y0 + sin(y6)*cos(y1 - y5))*cos(-y1 + 0.0782*y3*y7 + 0.432*y4 + 0.432*y6) + sin(y6)*cos(y1 - y5), 2*y1 - 0.0782*y3*y7 + 0.568*y4 - y5 + 0.568*y6 + cos(y1 - y5) + cos(-y1 + 0.0782*y3*y7 + 0.432*y4 + 0.432*y6)]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -271.05316162109375, equation: [y0 + y6, y0 + y6 + y7]
# Complexity: 7, fitness: -279.0177917480469, equation: [y0 + y4 + y6, y0 + y4 + y6 + y7]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 12, fitness: -338.8489685058594, equation: [2*y0 + y4 + 0.241, 2*y0 + 2*y1 + y4 - 2*sin(y0) + 0.241]
# Complexity: 13, fitness: -351.2760009765625, equation: [2*y0 + y4 + 0.241, 2*y0 + 2*y1 - 0.475*y2 + y4 + 0.241]
# Complexity: 14, fitness: -352.0947265625, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y4 + y6]
# Complexity: 16, fitness: -355.4464111328125, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y2 + y4 + y6]
# Complexity: 23, fitness: -356.855224609375, equation: [2*y0 + y4, y0*(y1 - 0.0563*y2)*(2*y0 + y1 - 0.237*y2 + y4 + y6) + 2*y0 + 3*y1 - 0.531*y2 + y4 + y6]
# Complexity: 26, fitness: -360.607421875, equation: [2*y0 + 0.362*y3*y7 + y4 + y6 + (2*y0 + sin(y6)*cos(y1 - y5))*cos(-y1 + 0.0782*y3*y7 + 0.432*y4 + 0.432*y6) + sin(y6)*cos(y1 - y5), 2*y1 - 0.0782*y3*y7 + 0.568*y4 - y5 + 0.568*y6 + cos(y1 - y5) + cos(-y1 + 0.0782*y3*y7 + 0.432*y4 + 0.432*y6)]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -271.05316162109375, equation: [y0 + y6, y0 + y6 + y7]
# Complexity: 7, fitness: -279.0177917480469, equation: [y0 + y4 + y6, y0 + y4 + y6 + y7]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 12, fitness: -338.8489685058594, equation: [2*y0 + y4 + 0.241, 2*y0 + 2*y1 + y4 - 2*sin(y0) + 0.241]
# Complexity: 13, fitness: -351.2760009765625, equation: [2*y0 + y4 + 0.241, 2*y0 + 2*y1 - 0.475*y2 + y4 + 0.241]
# Complexity: 14, fitness: -352.0947265625, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y4 + y6]
# Complexity: 16, fitness: -355.4464111328125, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y2 + y4 + y6]
# Complexity: 20, fitness: -355.94952392578125, equation: [2*y0 + y4, y0*(2*y1 - 2*y2 + y6 + cos(2*y0 + y4) - 0.237) + 3*y1 - 3*y2 + y6 + cos(2*y0 + y4) - 0.237]
# Complexity: 21, fitness: -359.28216552734375, equation: [2*y0 + y4, y0*(y1 - 0.237*y2)*(2*y0 + y1 + 0.763*y4 + y6) + 2*y0 + 3*y1 - 0.237*y2 + 0.526*y4 + y6]
# Complexity: 23, fitness: -359.419189453125, equation: [2*y0 + y4, y0*(y1 - y2 - 0.237)*(y1 + y6 - 0.237*cos(y2) + cos(2*y0 + y4)) + 3*y1 - y2 + y6 + 0.526*cos(y2) + cos(2*y0 + y4) - 0.237]
# Complexity: 26, fitness: -360.607421875, equation: [2*y0 + 0.362*y3*y7 + y4 + y6 + (2*y0 + sin(y6)*cos(y1 - y5))*cos(-y1 + 0.0782*y3*y7 + 0.432*y4 + 0.432*y6) + sin(y6)*cos(y1 - y5), 2*y1 - 0.0782*y3*y7 + 0.568*y4 - y5 + 0.568*y6 + cos(y1 - y5) + cos(-y1 + 0.0782*y3*y7 + 0.432*y4 + 0.432*y6)]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -271.05316162109375, equation: [y0 + y6, y0 + y6 + y7]
# Complexity: 7, fitness: -279.0177917480469, equation: [y0 + y4 + y6, y0 + y4 + y6 + y7]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 11, fitness: -354.587646484375, equation: [2*y0 + y4, 2*y0 + 2*y1 - 0.475*y2 + y4]
# Complexity: 16, fitness: -355.4464111328125, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y2 + y4 + y6]
# Complexity: 17, fitness: -356.976806640625, equation: [2*y0 + y4, y0*(y1 - 0.237*y2)*(3*y0 + y1 + y4) + 3*y0 + 2*y1 - 0.237*y2 + y4]
# Complexity: 21, fitness: -359.28216552734375, equation: [2*y0 + y4, y0*(y1 - 0.237*y2)*(2*y0 + y1 + 0.763*y4 + y6) + 2*y0 + 3*y1 - 0.237*y2 + 0.526*y4 + y6]
# Complexity: 22, fitness: -359.76678466796875, equation: [2*y0 + y4, y0*(y1 - 0.0563*y2)*(y1 - y2 + y6 + cos(2*y0 + y4)) + 3*y1 - 2.06*y2 + y6 + cos(2*y0 + y4)]
# Complexity: 26, fitness: -360.607421875, equation: [2*y0 + 0.362*y3*y7 + y4 + y6 + (2*y0 + sin(y6)*cos(y1 - y5))*cos(-y1 + 0.0782*y3*y7 + 0.432*y4 + 0.432*y6) + sin(y6)*cos(y1 - y5), 2*y1 - 0.0782*y3*y7 + 0.568*y4 - y5 + 0.568*y6 + cos(y1 - y5) + cos(-y1 + 0.0782*y3*y7 + 0.432*y4 + 0.432*y6)]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -271.05316162109375, equation: [y0 + y6, y0 + y6 + y7]
# Complexity: 7, fitness: -279.0177917480469, equation: [y0 + y4 + y6, y0 + y4 + y6 + y7]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 11, fitness: -354.587646484375, equation: [2*y0 + y4, 2*y0 + 2*y1 - 0.475*y2 + y4]
# Complexity: 16, fitness: -355.4464111328125, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y2 + y4 + y6]
# Complexity: 17, fitness: -356.976806640625, equation: [2*y0 + y4, y0*(y1 - 0.237*y2)*(3*y0 + y1 + y4) + 3*y0 + 2*y1 - 0.237*y2 + y4]
# Complexity: 20, fitness: -358.58905029296875, equation: [2*y0 + y4, 0.763*y0*y1*(y1 - y2 + y6 + cos(2*y0 + y4)) + 2.76*y1 - 2*y2 + y6 + cos(2*y0 + y4)]
# Complexity: 21, fitness: -359.67889404296875, equation: [2*y0 + y4, y0*(y6 + cos(2*y0 + y4))*(-0.237*y0 + y1 - 0.237*cos(y1 - y5)) - 0.237*y0 + 2*y1 - y5 + y6 + cos(2*y0 + y4) + 0.763*cos(y1 - y5)]
# Complexity: 22, fitness: -359.76885986328125, equation: [2*y0 + y4, y0*(y1 - 0.237*y2*y4)*(y1 - y2 + y6 + cos(2*y0 + y4)) + 3*y1 - 0.237*y2*y4 - 2*y2 + y6 + cos(2*y0 + y4)]
# Complexity: 26, fitness: -360.607421875, equation: [2*y0 + 0.362*y3*y7 + y4 + y6 + (2*y0 + sin(y6)*cos(y1 - y5))*cos(-y1 + 0.0782*y3*y7 + 0.432*y4 + 0.432*y6) + sin(y6)*cos(y1 - y5), 2*y1 - 0.0782*y3*y7 + 0.568*y4 - y5 + 0.568*y6 + cos(y1 - y5) + cos(-y1 + 0.0782*y3*y7 + 0.432*y4 + 0.432*y6)]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -271.05316162109375, equation: [y0 + y6, y0 + y6 + y7]
# Complexity: 7, fitness: -279.0177917480469, equation: [y0 + y4 + y6, y0 + y4 + y6 + y7]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 11, fitness: -354.587646484375, equation: [2*y0 + y4, 2*y0 + 2*y1 - 0.475*y2 + y4]
# Complexity: 14, fitness: -355.2044982910156, equation: [y0 + y4, 0.763*y0*y1*(y6 + cos(y0 + y4)) + 0.763*y1 + y6 + cos(y0 + y4)]
# Complexity: 16, fitness: -355.4464111328125, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y2 + y4 + y6]
# Complexity: 17, fitness: -356.976806640625, equation: [2*y0 + y4, y0*(y1 - 0.237*y2)*(3*y0 + y1 + y4) + 3*y0 + 2*y1 - 0.237*y2 + y4]
# Complexity: 20, fitness: -358.58905029296875, equation: [2*y0 + y4, 0.763*y0*y1*(y1 - y2 + y6 + cos(2*y0 + y4)) + 2.76*y1 - 2*y2 + y6 + cos(2*y0 + y4)]
# Complexity: 21, fitness: -359.67889404296875, equation: [2*y0 + y4, y0*(y6 + cos(2*y0 + y4))*(-0.237*y0 + y1 - 0.237*cos(y1 - y5)) - 0.237*y0 + 2*y1 - y5 + y6 + cos(2*y0 + y4) + 0.763*cos(y1 - y5)]
# Complexity: 22, fitness: -359.76885986328125, equation: [2*y0 + y4, y0*(y1 - 0.237*y2*y4)*(y1 - y2 + y6 + cos(2*y0 + y4)) + 3*y1 - 0.237*y2*y4 - 2*y2 + y6 + cos(2*y0 + y4)]
# Complexity: 24, fitness: -361.0915222167969, equation: [2*y0 + y4, 0.763*y0*y1*(y1 - y2 + 2*y3*cos(2*y0 + y4) + y6) + 2.76*y1 - 2*y2 + 2*y3*cos(2*y0 + y4) + y6]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -271.05316162109375, equation: [y0 + y6, y0 + y6 + y7]
# Complexity: 7, fitness: -279.0177917480469, equation: [y0 + y4 + y6, y0 + y4 + y6 + y7]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 11, fitness: -354.587646484375, equation: [2*y0 + y4, 2*y0 + 2*y1 - 0.475*y2 + y4]
# Complexity: 14, fitness: -355.2044982910156, equation: [y0 + y4, 0.763*y0*y1*(y6 + cos(y0 + y4)) + 0.763*y1 + y6 + cos(y0 + y4)]
# Complexity: 16, fitness: -355.4464111328125, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y2 + y4 + y6]
# Complexity: 17, fitness: -356.976806640625, equation: [2*y0 + y4, y0*(y1 - 0.237*y2)*(3*y0 + y1 + y4) + 3*y0 + 2*y1 - 0.237*y2 + y4]
# Complexity: 20, fitness: -358.58905029296875, equation: [2*y0 + y4, 0.763*y0*y1*(y1 - y2 + y6 + cos(2*y0 + y4)) + 2.76*y1 - 2*y2 + y6 + cos(2*y0 + y4)]
# Complexity: 21, fitness: -359.67889404296875, equation: [2*y0 + y4, y0*(y6 + cos(2*y0 + y4))*(-0.237*y0 + y1 - 0.237*cos(y1 - y5)) - 0.237*y0 + 2*y1 - y5 + y6 + cos(2*y0 + y4) + 0.763*cos(y1 - y5)]
# Complexity: 22, fitness: -359.76885986328125, equation: [2*y0 + y4, y0*(y1 - 0.237*y2*y4)*(y1 - y2 + y6 + cos(2*y0 + y4)) + 3*y1 - 0.237*y2*y4 - 2*y2 + y6 + cos(2*y0 + y4)]
# Complexity: 24, fitness: -361.0915222167969, equation: [2*y0 + y4, 0.763*y0*y1*(y1 - y2 + 2*y3*cos(2*y0 + y4) + y6) + 2.76*y1 - 2*y2 + 2*y3*cos(2*y0 + y4) + y6]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -271.05316162109375, equation: [y0 + y6, y0 + y6 + y7]
# Complexity: 7, fitness: -279.0177917480469, equation: [y0 + y4 + y6, y0 + y4 + y6 + y7]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 11, fitness: -354.587646484375, equation: [2*y0 + y4, 2*y0 + 2*y1 - 0.475*y2 + y4]
# Complexity: 14, fitness: -355.2044982910156, equation: [y0 + y4, 0.763*y0*y1*(y6 + cos(y0 + y4)) + 0.763*y1 + y6 + cos(y0 + y4)]
# Complexity: 16, fitness: -355.4464111328125, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y2 + y4 + y6]
# Complexity: 17, fitness: -356.976806640625, equation: [2*y0 + y4, y0*(y1 - 0.237*y2)*(3*y0 + y1 + y4) + 3*y0 + 2*y1 - 0.237*y2 + y4]
# Complexity: 20, fitness: -358.58905029296875, equation: [2*y0 + y4, 0.763*y0*y1*(y1 - y2 + y6 + cos(2*y0 + y4)) + 2.76*y1 - 2*y2 + y6 + cos(2*y0 + y4)]
# Complexity: 21, fitness: -359.67889404296875, equation: [2*y0 + y4, y0*(y6 + cos(2*y0 + y4))*(-0.237*y0 + y1 - 0.237*cos(y1 - y5)) - 0.237*y0 + 2*y1 - y5 + y6 + cos(2*y0 + y4) + 0.763*cos(y1 - y5)]
# Complexity: 22, fitness: -359.76885986328125, equation: [2*y0 + y4, y0*(y1 - 0.237*y2*y4)*(y1 - y2 + y6 + cos(2*y0 + y4)) + 3*y1 - 0.237*y2*y4 - 2*y2 + y6 + cos(2*y0 + y4)]
# Complexity: 23, fitness: -360.8125915527344, equation: [2*y0 + y4, y0*(y1 - y2 - 0.237)*(y1 + y2 + y6 - 0.237*cos(cos(2*y0 + y4))) + 3*y1 + y6 + 0.526*cos(cos(2*y0 + y4)) - 0.237]
# Complexity: 24, fitness: -361.0915832519531, equation: [2*y0 + y4, 0.763*y0*y1*(y1 - y2 + 2*y3*cos(2*y0 + y4) + y6) + 2.76*y1 - 2*y2 + 2*y3*cos(2*y0 + y4) + y6]
# Final pareto front:
# Complexity: 1, fitness: -12.50468921661377, equation: [y7, 0]
# Complexity: 3, fitness: -143.63124084472656, equation: [sin(y7), sin(sin(y7))]
# Complexity: 5, fitness: -271.05316162109375, equation: [y0 + y6, y0 + y6 + y7]
# Complexity: 7, fitness: -279.0177917480469, equation: [y0 + y4 + y6, y0 + y4 + y6 + y7]
# Complexity: 8, fitness: -318.91351318359375, equation: [y0 + y6, y0 + y1 + y6 + 2*sin(y1)]
# Complexity: 11, fitness: -354.587646484375, equation: [2*y0 + y4, 2*y0 + 2*y1 - 0.475*y2 + y4]
# Complexity: 14, fitness: -355.2044982910156, equation: [y0 + y4, 0.763*y0*y1*(y6 + cos(y0 + y4)) + 0.763*y1 + y6 + cos(y0 + y4)]
# Complexity: 16, fitness: -355.4464111328125, equation: [2*y0 + y6, y1*(2*y0 + y6)*sin(y0) + y2 + y4 + y6]
# Complexity: 17, fitness: -356.976806640625, equation: [2*y0 + y4, y0*(y1 - 0.237*y2)*(3*y0 + y1 + y4) + 3*y0 + 2*y1 - 0.237*y2 + y4]
# Complexity: 20, fitness: -358.58905029296875, equation: [2*y0 + y4, 0.763*y0*y1*(y1 - y2 + y6 + cos(2*y0 + y4)) + 2.76*y1 - 2*y2 + y6 + cos(2*y0 + y4)]
# Complexity: 21, fitness: -359.67889404296875, equation: [2*y0 + y4, y0*(y6 + cos(2*y0 + y4))*(-0.237*y0 + y1 - 0.237*cos(y1 - y5)) - 0.237*y0 + 2*y1 - y5 + y6 + cos(2*y0 + y4) + 0.763*cos(y1 - y5)]
# Complexity: 22, fitness: -359.76885986328125, equation: [2*y0 + y4, y0*(y1 - 0.237*y2*y4)*(y1 - y2 + y6 + cos(2*y0 + y4)) + 3*y1 - 0.237*y2*y4 - 2*y2 + y6 + cos(2*y0 + y4)]
# Complexity: 23, fitness: -360.8125915527344, equation: [2*y0 + y4, y0*(y1 - y2 - 0.237)*(y1 + y2 + y6 - 0.237*cos(cos(2*y0 + y4))) + 3*y1 + y6 + 0.526*cos(cos(2*y0 + y4)) - 0.237]
# Complexity: 24, fitness: -361.0915832519531, equation: [2*y0 + y4, 0.763*y0*y1*(y1 - y2 + 2*y3*cos(2*y0 + y4) + y6) + 2.76*y1 - 2*y2 + 2*y3*cos(2*y0 + y4) + y6]

# %%
brax_env = BraxGymnaxWrapper('hopper', 'generalized')
key = jr.PRNGKey(0)

#Define hyperparameters
population_size = 100
num_populations = 5
num_generations = 25
batch_size = 16

fitness_function = GymFitnessFunction.__new__(GymFitnessFunction)
fitness_function.env = brax_env
#in Gymnax, env_params are max_speed: float = 8.0, max_torque: float = 2.0, dt: float = 0.05, g: float = 10.0, m: float = 1.0, l: float = 1.0, max_steps_in_episode: int = 200
fitness_function.env_params = None
fitness_function.num_steps = 1000

#Define operators and variables
operator_list = [
    ("+", lambda x, y: jnp.add(x, y), 2, 0.5),
    ("-", lambda x, y: jnp.subtract(x, y), 2, 0.1),
    ("*", lambda x, y: jnp.multiply(x, y), 2, 0.5),
    ("sin", lambda x: jnp.sin(x), 1, 0.1),
    ("cos", lambda x: jnp.cos(x), 1, 0.1),
]

obs, _ = fitness_function.env.reset(jax.random.PRNGKey(0))
variable_list = [[f"y{i}" for i in range(obs.shape[0])]]

#Initialize strategy
strategy = GeneticProgramming(num_generations, population_size, fitness_function, operator_list, variable_list, num_populations=num_populations, device_type = 'gpu', num_outputs_per_tree=3, max_nodes = 31)
# Out:
# Input data should be formatted as: ['y0', 'y1', 'y2', 'y3', 'y4', 'y5', 'y6', 'y7', 'y8', 'y9', 'y10'].

# %%
key = jr.PRNGKey(0)
data_key, gp_key = jr.split(key, 2)

# The data comprises keys need to initialize the batch of environments.
batch_keys = jr.split(data_key, batch_size)

strategy.fit(gp_key, batch_keys, verbose=1)
# Out:
# Mujoco Modi (not updated)
# Compiling code for evaluation and evolution...
# Finished compilation in 120.56 seconds
# invalid solutions: 0 0
# In generation 1
# Complexity: 1, fitness: -212.62847900390625, equation: [0.639, 0, 0]
# Complexity: 2, fitness: -220.23828125, equation: [0, cos(y0), 0]
# Complexity: 5, fitness: -310.502685546875, equation: [0, y0*y1*y7 + y1*y7, 0]
# invalid solutions: 0 0
# In generation 2
# Complexity: 1, fitness: -238.040771484375, equation: [0, y10, 0]
# Complexity: 3, fitness: -283.037109375, equation: [0, y1*y7, 0]
# Complexity: 5, fitness: -310.502685546875, equation: [0, y0*y1*y7 + y1*y7, 0]
# Complexity: 17, fitness: -496.8201904296875, equation: [y7*(y10*y2*y4 + y3)*(y4 + y5 + y7*y8), y7*(y10*y2*y4 + y3), y10*y2 + y7*y8]
# Complexity: 20, fitness: -772.45751953125, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + sin(y6)) + 2*sin(y6), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# invalid solutions: 0 0
# In generation 3
# Complexity: 1, fitness: -250.2111358642578, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -283.037109375, equation: [0, y1*y7, 0]
# Complexity: 5, fitness: -318.0948486328125, equation: [0, 0.411*y2 - y7, 0]
# Complexity: 13, fitness: -374.99908447265625, equation: [y7*(y3 + y9)*(y4 + y5 + y7*y8), y7*(y3 + y9), y7*y8]
# Complexity: 17, fitness: -496.8406982421875, equation: [y7*(y10*y2*y4 + y3)*(y4 + y5 + y7*y8), y7*(y10*y2*y4 + y3), y10*y2 + y7*y8]
# Complexity: 20, fitness: -772.45751953125, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + sin(y6)) + 2*sin(y6), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# invalid solutions: 0 0
# In generation 4
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -311.00482177734375, equation: [0, y7*y9, 0]
# Complexity: 5, fitness: -345.2267150878906, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 13, fitness: -374.99908447265625, equation: [y7*(y3 + y9)*(y4 + y5 + y7*y8), y7*(y3 + y9), y7*y8]
# Complexity: 15, fitness: -384.9589538574219, equation: [y7*(y1 + y7*y8)*(y10*y2*y4 + y3), y7*(y10*y2*y4 + y3), y10*y2 + y7*y8]
# Complexity: 17, fitness: -508.929931640625, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + (y0*y10*y3*(-y0 + y6) + y0 + sin(y6))*cos(y6) + 2*sin(y6), 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 20, fitness: -772.45751953125, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + sin(y6)) + 2*sin(y6), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 23, fitness: -786.7802124023438, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + 1.42*y2*y5 + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + 0.712*y2*y5), y0*y1 + y2*y5, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# invalid solutions: 0 0
# In generation 5
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -311.00482177734375, equation: [0, y7*y9, 0]
# Complexity: 4, fitness: -313.70977783203125, equation: [0, y7*y9 + sin(y7*y9), 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -359.44940185546875, equation: [0, y7*(-y0 + y6), y4*y7*(-y0 + y6)]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 15, fitness: -524.6063232421875, equation: [2*y0 + 2*y10*y6*(-y0 + y6) + (y0 + y10*y6*(-y0 + y6) + sin(y6))*cos(y6) + 2*sin(y6), 0, y10*y6*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 19, fitness: -771.77099609375, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + y10 + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + y10), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 20, fitness: -772.45751953125, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + sin(y6)) + 2*sin(y6), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 23, fitness: -786.849853515625, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + 1.42*y2*y5 + (y0*y1 + y9)*(y0*y10*y3*(-y0 + y6) + y0 + 0.712*y2*y5), y0*y1 + y2*y5, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# invalid solutions: 0 0
# In generation 6
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -311.00482177734375, equation: [0, y7*y9, 0]
# Complexity: 4, fitness: -313.70977783203125, equation: [0, y7*y9 + sin(y7*y9), 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 15, fitness: -524.6064453125, equation: [2*y0 + 2*y10*y6*(-y0 + y6) + (y0 + y10*y6*(-y0 + y6) + sin(y6))*cos(y6) + 2*sin(y6), 0, y10*y6*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 17, fitness: -619.7861328125, equation: [y0*y10*y3*(-y0 + y6) + y0, y3*y7*(y0*y10*y3*(-y0 + y6) + y0 + 0.218) + y3*y7, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 19, fitness: -771.77099609375, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + y10 + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + y10), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 20, fitness: -850.4395751953125, equation: [2*y0*y1*y10*(-y0 + y6) + 2*y0 + (y3 + y4 + y7)*(y0*y1*y10*(-y0 + y6) + y0 + sin(y6)) + 2*sin(y6), y0*y1, y0*y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 28, fitness: -972.6084594726562, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + 1.42*y2*y5 + (y1*(y10 - y5 + sin(y10)) + y3)*(y0*y10*y3*(-y0 + y6) + y0 + 0.712*y2*y5), y1*(y10 - y5 + sin(y10)) + y10 + y2*y5 - y5 + sin(y10), y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# invalid solutions: 0 0
# In generation 7
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -311.00482177734375, equation: [0, y7*y9, 0]
# Complexity: 4, fitness: -313.70977783203125, equation: [0, y7*y9 + sin(y7*y9), 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 15, fitness: -544.305419921875, equation: [sin(y10*y8*y9*(-y0 + y6)*sin(y6 + 1.15)) + sin(y6 + 1.15), y8*y9, y10*y8*y9*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 17, fitness: -619.7861328125, equation: [y0*y10*y3*(-y0 + y6) + y0, y3*y7*(y0*y10*y3*(-y0 + y6) + y0 + 0.218) + y3*y7, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 19, fitness: -771.77099609375, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + y10 + (y0*y1 + y3)*(y0*y10*y3*(-y0 + y6) + y0 + y10), y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 20, fitness: -850.4395751953125, equation: [2*y0*y1*y10*(-y0 + y6) + 2*y0 + (y3 + y4 + y7)*(y0*y1*y10*(-y0 + y6) + y0 + sin(y6)) + 2*sin(y6), y0*y1, y0*y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 21, fitness: -965.1024780273438, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y2*y7 + y4 + y5), y7*(y10*y3*y4 + y3), y10*y3 + y2*y7]
# Complexity: 26, fitness: -972.7926025390625, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + y3 + y4 + (y1*(y10 - y5 + sin(y10)) + y3)*(y0*y10*y3*(-y0 + y6) + y0 + y3 + y4), y1*(y10 - y5 + sin(y10)) + y10 - y5 + sin(y10), y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# invalid solutions: 0 0
# In generation 8
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 15, fitness: -544.305419921875, equation: [sin(y10*y8*y9*(-y0 + y6)*sin(y6 + 1.15)) + sin(y6 + 1.15), y8*y9, y10*y8*y9*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 17, fitness: -619.7861328125, equation: [y0*y10*y3*(-y0 + y6) + y0, y3*y7*(y0*y10*y3*(-y0 + y6) + y0 + 0.218) + y3*y7, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 18, fitness: -773.828369140625, equation: [y10*(-y0 + y9) + (y0*y1 + y3)*(y10*(-y0 + y9) + sin(y0*y3 + 1.15)) + 2*sin(y0*y3 + 1.15), y0*y1, y10*(-y0 + y9)]
# Complexity: 20, fitness: -850.4395751953125, equation: [2*y0*y1*y10*(-y0 + y6) + 2*y0 + (y3 + y4 + y7)*(y0*y1*y10*(-y0 + y6) + y0 + sin(y6)) + 2*sin(y6), y0*y1, y0*y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 21, fitness: -965.1024780273438, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y2*y7 + y4 + y5), y7*(y10*y3*y4 + y3), y10*y3 + y2*y7]
# Complexity: 26, fitness: -972.823974609375, equation: [2*y0*y10*y3*(-y0 + y6) + 2*y0 + y3 + y4 + (y1*(y10 - y5 + sin(y10)) + y3)*(y0*y10*y3*(-y0 + y6) + y0 + y3 + y4), y1*(y10 - y5 + sin(y10)) + y10 - y5 + sin(y10), y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 27, fitness: -1049.911865234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y2*(y4 + y5 + y7*y8) + y4 + y5), y7*(y10*y3*y4 + y3), y10*y3 + y2*(y4 + y5 + y7*y8) + y7*y8]
# invalid solutions: 0 0
# In generation 9
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 15, fitness: -747.5399169921875, equation: [2*y0 + 2*y10*y6*(-y0 + y6) + (y0 + y10*y6*(-y0 + y6) + sin(y6))*sin(y4) + 2*sin(y6), sin(y4), y10*y6*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 17, fitness: -765.0213012695312, equation: [y0*y1*(y0*y10*y3*(-y0 + y6) + 2*y0) + 2*y0*y10*y3*(-y0 + y6) + 3*y0, y0*y1, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 18, fitness: -773.828369140625, equation: [y10*(-y0 + y9) + (y0*y1 + y3)*(y10*(-y0 + y9) + sin(y0*y3 + 1.15)) + 2*sin(y0*y3 + 1.15), y0*y1, y10*(-y0 + y9)]
# Complexity: 19, fitness: -786.3822021484375, equation: [y0*y1*y9*(y0 + y10*y4*(-y0 + y6) + 0.712*y9) + 2*y0 + 2*y10*y4*(-y0 + y6) + 1.42*y9, y0*y1, y10*y4*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 20, fitness: -850.4395751953125, equation: [2*y0*y1*y10*(-y0 + y6) + 2*y0 + (y3 + y4 + y7)*(y0*y1*y10*(-y0 + y6) + y0 + sin(y6)) + 2*sin(y6), y0*y1, y0*y1*y10*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 27, fitness: -1063.1549072265625, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y2*(y4*y5 + y7*y8) + y4 + y5), y7*(y10*y3*y4 + y3), y10*y3 + y2*(y4*y5 + y7*y8) + y7*y8]
# invalid solutions: 0 0
# In generation 10
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 27, fitness: -1063.1549072265625, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y2*(y4*y5 + y7*y8) + y4 + y5), y7*(y10*y3*y4 + y3), y10*y3 + y2*(y4*y5 + y7*y8) + y7*y8]
# invalid solutions: 0 0
# In generation 11
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -854.3087768554688, equation: [y0*y1*y10*(-y0 + y3 + y5) + y0, y0*y1, y0*y1*y10*(-y0 + y3 + y5) + y10*(-y0 + y3 + y5)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 27, fitness: -1063.2529296875, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y2*y4*y5*y7*y8 + y4 + y5), y7*(y10*y3*y4 + y3), y10*y3 + y2*y4*y5*y7*y8 + y7*y8]
# invalid solutions: 0 0
# In generation 12
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -947.95263671875, equation: [y0 + y1*y10*(-y0 + y6)**2, y1*(-y0 + y6), y1*y10*(-y0 + y6)**2 + y10*(-y0 + y6)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 27, fitness: -1065.201416015625, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y2*y4*y5*y7*y8 + y4 + y5), y7*(y10*y3*y4 + y3), y10*y3 + y2*y4*y5*y7*y8 + y7*y8]
# invalid solutions: 0 0
# In generation 13
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -947.95263671875, equation: [y0 + y1*y10*(-y0 + y6)**2, y1*(-y0 + y6), y1*y10*(-y0 + y6)**2 + y10*(-y0 + y6)]
# Complexity: 14, fitness: -947.9674072265625, equation: [y0*cos(0.742*y1*y10*(-y0 + y3 + y5)), -0.742*y1, -0.742*y1*y10*(-y0 + y3 + y5) + y10*(-y0 + y3 + y5)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 27, fitness: -1073.419921875, equation: [y3 + y4 + y7*(y10*y3*y5 + y3)*(y2*(y0*y5 + y7*y8) + y4 + y5), y7*(y10*y3*y5 + y3), y10*y3 + y2*(y0*y5 + y7*y8) + y7*y8]
# invalid solutions: 0 0
# In generation 14
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -947.95263671875, equation: [y0 + y1*y10*(-y0 + y6)**2, y1*(-y0 + y6), y1*y10*(-y0 + y6)**2 + y10*(-y0 + y6)]
# Complexity: 14, fitness: -947.9674072265625, equation: [y0*cos(0.742*y1*y10*(-y0 + y3 + y5)), -0.742*y1, -0.742*y1*y10*(-y0 + y3 + y5) + y10*(-y0 + y3 + y5)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 27, fitness: -1073.419921875, equation: [y3 + y4 + y7*(y10*y3*y5 + y3)*(y2*(y0*y5 + y7*y8) + y4 + y5), y7*(y10*y3*y5 + y3), y10*y3 + y2*(y0*y5 + y7*y8) + y7*y8]
# Complexity: 29, fitness: -1085.683349609375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*y4*y5*y7**2 + y4), y7*(y10*y3*y4 + y3), y10*y3*y4*y5*y7**2 + 2*y10*y3 + y7**2]
# invalid solutions: 0 0
# In generation 15
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -947.95263671875, equation: [y0 + y1*y10*(-y0 + y6)**2, y1*(-y0 + y6), y1*y10*(-y0 + y6)**2 + y10*(-y0 + y6)]
# Complexity: 14, fitness: -947.9674072265625, equation: [y0*cos(0.742*y1*y10*(-y0 + y3 + y5)), -0.742*y1, -0.742*y1*y10*(-y0 + y3 + y5) + y10*(-y0 + y3 + y5)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 27, fitness: -1073.419921875, equation: [y3 + y4 + y7*(y10*y3*y5 + y3)*(y2*(y0*y5 + y7*y8) + y4 + y5), y7*(y10*y3*y5 + y3), y10*y3 + y2*(y0*y5 + y7*y8) + y7*y8]
# Complexity: 29, fitness: -1089.277587890625, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*(y4*y5 + y7**2) + y4), y7*(y10*y3*y4 + y3), y10*y3*(y4*y5 + y7**2) + 2*y10*y3 + y7**2]
# invalid solutions: 0 0
# In generation 16
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -947.95263671875, equation: [y0 + y1*y10*(-y0 + y6)**2, y1*(-y0 + y6), y1*y10*(-y0 + y6)**2 + y10*(-y0 + y6)]
# Complexity: 14, fitness: -947.9674072265625, equation: [y0*cos(0.742*y1*y10*(-y0 + y3 + y5)), -0.742*y1, -0.742*y1*y10*(-y0 + y3 + y5) + y10*(-y0 + y3 + y5)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 20, fitness: -1048.6407470703125, equation: [y0 + y7*(y10*y3*y4 + y3)*sin(y10*y8 + y4 + y8), y7*(y10*y3*y4 + y3), y10*y3 + y10*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 27, fitness: -1073.419921875, equation: [y3 + y4 + y7*(y10*y3*y5 + y3)*(y2*(y0*y5 + y7*y8) + y4 + y5), y7*(y10*y3*y5 + y3), y10*y3 + y2*(y0*y5 + y7*y8) + y7*y8]
# Complexity: 29, fitness: -1091.98095703125, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*y4*y5*y7*y8 + y4), y7*(y10*y3*y4 + y3), y10*y3*y4*y5*y7*y8 + 2*y10*y3 + y7*y8]
# invalid solutions: 0 0
# In generation 17
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -947.95263671875, equation: [y0 + y1*y10*(-y0 + y6)**2, y1*(-y0 + y6), y1*y10*(-y0 + y6)**2 + y10*(-y0 + y6)]
# Complexity: 14, fitness: -947.9674072265625, equation: [y0*cos(0.742*y1*y10*(-y0 + y3 + y5)), -0.742*y1, -0.742*y1*y10*(-y0 + y3 + y5) + y10*(-y0 + y3 + y5)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 20, fitness: -1048.6407470703125, equation: [y0 + y7*(y10*y3*y4 + y3)*sin(y10*y8 + y4 + y8), y7*(y10*y3*y4 + y3), y10*y3 + y10*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 27, fitness: -1099.619384765625, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*(y7**2 + y8) + y4), y7*(y10*y3*y4 + y3), y10*y3*(y7**2 + y8) + 2*y10*y3 + y7**2]
# invalid solutions: 0 0
# In generation 18
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -947.95263671875, equation: [y0 + y1*y10*(-y0 + y6)**2, y1*(-y0 + y6), y1*y10*(-y0 + y6)**2 + y10*(-y0 + y6)]
# Complexity: 14, fitness: -947.9674072265625, equation: [y0*cos(0.742*y1*y10*(-y0 + y3 + y5)), -0.742*y1, -0.742*y1*y10*(-y0 + y3 + y5) + y10*(-y0 + y3 + y5)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 20, fitness: -1048.6407470703125, equation: [y0 + y7*(y10*y3*y4 + y3)*sin(y10*y8 + y4 + y8), y7*(y10*y3*y4 + y3), y10*y3 + y10*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 25, fitness: -1058.9908447265625, equation: [y0 + y7*(y10*y3 + y2*(y10 + y7*y8) + y4)*(y3*y5 + y3 - y4), y7*(y3*y5 + y3 - y4), y10*y3 + y2*(y10 + y7*y8) + y3*y5 + y7*y8]
# Complexity: 27, fitness: -1100.572998046875, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*(y7**2 + y8) + y4), y7*(y10*y3*y4 + y3), y10*y3*(y7**2 + y8) + 2*y10*y3 + y7**2]
# invalid solutions: 0 0
# In generation 19
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 10, fitness: -509.5116882324219, equation: [y0**2*cos(y10*(-y0 + y4)) + y0*cos(y10*(-y0 + y4)), 0, y10*(-y0 + y4)]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -947.95263671875, equation: [y0 + y1*y10*(-y0 + y6)**2, y1*(-y0 + y6), y1*y10*(-y0 + y6)**2 + y10*(-y0 + y6)]
# Complexity: 14, fitness: -947.9674072265625, equation: [y0*cos(0.742*y1*y10*(-y0 + y3 + y5)), -0.742*y1, -0.742*y1*y10*(-y0 + y3 + y5) + y10*(-y0 + y3 + y5)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 20, fitness: -1048.6407470703125, equation: [y0 + y7*(y10*y3*y4 + y3)*sin(y10*y8 + y4 + y8), y7*(y10*y3*y4 + y3), y10*y3 + y10*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 25, fitness: -1058.9908447265625, equation: [y0 + y7*(y10*y3 + y2*(y10 + y7*y8) + y4)*(y3*y5 + y3 - y4), y7*(y3*y5 + y3 - y4), y10*y3 + y2*(y10 + y7*y8) + y3*y5 + y7*y8]
# Complexity: 27, fitness: -1100.572998046875, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*(y7**2 + y8) + y4), y7*(y10*y3*y4 + y3), y10*y3*(y7**2 + y8) + 2*y10*y3 + y7**2]
# invalid solutions: 0 0
# In generation 20
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 10, fitness: -509.5116882324219, equation: [y0**2*cos(y10*(-y0 + y4)) + y0*cos(y10*(-y0 + y4)), 0, y10*(-y0 + y4)]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -947.95263671875, equation: [y0 + y1*y10*(-y0 + y6)**2, y1*(-y0 + y6), y1*y10*(-y0 + y6)**2 + y10*(-y0 + y6)]
# Complexity: 14, fitness: -947.9674072265625, equation: [y0*cos(0.742*y1*y10*(-y0 + y3 + y5)), -0.742*y1, -0.742*y1*y10*(-y0 + y3 + y5) + y10*(-y0 + y3 + y5)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 20, fitness: -1048.6407470703125, equation: [y0 + y7*(y10*y3*y4 + y3)*sin(y10*y8 + y4 + y8), y7*(y10*y3*y4 + y3), y10*y3 + y10*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 25, fitness: -1058.9908447265625, equation: [y0 + y7*(y10*y3 + y2*(y10 + y7*y8) + y4)*(y3*y5 + y3 - y4), y7*(y3*y5 + y3 - y4), y10*y3 + y2*(y10 + y7*y8) + y3*y5 + y7*y8]
# Complexity: 27, fitness: -1100.572998046875, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*(y7**2 + y8) + y4), y7*(y10*y3*y4 + y3), y10*y3*(y7**2 + y8) + 2*y10*y3 + y7**2]
# invalid solutions: 0 0
# In generation 21
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 10, fitness: -509.5116882324219, equation: [y0**2*cos(y10*(-y0 + y4)) + y0*cos(y10*(-y0 + y4)), 0, y10*(-y0 + y4)]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -947.95263671875, equation: [y0 + y1*y10*(-y0 + y6)**2, y1*(-y0 + y6), y1*y10*(-y0 + y6)**2 + y10*(-y0 + y6)]
# Complexity: 14, fitness: -947.9674072265625, equation: [y0*cos(0.742*y1*y10*(-y0 + y3 + y5)), -0.742*y1, -0.742*y1*y10*(-y0 + y3 + y5) + y10*(-y0 + y3 + y5)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 20, fitness: -1048.6407470703125, equation: [y0 + y7*(y10*y3*y4 + y3)*sin(y10*y8 + y4 + y8), y7*(y10*y3*y4 + y3), y10*y3 + y10*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 25, fitness: -1058.9908447265625, equation: [y0 + y7*(y10*y3 + y2*(y10 + y7*y8) + y4)*(y3*y5 + y3 - y4), y7*(y3*y5 + y3 - y4), y10*y3 + y2*(y10 + y7*y8) + y3*y5 + y7*y8]
# Complexity: 27, fitness: -1100.572998046875, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*(y7**2 + y8) + y4), y7*(y10*y3*y4 + y3), y10*y3*(y7**2 + y8) + 2*y10*y3 + y7**2]
# invalid solutions: 0 0
# In generation 22
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 10, fitness: -509.5116882324219, equation: [y0**2*cos(y10*(-y0 + y4)) + y0*cos(y10*(-y0 + y4)), 0, y10*(-y0 + y4)]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -947.95263671875, equation: [y0 + y1*y10*(-y0 + y6)**2, y1*(-y0 + y6), y1*y10*(-y0 + y6)**2 + y10*(-y0 + y6)]
# Complexity: 14, fitness: -947.9674072265625, equation: [y0*cos(0.742*y1*y10*(-y0 + y3 + y5)), -0.742*y1, -0.742*y1*y10*(-y0 + y3 + y5) + y10*(-y0 + y3 + y5)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 18, fitness: -1045.87451171875, equation: [y0*cos(y0*y1*y5*(-y0 + y6)*(-y0 + y6 - 0.161)), y1*(-y0 + y6 - 0.161), y0*y1*y5*(-y0 + y6)*(-y0 + y6 - 0.161) + y0*y5*(-y0 + y6)]
# Complexity: 20, fitness: -1048.6407470703125, equation: [y0 + y7*(y10*y3*y4 + y3)*sin(y10*y8 + y4 + y8), y7*(y10*y3*y4 + y3), y10*y3 + y10*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 25, fitness: -1062.935302734375, equation: [y2*y7*y8*y9 + y3 + y4 + (y2 + y7)*(y10*y3 + 2*y3 + y4), (y2 + y7)*(y10*y3 + 2*y3 + y4), y10*y3 + y2*y9 + y7*y8]
# Complexity: 27, fitness: -1100.572998046875, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*(y7**2 + y8) + y4), y7*(y10*y3*y4 + y3), y10*y3*(y7**2 + y8) + 2*y10*y3 + y7**2]
# invalid solutions: 0 0
# In generation 23
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 10, fitness: -509.5116882324219, equation: [y0**2*cos(y10*(-y0 + y4)) + y0*cos(y10*(-y0 + y4)), 0, y10*(-y0 + y4)]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -947.95263671875, equation: [y0 + y1*y10*(-y0 + y6)**2, y1*(-y0 + y6), y1*y10*(-y0 + y6)**2 + y10*(-y0 + y6)]
# Complexity: 14, fitness: -947.9674072265625, equation: [y0*cos(0.742*y1*y10*(-y0 + y3 + y5)), -0.742*y1, -0.742*y1*y10*(-y0 + y3 + y5) + y10*(-y0 + y3 + y5)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 18, fitness: -1045.87451171875, equation: [y0*cos(y0*y1*y5*(-y0 + y6)*(-y0 + y6 - 0.161)), y1*(-y0 + y6 - 0.161), y0*y1*y5*(-y0 + y6)*(-y0 + y6 - 0.161) + y0*y5*(-y0 + y6)]
# Complexity: 20, fitness: -1048.6407470703125, equation: [y0 + y7*(y10*y3*y4 + y3)*sin(y10*y8 + y4 + y8), y7*(y10*y3*y4 + y3), y10*y3 + y10*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 23, fitness: -1059.347412109375, equation: [y3*y7*y8 + y3 + y4 + (y2 + y7)*(y10*y3 + 2*y3 + y4), (y2 + y7)*(y10*y3 + 2*y3 + y4), y10*y3 + y7*y8]
# Complexity: 25, fitness: -1087.9658203125, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*y7*y8 + y4), y7*(y10*y3*y4 + y3), y10*y3*y7*y8 + 2*y10*y3 + y7*y8]
# Complexity: 27, fitness: -1101.923583984375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*(y7**2 + y8) + y4), y7*(y10*y3*y4 + y3), y10*y3*(y7**2 + y8) + 2*y10*y3 + y7**2]
# invalid solutions: 0 0
# In generation 24
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 10, fitness: -509.5116882324219, equation: [y0**2*cos(y10*(-y0 + y4)) + y0*cos(y10*(-y0 + y4)), 0, y10*(-y0 + y4)]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -947.95263671875, equation: [y0 + y1*y10*(-y0 + y6)**2, y1*(-y0 + y6), y1*y10*(-y0 + y6)**2 + y10*(-y0 + y6)]
# Complexity: 14, fitness: -947.9674072265625, equation: [y0*cos(0.742*y1*y10*(-y0 + y3 + y5)), -0.742*y1, -0.742*y1*y10*(-y0 + y3 + y5) + y10*(-y0 + y3 + y5)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 18, fitness: -1045.87451171875, equation: [y0*cos(y0*y1*y5*(-y0 + y6)*(-y0 + y6 - 0.161)), y1*(-y0 + y6 - 0.161), y0*y1*y5*(-y0 + y6)*(-y0 + y6 - 0.161) + y0*y5*(-y0 + y6)]
# Complexity: 20, fitness: -1048.6407470703125, equation: [y0 + y7*(y10*y3*y4 + y3)*sin(y10*y8 + y4 + y8), y7*(y10*y3*y4 + y3), y10*y3 + y10*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 23, fitness: -1059.347412109375, equation: [y3*y7*y8 + y3 + y4 + (y2 + y7)*(y10*y3 + 2*y3 + y4), (y2 + y7)*(y10*y3 + 2*y3 + y4), y10*y3 + y7*y8]
# Complexity: 25, fitness: -1087.9658203125, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*y7*y8 + y4), y7*(y10*y3*y4 + y3), y10*y3*y7*y8 + 2*y10*y3 + y7*y8]
# Complexity: 27, fitness: -1101.923583984375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*(y7**2 + y8) + y4), y7*(y10*y3*y4 + y3), y10*y3*(y7**2 + y8) + 2*y10*y3 + y7**2]
# invalid solutions: 0 0
# In generation 25
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 10, fitness: -509.5116882324219, equation: [y0**2*cos(y10*(-y0 + y4)) + y0*cos(y10*(-y0 + y4)), 0, y10*(-y0 + y4)]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -947.95263671875, equation: [y0 + y1*y10*(-y0 + y6)**2, y1*(-y0 + y6), y1*y10*(-y0 + y6)**2 + y10*(-y0 + y6)]
# Complexity: 14, fitness: -947.9674072265625, equation: [y0*cos(0.742*y1*y10*(-y0 + y3 + y5)), -0.742*y1, -0.742*y1*y10*(-y0 + y3 + y5) + y10*(-y0 + y3 + y5)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 18, fitness: -1045.87451171875, equation: [y0*cos(y0*y1*y5*(-y0 + y6)*(-y0 + y6 - 0.161)), y1*(-y0 + y6 - 0.161), y0*y1*y5*(-y0 + y6)*(-y0 + y6 - 0.161) + y0*y5*(-y0 + y6)]
# Complexity: 20, fitness: -1048.6407470703125, equation: [y0 + y7*(y10*y3*y4 + y3)*sin(y10*y8 + y4 + y8), y7*(y10*y3*y4 + y3), y10*y3 + y10*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 23, fitness: -1059.347412109375, equation: [y3*y7*y8 + y3 + y4 + (y2 + y7)*(y10*y3 + 2*y3 + y4), (y2 + y7)*(y10*y3 + 2*y3 + y4), y10*y3 + y7*y8]
# Complexity: 24, fitness: -1062.8812255859375, equation: [y3 + y4 + y7*(y2*y5 + y3)*(y10*y3*sin(y7**3) + y4), y7*(y2*y5 + y3), y10*y3*sin(y7**3) + y10*y3 + y7**2]
# Complexity: 25, fitness: -1087.9658203125, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*y7*y8 + y4), y7*(y10*y3*y4 + y3), y10*y3*y7*y8 + 2*y10*y3 + y7*y8]
# Complexity: 27, fitness: -1101.923583984375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*(y7**2 + y8) + y4), y7*(y10*y3*y4 + y3), y10*y3*(y7**2 + y8) + 2*y10*y3 + y7**2]
# Final pareto front:
# Complexity: 1, fitness: -250.24185180664062, equation: [0, y4, 0]
# Complexity: 2, fitness: -250.25164794921875, equation: [0, sin(y4), 0]
# Complexity: 3, fitness: -327.97406005859375, equation: [0, -0.164*y7, 0]
# Complexity: 5, fitness: -345.33758544921875, equation: [0, 2*y7*y8 - y7, 0]
# Complexity: 7, fitness: -370.6347961425781, equation: [0, y2*y7 - 0.875*y2, y2*y7]
# Complexity: 9, fitness: -401.39508056640625, equation: [0, y7*y8*(y7*y8 + y9) + y7*y8, y7*y8]
# Complexity: 10, fitness: -509.5116882324219, equation: [y0**2*cos(y10*(-y0 + y4)) + y0*cos(y10*(-y0 + y4)), 0, y10*(-y0 + y4)]
# Complexity: 11, fitness: -515.058837890625, equation: [y0*y10*y3*(-y0 + y6) + y0, 0, y0*y10*y3*(-y0 + y6) + y10*(-y0 + y6)]
# Complexity: 13, fitness: -947.95263671875, equation: [y0 + y1*y10*(-y0 + y6)**2, y1*(-y0 + y6), y1*y10*(-y0 + y6)**2 + y10*(-y0 + y6)]
# Complexity: 14, fitness: -947.9674072265625, equation: [y0*cos(0.742*y1*y10*(-y0 + y3 + y5)), -0.742*y1, -0.742*y1*y10*(-y0 + y3 + y5) + y10*(-y0 + y3 + y5)]
# Complexity: 15, fitness: -1037.193115234375, equation: [y7**2*y8*(y10*y3*y4 + y3) + 2.24, y7*(y10*y3*y4 + y3), y10*y3 + y7*y8]
# Complexity: 18, fitness: -1045.87451171875, equation: [y0*cos(y0*y1*y5*(-y0 + y6)*(-y0 + y6 - 0.161)), y1*(-y0 + y6 - 0.161), y0*y1*y5*(-y0 + y6)*(-y0 + y6 - 0.161) + y0*y5*(-y0 + y6)]
# Complexity: 20, fitness: -1048.6407470703125, equation: [y0 + y7*(y10*y3*y4 + y3)*sin(y10*y8 + y4 + y8), y7*(y10*y3*y4 + y3), y10*y3 + y10*y8]
# Complexity: 21, fitness: -1058.068115234375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y4 + y5 + y7**2), y7*(y10*y3*y4 + y3), y10*y3 + y7**2]
# Complexity: 23, fitness: -1059.347412109375, equation: [y3*y7*y8 + y3 + y4 + (y2 + y7)*(y10*y3 + 2*y3 + y4), (y2 + y7)*(y10*y3 + 2*y3 + y4), y10*y3 + y7*y8]
# Complexity: 24, fitness: -1062.8812255859375, equation: [y3 + y4 + y7*(y2*y5 + y3)*(y10*y3*sin(y7**3) + y4), y7*(y2*y5 + y3), y10*y3*sin(y7**3) + y10*y3 + y7**2]
# Complexity: 25, fitness: -1087.9658203125, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*y7*y8 + y4), y7*(y10*y3*y4 + y3), y10*y3*y7*y8 + 2*y10*y3 + y7*y8]
# Complexity: 27, fitness: -1101.923583984375, equation: [y3 + y4 + y7*(y10*y3*y4 + y3)*(y0 + y10*y3*(y7**2 + y8) + y4), y7*(y10*y3*y4 + y3), y10*y3*(y7**2 + y8) + 2*y10*y3 + y7**2]
